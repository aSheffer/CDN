# %%
import numpy as np
import tensorflow as tf
import json
from datetime import datetime
import os
import sys
sys.path.append('../')
import retriever
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
trainset_file = '../data/training/order_train_data.bin'
testset_file = '../data/training/order_test_data.bin'
vocab_file =  '../data/metadata/w2v_vocab.json'
params_dir_tmp = '../data/training/models/All/'
embed_path =  '../data/metadata/w2v.bin'

# %% [markdown]
# <h3>Each entry in this list has the following structure:</h3>
# <ul>
# <li>entry[0]: query indexes </li>
# <li>entry[1:n]: n items where each item is [bounding box vector, bounding box spaital features]. Note that different enteries might have different 'n' </li>
# <li>entry[n+1]: integer, entry[ 1 + entry[n+1]] is the ture bbox </li>
# </ul>

# %%
trainset = np.load(open(trainset_file, 'rb'))
trainset = [item for item in trainset if len(item)>2 and len(item[0])>0]
print('trainset barches #:', len(trainset))

test_N_val_set = np.load(open(testset_file, 'rb'))
test_N_val_set = [item for item in test_N_val_set if len(item)>2 and len(item[0])>0]
np.random.shuffle(test_N_val_set)
np.random.shuffle(test_N_val_set)
testset = test_N_val_set[:int(0.5*len(test_N_val_set))]
valset = test_N_val_set[int(0.5*len(test_N_val_set)):]

print('test barches #:', len(test_N_val_set))
print('val barches #:', len(valset))

with open(vocab_file, 'r') as f:
    vocab = json.loads(f.read())
# Out:
# trainset barches #: 297
# test barches #: 297
# val barches #: 149

# %%
vocab['<unk>'] = len(vocab)

# %%
len(vocab), vocab['<unk>']
# Out:
# (8242, 8241)

# %%
embed_vecs = np.load(open(embed_path, 'rb')).astype(np.float32)

# %% [markdown]
# <h3> augment_data function </h3>
# <br>We try sevral regularization methods. One of the things I've tried is to add data points where for each data I pick a query from a random data point and a set of bbox from a different random point. We build the labels (bboxes) distribution by giving an equal probability to each label. <br><br>
# The augment_data function does just that but the label of each added poind is writen as -1*number of bboxes. When we build the batch it self (function build_data in class Model), if we see a negative label index, we know its an added point and we know the number of bboxes so we can build the correct distribution.

# %%
def augment_data(data, ratio=0.5, addNoise=False):
        '''
        The function add data points. 
        We pick a query from a random data point,
        and a set of bbox from a different random point and we join them
        to build a new data point. The label distribution of the new data point will 
        uniform, that is, all labels will have equal probability. 
        
        
        Params:
            data: a list of data entries
                                                
        Returns: a list of augmented data
            
                        
        '''
                          
        q_idx = np.random.choice(range(len(data)), int(len(data)*ratio), replace=False)
        im_idx = np.random.choice([i for i in range(len(data)) if i not in q_idx], int(len(data)*ratio))
        for i in range(len(q_idx)):
            q, im = data[q_idx[i]][0], data[im_idx[i]][1:-1]
            item = [q]
            for im_tmp in im:
                item.append(im_tmp)
            item.append(-len(im))
            data.append(item)

# %%
def stats(test, train, ephocs=100, title=None, params=[50, 100, 150, 200]):
    '''
    Plot metrics graphs and print some stats.
    
    Params:
        test: list. 
              Each item is a tuple, [test accuracy, test IOU, test loss]
        
        train: list. 
               Each item is a tuple, [train accuracy, train IOU, train loss, 0]
               For now we can ignore the last part in the tuple (zero)
               
        params: The hyper-parameters to iterate over, defult to number of rnn's hidden units.
    '''
    
    ephocs = range(ephocs)
    test_res = np.array(test)
    train_res = np.array(train)
    test_Glabels = ['test accuracy', 'test IOU', 'test loss']
    train_Glabels = ['train accuracy', 'train IOU', 'train loss']

    for j, param in enumerate(params):
        print('num_hidden:', param)
        print('='*(len('num_hidden:')+3))
        for i in range(len(train_Glabels)):
            plt.plot(ephocs, test_res[j][:,i])
            plt.plot(ephocs, train_res[j][:,i])
            plt.legend([test_Glabels[i], train_Glabels[i]], loc='upper left')
            if title is not None:
                plt.title('%s: %d'%(title, param))
            plt.show()

            metric = ''.join(train_Glabels[i][len('train')+1:])
            if metric=='loss':
                print('Train min %s:%.3f'%(metric, min(train_res[j][:,i])))
                print('Test min %s:%.3f'%(metric, min(test_res[j][:,i])))
            else:
                print('Train max %s:%.3f'%(metric, max(train_res[j][:,i])))
                print('Test max %s:%.3f'%(metric, max(test_res[j][:,i])))
        print('-'*100,'\n')

# %% [markdown]
# # ALSTM
#
# This RNN cell has two LSTM cells, Bcell (for player B) and Acell (for Player A) and work as follow:
# <ol>
# <li>We run B's cells with the true query input word, getting the un-edited state. If use_worsAttn=True we add attention on the images vectors for each word.</li>
# <li>We run B's cells with the edited input word - 'unk', getting the edited state. If use_worsAttn=True we add attention on the images vectors for each word.</li>
# <li>We feed the un-edited state to A's cell.</li>
# <li>We run A's cells. A's input are:
# <ul><li>B's un-edited state</li><li>The reward for editing a word</li><li>B's loss having no edited words.</li></ul></li>
# <li>A's output is then goes throw a transformation which yields two values, one for editing a word and another for not.<br>If the the value for edit the word is higher, we pass B's edited state to the next time step, else we pass B's un_edit state.</li><br>
# </ol>

# %%
class ALSTM(tf.nn.rnn_cell.LSTMCell):
    def __init__(self, 
                 batch_size, 
                 num_units, 
                 
                 # Size of A's attention vector.
                 words_attn_dim, 
                 # B's outputs (for each time step).
                 words_attn_states, 
                 # Inicates whether attentionvec is a padding (0) or not (1).
                 words_attn_idx, 
                 
                 # Size of B's attention vector ([image vector, spital features] size) .
                 img_attn_dim, 
                 # B's outputs (for each time step).
                 img_attn_states, 
                 
                 
                 # Inicates whether attentionvec is a padding (0) or not (1).
                 img_attn_idx, 
                 
                 unk, #'unk' word vector
                 
                 # Whehter to edit the query or not.
                 isEdit, 
                 
                 # Whether B uses words levlel attention or not.
                 use_wordAttn,
                 
                 # Probabilty for choosing an action (edit or not) randomly, 
                 editRandomlyProb, 
                 # If the action is chosen randomly. edit with probability of rnn_editProb
                 rnn_editProb,
                 
                 # Dropin and dropout ratio.
                 dropout_in, 
                 dropout_out,
                 # If True add noise instead of using 'unk'
                 editByNoise=False,
                 
                 # If useNoise is true word vec = alpha*word_vector+(1-alpha)*noise
                 useNoise=False,
                 alpha=.5,
                 
                 #this holds A's rewards and B's losses to
                 # be add to A's feature vectors.
                 reward_loss=None,
                 state_is_tuple=True
                ):
        
        
        # When useing A, the cell state will contain the concatenation 
        # of both B and A states. Therefore we set the unit number to be
        # 2*(A and B unit size).
        super().__init__(2*num_units, state_is_tuple=state_is_tuple)
    
        self.words_attn_states = words_attn_states
        self.words_attn_idx = words_attn_idx
        self.words_attn_dim = words_attn_dim
        
        self.img_attn_states = img_attn_states
        self.img_attn_idx = img_attn_idx
        self.img_attn_dim = img_attn_dim
        
        self.num_units = num_units
        self.batch_size = batch_size
        self.unk = unk 
        self.isEdit = isEdit
        self.use_wordAttn=use_wordAttn
        
        self.Bcell = tf.nn.rnn_cell.DropoutWrapper(
                tf.nn.rnn_cell.LSTMCell(self.num_units, state_is_tuple=True), input_keep_prob=dropout_in, output_keep_prob=dropout_out)
        
        self.Acell = tf.nn.rnn_cell.DropoutWrapper(
                tf.nn.rnn_cell.LSTMCell(self.num_units, state_is_tuple=True), output_keep_prob=dropout_out)
        
        
        self.editRandomlyProb = editRandomlyProb
        self.rnn_editProb = rnn_editProb
        self.reward_loss = reward_loss
        self.useNoise=useNoise
        self.alpha=alpha
        

    def call(self, inputs, state):
        '''
        Params:
            inputs: word embadding.
            state:  [B's state form privious state, A's state form privious state]
        '''
        # takse B's state from state[:self.num_units]
        Bstate_c = tf.slice(state[0], [0, 0], [-1, self.num_units])
        Bstate_h = tf.slice(state[1], [0, 0], [-1, self.num_units])
        self.Bstate =  tf.nn.rnn_cell.LSTMStateTuple(c=Bstate_c, h=Bstate_h)
         
        # If B's cell uses attention
        if self.use_wordAttn:
            words_attn = self.attention(Bstate_h, self.img_attn_states, self.img_attn_dim, self.img_attn_idx)
            new_input = tf.concat([inputs, words_attn], -1)
            Boutputs, Bnew_state =  self.Bcell(new_input, self.Bstate, 'Bcell')
        else:
            Boutputs, Bnew_state =  self.Bcell(inputs, self.Bstate, 'Bcell')

        
        def f1(): # If isEdit==True
            # takse A's state from state[self.num_units: 2*self.num_units]
            Astate_c = tf.slice(state[0], [0, self.num_units], [-1, self.num_units])
            Astate_h = tf.slice(state[1], [0, self.num_units], [-1, self.num_units])
            self.Astate =  tf.nn.rnn_cell.LSTMStateTuple(c=Astate_c, h=Astate_h)
            
            if self.useNoise: # just add noise to the edited words
                new_unk_vecs = self.alpha*inputs + (1-alpha)*tf.random_normal(shape=inputs.get_shape(), stddev=0.1)
            else: # change the edited words by 'unk'
                unk_vecs = tf.concat([self.unk for _ in range(self.batch_size)], 0) # shape: self.batch_size x 1 x embed_size
                new_unk_vecs = tf.squeeze(unk_vecs) # shape: self.batch_size x embed_size
            
            # run B's cell with unk_batch
            if self.use_wordAttn:
                new_unk = tf.concat([new_unk_vecs, words_attn], -1)
            else:
                new_unk = new_unk_vecs
            edit_output, edit_new_state = self.Bcell(new_unk, self.Bstate, 'Bcell')  
            out1, state1 = self.runCell(Boutputs, Bnew_state, edit_new_state)
            return out1, state1
        
        def f2(): 
            outs = tf.concat([Boutputs, tf.zeros((self.batch_size, self.num_units))], 1)
            new_state_c = tf.concat([Bnew_state[0], tf.zeros_like(Bnew_state[0])], 1)
            new_state_h = tf.concat([Bnew_state[1], tf.zeros_like(Bnew_state[1])], 1)
            return outs, tf.nn.rnn_cell.LSTMStateTuple(c=new_state_c, h=new_state_h)
        
        new_output, new_state = tf.cond(self.isEdit, f1, f2)
        
        return new_output, new_state
    
    def runCell(self, Boutputs, Bnew_state, edit_new_state):
        '''
        Run B's cell after editing.
        
        params:
            Boutputs: output vector without editing.
            Bnew_state: state vector without editing.
            edit_new_state: state vector after editing the input word to 'unk'. 
        '''
        
        with tf.variable_scope('runcell'):
            # get action values according to B's hidden state
            Aout, Anew_state, actions_vals = self.action_vals(Boutputs) 
            
            # We can't use a tf.cond with batch_size  conditions so....
            
            # A choose to edit a word if actions_vals[0]<actions_vals[1].
            # Note: if we edit the word cond=1, else cond=0.
            a1, a2 = tf.split(value=actions_vals, num_or_size_splits=2, axis=1)
            A_choice = tf.cast(tf.less(a1, a2), tf.float32)
            
            # If action is chosen randomly, edit word with probability self.rnn_editProb
            # Note: if we edit the word cond=1, else cond=0.
            rand = tf.multinomial(tf.log([[self.rnn_editProb, 1-self.rnn_editProb]]), self.batch_size)
            rand_choice = tf.cast(tf.less(tf.transpose(rand), 1), tf.float32) 
            
            # Choose whether to edit a word randomly with probability of editRandomlyProb
            editRandomly = tf.multinomial(tf.log([[self.editRandomlyProb, 1-self.editRandomlyProb]]), self.batch_size)
            editRandomly_choice = tf.cast(tf.less(tf.transpose(editRandomly), 1), tf.float32)
            
            # A list of decisions for each word in the batch. actions_idx[i] = 1->edit word in query i (at this time step), 0->do not edit.
            actions_idx = editRandomly_choice*rand_choice + (1-editRandomly_choice)*A_choice

            # We'd like to know the action values and decision for each word,
            # therefore theses info are placed on the first 3 dimensions of the 
            # output vector. Note that this vector is not passed to the 
            # next tiee step so it won't affect the model. 
            outs = tf.concat([actions_vals,  actions_idx], 1)

            # B's i state is replaced by the edited state if actions_idx[i]=1 (i =1, 2, ..., batch_size)
            new_edit_state_c = (1-actions_idx)*Bnew_state[0] + actions_idx*edit_new_state[0]
            new_edit_state_h = (1-actions_idx)*Bnew_state[1] + actions_idx*edit_new_state[1]


            new_outs = tf.concat([outs, tf.zeros((self.batch_size, 2*self.num_units-3))], 1)
            new_state_c = tf.concat([new_edit_state_c, Anew_state[0]], 1)
            new_state_h = tf.concat([new_edit_state_h, Anew_state[1]], 1)
            return new_outs, tf.nn.rnn_cell.LSTMStateTuple(c=new_state_c, h=new_state_h)
    
    
    def action_vals(self, Boutputs):
        '''
        Get values for editing/not editing the input word.
        
        Params:
            Boutputs: output vector without editing.
            
        Returns vals where:
            Aout: A's cell output
            Anew_state: A's cell state
            vals: Tensor where vals[0] is the value for not editing the word 
                    and vals[1] is the value for editing the word.
        '''
        
        with tf.variable_scope('action_vals') as scope:
            Aattn = self.attention(self.Astate[1], self.words_attn_states, self.words_attn_dim, self.words_attn_idx)
            
            # A's input: [input, B's output, attntion state, reward, B's loss with no edits]
            Anew_inputs = tf.concat([Boutputs, Aattn, self.reward_loss], 1)
            
            Aout, Anew_state = self.Acell(Anew_inputs, self.Astate, 'Acell')
            vals = self.linear(Aout, 2)

            # Save the variables that only A uses. 
            # These variables will be trained separately from B's model.
            self.Avars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=scope.name)
            
            return Aout, Anew_state, vals
            
        
    def linear(self, inputs, output_dim, scope='linear', bias=True, reuse=False):
        with tf.variable_scope(scope, reuse=False):
            W = tf.get_variable('W', initializer=tf.contrib.layers.xavier_initializer(),
                                shape=(inputs.get_shape()[-1], output_dim))
            if bias:
                b = tf.get_variable('b', initializer=tf.constant_initializer(0.1),
                               shape=[1, output_dim])
                return tf.matmul(inputs, W) + b

        return tf.matmul(inputs, W)
    
    
    def attention(self, state, attn_states, attn_dim, attn_idx, relu=False):
        '''
        Attention mechanism (see https://arxiv.org/pdf/1409.0473.pdf)
        
        state: State from previous time step.
        attn_states: Attetntion states. 
                     Tensor of shape (batch_size x max([len(attention_vectors[i]) for i in range(bach_size)]) x attn_dim)
        attn_dim: Attention vector size.
        attn_idx,: Tensor used for masking of shape (batch_size x max([len(attention_vectors[i]) for i in range(bach_size)]). 
                   attn_idx[i, j]=1 if the j's attention vcctior of sample i  is not padding, else its equat to 0.
        '''
        
        self.attn_length = tf.shape(attn_states)[1]  
        
        # Computing... hidden_attn = W*v_att (use tf.nn.conv2d for efficiency)
        attn_vecs = tf.reshape(attn_states, [self.batch_size, self.attn_length, 1, attn_dim])
        W = tf.get_variable("attn_W", [1, 1, attn_dim, self.num_units])
        hidden_attn = tf.nn.conv2d(attn_vecs, W, [1, 1, 1, 1], "SAME")

        # Computing... hidden_s = U*v_state
        hidden_s = tf.reshape(
            self.linear(
                tf.cast(state, tf.float32), output_dim=self.num_units, scope='hidden_s_linear'), [-1, 1, 1,  self.num_units], name='hidden_s')

        # Computing alpha
        v = tf.get_variable("attn_v", [self.num_units])
        if relu:
            logits = tf.reduce_sum(v * tf.nn.relu(hidden_attn + hidden_s), [2, 3])
        else:
            logits = tf.reduce_sum(v * tf.nn.tanh(hidden_attn + hidden_s), [2, 3])

        # Masked softmax
        max_logits = tf.reduce_max(logits, axis=-1)
        masked_logits = tf.exp(logits-tf.expand_dims(max_logits, axis=1))*attn_idx
        alpha = masked_logits/tf.reduce_sum(masked_logits, axis=-1, keep_dims=True)

        a = tf.reduce_sum(tf.reshape(alpha, [-1, self.attn_length, 1, 1]) * attn_vecs, [1, 2])
        b = self.linear(a, output_dim=self.num_units, scope='b')
                                               

        return b

# %% [markdown]
# # Training
# When A joins the game, each iteration is completed via three steps:
# <ul>
# <li>We feed the query as it is to B and run it alone (no optimization nor training is done in this step)</li>
# <li>We run A and B together (no optimization nor training is done in this step). At this step we get A's decition and B's loss on the edited query. We use B's loss to calculate the Bellman's value for each time step. </li>
# <li>We again run A and B together, since now we know the real values for each time step and the real action for each time step (these will be the same as in the previous step since we did not train optimize the parameters yet), we finaly train the model</li>
# </ul>
# <br>
# But first we check the model's performance with out A. Class Model has a set of conditioning variables that set a different ragularization methods in the model. We start by checking them with out A's interference. We can also make the model RNN become bidirectional (by setting useBidirectionalRnn to True) and use words level attention (by setting use_wordAttn to True).

# %%
class Model():
    def __init__(self,
                 batch_size, 
                 num_hidden, 
                 
                 #Image's vector size.
                 img_dims, 
                 
                 #Spaital features length.tra
                 bbox_dims, 
                 vocab, 
                 
                 # For learning rate exponential decay
                 decay_steps, 
                 decay_rate, 
                 
                 # whether to use bach normaliztion for the last attention layer
                 bnorm,
                 
                 embed_size=embed_vecs.shape[1],
                 
                 # Whether B uses words levlel attention or not.
                 use_wordAttn=False,
                 
                 # Whther to use bidirectional rnn
                 useBidirectionalRnn=False,
                 
                 # Urnn_norm: Whether to use batch normalization for the queries.
                 # Uatt_norm: Whether to use batch normalization for the VGG outputs.
                 Urnn_norm=True, 
                 Uatt_norm=True,
                 
                 # If useNoise, A add Normal noise to a word 
                 # instead of editing it: word_vec = alpha*word_vec+(1-alpha)*noise
                 useNoise=False,
                 alpha=.5,
                 
                 # Whether to scale and normelize queries 
                 # embedding to have zero mean and QSTD std
                 toQscale = False,
                 Qstd = 0.1
                ):
#         with tf.device('/cpu:0'):

        self.batch_size = batch_size
        self.img_dims = img_dims
        self.bbox_dims = bbox_dims 
        self.num_hidden = num_hidden
        self.embed_size = embed_size
        self.vocab = vocab
        self.toQscale=toQscale
        self.Qstd=Qstd
        self.useNoise=useNoise
        self.alpha=alpha
        
        # length of the logest query (all queries will be padded to this length)
        self.qlen = tf.placeholder(tf.int32, name='qlen_holder')
        self.queries = tf.placeholder(tf.int32, [None, None], name='queries')
        self.img  = tf.placeholder(tf.float32, [None, None, self.img_dims], name='img')# VGG output vectors
        self.bboxes = tf.placeholder(tf.float32, [None, None, self.bbox_dims], name='bboxes')# spatial bbox's features.

        # attn_idx: inicates whether attention box is a dummy (0) or not (1).
        self.attn_idx = tf.placeholder(tf.float32, [None, None], name='attn_idx')

        self.labels = tf.placeholder(tf.float32, [None, None], name='labels')
        self.isEdit = tf.placeholder(tf.bool, name='isEdit') # whehter to edit the query or not.
        
        # Probabilty for choosing an action (edit or not) randomly, 
        self.editRandomlyProb = tf.placeholder(tf.float32, name='editRandomlyProb_holder')
        # If the action is chosen randomly. edit with probability of rnn_editProb
        self.rnn_editProb = tf.placeholder(tf.float32, name='rnn_editProb_holder')

        # After we run B with no edited words 
        # this holds B cross enthropy loss per query, de
        # and  A's rewards to be add to A's feature vectors.
        self.BCE_holder = tf.placeholder(tf.float32, [None,1], name='BCE_holder')
        self.reward_holder = tf.placeholder(tf.float32, [None,1], name='rewards_holder')

        # Dropout ratio for rnn's inputs and outpouts
        self.dropout_in = tf.placeholder(tf.float32, name='dropoutIn_holder')
        self.dropout_out = tf.placeholder(tf.float32, name='dropoutOut_holder')

        # Dropout ratio for attention vector (for the final attention layer before the loss function)
        self.dropout_img = tf.placeholder(tf.float32, name='dropoutImg_holder')
        # Dropout ratio for query vector (for the final attention layer before the loss function)
        self.dropout_q = tf.placeholder(tf.float32, name='dropoutImg_holder')
        
        # A and B learning rates.
        self.Alr = tf.placeholder(tf.float32, name='Alr_holder')
        self.Blr = tf.placeholder(tf.float32, name='Blr_holder')

        # B outputs vectors (with no words edits), These are A's attention vectors
        # which it uses to decide whter to edit a word.
        self.Aattn_vecs = tf.placeholder(tf.float32, [None, None, None], name='Aattn_vecs_holder')    
        self.unk = tf.constant([[vocab['<unk>']]], tf.int32)

        self.isTrain = tf.placeholder(tf.bool, name='isTrain_holder') 
        self.queries_lens = self.length(self.queries) # list of all the lengths  of the batch's queriey 

        # Concatinate images vectors and their spaital features. 
        # These vectors wlll be used for attenionn when 
        # we calculate the loss function.
        attn_vecs = tf.concat([self.img, self.bboxes], 2) 
        voc_size = len(self.vocab)

        # Load pre-trained word imaddings.
        # w2v_embed is not trainable.
        with tf.variable_scope('w2v'):
            w2v_embed = tf.get_variable('w2v_embed', initializer=embed_vecs, trainable=False)
            w2v_queries = tf.nn.embedding_lookup(w2v_embed, self.queries, name='w2v_queries')

        with tf.variable_scope('embed'):
            embed = tf.get_variable('embed', shape=[voc_size, self.embed_size], 
                                    initializer=tf.random_uniform_initializer(minval=-0.1, maxval=0.1))
            embed_queries_tmp = tf.nn.embedding_lookup(embed, self.queries, name='embed_queries')

        embed_queries = embed_queries_tmp+w2v_queries

        with tf.variable_scope('rnn'):
            Aattn_idx = tf.cast(tf.abs(tf.sign(self.queries)), tf.float32)

            reward_loss = tf.concat([self.reward_holder, self.BCE_holder], 1)
            cell = ALSTM(num_units=self.num_hidden, 
                            words_attn_dim=self.num_hidden, 
                            words_attn_states=self.Aattn_vecs, 
                            words_attn_idx=Aattn_idx,
                            img_attn_dim=self.img_dims+self.bbox_dims,
                            img_attn_states=attn_vecs,
                            img_attn_idx=self.attn_idx,
                            batch_size=self.batch_size, 
                            unk=tf.nn.embedding_lookup(embed, self.unk),
                            isEdit=self.isEdit,
                            reward_loss=reward_loss, use_wordAttn=use_wordAttn,
                            editRandomlyProb=self.editRandomlyProb, rnn_editProb=self.rnn_editProb,
                            dropout_in=self.dropout_in, dropout_out=self.dropout_out,
                            useNoise=self.useNoise, alpha=self.alpha)

            if useBidirectionalRnn:
                self.outputs, self.last_states = tf.nn.bidirectional_dynamic_rnn(
                    cell_fw=cell,
                    cell_bw=cell,
                    dtype=tf.float32,
                    sequence_length=self.queries_lens,
                    inputs=embed_queries)

                # self.last_states contain both forward state
                # and backward state.
                # We don't use A with bidirectional rnn
                # so no need for self.values (action values as calculated by A)
                Bstate = tf.concat(
                    [tf.slice(self.last_states[0][1], [0,0], [-1, self.num_hidden]), 
                     tf.slice(self.last_states[1][1], [0,0], [-1, self.num_hidden])], -1)
            else:
                self.outputs, self.last_states = tf.nn.dynamic_rnn(
                    cell=cell,
                    dtype=tf.float32,
                    sequence_length=self.queries_lens,
                    inputs=embed_queries)

                # self.values[0]=value for not editing, self.values[1]=value for editing
                self.values = tf.slice(self.outputs, [0,0,0], [-1,-1,2])
                Bstate = tf.slice(self.last_states[1], [0,0], [-1, self.num_hidden])  


        Avars = cell.Avars
        self.Avars = {var.name:var for var in Avars}
       

        if bnorm:
            self.scores = self.bnorm_attention(Bstate, Urnn_norm=Urnn_norm, Uatt_norm=Uatt_norm) 
        else:
            self.scores = self.attention(Bstate) 


        # Cross entophy loss per query in the batch.
        self.B_ce = -tf.reduce_sum(
                        self.labels*tf.log(self.scores+0.00000001)+
                            (1-self.labels)*tf.log((1-self.scores)+0.00000001), 
                            axis=-1)


        # We don't use A with bidirectional rnn
        if not useBidirectionalRnn:
            # A's decision for each word.
            # self.idx[i,j]=1 if word j in query i was edited, else zero.
            self.idx = tf.squeeze(tf.slice(self.outputs, [0,0,2], [-1,-1,1]))
            
            # edit_ratio: Over all ratio of edited words per query
            # 
            self.edit_ratio = tf.reduce_mean(tf.reduce_sum(
                tf.cast(self.idx, tf.float32)*tf.expand_dims(
                        1/tf.cast(self.queries_lens, tf.float32), axis=1), axis=1))

            # After running A for the first time, we get A's decisions and their values.
            # we then calulate the following tensors:
            # actions_idx[j,i] = 1 if the word i in query j was edited or 0 otherwise.     
            # bell_vall holds the values for each decision by the bellman function. 
            
           
            '''
            Now that we know what actions A took,
            we calculate the actual reward per word A gets:
            act_rewards[i,j] = idx[i,j]*edit_reward*BCE[i]/queries_lens[i]

            If word j in query i was edited then idx[i,j]=1 and:
               act_rewards[i,j] = 1*edit_reward*BCE[i]/queries_lens[i]=edit_reward*BCE[i]/queries_lens[i]
            else edited idx[i,j]=0 and:
               act_rewards[i,j] = 0*edit_reward*BCE[i]/queries_lens[i]=0
            
            if the word is '<pad>' than act_rewards[i,j]=0 always
            '''
            q_mask = tf.cast(tf.abs(tf.sign(self.queries)), tf.float32)
            act_rewards = q_mask*self.idx*self.reward_holder
            self.act_rewards=act_rewards
            # Scale B's loss per query, when words were edited. 
            # We scale all the losses to have mean 1 and std 0.5,
            # this gives A a fixed range of (state, action) values
            Bce_min = tf.reduce_min(self.B_ce)
            Bce_max = tf.reduce_max(self.B_ce)
            Bce_scale = (self.B_ce-Bce_min)/(Bce_max-Bce_min)
            s = tf.contrib.keras.backend.std(Bce_scale, keepdims=True)
            # new_BCE is the scaled B's losses with words edits.
            new_BCE = 0.5*Bce_scale/s # 0.5 std
            new_BCE = 1 + new_BCE - tf.reduce_mean(new_BCE) # 1 mean
            self.new_BCE=new_BCE
            # In order to get the values of A's real actions (see self.pyrite_val in __init)
            # Tensorflow need us to change idx to a list where each item
            # is [number of query x maximum number of words in a query, action (1 or 0 for edit or not respectively)]
            self.actions_idx = tf.concat(
                                [tf.expand_dims(tf.range(self.batch_size*self.qlen), 1), 
                                         tf.expand_dims(tf.reshape(tf.cast(self.idx,tf.int32), [-1]), 1)], -1)
            
            # Now that we have the real actions A took and
            # B's loss per query, we can calculate the REAL (word, action) value 
            # using bellman equation.
            self.bell_val = self.discount_rewards(act_rewards, new_BCE)
            
            # pyrite_val: holds A's predicted values for each of its (word, actions) pair.
            # self.pyrite_val[i,j] = 
            #            self.values[i,j][self.actions_idx[i,j]] = 
            #                               the value A predicted (i.e. self.values[i,j])
            #                               for the action it took (i.e. self.actions_idx[i,j])
            #                               at query i word j.
            # (see https://en.wikipedia.org/wiki/Pyrite.)
            pyrite_val = tf.reshape(tf.gather_nd(tf.reshape(self.values, (-1,2)), 
                                                      self.actions_idx), (self.batch_size, -1))
            
            self.pyrite_val=pyrite_val
            # RMSE loss between the real bellman value and 
            # A's predicted values. We mask the loss by zeroing the padded words.
            # A smooth factor is added to prevent the gradient from being nan. 
            self.A_loss = tf.sqrt(tf.reduce_mean(
                tf.reduce_sum(tf.square(q_mask*(self.bell_val-pyrite_val)), axis=1)/tf.expand_dims(tf.cast(self.queries_lens, tf.float32), 
                                                                                              axis=1))+0.00000001)

        self.B_loss = tf.reduce_mean(self.B_ce)
        self.Agrads = {Avar.name:Gvar for Avar, Gvar in zip(Avars, tf.gradients(self.A_loss, Avars))}
        ##############
        # Optimizers #
        ##############

        if not useBidirectionalRnn:
            # Train only A variables
            A_starter_learning_rate = self.Alr
            A_global_step = tf.Variable(0, name='A_global_step', trainable=False)
            self.A_learning_rate = tf.train.exponential_decay(A_starter_learning_rate, A_global_step,
                                                       decay_steps=decay_steps, decay_rate=decay_rate, staircase=True)
        
            self.A_optimizer =  tf.train.GradientDescentOptimizer(
                    learning_rate=self.A_learning_rate).minimize(self.A_loss, global_step=A_global_step, var_list=Avars)  

        # Train only B variables 
        B_starter_learning_rate = self.Blr
        self.global_step = tf.Variable(0, name='global_step', trainable=False)
        self.learning_rate = tf.train.exponential_decay(B_starter_learning_rate, self.global_step,
                                                   decay_steps=decay_steps, decay_rate=decay_rate, staircase=True)

        Bvars = [var for var in tf.trainable_variables() if var not in Avars]
        self.B_optimizer =  tf.train.GradientDescentOptimizer(
                    learning_rate=self.learning_rate).minimize(self.B_loss, global_step=self.global_step, 
                                                               var_list=Bvars)  

        if not os.path.exists(params_dir):
                os.makedirs(params_dir)
        self.saver = tf.train.Saver()

        
    def length(self, seq):
        '''
        Retruns real lengths (before addings) of all queries in seq  .
        '''
        return tf.cast(tf.reduce_sum(tf.sign(tf.abs(seq)), reduction_indices=1), tf.int32)
       

    def linear(self, inputs, output_dim, scope='linear', bias=True, reuse=False):

        with tf.variable_scope(scope, reuse=reuse):
            W = tf.get_variable('W', initializer=tf.contrib.layers.xavier_initializer(),
                                shape=(inputs.get_shape()[-1], output_dim))
            if bias:
                b = tf.get_variable('b', initializer=tf.constant_initializer(0.1),
                               shape=[1, output_dim])
                return tf.matmul(inputs, W) + b
            
            return tf.matmul(inputs, W)
        
    
    def Qscale(self, qVecs):
        '''
        Scale queries embedding vectors to have zero mean and std STD.
        
        Params:
            qVecs: Tensor (shape: batch_size x number_of_hidden_units) 
                   holding the queries vectors, 
        '''
        qVecs_min = tf.reduce_min(qVecs, axis=-1, keep_dims=True)
        qVecs_max = tf.reduce_max(qVecs, axis=-1, keep_dims=True)
        qVecs_scale = (qVecs-qVecs_min)/(qVecs_max-qVecs_min) # Scale to 0-1
        s = tf.contrib.keras.backend.std(qVecs_scale, axis=-1, keepdims=True)
        tmp = self.Qstd * qVecs_scale/s #Scale to have lf.Qstd std
        new_qVecs = tmp - tf.reduce_mean(tmp, axis=-1, keep_dims=True) # zero mean
        
        return new_qVecs
        

            
    def attention(self, q_embed):
        '''
        Given B's output vector, calculate the attention over 
        all the query's bounding boxes vectors, That is, calculate:
        
        probs = softmax(relu(context(Sq+Satt+b)))
        
        Where:
        Sq = <Wq, queries_states>
        Sattn = <Wattn, attention_bboxes_vectors>
        
        The  bounding box with the highest attention score will be chosen as the correct bounding box.
        
        Params:
            q_embed: Tensor of shape (batch size x num_hidden)B's outputs. 
            
        Returns:
            probs: Tensor of shape (batch_size x max bbox number for query).
                   Attention score for each bbox.
        '''
        # concatenate img vectors with spaical features
        attn_vecs = tf.concat([self.img, self.bboxes], 2)
        
        # B's outputs, shape: (batch size x num_hidden)
        if self.toQscale:
            Urnn = self.Qscale(q_embed)
        else:
            Urnn = q_embed
        
        # Attention vectors, 
        # shape: (batch size x max bbox number for query x attention vector size)
        Uatt = attn_vecs
           
        with tf.variable_scope('l1'):
            b = tf.get_variable(
                    'b', 
                    initializer=tf.constant_initializer(0.1), 
                    shape=[1, self.num_hidden])

            context = tf.get_variable(
                    'context', 
                    initializer=tf.random_uniform_initializer(minval=-0.1, maxval=0.1), 
                    shape=[self.num_hidden, 1])


            Sq = tf.nn.dropout(
                self.linear(Urnn, self.num_hidden, bias=False, scope='Sq'), 
                self.dropout_q)
            
            Sattn = tf.nn.dropout(
                tf.reshape(
                    self.linear(
                        tf.reshape(Uatt, (-1, self.img_dims+self.bbox_dims)), 
                        self.num_hidden, 
                        bias=False, scope='Sattn'), 
                    [self.batch_size, -1, self.num_hidden]),
                self.dropout_img)

        out = tf.nn.relu(tf.expand_dims(Sq, 1) + Sattn + b)
        logits = tf.reshape(tf.matmul(tf.reshape(out, (-1, tf.shape(out)[-1])),  context), (tf.shape(out)[0], -1))

        # Calculate logits's masked softmax (we use self.attn_idx to mas
        max_logits = tf.reduce_max(logits, axis=-1)
        masked_logits = tf.exp(logits-tf.expand_dims(max_logits, axis=1))*self.attn_idx
        probs = self.attn_idx*masked_logits/tf.reduce_sum(masked_logits, axis=-1, keep_dims=True)

        return probs

    
    def bnorm_attention(self, q_embed, Urnn_norm=True, Uatt_norm=True):
        '''
        Given B's output vector, calculate the attention over 
        all the query's bounding boxes vectors, That is, calculate:
        
        probs = softmax(relu(context(Sq+Satt+b)))
        
        Where:
        Sq = <Wq, queries_states>
        Sattn = <Wattn, attention_bboxes_vectors>
        
        The  bounding box with the highest attention score will be chosen as the correct bounding box.
        This function uses batch normalization. 
        
        Params:
            q_embed: Tensor of shape (batch size x num_hidden)B's outputs. 
            Urnn_norm: Whether to use batch normalization for the queries.
            Uatt_norm: Whether to use batch normalization for the VGG outputs.
            
        Returns:
            probs: Tensor of shape (batch_size x max bbox number for query).
                   Attention score for each bbox.
        '''
        # concatenate img vectors with with spaical features
        attn_vecs = tf.concat([self.img, self.bboxes], 2)
        if self.toQscale:
            q_embed = self.Qscale(q_embed)
            
        Urnn = q_embed
        Uatt = attn_vecs
        
        if Urnn_norm:
            # B's outputs with bath normalization. 
            # shape: (batch size x num_hidden)
            Urnn = tf.contrib.layers.batch_norm(
                q_embed, center=True, scale=True, is_training=self.isTrain) 
        
        if Uatt_norm:
            # Attention vectors with bath normalization. 
            # shape: (batch size x max bbox number for query x attention vector size)
            Uatt = tf.contrib.layers.batch_norm(
                attn_vecs, center=True, scale=True, is_training=self.isTrain)
           
        update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
        with tf.control_dependencies(update_ops):
            with tf.variable_scope('bnorm_l1'):
                b = tf.get_variable(
                        'b', 
                        initializer=tf.constant_initializer(0.1), 
                        shape=[1, self.num_hidden])

                context = tf.get_variable(
                        'context', 
                        initializer=tf.random_uniform_initializer(minval=-0.1, maxval=0.1), 
                        shape=[self.num_hidden, 1])


                Sq = tf.nn.dropout(
                    self.linear(Urnn, self.num_hidden, bias=False, scope='Sq'), 
                    self.dropout_q)
                
                Sattn = tf.nn.dropout(
                            tf.reshape(
                                self.linear(
                                    tf.reshape(Uatt, (-1, self.img_dims+self.bbox_dims)), 
                                    self.num_hidden, 
                                    bias=False, scope='Sattn'), 
                                 [self.batch_size, -1, self.num_hidden]),
                            self.dropout_img)
                    
                   
            out = tf.nn.relu(tf.expand_dims(Sq, 1) + Sattn + b)
            logits = tf.reshape(tf.matmul(tf.reshape(out, (-1, tf.shape(out)[-1])),  context), (tf.shape(out)[0], -1))

            # Calculate logits's masked softmax (we use self.attn_idx to mas
            max_logits = tf.reduce_max(logits, axis=-1)
            masked_logits = tf.exp(logits-tf.expand_dims(max_logits, axis=1))*self.attn_idx
            probs = self.attn_idx*masked_logits/tf.reduce_sum(masked_logits, axis=-1, keep_dims=True)

            return probs
  
        
    def q_padding(self, seq, max_length):
        '''
        Pad  seq with vocab['<pad>'] (0) to max_length length.
        '''                  
        return seq + [self.vocab['<pad>']]*(max_length-len(seq))

    
    def build_data(self, data, start, end, imScale, addNoiseImg=False):
        '''
        Build batch.
        ------------
        
        Params:
            data: each entry in this list has the following structure:
                  [query indexes, [bounding box vector (VGG), bounding box spaital features], ..., 
                  [bounding box vector (VGG), bounding box spaital features], index of the true label]
                  
            start/end: batch data is built from data[start:end]
            
        Returns:
            attn_idx: attn_idx[i, j]=1 if the j'th bbox in the i'th query is not padding, else equals to 0. 
            
            padded_queries: list of queries, padded to the length of the longest query in the batch.
                            Note: vocab['pad']=0
                            
            padded_im: list of bounding boxes vectors, padded to the maximum number of bbox per query.
                       Note: padded vector is vector of zeros. 
                            
            padded_bbox: list of bounding boxes spatial features, padded to the maximum number of bbox per query.
                         Note: padded vector is vector of zeros.  
        
            onehot_labels: onehot_labels[i][j]=1 if j is the true bbox for query i, else  onehot_labels[i][j]=0
            
            addNoiseImg: Boolean. Whether to add normal noise to the images.
            
            imScale: If not None, scale the image vectors (VGG16 outputs) to have 0 mean and imScale std
                        
        '''
                          
        qlen = max([len(data[i][0]) for i in range(start, end)]) # Length fo the longest query
        imlen = max([len(data[i]) for i in range(start, end)])-2 # Maximum number of bbox per query.
        padded_queries, padded_im, padded_bbox, attn_idx = [], [], [], []
        
        # Build one hot labels from the labels index, given in the data.                  
        labels = [item[-1] for item in data[start:end]] #data[i][-1]=index of the true bbox of query i
        dist_labels = np.zeros((end-start, imlen)) #label distribution
        
        # Real data points
        dist_labels[[i for i in np.arange(end-start) if labels[i]>0], [l for l in labels if l>0]]=1
        
        # augmented data points
        for i in np.arange(end-start):
            if labels[i]<0:
                dist_labels[i] = [-1/labels[i] for _ in range(-labels[i])]+[0. for _ in range(imlen+labels[i])]
                          
        im_dim, bbox_dim = data[0][1][0].shape[1], data[0][1][1].shape[1]
        for i in range(start, end):
            padded_queries.append(self.q_padding(data[i][0], qlen))
            
            attn_idx.append([1 for _ in range(len(data[i])-2)]+[0 for _ in range(imlen-(len(data[i])-2))])
            
            padded_im.append(np.concatenate([data[i][j][0] for j in range(1, len(data[i])-1)] + 
                                       [np.full((imlen-(len(data[i])-2), im_dim), vocab['<pad>'], dtype=np.float32)], axis=0))
            
            padded_bbox.append(np.concatenate([data[i][j][1] for j in range(1, len(data[i])-1)] + 
                                       [np.full((imlen-(len(data[i])-2),bbox_dim), vocab['<pad>'], dtype=np.float32)], axis=0))
           
        
        
        if addNoiseImg:
            padded_im+=(padded_im+np.random.normal(0, .1, np.array(padded_im).shape))*np.expand_dims(attn_idx, 2)
        else:
            padded_im=np.array(padded_im)
            
        if imScale is not None:
            # Smoothing factor
            halper = (1-np.expand_dims(np.array(attn_idx).astype(np.float32), 2))
            img_min = np.min(padded_im, axis=-1, keepdims=True)
            img_max = np.max(padded_im, axis=-1, keepdims=True)
            img_scale = (padded_im-img_min)/((img_max-img_min)+halper) # Scale to 0-1
            s = np.std(img_scale, axis=-1, keepdims=True)
            padded_im = imScale*img_scale/(s+halper)  #Scale to have imScale std
            padded_im = padded_im - np.mean(padded_im, axis=-1, keepdims=True) # scale to zero mean
            
        return qlen, np.array(attn_idx), np.array(padded_queries, dtype=np.int32), padded_im, np.array(padded_bbox), np.array(dist_labels)
            
   
    def ground(self, data=None, start=None, end=None, sess=None, feed_dict = None, isEdit=True, imScale=False, addNoiseImg=False):
        '''
        Given a query and a list of bboxes, the function returns the index of the referred bbox.
        '''
        isSess = (sess==None)
        if isSess:
            sess = tf.Session()
        with sess.as_default():
            if isSess:
                tf.global_variables_initializer().run()
                ckpt = tf.train.get_checkpoint_state(params_dir)
                if ckpt and ckpt.model_checkpoint_path:
                    self.saver.restore(sess, ckpt.model_checkpoint_path) # restore all variables
                else:
                    print('Initializing variables')
            if feed_dict is None:
                qlen, attn_idx, padded_queries, padded_im, padded_bbox, labels = self.build_data(data, start, end, 
                                                                                                 imScale=imScale, addNoiseImg=addNoiseImg)
                feed_dict = {
                        self.qlen:qlen,
                        self.queries:padded_queries,
                        self.img:padded_im,
                        self.bboxes:padded_bbox,
                        self.labels:labels,
                        self.attn_idx:attn_idx
                    }
            feed_dict[self.isTrain]=False
            feed_dict[self.isEdit] = isEdit
            feed_dict[self.dropout_in]=1.
            feed_dict[self.dropout_out]=1.
            feed_dict[self.dropout_img]=1.
            feed_dict[self.dropout_q]=1.
            scores = sess.run(self.scores, feed_dict=feed_dict) # get score for each bbox

        return np.argmax(scores, axis=1), np.argmax(feed_dict[self.labels], axis=1)
        
        
    def iou_accuracy(self, data, start, end, imScale, sess=None, feed_dict = None, addNoiseImg=False, 
                     threshold=0.5, test=False, isEdit=True, scores=[], labels=[]):
        '''
        Calculate the IOU score between the Model bbox and the true bbox.
        ''' 
        # Get score for each bbox (labels) and the true bbox index (gt_idx)  
        if len(scores)!=0  and len(labels)!=0:
            labels, gt_idx = np.argmax(scores, axis=1), np.argmax(labels, axis=1)
        else:             
            if feed_dict is None:
                labels, gt_idx = self.ground(data, start, end, sess=sess, feed_dict=feed_dict, 
                                             isEdit=isEdit, imScale=imScale,addNoiseImg=addNoiseImg)
            else: labels, gt_idx = self.ground(sess=sess, feed_dict=feed_dict, 
                                               isEdit=isEdit, imScale=imScale, addNoiseImg=addNoiseImg)
            
        acc = 0
        for i in range(start, end):
            gt = data[i][gt_idx[i-start]+1][1][0] # ground truth bbox
            crops = np.expand_dims(data[i][labels[i-start]+1][1][0], axis=0) #Model chosen bbox
            acc += (retriever.compute_iou(crops, gt)[0]>threshold) #IOU for the i sample.
            
        return acc/(end-start)
        
    def accuracy(self, imScale, data=None, start=None, end=None, sess=None, feed_dict = None, isEdit=True, addNoiseImg=False):
        isSess = (sess==None)
        if isSess:
            print('Building sess')
            sess = tf.Session()
        with sess.as_default():
            if isSess:
                print('Building sess used')
                tf.global_variables_initializer().run()
                ckpt = tf.train.get_checkpoint_state(params_dir)
                if ckpt and ckpt.model_checkpoint_path:
                    print('3')
                    self.saver.restore(sess, ckpt.model_checkpoint_path) # restore all variables
                else:
                    print('Initializing variables')
            if feed_dict is None:
                print('Building feed_dict')
                qlen, attn_idx, padded_queries, padded_im, padded_bbox, labels = self.build_data(data, start, end, 
                                                                                                 imScale=imScale, addNoiseImg=addNoiseImg)
                feed_dict = {
                        self.qlen:qlen,
                        self.queries:padded_queries,
                        self.img:padded_im,
                        self.bboxes:padded_bbox,
                        self.attn_idx:attn_idx,
                        self.labels:labels,
                    }
                
            feed_dict[self.isTrain]=False
            feed_dict[self.isEdit] = isEdit
            feed_dict[self.dropout_in]=1.
            feed_dict[self.dropout_out]=1.
            feed_dict[self.dropout_img]=1.
            feed_dict[self.dropout_q]=1.
            scores = sess.run(self.scores, feed_dict=feed_dict)
            acc = sum(np.equal(np.argmax(scores, axis=1), np.argmax(feed_dict[self.labels], axis=1))/len(feed_dict[self.labels]))

                    
        return acc
    
    def discount_rewards(self, rewards, last_rewards, gamma=1.0):
        """ 
        take 1D float array of rewards and compute discounted reward 
        using bellman function, i.e. for some query:
                
                value_(time step t) = rewards[t] + gamma*values_(time step t+1)
    
        We need to iterate over the rewards tensor, which is tricky 
        with Tensorflow, specially when the query maximum length (rewards.shape[1])
        can change at each iteration.
        
        We start with initializer tensor with shape (batch_size+1) x self.qlen.
        The first vector in initializer is BCE (B's loss per query) all the other 
        vectors are zero vectors, that is:
        
        initializer[0][i] is B's loss for query i.
        initializer[1:batch_size] are all zero vectors.
        
        This is doen since tf.foldl does not allow the shape of the function accumulator (bell_vals) to change.
        We then use tf.foldl function to go over all the words in reverse (see tf.range(self.qlen)[::-1] in 
        tf.foldl below). tf.foldl initialize fn's argument, bell_vals, with initializer and change it at each iteration.
        
        params:
            rewards: rewards[i,j] is the reward for the action A took on word j at query i.
            last_rewards: last_rewards[i] is B's loss for query i with no edits. This is the final reward.
            gamma: discount factor.
        """
                 
        initializer = tf.concat(
            [tf.expand_dims(last_rewards,1), tf.zeros(shape=(self.batch_size, self.qlen), dtype=tf.float32)], 1)
        
        def fn(bell_vals, time_steps):
            '''
            calculate bellman function.
            
            returns: 
                bell_vals: Tensor where bell_vals[i][t] is the value for word t in query i. 
            
            algorithm description:
                initialization: bell_vals=intitializer.
                for time_step in range(maximum_time_step-1, 0, -1):
                    1. val_ts = rewards[:,time_step]+bell_vals[0] (time step t values at each query)
                    2. bell_vals = bell_vals[:,:-1] (pop last column (zero vector) from bell_vals)
                    3. push (concatenate) rewards_ts to the begining of bell_vals so that
                       bell_vals[0] = val_ts (time step t values)
                    
                
            '''
            
            val_ts = tf.slice(bell_vals, [0, 0], [-1, 1]) + tf.slice(rewards, [0, time_steps], [-1 ,1])
            bell_vals = tf.concat([val_ts, bell_vals[:,:-1]], 1)
            return bell_vals
        
        bell_vals = tf.foldl(fn, tf.range(self.qlen)[::-1], initializer=initializer)[:,:-1]
        
        return bell_vals
        
    def train(self, trn_data, tst_data, val_data, ephocs_num, edit_reward, startA=10, 
              activation_ephoc=19, muteBnum=3, start_ephoc=0, dropout_in=1., rnn_editProb=0.2,
              dropout_out=1., dropout_img=1., dropout_q=1., queries_editProb=0.95,  
              addNoiseImg=False, imScale=None, Alr=0.1, Blr=0.05):
                          
        '''
        Params:
            trn_data: list, train set. 
 
            tst_data: list, test set.
            
            val_data: list, validation data.
                      At each ephoc>activation_ephoc, if we don't train
                      B at this ephoc than we run the model twice on val_data:
                      
                      * The first time no action will be chosen randomly. 
                        We calculate Bloss (ABloss) and the average ratio of 
                        edited words per query (p). 
                      * Then, at the second run, all the actions are chosen
                        randomly with probability of p to edit a word. Again, we
                        calculate B's loss (RandBloss)
                        
                      We then define A's gain at ephoc ep as:
                          AGain_ep = ABloss_ep - RandBloss_ep
                          
                      If AGain_ep<AGain_(ep-1) we reduce A's learning rate
                      and aventialy stop A training but keep training B with A's
                      edits.
             
            ephocs_num: number of ephocs
             
            start_ephoc: number of first ephoc.
             
            edit_reward: int, coefficient to multiply the reward by when editing a word.
             
            startA: int, Start competition only at ephoc # startA.
             
            muteBnum: After A starts, for each ephoc which A & B trains, 
                      only A will be trained for this amount of ephocs.
                   
            activation_ephoc: at ephoc numer "activation_ephoc", A will be activate.
                               That is, for (activation_ephoc-startA) number of ephocs, 
                               A will choose an action randomly and train only when B 
                               does not (see muteBnum argument).
                   
            queries_editProb: probabilty for editing a query.
            
            rnn_edit_prob: If the action is chosen randomly. edit with probability of rnn_editProb
            
            dropout_in: dropout ratio of B's rnn inputs.
            
            dropout_output: dropout ratio of B's rnn output.
            
            dropout_img: dropout ratio of images vectors before the last attention layer .
            
            addNoiseImg: Boolean. Whether to add normal noise to the images (see build_data).
            
            imScale: If not None, scale the image vectors (VGG16 outputs) to have 0 mean and 1/imScale std
            
            Alr: A's learning rate
            
            Blr: B's learning rate
                               
        '''                  
        
        trn_nbatch = len(trn_data)
        tst_nbatch = len(tst_data)
        val_nbatch = len(val_data)
        print('# Train set size:', sum([len(batch) for batch in trn_data]))
        print('# Training batches:', trn_nbatch)
        print('# Validation set size:', sum([len(batch) for batch in val_data]))
        print('# Validation batches:', val_nbatch)
        print('# Test set size:', sum([len(batch) for batch in tst_data]))
        print('# Testing batches:', tst_nbatch)
        self.test_res, self.train_res, self.val_res = [], [], [] #list to hold reults for train, test and validation sets
        
        # Holds different between validation B loss with and without random actions selections (see val_data in params)
        self.AGain = []
        
        Nrounds = 1 # number of time editRandomlyProb was decreased (see below for details)
        AlrDecreaseNum = 0 # number of time we've decrease A's learing rate
        
        # When AlrDecreaseNum=maxDecreaseNum stop training A (toTrainA=False)
        # but keeping using it for B training.
        maxDecreaseNum = 6 
        toTrainA = True
        rnn_editProb_tmp = rnn_editProb
        
        sess = tf.Session()
        with sess.as_default():
            tf.global_variables_initializer().run()
            ckpt = tf.train.get_checkpoint_state(params_dir)
            if ckpt and ckpt.model_checkpoint_path:
                print('Loading parameters from', ckpt.model_checkpoint_path)
                self.saver.restore(sess, ckpt.model_checkpoint_path) # restore all variables
            else:
                print('Initializing variables')
                
            for ephoc in range(start_ephoc, ephocs_num):
                startTime = datetime.now().replace(microsecond=0)
                          
                # Start training A only at ephooc number startA. 
                # when ephoc>=startA, each time we train B we train 
                # only A for muteBnum ephocs, so at ephoc startA, only 
                # A will train for muteBnum ephocs and B will only then be trained again.
                toTrainB = toTrainA==False or ephoc<startA or (ephoc-(startA-1))%(muteBnum+1)==0 # Whether to train only B 
                  
                '''
                If activation_ephoc> ephoc >=startA, A will always choose an action
                randomly (i.e. editRandomlyProb=1) and will not edit words while B
                is training. At ephoc 'activation_ephoc', editRandomlyProb will decrease 
                and an action will be chosen randomly only if only A is training, in 
                other words, when B is training editRandomlyProb will always be 0.
                
                If ephoc >=activation_ephoc, after each round (in each round we train only A 
                for muteBnum ephocs and then B for one ephoc, so each round takes muteBnum+1 epohocs
                and the first round start at ephoc startA), the probability for choosing an action 
                randomly will decrease:
                let Nrounds be the number of time editRandomlyProb was decreased so far 
                (Nrounds initialize to be 1), than for every rounds:
                    Nrounds+=1
                    editRandomlyProb = 1/Nrounds
                    
                While training B we never choose an action randomly.
                    
                Note that we set activation_ephoc so that (activation_ephoc-startA)%(muteBnum+1)=0
                thereby insuring that editRandomlyProb will start decreasing at the begining of
                a round and won't decrease during the following round.
                '''
                assert (activation_ephoc-startA)%(muteBnum+1)==0, 'activation_ephoc-(startA-1) mod %d != 0'%(muteBnum+1)
                editRandomlyProb=0.
                # editRandomlyProb: Probabilty for choosing an action (edit or not) randomly, 
                if ephoc>=activation_ephoc and (toTrainB or not toTrainA):
                    # Never choose an action randomly if training B or 
                    # A stoped its training (toTrainA=False).
                    # If ephoc<activation_ephoc we set isEdit to False
                    # when training B hence no words will be edited 
                    # during B's training any way, only A training 
                    # will be effected so we can ignore this case.
                    editRandomlyProb=0
#                 else:
#                     if (ephoc-startA)%(muteBnum+1)==0: # If this is true toTrainB=False
#                         Nrounds+=1 
#                     editRandomlyProb=1/Nrounds
                    
                        
                # When we train B, we show B's results on the trainset 
                # with edits (itrInEphoc=1) and without (itrInEphoc=2)
                itrInEphoc=1 
                if ephoc>=startA and toTrainB:
                    # we show B's results on the trainset without edits
                    itrInEphoc=2
                    
                print('='*50,'\nTRAIN, ephoc:%d; Training B:%s; A is a know-it-all:%s; ActivateA:%s'%(ephoc, toTrainB, 
                                                                                                      toTrainA==False, 
                                                                                                      ephoc>=activation_ephoc))
                np.random.shuffle(trn_data)
                for ep in range(itrInEphoc):
                    A_trn_loss, B_trn_loss, trn_acc, trn_iou = 0, 0, 0, 0
                    ephoc_edits_ratio = 0 # edited words per query average
                    tst_loss, tst_acc, tst_iou = 0, 0, 0
                    if ep==1:
                        # If ep=1, we're in round 2 in which we only show B's 
                        # results with out editing (on the train set).
                        print('No Edit')
                        print('ooooooo')
                        
                    
                    # There's a probability of 1-queries_editProb that B will be trained 
                    # with no edits in a batch. 
                    # editRount_count counts the number of batches with competition.
                    editRount_count = 0 
                    for b in range(trn_nbatch):
                        if ep==1:
                            # If ep=1, we're in round 2 in which we only show B's 
                            # results with out editing (on the train set).
                            isEdit=False
                        else:
                            # Edit queries in this 
                            # batch with probability of queries_editProb else don't edit.
                            isEdit = toTrainB==False or np.random.rand(1)[0]<queries_editProb
                            
                            # If ephoc<startA train A with no edits
                            if ephoc<startA:
                                editRandomlyProb=1.
                                rnn_editProb=0.
                            else:
                                rnn_editProb=rnn_editProb_tmp
                        
                        np.random.shuffle(trn_data[b])
                        qlen, attn_idx, padded_queries, padded_im, padded_bbox, labels = self.build_data(trn_data[b], 
                                                                                            0, 
                                                                                            self.batch_size, 
                                                                                            addNoiseImg=addNoiseImg,
                                                                                            imScale=imScale)
                
                        feed_dict = {
                            self.qlen:qlen,
                            self.queries:padded_queries,
                            self.img:padded_im,
                            self.bboxes:padded_bbox,
                            self.attn_idx:attn_idx,
                            self.labels: labels,
                            self.unk:np.array([[vocab['<unk>']]]),
                            self.isEdit:isEdit,
                            self.reward_holder:np.array([[0.] for _ in range(self.batch_size)]), # dummy holder 
                            self.BCE_holder:np.array([[0.] for _ in range(self.batch_size)]), # dummy holder 
                            self.Aattn_vecs:[[[]]],# dummy holder 
                            self.dropout_in:dropout_in,
                            self.dropout_out:dropout_out,
                            self.dropout_img:dropout_img,
                            self.dropout_q:dropout_q,
                            self.editRandomlyProb:editRandomlyProb,
                            self.rnn_editProb:rnn_editProb,
                            self.Alr:Alr,
                            self.Blr:Blr,
                            self.isTrain:True
                        }
                        
                        
                        if isEdit:
                            editRount_count+=1

                            # We first run B with no edit in order to get it's loss, which will be given to A,
                            # and outputs, which A will use attention mechanism over them.   
                            feed_dict[self.isEdit] = False
                            queries_lens, B_ce, outputs = sess.run([self.queries_lens, self.B_ce, self.outputs], feed_dict=feed_dict)
                            feed_dict[self.isEdit] = True
                            
                            # B_ce contain the cross entrophy loss for each query.
                            # We scale all the losses to have mean 1 and std 0.5,
                            # this gives A a fixed range of (state, action) values
                            Bce_min = min(B_ce)
                            Bce_max = max(B_ce)
                            Bce_scale = (B_ce-Bce_min)/(Bce_max-Bce_min)
                            s = np.std(Bce_scale)
                            # BCE is the scaled B's losses
                            BCE = 0.5*Bce_scale/s
                            BCE = 1 + BCE - np.mean(BCE)
                          
                            # Reward for edit a word = edit_reward*BCE/queries_lens.
                            # A's get the reward for edit a word and loss per query as 2 of its features.
                            feed_dict[self.reward_holder]=np.expand_dims(edit_reward*BCE/queries_lens, 1)
                            feed_dict[self.BCE_holder]=np.expand_dims(BCE, 1)
                           
                            
                            # A's attention vectors are B's outputs 
                            # when not words were edited (for all time steps).
                            Aattn_vecs = outputs[:,:,:self.num_hidden]
                            feed_dict[self.Aattn_vecs]=Aattn_vecs
                           
                            # Next we run B with edits. Now we have everything we need to train A.
                            # Note that we din't optemize A or B yet, hence 
                            # B will losses and un-edited outputs is still relevent
                            if toTrainA:
                                Agrads, Avars, gs, scores, batch_Alr, batch_Blr, B_loss, batch_edit_ratio, A_loss, _ = sess.run(
                                    [self.Agrads, self.Avars, self.global_step, self.scores, self.A_learning_rate, self.learning_rate,
                                         self.B_loss, self.edit_ratio, self.A_loss, self.A_optimizer], feed_dict=feed_dict)
                                
                               
                            else:
                                gs, scores, batch_Blr, B_loss, batch_edit_ratio, A_loss, _ = sess.run([self.global_step, self.scores, self.learning_rate, self.B_loss, 
                                                                                                    self.edit_ratio, self.A_loss, self.B_optimizer], 
                                                                                               feed_dict=feed_dict)
                                
                            # After calculating A results we  want to see
                            # B results in this context, therefore we calulate B
                            # metrics before optimizing it.
                            # In ep=1 we'll see B loss for the unedited inputs.
                            acc = sum(np.equal(np.argmax(scores, axis=1), np.argmax(labels, axis=1))/len(labels))
                            iou_acc = self.iou_accuracy(
                                trn_data[b], 0, self.batch_size, imScale=imScale, addNoiseImg=addNoiseImg,
                                sess=sess, feed_dict=feed_dict, isEdit=isEdit, scores=scores, labels=labels)

                            trn_acc += acc/trn_nbatch
                            A_trn_loss += A_loss
                            B_trn_loss += B_loss/trn_nbatch
                            trn_iou += iou_acc/trn_nbatch
                            ephoc_edits_ratio += batch_edit_ratio
                            
                            # Optimize B separately from A to insure the correct flow
                            if toTrainB and toTrainA:
                                if ephoc<activation_ephoc:
                                    # if ephoc<activation_ephoc all actions
                                    # are chosen randomly and we don't edit words 
                                    # while B is training.
                                    isEdit = False
                                    feed_dict[self.isEdit]=isEdit
                                    
                                batch_Blr, gs, _ = sess.run(
                                    [self.learning_rate, self.global_step, self.B_optimizer], 
                                    feed_dict=feed_dict)
                            if b%50==0:
                                if toTrainA==0:
                                    batch_Alr=-1
                                print( 'Edit:', isEdit, 
                                      ';batch:%s'%(b), ';gs:%d'%(gs), ';Blr: %.3f'%(batch_Blr), 
                                      ';Alr:%.3f'%(batch_Alr), ';ERP:%.2f'%(editRandomlyProb),
                                      ';Bloss:%.3f'%(B_loss), ';Aloss:%.3f'%(A_loss), 
                                      ';edits ratio:%.3f'%(batch_edit_ratio), ';acc:%.3f'%(acc), 
                                      ';iou:%.3f'%(iou_acc), ';time:', datetime.now().replace(microsecond=0)-startTime)
                                        
                        else: # isEdit=False
                            if ep==0:
                                B_loss, lr, gs, _ = sess.run([self.B_loss, self.learning_rate, 
                                                                self.global_step, self.B_optimizer], feed_dict=feed_dict)
                            else: 
                                # just show results of B with no edits
                                B_loss, lr, gs = sess.run([self.B_loss, self.learning_rate, self.global_step], feed_dict=feed_dict)

                            acc = self.accuracy(sess=sess, feed_dict=feed_dict, isEdit=isEdit, imScale=imScale, addNoiseImg=addNoiseImg)  
                            iou_acc = self.iou_accuracy(trn_data[b], 0, self.batch_size, imScale=imScale,
                                                        sess=sess, feed_dict=feed_dict, isEdit=isEdit, addNoiseImg=addNoiseImg)

                            trn_acc += acc/trn_nbatch
                            B_trn_loss += B_loss/trn_nbatch
                            trn_iou += iou_acc/trn_nbatch

                            if b%50==0:
                                print('Edit:', isEdit, 
                                      ';batch:', b, ';gs:', gs, ';Blr: %.3f'%(lr), 
                                      ';B loss: %.3f'%(B_loss),  ';acc: %.3f'%(acc), 
                                      ';iou: %.3f'%(iou_acc),';time:', datetime.now().replace(microsecond=0)-startTime)

                    if editRount_count>0: 
                        # If we edited any words during this ephoc,
                        # if ephoc <startA we don't.
                        print('\n*B Train loss: %.3f'%(B_trn_loss), 
                              ';A Train loss: %.3f'%(A_trn_loss/editRount_count),
                              ';Edit ratio: %.3f'%(ephoc_edits_ratio/editRount_count), 
                              ';Train accuracy: %.3f'%(trn_acc),  ';IOU accuracy: %.3f'%(trn_iou), 
                              ';Time:', datetime.now().replace(microsecond=0)-startTime, '\n')
                        self.train_res.append([trn_acc, trn_iou, B_trn_loss, A_trn_loss/editRount_count])
                    else:
                        print('\n*B Train loss: %.3f'%(B_trn_loss),
                              ';Train accuracy: %.3f'%(trn_acc), 
                              ';IOU accuracy: %.3f'%(trn_iou),  
                              ';Time:', datetime.now().replace(microsecond=0)-startTime, '\n')
                        self.train_res.append([trn_acc, trn_iou, B_trn_loss, 0])
                self.saver.save(sess, params_dir + "/model.ckpt", global_step=ephoc)    
                
#                 print('GRADS:')
#                 print('#'*100)
#                 for item in Agrads.items():
#                     print(item[0])
#                     print(item[1], '\n')
#                 print('#'*100, '\n')
#                 print('VARS:')
#                 print('#'*100)
#                 for item in Avars.items():
#                     print(item[0])
#                     print(item[1], '\n')
#                 print('#'*100, '\n')


                if toTrainB==False:
                    print('VALIDATION, ephoc:',ephoc)
                    print('-'*len('VALIDATION, ephoc: %d'%(ephoc)))
                    '''
                    VALIDATION

                    If ephoc>activation_ephoc, and B's not training (toTrainB=False)
                    we run the model twice on val_data:

                    * The first time no action will be chosen randomly. 
                        We calculate Bloss (ABloss) and the average ratio of 
                        edited words per query (p). 
                    * Then, at the second run, all the actions are chosen
                        randomly with probability of p to edit a word. Again, we
                        calculate B's loss (RandBloss)

                    We then define A's gain at ephoc # ep as: AGain_ep = ABloss_ep - RandBloss_ep

                    If AGain_ep<AGain_(ep-1) we reduce A's learning rate, after maxDecreaseNum 
                    reductions we stop A training but keep training B with A's edits.
                    '''
                    ABloss = 0 # B loss when none of the actions are chosen randomly
                    RandBloss = 0 # B loss when all actions are chosen randomly
                    for ep in range(2):
                        startTime = datetime.now().replace(microsecond=0)
                        
                        if ep==0:
                            # If ep==0, none of the actions will be chosen randomly
                            editRandomlyProb=0
                            val_rnn_editProb = rnn_editProb
                        else:
                            # If ep==1, all actions will be chosen randomly
                            editRandomlyProb=1
                            val_rnn_editProb = ephoc_edits_ratio
                            
                        Aval_loss, Bval_loss, val_acc, val_iou, ephoc_edits_ratio = 0, 0, 0, 0, 0
                        print('\nRandom choice:', ep==1)
                        for b in range(val_nbatch):
                            qlen, attn_idx, padded_queries, padded_im, padded_bbox, labels = self.build_data(val_data[b],
                                                                                        0, self.batch_size, imScale=imScale, addNoiseImg=False)
                            feed_dict = {
                                        self.qlen:qlen,
                                        self.queries:padded_queries,
                                        self.img:padded_im,
                                        self.bboxes:padded_bbox,
                                        self.attn_idx:attn_idx,
                                        self.labels: labels,
                                        self.unk:np.array([[vocab['<unk>']]]),
                                        self.isEdit:True,
                                        self.reward_holder:np.array([[0.] for _ in range(self.batch_size)]), # dummy holder 
                                        self.BCE_holder:np.array([[0.] for _ in range(self.batch_size)]), # dummy holder 
                                        self.Aattn_vecs:[[[]]],# dummy holder 
                                        self.dropout_in:1.,
                                        self.dropout_out:1.,
                                        self.dropout_img:1.,
                                        self.dropout_q:1.,
                                        self.editRandomlyProb:editRandomlyProb,
                                        self.rnn_editProb:val_rnn_editProb,
                                        self.Alr:Alr,
                                        self.Blr:Blr,
                                        self.isTrain:False
                                    }

                            feed_dict[self.isEdit] = False
                            queries_lens, B_ce, outputs = sess.run([self.queries_lens, self.B_ce, self.outputs], feed_dict=feed_dict)
                            feed_dict[self.isEdit] = True

                            Bce_min = min(B_ce)
                            Bce_max = max(B_ce)
                            Bce_scale = (B_ce-Bce_min)/(Bce_max-Bce_min)
                            s = np.std(Bce_scale)
                            BCE = 0.5*Bce_scale/s
                            BCE = 1 + BCE - np.mean(BCE)

                            feed_dict[self.reward_holder]=np.expand_dims(edit_reward*BCE/queries_lens, 1)
                            feed_dict[self.BCE_holder]=np.expand_dims(BCE, 1)

                            Aattn_vecs = outputs[:,:,:self.num_hidden]
                            feed_dict[self.Aattn_vecs]=Aattn_vecs

                            scores, B_loss, A_loss, batch_edit_ratio = sess.run(
                                [self.scores, self.B_loss, self.A_loss, self.edit_ratio], feed_dict=feed_dict)
                            acc = sum(np.equal(np.argmax(scores, axis=1), np.argmax(labels, axis=1))/len(labels))
                            iou_acc = self.iou_accuracy(
                                val_data[b], 0, self.batch_size, sess=sess, 
                                feed_dict=feed_dict, isEdit=True, imScale=imScale, labels=labels, scores=scores)

                            val_acc += acc/val_nbatch
                            Bval_loss += B_loss/val_nbatch
                            Aval_loss += A_loss/val_nbatch
                            val_iou += iou_acc/val_nbatch
                            ephoc_edits_ratio += batch_edit_ratio/val_nbatch

                            if b%50==0:
                                print('batch:', b, ';edits ratio: %.3f'%(batch_edit_ratio), 
                                      ';B loss: %.3f'%(B_loss), ';A loss: %.3f'%(A_loss), ';acc: %.3f'%(acc), 
                                      ';iou_acc: %.3f'%(iou_acc), ';time:', datetime.now().replace(microsecond=0)-startTime)

                        print('\n*B loss: %.3f'%(Bval_loss), ';A loss: %.3f'%(Aval_loss), ';Edit ratio: %.3f'%(ephoc_edits_ratio),  
                              ';Accuracy %.3f'%(val_acc), ';IOU accuracy: %.3f'%(val_iou), ';Time:', datetime.now().replace(microsecond=0)-startTime)
                        
                        if ep==0:
                            self.val_res.append([[val_acc, val_iou, Bval_loss, Aval_loss]])
                            self.AGain.append(Bval_loss)
                        else:
                            self.val_res[-1].append([val_acc, val_iou, Bval_loss, Aval_loss])
                            self.AGain[-1] = self.AGain[-1]-Bval_loss

#                     if toTrainA and  len(self.AGain)>3 and self.AGain[-1]<min(self.AGain[-4:-1]):
#                         Alr=Alr*0.8
#                         AlrDecreaseNum+=1
#                         toTrainA = AlrDecreaseNum<=maxDecreaseNum
                        
                    print('\n*AlrDecreaseNum: %d'%(AlrDecreaseNum), '; maxDecreaseNum: %d'%(maxDecreaseNum), 
                          ';AGain: %.3f'%(self.AGain[-1]), ';toTrainA: %s'%(toTrainA))
                    print('-'*len('*AlrDecreaseNum: %d ; maxDecreaseNum: %d ;AGain: %.3f ;toTrainA: %s'%(AlrDecreaseNum, maxDecreaseNum, self.AGain[-1], toTrainA)), '\n')
                    
                
                
                
                '''
                TESTING
                '''
                if toTrainB:
                    print('TESTING, ephoc:',ephoc)
                    tstTime = datetime.now().replace(microsecond=0)
                    tst_loss, tst_acc, tst_iou = 0, 0, 0
                    t_data = tst_data+val_data
                    t_nbatch = len(t_data)
                    print('# t_data size:', sum([len(batch) for batch in t_data]))
                    print('# t_data batches:', t_nbatch)
                    
                    for b in range(t_nbatch):
                        qlen, attn_idx, padded_queries, padded_im, padded_bbox, labels = self.build_data(t_data[b],
                                                                                    0, self.batch_size, imScale=imScale, addNoiseImg=False)
                        
                        feed_dict={
                                    self.qlen:qlen,
                                    self.queries:padded_queries,
                                    self.img:padded_im,
                                    self.bboxes:padded_bbox,
                                    self.attn_idx:attn_idx,
                                    self.labels: labels,
                                    self.unk:np.array([[vocab['<unk>']]]),
                                    self.isEdit:False,
                                    self.reward_holder:np.array([[0.] for _ in range(self.batch_size)]),# dummy holder 
                                    self.BCE_holder:np.array([[0.] for _ in range(self.batch_size)]),# dummy holder 
                                    self.Aattn_vecs:[[[]]],# dummy holder 
                                    self.dropout_in:1.,
                                    self.dropout_out:1.,
                                    self.dropout_img:1.,
                                    self.dropout_q:1.,
                                    self.editRandomlyProb:0.,
                                    self.rnn_editProb:0.,
                                    self.Alr:Alr,
                                    self.Blr:Blr,
                                    self.isTrain:False
                                }
                       
                        scores, B_loss = sess.run([self.scores, self.B_loss], feed_dict=feed_dict)
                        acc = sum(np.equal(np.argmax(scores, axis=1), np.argmax(labels, axis=1))/len(labels))

                        iou_acc = self.iou_accuracy(
                            t_data[b], 0, self.batch_size, sess=sess, 
                            feed_dict=feed_dict, isEdit=False, imScale=imScale)
                        
                        tst_acc += acc/t_nbatch
                        tst_loss += B_loss/t_nbatch
                        tst_iou += iou_acc/t_nbatch
                        if b%50==0:
                            print('batch:', b, ';B loss: %.3f'%(B_loss), ';acc: %.3f'%(acc), 
                                   ';iou_acc: %.3f'%(iou_acc), ';time:', datetime.now().replace(microsecond=0)-startTime)
                            
                    print('\n*Test loss: %.3f'%(tst_loss), ';Test accuracy %.3f'%(tst_acc), 
                          ';IOU accuracy: %.3f'%(tst_iou), ';Time:', datetime.now().replace(microsecond=0)-startTime)
                    self.test_res.append([tst_acc, tst_iou, tst_loss])
#                     if len(self.test_res)>10 and self.test_res[-1][-1]>max([item[-1] for item in self.test_res[-6:-1]]):
#                         Blr=Blr*0.9
                    
                print('='*50,'\n')
            return self.test_res, self.train_res, self.val_res, self.AGain

# %% [markdown]
# # We start by runnging the Grounder in its simplest form
# <p> We test the model with different state sizes: 50, 100, 150 and 200. We run each test for 100 ephocs</p>
# <p> We get about 60% IOU in all the test, about the same as the baseline.<br> On the other hand, the train set IOU gets bigger as the hidden state gets bigger, starting from about 89%, for 50 hidden units, to about 97% with 200.

# %%
num_hidden=200
edit_rewards = [-1., -.9, -.8, -0.7, -0.6]
edit_rewards_tst, edit_rewards_trn, edit_rewards_val, edit_rewards_AGain = [], [], [], []

for edit_reward in edit_rewards:
    params_dir = params_dir_tmp+'RL/edit_rewards_'+str(-1*edit_reward)+'hidden_'+str(num_hidden)
    tf.reset_default_graph()
    m = Model(
        batch_size=200, 
        num_hidden=num_hidden,
        embed_size=embed_vecs.shape[1],
        img_dims=trainset[0][0][1][0].shape[1], 
        bbox_dims=trainset[0][0][1][1].shape[1], 
        vocab=vocab, 
        decay_steps=10000, 
        decay_rate=0.9, 
        bnorm=False,
        toQscale=True
    )

    print('params_dir:', params_dir)
    print('num_hidden:', m.num_hidden)
    print('edit_reward:', edit_reward)
    act_rewards, BCE, bell_val, idx = m.train(trainset, testset, valset,
                                    ephocs_num=200,
                                    start_ephoc=51,
                                    startA=8,
                                    activation_ephoc=12,
                                    muteBnum=3, 
                                    queries_editProb=0.95,
                                    edit_reward=edit_reward,
                                    rnn_editProb=0.2,
                                    Blr=.5,
                                    Alr=.1,
                                    imScale=1/50)
    edit_rewards_tst.append(tst) 
    edit_rewards_trn.append(trn)
    edit_rewards_val.append(val) 
    edit_rewards_AGain.append(AGain)

    print('\n'+'*'*100)
    print('*'*100)
    print('*'*100,'\n')
# Out:
# params_dir: ../data/training/models/All/RL/edit_rewards_1.0hidden_200
# num_hidden: 200
# edit_reward: -1.0
# # Train set size: 59400
# # Training batches: 297
# # Validation set size: 29800
# # Validation batches: 149
# # Test set size: 29600
# # Testing batches: 148
# Loading parameters from ../data/training/models/All/RL/edit_rewards_1.0hidden_200/model.ckpt-51
# INFO:tensorflow:Restoring parameters from ../data/training/models/All/RL/edit_rewards_1.0hidden_200/model.ckpt-51
# ==================================================
# TRAIN, ephoc:51; Training B:True; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:5644 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.028 ;Aloss:0.329 ;edits ratio:0.227 ;acc:0.495 ;iou:0.640 ;time: 0:00:01
# Edit: True ;batch:50 ;gs:5694 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.669 ;Aloss:0.378 ;edits ratio:0.239 ;acc:0.590 ;iou:0.670 ;time: 0:00:16
# Edit: True ;batch:100 ;gs:5744 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.567 ;Aloss:0.437 ;edits ratio:0.184 ;acc:0.715 ;iou:0.785 ;time: 0:00:32
# Edit: True ;batch:150 ;gs:5794 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.771 ;Aloss:0.470 ;edits ratio:0.233 ;acc:0.550 ;iou:0.665 ;time: 0:00:46
# Edit: True ;batch:200 ;gs:5844 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.635 ;Aloss:0.339 ;edits ratio:0.287 ;acc:0.300 ;iou:0.520 ;time: 0:01:02
# Edit: True ;batch:250 ;gs:5894 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.341 ;Aloss:0.348 ;edits ratio:0.322 ;acc:0.370 ;iou:0.480 ;time: 0:01:17
#
# *B Train loss: 2.068 ;A Train loss: 0.342 ;Edit ratio: 0.223 ;Train accuracy: 0.517 ;IOU accuracy: 0.625 ;Time: 0:01:31
#
# No Edit
# ooooooo
# Edit: False ;batch: 0 ;gs: 5940 ;Blr: 0.500 ;B loss: 1.880 ;acc: 0.545 ;iou: 0.670 ;time: 0:01:31
# Edit: False ;batch: 50 ;gs: 5940 ;Blr: 0.500 ;B loss: 1.276 ;acc: 0.760 ;iou: 0.830 ;time: 0:01:38
# Edit: False ;batch: 100 ;gs: 5940 ;Blr: 0.500 ;B loss: 1.267 ;acc: 0.880 ;iou: 0.930 ;time: 0:01:45
# Edit: False ;batch: 150 ;gs: 5940 ;Blr: 0.500 ;B loss: 1.411 ;acc: 0.700 ;iou: 0.795 ;time: 0:01:52
# Edit: False ;batch: 200 ;gs: 5940 ;Blr: 0.500 ;B loss: 2.373 ;acc: 0.480 ;iou: 0.655 ;time: 0:02:00
# Edit: False ;batch: 250 ;gs: 5940 ;Blr: 0.500 ;B loss: 1.954 ;acc: 0.595 ;iou: 0.685 ;time: 0:02:07
#
# *B Train loss: 1.698 ;Train accuracy: 0.681 ;IOU accuracy: 0.778 ;Time: 0:02:13
#
# TESTING, ephoc: 51
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.310 ;acc: 0.840 ;iou_acc: 0.880 ;time: 0:02:15
# batch: 50 ;B loss: 1.944 ;acc: 0.610 ;iou_acc: 0.700 ;time: 0:02:21
# batch: 100 ;B loss: 1.870 ;acc: 0.585 ;iou_acc: 0.700 ;time: 0:02:27
# batch: 150 ;B loss: 1.312 ;acc: 0.835 ;iou_acc: 0.860 ;time: 0:02:34
# batch: 200 ;B loss: 2.282 ;acc: 0.460 ;iou_acc: 0.620 ;time: 0:02:40
# batch: 250 ;B loss: 1.258 ;acc: 0.835 ;iou_acc: 0.885 ;time: 0:02:46
#
# *Test loss: 1.742 ;Test accuracy 0.663 ;IOU accuracy: 0.760 ;Time: 0:02:52
# ==================================================
#
# ==================================================
# TRAIN, ephoc:52; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:5940 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.776 ;Aloss:0.366 ;edits ratio:0.200 ;acc:0.615 ;iou:0.685 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:5940 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.857 ;Aloss:0.291 ;edits ratio:0.208 ;acc:0.300 ;iou:0.480 ;time: 0:00:11
# Edit: True ;batch:100 ;gs:5940 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.599 ;Aloss:0.402 ;edits ratio:0.237 ;acc:0.725 ;iou:0.760 ;time: 0:00:23
# Edit: True ;batch:150 ;gs:5940 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.245 ;Aloss:0.414 ;edits ratio:0.375 ;acc:0.390 ;iou:0.460 ;time: 0:00:34
# Edit: True ;batch:200 ;gs:5940 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.986 ;Aloss:0.424 ;edits ratio:0.302 ;acc:0.205 ;iou:0.405 ;time: 0:00:45
# Edit: True ;batch:250 ;gs:5940 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.580 ;Aloss:0.360 ;edits ratio:0.246 ;acc:0.720 ;iou:0.760 ;time: 0:00:57
#
# *B Train loss: 2.072 ;A Train loss: 0.391 ;Edit ratio: 0.283 ;Train accuracy: 0.505 ;IOU accuracy: 0.609 ;Time: 0:01:07
#
# VALIDATION, ephoc: 52
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.252 ;B loss: 1.972 ;A loss: 0.360 ;acc: 0.500 ;iou_acc: 0.610 ;time: 0:00:01
# batch: 50 ;edits ratio: 0.305 ;B loss: 3.182 ;A loss: 0.425 ;acc: 0.205 ;iou_acc: 0.340 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.286 ;B loss: 2.145 ;A loss: 0.333 ;acc: 0.420 ;iou_acc: 0.535 ;time: 0:00:15
#
# *B loss: 2.046 ;A loss: 0.385 ;Edit ratio: 0.280 ;Accuracy 0.511 ;IOU accuracy: 0.609 ;Time: 0:00:22
#
# Random choice: True
# batch: 0 ;edits ratio: 0.287 ;B loss: 1.855 ;A loss: 0.659 ;acc: 0.525 ;iou_acc: 0.630 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.267 ;B loss: 3.094 ;A loss: 0.574 ;acc: 0.280 ;iou_acc: 0.375 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.320 ;B loss: 1.978 ;A loss: 0.657 ;acc: 0.515 ;iou_acc: 0.625 ;time: 0:00:15
#
# *B loss: 1.900 ;A loss: 0.651 ;Edit ratio: 0.282 ;Accuracy 0.557 ;IOU accuracy: 0.652 ;Time: 0:00:22
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.147 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:53; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:5940 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.582 ;Aloss:0.325 ;edits ratio:0.246 ;acc:0.665 ;iou:0.740 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:5940 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.297 ;Aloss:0.510 ;edits ratio:0.373 ;acc:0.370 ;iou:0.500 ;time: 0:00:11
# Edit: True ;batch:100 ;gs:5940 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.448 ;Aloss:0.415 ;edits ratio:0.335 ;acc:0.365 ;iou:0.495 ;time: 0:00:23
# Edit: True ;batch:150 ;gs:5940 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.064 ;Aloss:0.425 ;edits ratio:0.312 ;acc:0.485 ;iou:0.585 ;time: 0:00:35
# Edit: True ;batch:200 ;gs:5940 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.753 ;Aloss:0.356 ;edits ratio:0.264 ;acc:0.580 ;iou:0.675 ;time: 0:00:46
# Edit: True ;batch:250 ;gs:5940 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:3.059 ;Aloss:0.424 ;edits ratio:0.393 ;acc:0.170 ;iou:0.330 ;time: 0:00:57
#
# *B Train loss: 2.075 ;A Train loss: 0.389 ;Edit ratio: 0.280 ;Train accuracy: 0.504 ;IOU accuracy: 0.607 ;Time: 0:01:07
#
# VALIDATION, ephoc: 53
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.192 ;B loss: 1.926 ;A loss: 0.299 ;acc: 0.530 ;iou_acc: 0.630 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.236 ;B loss: 3.050 ;A loss: 0.379 ;acc: 0.245 ;iou_acc: 0.420 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.220 ;B loss: 2.059 ;A loss: 0.299 ;acc: 0.470 ;iou_acc: 0.590 ;time: 0:00:14
#
# *B loss: 1.987 ;A loss: 0.351 ;Edit ratio: 0.218 ;Accuracy 0.548 ;IOU accuracy: 0.645 ;Time: 0:00:21
#
# Random choice: True
# batch: 0 ;edits ratio: 0.213 ;B loss: 1.826 ;A loss: 0.628 ;acc: 0.570 ;iou_acc: 0.665 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.221 ;B loss: 2.955 ;A loss: 0.542 ;acc: 0.340 ;iou_acc: 0.460 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.208 ;B loss: 1.900 ;A loss: 0.581 ;acc: 0.520 ;iou_acc: 0.620 ;time: 0:00:15
#
# *B loss: 1.848 ;A loss: 0.624 ;Edit ratio: 0.218 ;Accuracy 0.584 ;IOU accuracy: 0.680 ;Time: 0:00:22
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.139 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:54; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:5940 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.988 ;Aloss:0.367 ;edits ratio:0.252 ;acc:0.515 ;iou:0.605 ;time: 0:00:01
# Edit: True ;batch:50 ;gs:5940 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.364 ;Aloss:0.363 ;edits ratio:0.283 ;acc:0.420 ;iou:0.565 ;time: 0:00:12
# Edit: True ;batch:100 ;gs:5940 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:3.397 ;Aloss:0.441 ;edits ratio:0.376 ;acc:0.130 ;iou:0.285 ;time: 0:00:23
# Edit: True ;batch:150 ;gs:5940 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.003 ;Aloss:0.328 ;edits ratio:0.288 ;acc:0.505 ;iou:0.595 ;time: 0:00:35
# Edit: True ;batch:200 ;gs:5940 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.251 ;Aloss:0.431 ;edits ratio:0.378 ;acc:0.365 ;iou:0.505 ;time: 0:00:45
# Edit: True ;batch:250 ;gs:5940 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:3.117 ;Aloss:0.400 ;edits ratio:0.310 ;acc:0.210 ;iou:0.335 ;time: 0:00:56
#
# *B Train loss: 2.065 ;A Train loss: 0.384 ;Edit ratio: 0.272 ;Train accuracy: 0.510 ;IOU accuracy: 0.613 ;Time: 0:01:07
#
# VALIDATION, ephoc: 54
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.280 ;B loss: 1.986 ;A loss: 0.370 ;acc: 0.475 ;iou_acc: 0.600 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.318 ;B loss: 3.212 ;A loss: 0.420 ;acc: 0.195 ;iou_acc: 0.330 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.307 ;B loss: 2.159 ;A loss: 0.336 ;acc: 0.415 ;iou_acc: 0.530 ;time: 0:00:14
#
# *B loss: 2.055 ;A loss: 0.387 ;Edit ratio: 0.290 ;Accuracy 0.504 ;IOU accuracy: 0.603 ;Time: 0:00:21
#
# Random choice: True
# batch: 0 ;edits ratio: 0.327 ;B loss: 1.918 ;A loss: 0.680 ;acc: 0.535 ;iou_acc: 0.640 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.292 ;B loss: 3.050 ;A loss: 0.560 ;acc: 0.275 ;iou_acc: 0.385 ;time: 0:00:06
# batch: 100 ;edits ratio: 0.306 ;B loss: 2.035 ;A loss: 0.652 ;acc: 0.480 ;iou_acc: 0.595 ;time: 0:00:13
#
# *B loss: 1.907 ;A loss: 0.667 ;Edit ratio: 0.292 ;Accuracy 0.551 ;IOU accuracy: 0.648 ;Time: 0:00:21
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.148 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:55; Training B:True; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:5941 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.035 ;Aloss:0.452 ;edits ratio:0.325 ;acc:0.465 ;iou:0.550 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:5991 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.397 ;Aloss:0.506 ;edits ratio:0.236 ;acc:0.780 ;iou:0.830 ;time: 0:00:15
# Edit: True ;batch:100 ;gs:6041 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.736 ;Aloss:0.393 ;edits ratio:0.253 ;acc:0.610 ;iou:0.720 ;time: 0:00:31
# Edit: True ;batch:150 ;gs:6091 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.443 ;Aloss:0.334 ;edits ratio:0.289 ;acc:0.355 ;iou:0.515 ;time: 0:00:48
# Edit: True ;batch:200 ;gs:6141 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.107 ;Aloss:0.475 ;edits ratio:0.398 ;acc:0.490 ;iou:0.600 ;time: 0:01:03
# Edit: True ;batch:250 ;gs:6191 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.345 ;Aloss:0.370 ;edits ratio:0.261 ;acc:0.350 ;iou:0.500 ;time: 0:01:19
#
# *B Train loss: 2.033 ;A Train loss: 0.384 ;Edit ratio: 0.273 ;Train accuracy: 0.539 ;IOU accuracy: 0.643 ;Time: 0:01:33
#
# No Edit
# ooooooo
# Edit: False ;batch: 0 ;gs: 6237 ;Blr: 0.500 ;B loss: 1.537 ;acc: 0.730 ;iou: 0.810 ;time: 0:01:33
# Edit: False ;batch: 50 ;gs: 6237 ;Blr: 0.500 ;B loss: 1.150 ;acc: 0.880 ;iou: 0.925 ;time: 0:01:40
# Edit: False ;batch: 100 ;gs: 6237 ;Blr: 0.500 ;B loss: 1.378 ;acc: 0.780 ;iou: 0.855 ;time: 0:01:47
# Edit: False ;batch: 150 ;gs: 6237 ;Blr: 0.500 ;B loss: 2.070 ;acc: 0.590 ;iou: 0.745 ;time: 0:01:54
# Edit: False ;batch: 200 ;gs: 6237 ;Blr: 0.500 ;B loss: 1.580 ;acc: 0.740 ;iou: 0.845 ;time: 0:02:00
# Edit: False ;batch: 250 ;gs: 6237 ;Blr: 0.500 ;B loss: 2.005 ;acc: 0.575 ;iou: 0.685 ;time: 0:02:07
#
# *B Train loss: 1.659 ;Train accuracy: 0.721 ;IOU accuracy: 0.813 ;Time: 0:02:13
#
# TESTING, ephoc: 55
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.307 ;acc: 0.845 ;iou_acc: 0.890 ;time: 0:02:14
# batch: 50 ;B loss: 1.929 ;acc: 0.625 ;iou_acc: 0.720 ;time: 0:02:20
# batch: 100 ;B loss: 1.876 ;acc: 0.590 ;iou_acc: 0.710 ;time: 0:02:27
# batch: 150 ;B loss: 1.300 ;acc: 0.855 ;iou_acc: 0.880 ;time: 0:02:34
# batch: 200 ;B loss: 2.249 ;acc: 0.495 ;iou_acc: 0.650 ;time: 0:02:40
# batch: 250 ;B loss: 1.271 ;acc: 0.870 ;iou_acc: 0.915 ;time: 0:02:45
#
# *Test loss: 1.715 ;Test accuracy 0.691 ;IOU accuracy: 0.788 ;Time: 0:02:51
# ==================================================
#
# ==================================================
# TRAIN, ephoc:56; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:6237 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.580 ;Aloss:0.530 ;edits ratio:0.255 ;acc:0.705 ;iou:0.775 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:6237 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.330 ;Aloss:0.425 ;edits ratio:0.372 ;acc:0.370 ;iou:0.475 ;time: 0:00:12
# Edit: True ;batch:100 ;gs:6237 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.833 ;Aloss:0.322 ;edits ratio:0.220 ;acc:0.610 ;iou:0.700 ;time: 0:00:23
# Edit: True ;batch:150 ;gs:6237 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.746 ;Aloss:0.296 ;edits ratio:0.213 ;acc:0.580 ;iou:0.635 ;time: 0:00:33
# Edit: True ;batch:200 ;gs:6237 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.896 ;Aloss:0.323 ;edits ratio:0.163 ;acc:0.605 ;iou:0.690 ;time: 0:00:44
# Edit: True ;batch:250 ;gs:6237 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.867 ;Aloss:0.353 ;edits ratio:0.262 ;acc:0.565 ;iou:0.665 ;time: 0:00:55
#
# *B Train loss: 2.004 ;A Train loss: 0.409 ;Edit ratio: 0.286 ;Train accuracy: 0.546 ;IOU accuracy: 0.648 ;Time: 0:01:06
#
# VALIDATION, ephoc: 56
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.150 ;B loss: 1.798 ;A loss: 0.254 ;acc: 0.660 ;iou_acc: 0.740 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.235 ;B loss: 2.966 ;A loss: 0.370 ;acc: 0.245 ;iou_acc: 0.440 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.187 ;B loss: 1.954 ;A loss: 0.260 ;acc: 0.525 ;iou_acc: 0.630 ;time: 0:00:14
#
# *B loss: 1.917 ;A loss: 0.360 ;Edit ratio: 0.206 ;Accuracy 0.590 ;IOU accuracy: 0.685 ;Time: 0:00:21
#
# Random choice: True
# batch: 0 ;edits ratio: 0.183 ;B loss: 1.777 ;A loss: 0.547 ;acc: 0.665 ;iou_acc: 0.730 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.178 ;B loss: 2.900 ;A loss: 0.571 ;acc: 0.360 ;iou_acc: 0.510 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.188 ;B loss: 1.788 ;A loss: 0.673 ;acc: 0.610 ;iou_acc: 0.700 ;time: 0:00:13
#
# *B loss: 1.815 ;A loss: 0.612 ;Edit ratio: 0.206 ;Accuracy 0.614 ;IOU accuracy: 0.710 ;Time: 0:00:21
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.103 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:57; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:6237 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.818 ;Aloss:0.324 ;edits ratio:0.195 ;acc:0.605 ;iou:0.710 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:6237 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.836 ;Aloss:0.507 ;edits ratio:0.370 ;acc:0.760 ;iou:0.835 ;time: 0:00:10
# Edit: True ;batch:100 ;gs:6237 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.883 ;Aloss:0.319 ;edits ratio:0.242 ;acc:0.330 ;iou:0.455 ;time: 0:00:22
# Edit: True ;batch:150 ;gs:6237 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.845 ;Aloss:0.492 ;edits ratio:0.316 ;acc:0.765 ;iou:0.860 ;time: 0:00:33
# Edit: True ;batch:200 ;gs:6237 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.518 ;Aloss:0.428 ;edits ratio:0.266 ;acc:0.755 ;iou:0.800 ;time: 0:00:45
# Edit: True ;batch:250 ;gs:6237 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.625 ;Aloss:0.374 ;edits ratio:0.267 ;acc:0.625 ;iou:0.710 ;time: 0:00:56
#
# *B Train loss: 1.997 ;A Train loss: 0.404 ;Edit ratio: 0.275 ;Train accuracy: 0.551 ;IOU accuracy: 0.652 ;Time: 0:01:07
#
# VALIDATION, ephoc: 57
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.242 ;B loss: 1.882 ;A loss: 0.386 ;acc: 0.615 ;iou_acc: 0.690 ;time: 0:00:01
# batch: 50 ;edits ratio: 0.292 ;B loss: 3.047 ;A loss: 0.401 ;acc: 0.195 ;iou_acc: 0.390 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.302 ;B loss: 2.077 ;A loss: 0.331 ;acc: 0.460 ;iou_acc: 0.555 ;time: 0:00:14
#
# *B loss: 1.981 ;A loss: 0.394 ;Edit ratio: 0.269 ;Accuracy 0.548 ;IOU accuracy: 0.648 ;Time: 0:00:22
#
# Random choice: True
# batch: 0 ;edits ratio: 0.290 ;B loss: 1.868 ;A loss: 0.721 ;acc: 0.580 ;iou_acc: 0.665 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.274 ;B loss: 2.965 ;A loss: 0.641 ;acc: 0.335 ;iou_acc: 0.475 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.275 ;B loss: 1.865 ;A loss: 0.710 ;acc: 0.555 ;iou_acc: 0.655 ;time: 0:00:14
#
# *B loss: 1.863 ;A loss: 0.658 ;Edit ratio: 0.267 ;Accuracy 0.584 ;IOU accuracy: 0.681 ;Time: 0:00:21
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.119 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:58; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:6237 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.696 ;Aloss:0.382 ;edits ratio:0.236 ;acc:0.650 ;iou:0.760 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:6237 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.870 ;Aloss:0.407 ;edits ratio:0.262 ;acc:0.580 ;iou:0.685 ;time: 0:00:11
# Edit: True ;batch:100 ;gs:6237 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.651 ;Aloss:0.389 ;edits ratio:0.241 ;acc:0.680 ;iou:0.740 ;time: 0:00:22
# Edit: True ;batch:150 ;gs:6237 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.912 ;Aloss:0.387 ;edits ratio:0.265 ;acc:0.250 ;iou:0.425 ;time: 0:00:34
# Edit: True ;batch:200 ;gs:6237 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.434 ;Aloss:0.411 ;edits ratio:0.355 ;acc:0.375 ;iou:0.520 ;time: 0:00:45
# Edit: True ;batch:250 ;gs:6237 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.536 ;Aloss:0.360 ;edits ratio:0.284 ;acc:0.330 ;iou:0.495 ;time: 0:00:57
#
# *B Train loss: 2.000 ;A Train loss: 0.403 ;Edit ratio: 0.274 ;Train accuracy: 0.550 ;IOU accuracy: 0.651 ;Time: 0:01:07
#
# VALIDATION, ephoc: 58
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.264 ;B loss: 1.926 ;A loss: 0.433 ;acc: 0.590 ;iou_acc: 0.665 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.315 ;B loss: 3.098 ;A loss: 0.417 ;acc: 0.180 ;iou_acc: 0.365 ;time: 0:00:06
# batch: 100 ;edits ratio: 0.319 ;B loss: 2.081 ;A loss: 0.358 ;acc: 0.450 ;iou_acc: 0.555 ;time: 0:00:14
#
# *B loss: 2.002 ;A loss: 0.413 ;Edit ratio: 0.288 ;Accuracy 0.534 ;IOU accuracy: 0.635 ;Time: 0:00:21
#
# Random choice: True
# batch: 0 ;edits ratio: 0.288 ;B loss: 1.829 ;A loss: 0.621 ;acc: 0.600 ;iou_acc: 0.670 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.267 ;B loss: 2.967 ;A loss: 0.636 ;acc: 0.300 ;iou_acc: 0.455 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.283 ;B loss: 1.918 ;A loss: 0.656 ;acc: 0.515 ;iou_acc: 0.615 ;time: 0:00:14
#
# *B loss: 1.875 ;A loss: 0.656 ;Edit ratio: 0.288 ;Accuracy 0.573 ;IOU accuracy: 0.673 ;Time: 0:00:22
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.127 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:59; Training B:True; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:6238 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.906 ;Aloss:0.476 ;edits ratio:0.292 ;acc:0.770 ;iou:0.865 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:6288 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.722 ;Aloss:0.404 ;edits ratio:0.338 ;acc:0.615 ;iou:0.710 ;time: 0:00:15
# Edit: True ;batch:100 ;gs:6338 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.799 ;Aloss:0.347 ;edits ratio:0.301 ;acc:0.620 ;iou:0.665 ;time: 0:00:29
# Edit: True ;batch:150 ;gs:6388 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.758 ;Aloss:0.564 ;edits ratio:0.321 ;acc:0.725 ;iou:0.785 ;time: 0:00:44
# Edit: True ;batch:200 ;gs:6438 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.623 ;Aloss:0.480 ;edits ratio:0.284 ;acc:0.700 ;iou:0.735 ;time: 0:01:00
# Edit: True ;batch:250 ;gs:6488 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.257 ;Aloss:0.335 ;edits ratio:0.281 ;acc:0.415 ;iou:0.560 ;time: 0:01:15
#
# *B Train loss: 2.018 ;A Train loss: 0.401 ;Edit ratio: 0.293 ;Train accuracy: 0.546 ;IOU accuracy: 0.650 ;Time: 0:01:29
#
# No Edit
# ooooooo
# Edit: False ;batch: 0 ;gs: 6534 ;Blr: 0.500 ;B loss: 1.953 ;acc: 0.890 ;iou: 0.935 ;time: 0:01:29
# Edit: False ;batch: 50 ;gs: 6534 ;Blr: 0.500 ;B loss: 1.228 ;acc: 0.815 ;iou: 0.880 ;time: 0:01:36
# Edit: False ;batch: 100 ;gs: 6534 ;Blr: 0.500 ;B loss: 1.290 ;acc: 0.790 ;iou: 0.830 ;time: 0:01:43
# Edit: False ;batch: 150 ;gs: 6534 ;Blr: 0.500 ;B loss: 1.258 ;acc: 0.905 ;iou: 0.940 ;time: 0:01:50
# Edit: False ;batch: 200 ;gs: 6534 ;Blr: 0.500 ;B loss: 1.202 ;acc: 0.915 ;iou: 0.935 ;time: 0:01:58
# Edit: False ;batch: 250 ;gs: 6534 ;Blr: 0.500 ;B loss: 1.839 ;acc: 0.630 ;iou: 0.760 ;time: 0:02:05
#
# *B Train loss: 1.585 ;Train accuracy: 0.732 ;IOU accuracy: 0.822 ;Time: 0:02:11
#
# TESTING, ephoc: 59
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.294 ;acc: 0.865 ;iou_acc: 0.905 ;time: 0:02:12
# batch: 50 ;B loss: 1.797 ;acc: 0.615 ;iou_acc: 0.735 ;time: 0:02:18
# batch: 100 ;B loss: 1.780 ;acc: 0.625 ;iou_acc: 0.730 ;time: 0:02:25
# batch: 150 ;B loss: 1.322 ;acc: 0.875 ;iou_acc: 0.900 ;time: 0:02:32
# batch: 200 ;B loss: 2.155 ;acc: 0.565 ;iou_acc: 0.690 ;time: 0:02:38
# batch: 250 ;B loss: 1.279 ;acc: 0.830 ;iou_acc: 0.880 ;time: 0:02:43
#
# *Test loss: 1.658 ;Test accuracy 0.698 ;IOU accuracy: 0.794 ;Time: 0:02:49
# ==================================================
#
# ==================================================
# TRAIN, ephoc:60; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:6534 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.349 ;Aloss:0.455 ;edits ratio:0.371 ;acc:0.410 ;iou:0.535 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:6534 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.994 ;Aloss:0.375 ;edits ratio:0.342 ;acc:0.545 ;iou:0.615 ;time: 0:00:12
# Edit: True ;batch:100 ;gs:6534 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.880 ;Aloss:0.479 ;edits ratio:0.345 ;acc:0.190 ;iou:0.420 ;time: 0:00:22
# Edit: True ;batch:150 ;gs:6534 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.096 ;Aloss:0.479 ;edits ratio:0.414 ;acc:0.450 ;iou:0.570 ;time: 0:00:33
# Edit: True ;batch:200 ;gs:6534 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.952 ;Aloss:0.473 ;edits ratio:0.336 ;acc:0.480 ;iou:0.595 ;time: 0:00:44
# Edit: True ;batch:250 ;gs:6534 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.850 ;Aloss:0.240 ;edits ratio:0.153 ;acc:0.585 ;iou:0.685 ;time: 0:00:56
#
# *B Train loss: 2.062 ;A Train loss: 0.434 ;Edit ratio: 0.346 ;Train accuracy: 0.522 ;IOU accuracy: 0.625 ;Time: 0:01:05
#
# VALIDATION, ephoc: 60
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.311 ;B loss: 1.970 ;A loss: 0.392 ;acc: 0.570 ;iou_acc: 0.655 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.302 ;B loss: 3.045 ;A loss: 0.387 ;acc: 0.215 ;iou_acc: 0.430 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.345 ;B loss: 2.170 ;A loss: 0.354 ;acc: 0.465 ;iou_acc: 0.555 ;time: 0:00:14
#
# *B loss: 2.058 ;A loss: 0.416 ;Edit ratio: 0.337 ;Accuracy 0.518 ;IOU accuracy: 0.621 ;Time: 0:00:22
#
# Random choice: True
# batch: 0 ;edits ratio: 0.367 ;B loss: 1.868 ;A loss: 0.710 ;acc: 0.510 ;iou_acc: 0.600 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.322 ;B loss: 2.984 ;A loss: 0.662 ;acc: 0.310 ;iou_acc: 0.430 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.326 ;B loss: 1.887 ;A loss: 0.715 ;acc: 0.515 ;iou_acc: 0.605 ;time: 0:00:14
#
# *B loss: 1.877 ;A loss: 0.714 ;Edit ratio: 0.337 ;Accuracy 0.556 ;IOU accuracy: 0.651 ;Time: 0:00:21
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.181 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:61; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:6534 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.096 ;Aloss:0.389 ;edits ratio:0.354 ;acc:0.480 ;iou:0.595 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:6534 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.839 ;Aloss:0.354 ;edits ratio:0.349 ;acc:0.610 ;iou:0.690 ;time: 0:00:11
# Edit: True ;batch:100 ;gs:6534 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.981 ;Aloss:0.343 ;edits ratio:0.341 ;acc:0.220 ;iou:0.340 ;time: 0:00:21
# Edit: True ;batch:150 ;gs:6534 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.862 ;Aloss:0.376 ;edits ratio:0.341 ;acc:0.195 ;iou:0.395 ;time: 0:00:32
# Edit: True ;batch:200 ;gs:6534 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.795 ;Aloss:0.313 ;edits ratio:0.304 ;acc:0.595 ;iou:0.720 ;time: 0:00:44
# Edit: True ;batch:250 ;gs:6534 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.766 ;Aloss:0.429 ;edits ratio:0.369 ;acc:0.595 ;iou:0.715 ;time: 0:00:55
#
# *B Train loss: 2.060 ;A Train loss: 0.432 ;Edit ratio: 0.346 ;Train accuracy: 0.523 ;IOU accuracy: 0.626 ;Time: 0:01:07
#
# VALIDATION, ephoc: 61
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.342 ;B loss: 2.013 ;A loss: 0.419 ;acc: 0.555 ;iou_acc: 0.640 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.313 ;B loss: 3.058 ;A loss: 0.393 ;acc: 0.210 ;iou_acc: 0.425 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.366 ;B loss: 2.193 ;A loss: 0.383 ;acc: 0.435 ;iou_acc: 0.530 ;time: 0:00:14
#
# *B loss: 2.074 ;A loss: 0.430 ;Edit ratio: 0.352 ;Accuracy 0.509 ;IOU accuracy: 0.614 ;Time: 0:00:22
#
# Random choice: True
# batch: 0 ;edits ratio: 0.337 ;B loss: 1.861 ;A loss: 0.731 ;acc: 0.570 ;iou_acc: 0.640 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.362 ;B loss: 2.963 ;A loss: 0.657 ;acc: 0.280 ;iou_acc: 0.420 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.321 ;B loss: 1.955 ;A loss: 0.634 ;acc: 0.480 ;iou_acc: 0.575 ;time: 0:00:14
#
# *B loss: 1.887 ;A loss: 0.720 ;Edit ratio: 0.353 ;Accuracy 0.549 ;IOU accuracy: 0.645 ;Time: 0:00:21
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.187 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:62; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:6534 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.160 ;Aloss:0.373 ;edits ratio:0.378 ;acc:0.465 ;iou:0.565 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:6534 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.788 ;Aloss:0.364 ;edits ratio:0.346 ;acc:0.295 ;iou:0.455 ;time: 0:00:12
# Edit: True ;batch:100 ;gs:6534 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.563 ;Aloss:0.487 ;edits ratio:0.318 ;acc:0.765 ;iou:0.800 ;time: 0:00:23
# Edit: True ;batch:150 ;gs:6534 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.601 ;Aloss:0.448 ;edits ratio:0.291 ;acc:0.730 ;iou:0.785 ;time: 0:00:34
# Edit: True ;batch:200 ;gs:6534 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.673 ;Aloss:0.410 ;edits ratio:0.347 ;acc:0.715 ;iou:0.765 ;time: 0:00:45
# Edit: True ;batch:250 ;gs:6534 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.622 ;Aloss:0.434 ;edits ratio:0.379 ;acc:0.345 ;iou:0.485 ;time: 0:00:57
#
# *B Train loss: 2.062 ;A Train loss: 0.433 ;Edit ratio: 0.347 ;Train accuracy: 0.523 ;IOU accuracy: 0.626 ;Time: 0:01:07
#
# VALIDATION, ephoc: 62
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.358 ;B loss: 2.010 ;A loss: 0.415 ;acc: 0.545 ;iou_acc: 0.630 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.321 ;B loss: 3.081 ;A loss: 0.398 ;acc: 0.190 ;iou_acc: 0.405 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.380 ;B loss: 2.201 ;A loss: 0.404 ;acc: 0.440 ;iou_acc: 0.530 ;time: 0:00:14
#
# *B loss: 2.088 ;A loss: 0.445 ;Edit ratio: 0.366 ;Accuracy 0.498 ;IOU accuracy: 0.603 ;Time: 0:00:22
#
# Random choice: True
# batch: 0 ;edits ratio: 0.385 ;B loss: 1.832 ;A loss: 0.734 ;acc: 0.550 ;iou_acc: 0.625 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.395 ;B loss: 3.049 ;A loss: 0.662 ;acc: 0.270 ;iou_acc: 0.390 ;time: 0:00:06
# batch: 100 ;edits ratio: 0.347 ;B loss: 1.861 ;A loss: 0.713 ;acc: 0.545 ;iou_acc: 0.635 ;time: 0:00:13
#
# *B loss: 1.902 ;A loss: 0.719 ;Edit ratio: 0.368 ;Accuracy 0.537 ;IOU accuracy: 0.634 ;Time: 0:00:21
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.186 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:63; Training B:True; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:6535 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.622 ;Aloss:0.436 ;edits ratio:0.330 ;acc:0.730 ;iou:0.785 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:6585 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:1.650 ;Aloss:0.468 ;edits ratio:0.311 ;acc:0.620 ;iou:0.690 ;time: 0:00:16
# Edit: True ;batch:100 ;gs:6635 ;Blr: 0.500 ;Alr:0.090 ;ERP:0.00 ;Bloss:2.452 ;Aloss:0.421 ;edits ratio:0.351 ;acc:0.380 ;iou:0.510 ;time: 0:00:31
# Edit: True ;batch:150 ;gs:6685 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.815 ;Aloss:0.446 ;edits ratio:0.278 ;acc:0.640 ;iou:0.690 ;time: 0:00:47
# Edit: True ;batch:200 ;gs:6735 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.859 ;Aloss:0.373 ;edits ratio:0.325 ;acc:0.595 ;iou:0.675 ;time: 0:01:01
# Edit: True ;batch:250 ;gs:6785 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:2.495 ;Aloss:0.495 ;edits ratio:0.385 ;acc:0.305 ;iou:0.500 ;time: 0:01:17
#
# *B Train loss: 2.034 ;A Train loss: 0.431 ;Edit ratio: 0.326 ;Train accuracy: 0.539 ;IOU accuracy: 0.641 ;Time: 0:01:31
#
# No Edit
# ooooooo
# Edit: False ;batch: 0 ;gs: 6831 ;Blr: 0.500 ;B loss: 1.275 ;acc: 0.860 ;iou: 0.900 ;time: 0:01:31
# Edit: False ;batch: 50 ;gs: 6831 ;Blr: 0.500 ;B loss: 1.163 ;acc: 0.805 ;iou: 0.880 ;time: 0:01:38
# Edit: False ;batch: 100 ;gs: 6831 ;Blr: 0.500 ;B loss: 1.895 ;acc: 0.590 ;iou: 0.715 ;time: 0:01:45
# Edit: False ;batch: 150 ;gs: 6831 ;Blr: 0.500 ;B loss: 1.286 ;acc: 0.825 ;iou: 0.885 ;time: 0:01:53
# Edit: False ;batch: 200 ;gs: 6831 ;Blr: 0.500 ;B loss: 1.343 ;acc: 0.760 ;iou: 0.830 ;time: 0:02:00
# Edit: False ;batch: 250 ;gs: 6831 ;Blr: 0.500 ;B loss: 1.865 ;acc: 0.620 ;iou: 0.765 ;time: 0:02:07
#
# *B Train loss: 1.565 ;Train accuracy: 0.739 ;IOU accuracy: 0.828 ;Time: 0:02:14
#
# TESTING, ephoc: 63
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.272 ;acc: 0.845 ;iou_acc: 0.895 ;time: 0:02:15
# batch: 50 ;B loss: 1.798 ;acc: 0.645 ;iou_acc: 0.735 ;time: 0:02:21
# batch: 100 ;B loss: 1.746 ;acc: 0.605 ;iou_acc: 0.725 ;time: 0:02:27
# batch: 150 ;B loss: 1.280 ;acc: 0.860 ;iou_acc: 0.890 ;time: 0:02:34
# batch: 200 ;B loss: 2.122 ;acc: 0.555 ;iou_acc: 0.690 ;time: 0:02:40
# batch: 250 ;B loss: 1.270 ;acc: 0.855 ;iou_acc: 0.895 ;time: 0:02:46
#
# *Test loss: 1.645 ;Test accuracy 0.703 ;IOU accuracy: 0.799 ;Time: 0:02:52
# ==================================================
#
# ==================================================
# TRAIN, ephoc:64; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:6831 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.942 ;Aloss:0.428 ;edits ratio:0.341 ;acc:0.560 ;iou:0.650 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:6831 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.657 ;Aloss:0.488 ;edits ratio:0.317 ;acc:0.750 ;iou:0.785 ;time: 0:00:12
# Edit: True ;batch:100 ;gs:6831 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:2.075 ;Aloss:0.391 ;edits ratio:0.335 ;acc:0.510 ;iou:0.630 ;time: 0:00:23
# Edit: True ;batch:150 ;gs:6831 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:2.399 ;Aloss:0.434 ;edits ratio:0.410 ;acc:0.320 ;iou:0.450 ;time: 0:00:35
# Edit: True ;batch:200 ;gs:6831 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.823 ;Aloss:0.433 ;edits ratio:0.299 ;acc:0.575 ;iou:0.650 ;time: 0:00:45
# Edit: True ;batch:250 ;gs:6831 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.754 ;Aloss:0.625 ;edits ratio:0.301 ;acc:0.640 ;iou:0.705 ;time: 0:00:57
#
# *B Train loss: 2.085 ;A Train loss: 0.454 ;Edit ratio: 0.348 ;Train accuracy: 0.512 ;IOU accuracy: 0.613 ;Time: 0:01:07
#
# VALIDATION, ephoc: 64
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.385 ;B loss: 2.096 ;A loss: 0.471 ;acc: 0.470 ;iou_acc: 0.545 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.318 ;B loss: 3.141 ;A loss: 0.392 ;acc: 0.225 ;iou_acc: 0.395 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.370 ;B loss: 2.211 ;A loss: 0.364 ;acc: 0.385 ;iou_acc: 0.495 ;time: 0:00:13
#
# *B loss: 2.110 ;A loss: 0.463 ;Edit ratio: 0.361 ;Accuracy 0.488 ;IOU accuracy: 0.591 ;Time: 0:00:20
#
# Random choice: True
# batch: 0 ;edits ratio: 0.386 ;B loss: 1.917 ;A loss: 0.761 ;acc: 0.525 ;iou_acc: 0.625 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.360 ;B loss: 2.992 ;A loss: 0.703 ;acc: 0.315 ;iou_acc: 0.485 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.346 ;B loss: 1.900 ;A loss: 0.762 ;acc: 0.510 ;iou_acc: 0.605 ;time: 0:00:14
#
# *B loss: 1.900 ;A loss: 0.734 ;Edit ratio: 0.359 ;Accuracy 0.544 ;IOU accuracy: 0.638 ;Time: 0:00:21
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.210 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:65; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:6831 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:2.798 ;Aloss:0.392 ;edits ratio:0.344 ;acc:0.280 ;iou:0.445 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:6831 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:2.621 ;Aloss:0.339 ;edits ratio:0.365 ;acc:0.325 ;iou:0.485 ;time: 0:00:11
# Edit: True ;batch:100 ;gs:6831 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:2.300 ;Aloss:0.424 ;edits ratio:0.310 ;acc:0.415 ;iou:0.550 ;time: 0:00:22
# Edit: True ;batch:150 ;gs:6831 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.752 ;Aloss:0.329 ;edits ratio:0.293 ;acc:0.640 ;iou:0.710 ;time: 0:00:34
# Edit: True ;batch:200 ;gs:6831 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:2.400 ;Aloss:0.460 ;edits ratio:0.371 ;acc:0.335 ;iou:0.495 ;time: 0:00:44
# Edit: True ;batch:250 ;gs:6831 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.887 ;Aloss:0.411 ;edits ratio:0.269 ;acc:0.575 ;iou:0.660 ;time: 0:00:55
#
# *B Train loss: 2.072 ;A Train loss: 0.443 ;Edit ratio: 0.335 ;Train accuracy: 0.520 ;IOU accuracy: 0.620 ;Time: 0:01:05
#
# VALIDATION, ephoc: 65
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.381 ;B loss: 2.099 ;A loss: 0.446 ;acc: 0.470 ;iou_acc: 0.545 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.314 ;B loss: 3.142 ;A loss: 0.393 ;acc: 0.215 ;iou_acc: 0.395 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.375 ;B loss: 2.206 ;A loss: 0.396 ;acc: 0.395 ;iou_acc: 0.505 ;time: 0:00:13
#
# *B loss: 2.109 ;A loss: 0.461 ;Edit ratio: 0.361 ;Accuracy 0.490 ;IOU accuracy: 0.593 ;Time: 0:00:20
#
# Random choice: True
# batch: 0 ;edits ratio: 0.308 ;B loss: 1.878 ;A loss: 0.821 ;acc: 0.570 ;iou_acc: 0.640 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.362 ;B loss: 3.070 ;A loss: 0.733 ;acc: 0.275 ;iou_acc: 0.430 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.356 ;B loss: 1.923 ;A loss: 0.745 ;acc: 0.545 ;iou_acc: 0.635 ;time: 0:00:15
#
# *B loss: 1.906 ;A loss: 0.740 ;Edit ratio: 0.363 ;Accuracy 0.540 ;IOU accuracy: 0.636 ;Time: 0:00:23
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.202 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:66; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:6831 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:2.658 ;Aloss:0.414 ;edits ratio:0.335 ;acc:0.335 ;iou:0.555 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:6831 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.746 ;Aloss:0.392 ;edits ratio:0.332 ;acc:0.645 ;iou:0.670 ;time: 0:00:11
# Edit: True ;batch:100 ;gs:6831 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.628 ;Aloss:0.444 ;edits ratio:0.332 ;acc:0.710 ;iou:0.755 ;time: 0:00:22
# Edit: True ;batch:150 ;gs:6831 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.908 ;Aloss:0.689 ;edits ratio:0.441 ;acc:0.720 ;iou:0.815 ;time: 0:00:33
# Edit: True ;batch:200 ;gs:6831 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.675 ;Aloss:0.481 ;edits ratio:0.297 ;acc:0.695 ;iou:0.790 ;time: 0:00:44
# Edit: True ;batch:250 ;gs:6831 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:2.677 ;Aloss:0.390 ;edits ratio:0.363 ;acc:0.310 ;iou:0.480 ;time: 0:00:55
#
# *B Train loss: 2.066 ;A Train loss: 0.438 ;Edit ratio: 0.329 ;Train accuracy: 0.523 ;IOU accuracy: 0.623 ;Time: 0:01:06
#
# VALIDATION, ephoc: 66
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.388 ;B loss: 2.102 ;A loss: 0.468 ;acc: 0.455 ;iou_acc: 0.530 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.319 ;B loss: 3.142 ;A loss: 0.398 ;acc: 0.215 ;iou_acc: 0.395 ;time: 0:00:06
# batch: 100 ;edits ratio: 0.379 ;B loss: 2.210 ;A loss: 0.397 ;acc: 0.390 ;iou_acc: 0.500 ;time: 0:00:13
#
# *B loss: 2.113 ;A loss: 0.466 ;Edit ratio: 0.364 ;Accuracy 0.487 ;IOU accuracy: 0.589 ;Time: 0:00:21
#
# Random choice: True
# batch: 0 ;edits ratio: 0.347 ;B loss: 1.868 ;A loss: 0.756 ;acc: 0.550 ;iou_acc: 0.615 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.389 ;B loss: 3.130 ;A loss: 0.701 ;acc: 0.280 ;iou_acc: 0.410 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.371 ;B loss: 1.966 ;A loss: 0.795 ;acc: 0.475 ;iou_acc: 0.570 ;time: 0:00:14
#
# *B loss: 1.903 ;A loss: 0.744 ;Edit ratio: 0.366 ;Accuracy 0.538 ;IOU accuracy: 0.634 ;Time: 0:00:21
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.210 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:67; Training B:True; A is a know-it-all:False; ActivateA:True
# Edit: False ;batch: 0 ;gs: 6832 ;Blr: 0.500 ;B loss: 1.152 ;acc: 0.900 ;iou: 0.960 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:6882 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:2.559 ;Aloss:0.475 ;edits ratio:0.412 ;acc:0.290 ;iou:0.410 ;time: 0:00:16
# Edit: True ;batch:100 ;gs:6932 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.580 ;Aloss:0.488 ;edits ratio:0.244 ;acc:0.730 ;iou:0.790 ;time: 0:00:32
# Edit: True ;batch:150 ;gs:6982 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.670 ;Aloss:0.464 ;edits ratio:0.337 ;acc:0.635 ;iou:0.705 ;time: 0:00:48
# Edit: True ;batch:200 ;gs:7032 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.722 ;Aloss:0.407 ;edits ratio:0.186 ;acc:0.630 ;iou:0.710 ;time: 0:01:04
# Edit: True ;batch:250 ;gs:7082 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.860 ;Aloss:0.424 ;edits ratio:0.310 ;acc:0.660 ;iou:0.715 ;time: 0:01:19
#
# *B Train loss: 2.019 ;A Train loss: 0.429 ;Edit ratio: 0.322 ;Train accuracy: 0.546 ;IOU accuracy: 0.648 ;Time: 0:01:33
#
# No Edit
# ooooooo
# Edit: False ;batch: 0 ;gs: 7128 ;Blr: 0.500 ;B loss: 1.143 ;acc: 0.885 ;iou: 0.935 ;time: 0:01:33
# Edit: False ;batch: 50 ;gs: 7128 ;Blr: 0.500 ;B loss: 1.877 ;acc: 0.635 ;iou: 0.750 ;time: 0:01:40
# Edit: False ;batch: 100 ;gs: 7128 ;Blr: 0.500 ;B loss: 1.170 ;acc: 0.840 ;iou: 0.910 ;time: 0:01:47
# Edit: False ;batch: 150 ;gs: 7128 ;Blr: 0.500 ;B loss: 1.198 ;acc: 0.795 ;iou: 0.850 ;time: 0:01:53
# Edit: False ;batch: 200 ;gs: 7128 ;Blr: 0.500 ;B loss: 1.320 ;acc: 0.815 ;iou: 0.865 ;time: 0:02:00
# Edit: False ;batch: 250 ;gs: 7128 ;Blr: 0.500 ;B loss: 1.303 ;acc: 0.805 ;iou: 0.880 ;time: 0:02:07
#
# *B Train loss: 1.555 ;Train accuracy: 0.745 ;IOU accuracy: 0.829 ;Time: 0:02:13
#
# TESTING, ephoc: 67
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.283 ;acc: 0.855 ;iou_acc: 0.910 ;time: 0:02:14
# batch: 50 ;B loss: 1.829 ;acc: 0.600 ;iou_acc: 0.705 ;time: 0:02:20
# batch: 100 ;B loss: 1.762 ;acc: 0.610 ;iou_acc: 0.720 ;time: 0:02:27
# batch: 150 ;B loss: 1.283 ;acc: 0.870 ;iou_acc: 0.895 ;time: 0:02:34
# batch: 200 ;B loss: 2.111 ;acc: 0.540 ;iou_acc: 0.655 ;time: 0:02:39
# batch: 250 ;B loss: 1.286 ;acc: 0.870 ;iou_acc: 0.925 ;time: 0:02:45
#
# *Test loss: 1.647 ;Test accuracy 0.705 ;IOU accuracy: 0.796 ;Time: 0:02:51
# ==================================================
#
# ==================================================
# TRAIN, ephoc:68; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:7128 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.669 ;Aloss:0.431 ;edits ratio:0.340 ;acc:0.710 ;iou:0.770 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:7128 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:2.584 ;Aloss:0.494 ;edits ratio:0.495 ;acc:0.270 ;iou:0.365 ;time: 0:00:11
# Edit: True ;batch:100 ;gs:7128 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.534 ;Aloss:0.409 ;edits ratio:0.223 ;acc:0.680 ;iou:0.755 ;time: 0:00:22
# Edit: True ;batch:150 ;gs:7128 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:2.448 ;Aloss:0.539 ;edits ratio:0.440 ;acc:0.345 ;iou:0.470 ;time: 0:00:33
# Edit: True ;batch:200 ;gs:7128 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:2.063 ;Aloss:0.360 ;edits ratio:0.360 ;acc:0.455 ;iou:0.555 ;time: 0:00:44
# Edit: True ;batch:250 ;gs:7128 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:2.016 ;Aloss:0.395 ;edits ratio:0.234 ;acc:0.550 ;iou:0.670 ;time: 0:00:56
#
# *B Train loss: 2.065 ;A Train loss: 0.428 ;Edit ratio: 0.356 ;Train accuracy: 0.523 ;IOU accuracy: 0.622 ;Time: 0:01:07
#
# VALIDATION, ephoc: 68
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.422 ;B loss: 2.112 ;A loss: 0.481 ;acc: 0.505 ;iou_acc: 0.575 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.391 ;B loss: 3.143 ;A loss: 0.435 ;acc: 0.200 ;iou_acc: 0.395 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.432 ;B loss: 2.217 ;A loss: 0.461 ;acc: 0.375 ;iou_acc: 0.470 ;time: 0:00:14
#
# *B loss: 2.145 ;A loss: 0.487 ;Edit ratio: 0.413 ;Accuracy 0.466 ;IOU accuracy: 0.570 ;Time: 0:00:22
#
# Random choice: True
# batch: 0 ;edits ratio: 0.423 ;B loss: 1.945 ;A loss: 0.653 ;acc: 0.535 ;iou_acc: 0.605 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.423 ;B loss: 3.040 ;A loss: 0.583 ;acc: 0.295 ;iou_acc: 0.445 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.359 ;B loss: 1.903 ;A loss: 0.674 ;acc: 0.485 ;iou_acc: 0.575 ;time: 0:00:14
#
# *B loss: 1.917 ;A loss: 0.698 ;Edit ratio: 0.411 ;Accuracy 0.531 ;IOU accuracy: 0.626 ;Time: 0:00:22
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.228 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:69; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:7128 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.964 ;Aloss:0.508 ;edits ratio:0.419 ;acc:0.525 ;iou:0.595 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:7128 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.610 ;Aloss:0.408 ;edits ratio:0.325 ;acc:0.720 ;iou:0.790 ;time: 0:00:11
# Edit: True ;batch:100 ;gs:7128 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:2.144 ;Aloss:0.431 ;edits ratio:0.267 ;acc:0.500 ;iou:0.625 ;time: 0:00:22
# Edit: True ;batch:150 ;gs:7128 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.885 ;Aloss:0.457 ;edits ratio:0.358 ;acc:0.505 ;iou:0.590 ;time: 0:00:33
# Edit: True ;batch:200 ;gs:7128 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.758 ;Aloss:0.341 ;edits ratio:0.346 ;acc:0.610 ;iou:0.700 ;time: 0:00:44
# Edit: True ;batch:250 ;gs:7128 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.700 ;Aloss:0.295 ;edits ratio:0.247 ;acc:0.645 ;iou:0.725 ;time: 0:00:55
#
# *B Train loss: 2.066 ;A Train loss: 0.423 ;Edit ratio: 0.357 ;Train accuracy: 0.522 ;IOU accuracy: 0.620 ;Time: 0:01:06
#
# VALIDATION, ephoc: 69
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.412 ;B loss: 2.091 ;A loss: 0.440 ;acc: 0.525 ;iou_acc: 0.595 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.365 ;B loss: 3.100 ;A loss: 0.415 ;acc: 0.215 ;iou_acc: 0.420 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.418 ;B loss: 2.191 ;A loss: 0.420 ;acc: 0.385 ;iou_acc: 0.485 ;time: 0:00:14
#
# *B loss: 2.118 ;A loss: 0.446 ;Edit ratio: 0.388 ;Accuracy 0.484 ;IOU accuracy: 0.587 ;Time: 0:00:21
#
# Random choice: True
# batch: 0 ;edits ratio: 0.409 ;B loss: 1.812 ;A loss: 0.705 ;acc: 0.580 ;iou_acc: 0.655 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.399 ;B loss: 3.015 ;A loss: 0.654 ;acc: 0.280 ;iou_acc: 0.455 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.388 ;B loss: 1.965 ;A loss: 0.696 ;acc: 0.490 ;iou_acc: 0.595 ;time: 0:00:15
#
# *B loss: 1.893 ;A loss: 0.717 ;Edit ratio: 0.387 ;Accuracy 0.542 ;IOU accuracy: 0.638 ;Time: 0:00:22
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.225 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:70; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:7128 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.633 ;Aloss:0.580 ;edits ratio:0.360 ;acc:0.695 ;iou:0.775 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:7128 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.972 ;Aloss:0.402 ;edits ratio:0.388 ;acc:0.555 ;iou:0.620 ;time: 0:00:11
# Edit: True ;batch:100 ;gs:7128 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.742 ;Aloss:0.438 ;edits ratio:0.347 ;acc:0.650 ;iou:0.715 ;time: 0:00:22
# Edit: True ;batch:150 ;gs:7128 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.728 ;Aloss:0.393 ;edits ratio:0.321 ;acc:0.625 ;iou:0.715 ;time: 0:00:33
# Edit: True ;batch:200 ;gs:7128 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:2.172 ;Aloss:0.359 ;edits ratio:0.286 ;acc:0.485 ;iou:0.620 ;time: 0:00:45
# Edit: True ;batch:250 ;gs:7128 ;Blr: 0.500 ;Alr:0.081 ;ERP:0.00 ;Bloss:1.820 ;Aloss:0.284 ;edits ratio:0.300 ;acc:0.590 ;iou:0.685 ;time: 0:00:56
#
# *B Train loss: 2.067 ;A Train loss: 0.422 ;Edit ratio: 0.357 ;Train accuracy: 0.521 ;IOU accuracy: 0.620 ;Time: 0:01:07
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-848008fecffd> in <module>()
#      33                                     Blr=.5,
#      34                                     Alr=.1,
# ---> 35                                     imScale=1/50)
#      36     edit_rewards_tst.append(tst)
#      37     edit_rewards_trn.append(trn)
#
# <ipython-input-10-11cd4775b334> in train(self, trn_data, tst_data, val_data, ephocs_num, edit_reward, startA, activation_ephoc, muteBnum, start_ephoc, dropout_in, rnn_editProb, dropout_out, dropout_img, dropout_q, queries_editProb, addNoiseImg, imScale, Alr, Blr)
#    1059                               ';Time:', datetime.now().replace(microsecond=0)-startTime, '\n')
#    1060                         self.train_res.append([trn_acc, trn_iou, B_trn_loss, 0])
# -> 1061                 self.saver.save(sess, params_dir + "/model.ckpt", global_step=ephoc)
#    1062
#    1063 #                 print('GRADS:')
#
# /home/asi/.local/lib/python3.5/site-packages/tensorflow/python/training/saver.py in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state)
#    1492           checkpoint_file, meta_graph_suffix=meta_graph_suffix)
#    1493       with sess.graph.as_default():
# -> 1494         self.export_meta_graph(meta_graph_filename)
#    1495
#    1496     if self._is_empty:
#
# KeyboardInterrupt:

# %%
num_hidden=200
edit_rewards = [-1., -.9, -.8, -0.7, -0.6]
edit_rewards_tst, edit_rewards_trn, edit_rewards_val, edit_rewards_AGain = [], [], [], []

for edit_reward in edit_rewards:
    params_dir = params_dir_tmp+'RL/edit_rewards_'+str(-1*edit_reward)+'hidden_'+str(num_hidden)
    tf.reset_default_graph()
    m = Model(
        batch_size=200, 
        num_hidden=num_hidden,
        embed_size=embed_vecs.shape[1],
        img_dims=trainset[0][0][1][0].shape[1], 
        bbox_dims=trainset[0][0][1][1].shape[1], 
        vocab=vocab, 
        decay_steps=10000, 
        decay_rate=0.9, 
        bnorm=False,
        toQscale=True
    )

    print('params_dir:', params_dir)
    print('num_hidden:', m.num_hidden)
    print('edit_reward:', edit_reward)
    act_rewards, BCE, bell_val, idx = m.train(trainset, testset, valset,
                                    ephocs_num=200,
                                    start_ephoc=45,
                                    startA=8,
                                    activation_ephoc=12,
                                    muteBnum=3, 
                                    queries_editProb=0.95,
                                    edit_reward=edit_reward,
                                    rnn_editProb=0.2,
                                    Blr=.01,
                                    Alr=.3,
                                    imScale=1/50)
    edit_rewards_tst.append(tst) 
    edit_rewards_trn.append(trn)
    edit_rewards_val.append(val) 
    edit_rewards_AGain.append(AGain)

    print('\n'+'*'*100)
    print('*'*100)
    print('*'*100,'\n')
# Out:
# params_dir: ../data/training/models/All/RL/edit_rewards_1.0hidden_200
# num_hidden: 200
# edit_reward: -1.0
# # Train set size: 59400
# # Training batches: 297
# # Validation set size: 29800
# # Validation batches: 149
# # Test set size: 29600
# # Testing batches: 148
# Loading parameters from ../data/training/models/All/RL/edit_rewards_1.0hidden_200/model.ckpt-46
# INFO:tensorflow:Restoring parameters from ../data/training/models/All/RL/edit_rewards_1.0hidden_200/model.ckpt-46
# ==================================================
# TRAIN, ephoc:45; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:5049 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:2.308 ;Aloss:0.603 ;edits ratio:0.454 ;acc:0.390 ;iou:0.535 ;time: 0:00:01
# Edit: True ;batch:50 ;gs:5049 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.741 ;Aloss:0.468 ;edits ratio:0.381 ;acc:0.600 ;iou:0.690 ;time: 0:00:13
# Edit: True ;batch:100 ;gs:5049 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.937 ;Aloss:0.437 ;edits ratio:0.345 ;acc:0.530 ;iou:0.600 ;time: 0:00:24
# Edit: True ;batch:150 ;gs:5049 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.541 ;Aloss:0.392 ;edits ratio:0.249 ;acc:0.765 ;iou:0.810 ;time: 0:00:35
# Edit: True ;batch:200 ;gs:5049 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.711 ;Aloss:0.436 ;edits ratio:0.307 ;acc:0.670 ;iou:0.710 ;time: 0:00:46
# Edit: True ;batch:250 ;gs:5049 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:2.044 ;Aloss:0.375 ;edits ratio:0.175 ;acc:0.495 ;iou:0.605 ;time: 0:00:58
#
# *B Train loss: 2.047 ;A Train loss: 0.457 ;Edit ratio: 0.336 ;Train accuracy: 0.524 ;IOU accuracy: 0.628 ;Time: 0:01:08
#
# VALIDATION, ephoc: 45
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.433 ;B loss: 1.996 ;A loss: 0.569 ;acc: 0.475 ;iou_acc: 0.580 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.375 ;B loss: 3.140 ;A loss: 0.480 ;acc: 0.230 ;iou_acc: 0.430 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.490 ;B loss: 2.213 ;A loss: 0.530 ;acc: 0.380 ;iou_acc: 0.485 ;time: 0:00:14
#
# *B loss: 2.090 ;A loss: 0.521 ;Edit ratio: 0.410 ;Accuracy 0.471 ;IOU accuracy: 0.580 ;Time: 0:00:21
#
# Random choice: True
# batch: 0 ;edits ratio: 0.457 ;B loss: 1.909 ;A loss: 0.674 ;acc: 0.510 ;iou_acc: 0.610 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.415 ;B loss: 3.054 ;A loss: 0.661 ;acc: 0.320 ;iou_acc: 0.445 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.424 ;B loss: 1.959 ;A loss: 0.684 ;acc: 0.475 ;iou_acc: 0.590 ;time: 0:00:15
#
# *B loss: 1.917 ;A loss: 0.680 ;Edit ratio: 0.413 ;Accuracy 0.534 ;IOU accuracy: 0.632 ;Time: 0:00:23
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.173 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:46; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:5049 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.932 ;Aloss:0.477 ;edits ratio:0.411 ;acc:0.525 ;iou:0.625 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:5049 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.760 ;Aloss:0.440 ;edits ratio:0.203 ;acc:0.645 ;iou:0.735 ;time: 0:00:12
# Edit: True ;batch:100 ;gs:5049 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:2.027 ;Aloss:0.517 ;edits ratio:0.413 ;acc:0.455 ;iou:0.590 ;time: 0:00:23
# Edit: True ;batch:150 ;gs:5049 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.618 ;Aloss:0.487 ;edits ratio:0.214 ;acc:0.630 ;iou:0.730 ;time: 0:00:34
# Edit: True ;batch:200 ;gs:5049 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.682 ;Aloss:0.436 ;edits ratio:0.290 ;acc:0.665 ;iou:0.725 ;time: 0:00:45
# Edit: True ;batch:250 ;gs:5049 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:2.076 ;Aloss:0.472 ;edits ratio:0.296 ;acc:0.490 ;iou:0.575 ;time: 0:00:56
#
# *B Train loss: 2.029 ;A Train loss: 0.449 ;Edit ratio: 0.319 ;Train accuracy: 0.533 ;IOU accuracy: 0.638 ;Time: 0:01:06
#
# VALIDATION, ephoc: 46
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.240 ;B loss: 1.897 ;A loss: 0.421 ;acc: 0.615 ;iou_acc: 0.700 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.242 ;B loss: 2.955 ;A loss: 0.418 ;acc: 0.315 ;iou_acc: 0.525 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.252 ;B loss: 2.063 ;A loss: 0.350 ;acc: 0.515 ;iou_acc: 0.610 ;time: 0:00:14
#
# *B loss: 1.969 ;A loss: 0.409 ;Edit ratio: 0.267 ;Accuracy 0.560 ;IOU accuracy: 0.660 ;Time: 0:00:21
#
# Random choice: True
# batch: 0 ;edits ratio: 0.298 ;B loss: 1.781 ;A loss: 0.743 ;acc: 0.565 ;iou_acc: 0.640 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.279 ;B loss: 2.922 ;A loss: 0.648 ;acc: 0.355 ;iou_acc: 0.510 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.291 ;B loss: 1.848 ;A loss: 0.729 ;acc: 0.575 ;iou_acc: 0.675 ;time: 0:00:14
#
# *B loss: 1.815 ;A loss: 0.705 ;Edit ratio: 0.267 ;Accuracy 0.599 ;IOU accuracy: 0.697 ;Time: 0:00:22
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.154 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:47; Training B:True; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:5050 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:2.093 ;Aloss:0.351 ;edits ratio:0.279 ;acc:0.500 ;iou:0.580 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:5100 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:2.331 ;Aloss:0.406 ;edits ratio:0.334 ;acc:0.375 ;iou:0.540 ;time: 0:00:16
# Edit: True ;batch:100 ;gs:5150 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.962 ;Aloss:0.451 ;edits ratio:0.350 ;acc:0.555 ;iou:0.635 ;time: 0:00:32
# Edit: True ;batch:150 ;gs:5200 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.655 ;Aloss:0.535 ;edits ratio:0.293 ;acc:0.640 ;iou:0.715 ;time: 0:00:47
# Edit: True ;batch:200 ;gs:5250 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.692 ;Aloss:0.417 ;edits ratio:0.276 ;acc:0.685 ;iou:0.730 ;time: 0:01:03
# Edit: True ;batch:250 ;gs:5300 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:2.179 ;Aloss:0.356 ;edits ratio:0.045 ;acc:0.545 ;iou:0.715 ;time: 0:01:18
#
# *B Train loss: 2.015 ;A Train loss: 0.441 ;Edit ratio: 0.317 ;Train accuracy: 0.543 ;IOU accuracy: 0.646 ;Time: 0:01:31
#
# No Edit
# ooooooo
# Edit: False ;batch: 0 ;gs: 5346 ;Blr: 0.010 ;B loss: 1.675 ;acc: 0.660 ;iou: 0.750 ;time: 0:01:31
# Edit: False ;batch: 50 ;gs: 5346 ;Blr: 0.010 ;B loss: 1.948 ;acc: 0.615 ;iou: 0.765 ;time: 0:01:38
# Edit: False ;batch: 100 ;gs: 5346 ;Blr: 0.010 ;B loss: 1.509 ;acc: 0.735 ;iou: 0.815 ;time: 0:01:45
# Edit: False ;batch: 150 ;gs: 5346 ;Blr: 0.010 ;B loss: 1.282 ;acc: 0.815 ;iou: 0.865 ;time: 0:01:53
# Edit: False ;batch: 200 ;gs: 5346 ;Blr: 0.010 ;B loss: 1.283 ;acc: 0.825 ;iou: 0.875 ;time: 0:02:00
# Edit: False ;batch: 250 ;gs: 5346 ;Blr: 0.010 ;B loss: 2.088 ;acc: 0.590 ;iou: 0.755 ;time: 0:02:07
#
# *B Train loss: 1.641 ;Train accuracy: 0.725 ;IOU accuracy: 0.816 ;Time: 0:02:13
#
# TESTING, ephoc: 47
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.299 ;acc: 0.835 ;iou_acc: 0.890 ;time: 0:02:14
# batch: 50 ;B loss: 1.860 ;acc: 0.635 ;iou_acc: 0.745 ;time: 0:02:20
# batch: 100 ;B loss: 1.840 ;acc: 0.590 ;iou_acc: 0.705 ;time: 0:02:27
# batch: 150 ;B loss: 1.304 ;acc: 0.835 ;iou_acc: 0.870 ;time: 0:02:34
# batch: 200 ;B loss: 2.228 ;acc: 0.505 ;iou_acc: 0.650 ;time: 0:02:40
# batch: 250 ;B loss: 1.250 ;acc: 0.860 ;iou_acc: 0.905 ;time: 0:02:45
#
# *Test loss: 1.694 ;Test accuracy 0.694 ;IOU accuracy: 0.791 ;Time: 0:02:50
# ==================================================
#
# ==================================================
# TRAIN, ephoc:48; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:5346 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.938 ;Aloss:0.348 ;edits ratio:0.249 ;acc:0.475 ;iou:0.580 ;time: 0:00:01
# Edit: True ;batch:50 ;gs:5346 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.850 ;Aloss:0.480 ;edits ratio:0.366 ;acc:0.790 ;iou:0.880 ;time: 0:00:12
# Edit: True ;batch:100 ;gs:5346 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.767 ;Aloss:0.409 ;edits ratio:0.194 ;acc:0.690 ;iou:0.725 ;time: 0:00:23
# Edit: True ;batch:150 ;gs:5346 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.651 ;Aloss:0.360 ;edits ratio:0.205 ;acc:0.685 ;iou:0.785 ;time: 0:00:34
# Edit: True ;batch:200 ;gs:5346 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:2.919 ;Aloss:0.452 ;edits ratio:0.401 ;acc:0.215 ;iou:0.415 ;time: 0:00:46
# Edit: True ;batch:250 ;gs:5346 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:2.278 ;Aloss:0.507 ;edits ratio:0.455 ;acc:0.350 ;iou:0.425 ;time: 0:00:57
#
# *B Train loss: 2.041 ;A Train loss: 0.443 ;Edit ratio: 0.325 ;Train accuracy: 0.530 ;IOU accuracy: 0.634 ;Time: 0:01:09
#
# VALIDATION, ephoc: 48
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.295 ;B loss: 1.937 ;A loss: 0.452 ;acc: 0.585 ;iou_acc: 0.660 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.304 ;B loss: 3.017 ;A loss: 0.438 ;acc: 0.270 ;iou_acc: 0.465 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.332 ;B loss: 2.116 ;A loss: 0.345 ;acc: 0.465 ;iou_acc: 0.555 ;time: 0:00:14
#
# *B loss: 2.020 ;A loss: 0.427 ;Edit ratio: 0.318 ;Accuracy 0.526 ;IOU accuracy: 0.631 ;Time: 0:00:21
#
# Random choice: True
# batch: 0 ;edits ratio: 0.298 ;B loss: 1.787 ;A loss: 0.737 ;acc: 0.615 ;iou_acc: 0.685 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.306 ;B loss: 2.912 ;A loss: 0.723 ;acc: 0.355 ;iou_acc: 0.520 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.355 ;B loss: 1.952 ;A loss: 0.728 ;acc: 0.495 ;iou_acc: 0.565 ;time: 0:00:15
#
# *B loss: 1.848 ;A loss: 0.711 ;Edit ratio: 0.319 ;Accuracy 0.576 ;IOU accuracy: 0.674 ;Time: 0:00:22
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.172 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:49; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:5346 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.665 ;Aloss:0.536 ;edits ratio:0.293 ;acc:0.655 ;iou:0.715 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:5346 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.512 ;Aloss:0.355 ;edits ratio:0.179 ;acc:0.700 ;iou:0.765 ;time: 0:00:12
# Edit: True ;batch:100 ;gs:5346 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.901 ;Aloss:0.585 ;edits ratio:0.447 ;acc:0.750 ;iou:0.885 ;time: 0:00:23
# Edit: True ;batch:150 ;gs:5346 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:2.309 ;Aloss:0.533 ;edits ratio:0.503 ;acc:0.325 ;iou:0.445 ;time: 0:00:35
# Edit: True ;batch:200 ;gs:5346 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.661 ;Aloss:0.428 ;edits ratio:0.291 ;acc:0.685 ;iou:0.740 ;time: 0:00:45
# Edit: True ;batch:250 ;gs:5346 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:2.169 ;Aloss:0.285 ;edits ratio:0.149 ;acc:0.515 ;iou:0.655 ;time: 0:00:56
#
# *B Train loss: 2.044 ;A Train loss: 0.444 ;Edit ratio: 0.326 ;Train accuracy: 0.529 ;IOU accuracy: 0.632 ;Time: 0:01:07
#
# VALIDATION, ephoc: 49
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.129 ;B loss: 1.742 ;A loss: 0.319 ;acc: 0.680 ;iou_acc: 0.750 ;time: 0:00:01
# batch: 50 ;edits ratio: 0.170 ;B loss: 2.799 ;A loss: 0.292 ;acc: 0.365 ;iou_acc: 0.545 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.124 ;B loss: 1.842 ;A loss: 0.246 ;acc: 0.635 ;iou_acc: 0.715 ;time: 0:00:15
#
# *B loss: 1.842 ;A loss: 0.345 ;Edit ratio: 0.145 ;Accuracy 0.632 ;IOU accuracy: 0.724 ;Time: 0:00:22
#
# Random choice: True
# batch: 0 ;edits ratio: 0.158 ;B loss: 1.665 ;A loss: 0.575 ;acc: 0.710 ;iou_acc: 0.785 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.132 ;B loss: 2.731 ;A loss: 0.588 ;acc: 0.430 ;iou_acc: 0.600 ;time: 0:00:06
# batch: 100 ;edits ratio: 0.142 ;B loss: 1.711 ;A loss: 0.730 ;acc: 0.625 ;iou_acc: 0.710 ;time: 0:00:13
#
# *B loss: 1.721 ;A loss: 0.573 ;Edit ratio: 0.144 ;Accuracy 0.656 ;IOU accuracy: 0.750 ;Time: 0:00:20
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.122 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:50; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:5346 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.493 ;Aloss:0.473 ;edits ratio:0.198 ;acc:0.750 ;iou:0.810 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:5346 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.731 ;Aloss:0.363 ;edits ratio:0.178 ;acc:0.625 ;iou:0.750 ;time: 0:00:11
# Edit: True ;batch:100 ;gs:5346 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:2.156 ;Aloss:0.531 ;edits ratio:0.505 ;acc:0.440 ;iou:0.520 ;time: 0:00:22
# Edit: True ;batch:150 ;gs:5346 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:3.012 ;Aloss:0.405 ;edits ratio:0.250 ;acc:0.325 ;iou:0.520 ;time: 0:00:32
# Edit: True ;batch:200 ;gs:5346 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:2.027 ;Aloss:0.388 ;edits ratio:0.250 ;acc:0.505 ;iou:0.580 ;time: 0:00:43
# Edit: True ;batch:250 ;gs:5346 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.804 ;Aloss:0.381 ;edits ratio:0.239 ;acc:0.825 ;iou:0.885 ;time: 0:00:55
#
# *B Train loss: 2.033 ;A Train loss: 0.437 ;Edit ratio: 0.319 ;Train accuracy: 0.534 ;IOU accuracy: 0.637 ;Time: 0:01:05
#
# VALIDATION, ephoc: 50
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.172 ;B loss: 1.835 ;A loss: 0.330 ;acc: 0.645 ;iou_acc: 0.715 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.217 ;B loss: 2.884 ;A loss: 0.372 ;acc: 0.340 ;iou_acc: 0.520 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.170 ;B loss: 1.942 ;A loss: 0.281 ;acc: 0.590 ;iou_acc: 0.670 ;time: 0:00:13
#
# *B loss: 1.917 ;A loss: 0.376 ;Edit ratio: 0.210 ;Accuracy 0.594 ;IOU accuracy: 0.690 ;Time: 0:00:20
#
# Random choice: True
# batch: 0 ;edits ratio: 0.165 ;B loss: 1.679 ;A loss: 0.599 ;acc: 0.640 ;iou_acc: 0.710 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.223 ;B loss: 2.867 ;A loss: 0.668 ;acc: 0.390 ;iou_acc: 0.585 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.214 ;B loss: 1.886 ;A loss: 0.727 ;acc: 0.565 ;iou_acc: 0.650 ;time: 0:00:13
#
# *B loss: 1.772 ;A loss: 0.666 ;Edit ratio: 0.210 ;Accuracy 0.625 ;IOU accuracy: 0.722 ;Time: 0:00:21
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.145 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:51; Training B:True; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:5347 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.736 ;Aloss:0.425 ;edits ratio:0.186 ;acc:0.645 ;iou:0.735 ;time: 0:00:00
# Edit: False ;batch: 50 ;gs: 5397 ;Blr: 0.010 ;B loss: 1.486 ;acc: 0.735 ;iou: 0.815 ;time: 0:00:16
# Edit: True ;batch:100 ;gs:5447 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.521 ;Aloss:0.258 ;edits ratio:0.053 ;acc:0.740 ;iou:0.830 ;time: 0:00:31
# Edit: True ;batch:150 ;gs:5497 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.804 ;Aloss:0.450 ;edits ratio:0.356 ;acc:0.750 ;iou:0.850 ;time: 0:00:46
# Edit: True ;batch:200 ;gs:5547 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.763 ;Aloss:0.482 ;edits ratio:0.288 ;acc:0.655 ;iou:0.715 ;time: 0:01:01
# Edit: True ;batch:250 ;gs:5597 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.700 ;Aloss:0.403 ;edits ratio:0.345 ;acc:0.645 ;iou:0.730 ;time: 0:01:16
#
# *B Train loss: 2.016 ;A Train loss: 0.437 ;Edit ratio: 0.319 ;Train accuracy: 0.543 ;IOU accuracy: 0.645 ;Time: 0:01:30
#
# No Edit
# ooooooo
# Edit: False ;batch: 0 ;gs: 5643 ;Blr: 0.010 ;B loss: 1.436 ;acc: 0.775 ;iou: 0.855 ;time: 0:01:31
# Edit: False ;batch: 50 ;gs: 5643 ;Blr: 0.010 ;B loss: 1.484 ;acc: 0.730 ;iou: 0.820 ;time: 0:01:38
# Edit: False ;batch: 100 ;gs: 5643 ;Blr: 0.010 ;B loss: 1.444 ;acc: 0.765 ;iou: 0.860 ;time: 0:01:45
# Edit: False ;batch: 150 ;gs: 5643 ;Blr: 0.010 ;B loss: 1.788 ;acc: 0.870 ;iou: 0.910 ;time: 0:01:51
# Edit: False ;batch: 200 ;gs: 5643 ;Blr: 0.010 ;B loss: 1.292 ;acc: 0.845 ;iou: 0.890 ;time: 0:01:58
# Edit: False ;batch: 250 ;gs: 5643 ;Blr: 0.010 ;B loss: 1.207 ;acc: 0.830 ;iou: 0.890 ;time: 0:02:06
#
# *B Train loss: 1.636 ;Train accuracy: 0.725 ;IOU accuracy: 0.816 ;Time: 0:02:12
#
# TESTING, ephoc: 51
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.295 ;acc: 0.845 ;iou_acc: 0.890 ;time: 0:02:13
# batch: 50 ;B loss: 1.856 ;acc: 0.635 ;iou_acc: 0.740 ;time: 0:02:19
# batch: 100 ;B loss: 1.834 ;acc: 0.600 ;iou_acc: 0.715 ;time: 0:02:26
# batch: 150 ;B loss: 1.302 ;acc: 0.835 ;iou_acc: 0.870 ;time: 0:02:33
# batch: 200 ;B loss: 2.220 ;acc: 0.505 ;iou_acc: 0.650 ;time: 0:02:39
# batch: 250 ;B loss: 1.250 ;acc: 0.860 ;iou_acc: 0.905 ;time: 0:02:45
#
# *Test loss: 1.690 ;Test accuracy 0.695 ;IOU accuracy: 0.792 ;Time: 0:02:50
# ==================================================
#
# ==================================================
# TRAIN, ephoc:52; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:5643 ;Blr: 0.010 ;Alr:0.270 ;ERP:0.00 ;Bloss:1.569 ;Aloss:0.419 ;edits ratio:0.259 ;acc:0.765 ;iou:0.835 ;time: 0:00:00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-14418f8f2577> in <module>()
#      33                                     Blr=.01,
#      34                                     Alr=.3,
# ---> 35                                     imScale=1/50)
#      36     edit_rewards_tst.append(tst)
#      37     edit_rewards_trn.append(trn)
#
# <ipython-input-10-11cd4775b334> in train(self, trn_data, tst_data, val_data, ephocs_num, edit_reward, startA, activation_ephoc, muteBnum, start_ephoc, dropout_in, rnn_editProb, dropout_out, dropout_img, dropout_q, queries_editProb, addNoiseImg, imScale, Alr, Blr)
#     914                                                                                             self.batch_size,
#     915                                                                                             addNoiseImg=addNoiseImg,
# --> 916                                                                                             imScale=imScale)
#     917
#     918                         feed_dict = {
#
# <ipython-input-10-11cd4775b334> in build_data(self, data, start, end, imScale, addNoiseImg)
#     558             s = np.std(img_scale, axis=-1, keepdims=True)
#     559             padded_im = imScale*img_scale/(s+halper)  #Scale to have imScale std
# --> 560             padded_im = padded_im - np.mean(padded_im, axis=-1, keepdims=True) # scale to zero mean
#     561
#     562         return qlen, np.array(attn_idx), np.array(padded_queries, dtype=np.int32), padded_im, np.array(padded_bbox), np.array(dist_labels)
#
# /home/asi/.local/lib/python3.5/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    2907
#    2908     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2909                           out=out, **kwargs)
#    2910
#    2911
#
# /home/asi/.local/lib/python3.5/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      68             is_float16_result = True
#      69
# ---> 70     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      71     if isinstance(ret, mu.ndarray):
#      72         ret = um.true_divide(
#
# KeyboardInterrupt:

# %%
num_hidden=200
edit_rewards = [-1., -.9, -.8, -0.7, -0.6]
edit_rewards_tst, edit_rewards_trn, edit_rewards_val, edit_rewards_AGain = [], [], [], []

for edit_reward in edit_rewards:
    params_dir = params_dir_tmp+'RL/edit_rewards_'+str(-1*edit_reward)+'hidden_'+str(num_hidden)
    tf.reset_default_graph()
    m = Model(
        batch_size=200, 
        num_hidden=num_hidden,
        embed_size=embed_vecs.shape[1],
        img_dims=trainset[0][0][1][0].shape[1], 
        bbox_dims=trainset[0][0][1][1].shape[1], 
        vocab=vocab, 
        decay_steps=10000, 
        decay_rate=0.9, 
        bnorm=False,
        toQscale=True
    )

    print('params_dir:', params_dir)
    print('num_hidden:', m.num_hidden)
    print('edit_reward:', edit_reward)
    act_rewards, BCE, bell_val, idx = m.train(trainset, testset, valset,
                                    ephocs_num=200,
                                    start_ephoc=37,
                                    startA=8,
                                    activation_ephoc=12,
                                    muteBnum=3, 
                                    queries_editProb=0.95,
                                    edit_reward=edit_reward,
                                    rnn_editProb=0.2,
                                    Blr=.01,
                                    Alr=.001,
                                    imScale=1/50)
    edit_rewards_tst.append(tst) 
    edit_rewards_trn.append(trn)
    edit_rewards_val.append(val) 
    edit_rewards_AGain.append(AGain)

    print('\n'+'*'*100)
    print('*'*100)
    print('*'*100,'\n')
# Out:
# params_dir: ../data/training/models/All/RL/edit_rewards_1.0hidden_200
# num_hidden: 200
# edit_reward: -1.0
# # Train set size: 59400
# # Training batches: 297
# # Validation set size: 29800
# # Validation batches: 149
# # Test set size: 29600
# # Testing batches: 148
# Loading parameters from ../data/training/models/All/RL/edit_rewards_1.0hidden_200/model.ckpt-37
# INFO:tensorflow:Restoring parameters from ../data/training/models/All/RL/edit_rewards_1.0hidden_200/model.ckpt-37
# ==================================================
# TRAIN, ephoc:37; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:4455 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.749 ;Aloss:0.395 ;edits ratio:0.346 ;acc:0.640 ;iou:0.710 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:4455 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.728 ;Aloss:0.453 ;edits ratio:0.300 ;acc:0.610 ;iou:0.710 ;time: 0:00:10
# Edit: True ;batch:100 ;gs:4455 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.685 ;Aloss:0.468 ;edits ratio:0.308 ;acc:0.670 ;iou:0.710 ;time: 0:00:19
# Edit: True ;batch:150 ;gs:4455 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:2.218 ;Aloss:0.466 ;edits ratio:0.425 ;acc:0.355 ;iou:0.480 ;time: 0:00:29
# Edit: True ;batch:200 ;gs:4455 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:2.055 ;Aloss:0.444 ;edits ratio:0.433 ;acc:0.420 ;iou:0.555 ;time: 0:00:38
# Edit: True ;batch:250 ;gs:4455 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.909 ;Aloss:0.521 ;edits ratio:0.418 ;acc:0.725 ;iou:0.880 ;time: 0:00:49
#
# *B Train loss: 2.111 ;A Train loss: 0.445 ;Edit ratio: 0.372 ;Train accuracy: 0.469 ;IOU accuracy: 0.581 ;Time: 0:00:58
#
# VALIDATION, ephoc: 37
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.383 ;B loss: 3.262 ;A loss: 0.421 ;acc: 0.125 ;iou_acc: 0.245 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.409 ;B loss: 1.903 ;A loss: 0.452 ;acc: 0.500 ;iou_acc: 0.600 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.283 ;B loss: 1.654 ;A loss: 0.362 ;acc: 0.650 ;iou_acc: 0.740 ;time: 0:00:14
#
# *B loss: 2.136 ;A loss: 0.445 ;Edit ratio: 0.371 ;Accuracy 0.459 ;IOU accuracy: 0.574 ;Time: 0:00:22
#
# Random choice: True
# batch: 0 ;edits ratio: 0.376 ;B loss: 3.099 ;A loss: 0.567 ;acc: 0.255 ;iou_acc: 0.365 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.382 ;B loss: 1.789 ;A loss: 0.522 ;acc: 0.545 ;iou_acc: 0.660 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.357 ;B loss: 1.368 ;A loss: 0.638 ;acc: 0.675 ;iou_acc: 0.770 ;time: 0:00:15
#
# *B loss: 1.987 ;A loss: 0.578 ;Edit ratio: 0.372 ;Accuracy 0.531 ;IOU accuracy: 0.633 ;Time: 0:00:22
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.149 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:38; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:4455 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.928 ;Aloss:0.412 ;edits ratio:0.360 ;acc:0.480 ;iou:0.590 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:4455 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.595 ;Aloss:0.436 ;edits ratio:0.287 ;acc:0.745 ;iou:0.815 ;time: 0:00:10
# Edit: True ;batch:100 ;gs:4455 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.822 ;Aloss:0.404 ;edits ratio:0.329 ;acc:0.610 ;iou:0.690 ;time: 0:00:20
# Edit: True ;batch:150 ;gs:4455 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.938 ;Aloss:0.430 ;edits ratio:0.381 ;acc:0.455 ;iou:0.550 ;time: 0:00:29
# Edit: True ;batch:200 ;gs:4455 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:2.720 ;Aloss:0.403 ;edits ratio:0.346 ;acc:0.240 ;iou:0.390 ;time: 0:00:38
# Edit: True ;batch:250 ;gs:4455 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:2.514 ;Aloss:0.460 ;edits ratio:0.417 ;acc:0.280 ;iou:0.415 ;time: 0:00:48
#
# *B Train loss: 2.103 ;A Train loss: 0.441 ;Edit ratio: 0.364 ;Train accuracy: 0.475 ;IOU accuracy: 0.586 ;Time: 0:00:57
#
# VALIDATION, ephoc: 38
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.379 ;B loss: 3.267 ;A loss: 0.417 ;acc: 0.125 ;iou_acc: 0.245 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.393 ;B loss: 1.902 ;A loss: 0.446 ;acc: 0.505 ;iou_acc: 0.600 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.279 ;B loss: 1.651 ;A loss: 0.354 ;acc: 0.655 ;iou_acc: 0.740 ;time: 0:00:14
#
# *B loss: 2.129 ;A loss: 0.440 ;Edit ratio: 0.363 ;Accuracy 0.463 ;IOU accuracy: 0.578 ;Time: 0:00:22
#
# Random choice: True
# batch: 0 ;edits ratio: 0.336 ;B loss: 3.016 ;A loss: 0.565 ;acc: 0.310 ;iou_acc: 0.440 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.352 ;B loss: 1.802 ;A loss: 0.595 ;acc: 0.550 ;iou_acc: 0.670 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.378 ;B loss: 1.338 ;A loss: 0.541 ;acc: 0.720 ;iou_acc: 0.780 ;time: 0:00:15
#
# *B loss: 1.989 ;A loss: 0.576 ;Edit ratio: 0.364 ;Accuracy 0.529 ;IOU accuracy: 0.633 ;Time: 0:00:22
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.140 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:39; Training B:True; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:4456 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:2.604 ;Aloss:0.407 ;edits ratio:0.361 ;acc:0.250 ;iou:0.375 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:4506 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.598 ;Aloss:0.509 ;edits ratio:0.251 ;acc:0.705 ;iou:0.775 ;time: 0:00:14
# Edit: True ;batch:100 ;gs:4556 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.746 ;Aloss:0.424 ;edits ratio:0.283 ;acc:0.635 ;iou:0.705 ;time: 0:00:27
# Edit: True ;batch:150 ;gs:4606 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:2.180 ;Aloss:0.426 ;edits ratio:0.417 ;acc:0.405 ;iou:0.555 ;time: 0:00:41
# Edit: True ;batch:200 ;gs:4656 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:2.602 ;Aloss:0.396 ;edits ratio:0.370 ;acc:0.350 ;iou:0.515 ;time: 0:00:55
# Edit: False ;batch: 250 ;gs: 4706 ;Blr: 0.010 ;B loss: 1.313 ;acc: 0.780 ;iou: 0.840 ;time: 0:01:08
#
# *B Train loss: 2.048 ;A Train loss: 0.451 ;Edit ratio: 0.351 ;Train accuracy: 0.520 ;IOU accuracy: 0.626 ;Time: 0:01:22
#
# No Edit
# ooooooo
# Edit: False ;batch: 0 ;gs: 4752 ;Blr: 0.010 ;B loss: 2.136 ;acc: 0.525 ;iou: 0.690 ;time: 0:01:22
# Edit: False ;batch: 50 ;gs: 4752 ;Blr: 0.010 ;B loss: 1.271 ;acc: 0.855 ;iou: 0.915 ;time: 0:01:28
# Edit: False ;batch: 100 ;gs: 4752 ;Blr: 0.010 ;B loss: 1.347 ;acc: 0.780 ;iou: 0.840 ;time: 0:01:35
# Edit: False ;batch: 150 ;gs: 4752 ;Blr: 0.010 ;B loss: 1.759 ;acc: 0.665 ;iou: 0.775 ;time: 0:01:42
# Edit: False ;batch: 200 ;gs: 4752 ;Blr: 0.010 ;B loss: 2.109 ;acc: 0.585 ;iou: 0.750 ;time: 0:01:49
# Edit: False ;batch: 250 ;gs: 4752 ;Blr: 0.010 ;B loss: 1.307 ;acc: 0.770 ;iou: 0.830 ;time: 0:01:55
#
# *B Train loss: 1.650 ;Train accuracy: 0.722 ;IOU accuracy: 0.814 ;Time: 0:02:02
#
# TESTING, ephoc: 39
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.348 ;acc: 0.790 ;iou_acc: 0.865 ;time: 0:02:03
# batch: 50 ;B loss: 1.296 ;acc: 0.785 ;iou_acc: 0.830 ;time: 0:02:09
# batch: 100 ;B loss: 1.749 ;acc: 0.640 ;iou_acc: 0.760 ;time: 0:02:16
# batch: 150 ;B loss: 1.232 ;acc: 0.785 ;iou_acc: 0.865 ;time: 0:02:22
# batch: 200 ;B loss: 1.312 ;acc: 0.810 ;iou_acc: 0.860 ;time: 0:02:28
# batch: 250 ;B loss: 1.285 ;acc: 0.815 ;iou_acc: 0.880 ;time: 0:02:34
#
# *Test loss: 1.700 ;Test accuracy 0.694 ;IOU accuracy: 0.791 ;Time: 0:02:39
# ==================================================
#
# ==================================================
# TRAIN, ephoc:40; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:4752 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:2.151 ;Aloss:0.503 ;edits ratio:0.398 ;acc:0.435 ;iou:0.540 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:4752 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:2.285 ;Aloss:0.498 ;edits ratio:0.428 ;acc:0.435 ;iou:0.540 ;time: 0:00:11
# Edit: True ;batch:100 ;gs:4752 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:2.109 ;Aloss:0.468 ;edits ratio:0.412 ;acc:0.445 ;iou:0.535 ;time: 0:00:21
# Edit: True ;batch:150 ;gs:4752 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:2.316 ;Aloss:0.446 ;edits ratio:0.443 ;acc:0.385 ;iou:0.515 ;time: 0:00:30
# Edit: True ;batch:200 ;gs:4752 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.701 ;Aloss:0.502 ;edits ratio:0.298 ;acc:0.665 ;iou:0.735 ;time: 0:00:40
# Edit: True ;batch:250 ;gs:4752 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.627 ;Aloss:0.497 ;edits ratio:0.278 ;acc:0.710 ;iou:0.790 ;time: 0:00:50
#
# *B Train loss: 2.087 ;A Train loss: 0.460 ;Edit ratio: 0.371 ;Train accuracy: 0.499 ;IOU accuracy: 0.606 ;Time: 0:00:58
#
# VALIDATION, ephoc: 40
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.363 ;B loss: 3.166 ;A loss: 0.410 ;acc: 0.150 ;iou_acc: 0.310 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.419 ;B loss: 1.911 ;A loss: 0.480 ;acc: 0.450 ;iou_acc: 0.540 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.328 ;B loss: 1.688 ;A loss: 0.431 ;acc: 0.660 ;iou_acc: 0.730 ;time: 0:00:14
#
# *B loss: 2.122 ;A loss: 0.459 ;Edit ratio: 0.379 ;Accuracy 0.478 ;IOU accuracy: 0.590 ;Time: 0:00:21
#
# Random choice: True
# batch: 0 ;edits ratio: 0.368 ;B loss: 2.966 ;A loss: 0.589 ;acc: 0.270 ;iou_acc: 0.440 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.395 ;B loss: 1.788 ;A loss: 0.633 ;acc: 0.555 ;iou_acc: 0.650 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.409 ;B loss: 1.444 ;A loss: 0.614 ;acc: 0.675 ;iou_acc: 0.780 ;time: 0:00:14
#
# *B loss: 1.955 ;A loss: 0.604 ;Edit ratio: 0.377 ;Accuracy 0.540 ;IOU accuracy: 0.642 ;Time: 0:00:21
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.167 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:41; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:4752 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:2.166 ;Aloss:0.495 ;edits ratio:0.436 ;acc:0.480 ;iou:0.550 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:4752 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.756 ;Aloss:0.454 ;edits ratio:0.320 ;acc:0.540 ;iou:0.610 ;time: 0:00:09
# Edit: True ;batch:100 ;gs:4752 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.891 ;Aloss:0.541 ;edits ratio:0.438 ;acc:0.755 ;iou:0.885 ;time: 0:00:19
# Edit: True ;batch:150 ;gs:4752 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.704 ;Aloss:0.648 ;edits ratio:0.305 ;acc:0.700 ;iou:0.775 ;time: 0:00:28
# Edit: True ;batch:200 ;gs:4752 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.673 ;Aloss:0.514 ;edits ratio:0.360 ;acc:0.665 ;iou:0.755 ;time: 0:00:37
# Edit: True ;batch:250 ;gs:4752 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:2.034 ;Aloss:0.550 ;edits ratio:0.426 ;acc:0.425 ;iou:0.575 ;time: 0:00:47
#
# *B Train loss: 2.094 ;A Train loss: 0.464 ;Edit ratio: 0.379 ;Train accuracy: 0.494 ;IOU accuracy: 0.601 ;Time: 0:00:55
#
# VALIDATION, ephoc: 41
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.372 ;B loss: 3.176 ;A loss: 0.414 ;acc: 0.140 ;iou_acc: 0.295 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.440 ;B loss: 1.917 ;A loss: 0.489 ;acc: 0.435 ;iou_acc: 0.525 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.335 ;B loss: 1.687 ;A loss: 0.441 ;acc: 0.675 ;iou_acc: 0.740 ;time: 0:00:14
#
# *B loss: 2.128 ;A loss: 0.464 ;Edit ratio: 0.387 ;Accuracy 0.474 ;IOU accuracy: 0.586 ;Time: 0:00:21
#
# Random choice: True
# batch: 0 ;edits ratio: 0.410 ;B loss: 3.107 ;A loss: 0.569 ;acc: 0.230 ;iou_acc: 0.360 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.369 ;B loss: 1.764 ;A loss: 0.585 ;acc: 0.540 ;iou_acc: 0.630 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.330 ;B loss: 1.400 ;A loss: 0.593 ;acc: 0.725 ;iou_acc: 0.815 ;time: 0:00:14
#
# *B loss: 1.965 ;A loss: 0.609 ;Edit ratio: 0.390 ;Accuracy 0.534 ;IOU accuracy: 0.634 ;Time: 0:00:21
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.162 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:42; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:4752 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.624 ;Aloss:0.551 ;edits ratio:0.317 ;acc:0.680 ;iou:0.760 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:4752 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:2.183 ;Aloss:0.495 ;edits ratio:0.458 ;acc:0.395 ;iou:0.510 ;time: 0:00:09
# Edit: True ;batch:100 ;gs:4752 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:2.363 ;Aloss:0.470 ;edits ratio:0.401 ;acc:0.390 ;iou:0.500 ;time: 0:00:18
# Edit: True ;batch:150 ;gs:4752 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:3.758 ;Aloss:0.365 ;edits ratio:0.270 ;acc:0.115 ;iou:0.405 ;time: 0:00:28
# Edit: True ;batch:200 ;gs:4752 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:3.115 ;Aloss:0.428 ;edits ratio:0.337 ;acc:0.185 ;iou:0.385 ;time: 0:00:37
# Edit: True ;batch:250 ;gs:4752 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.724 ;Aloss:0.490 ;edits ratio:0.347 ;acc:0.645 ;iou:0.695 ;time: 0:00:46
#
# *B Train loss: 2.100 ;A Train loss: 0.468 ;Edit ratio: 0.386 ;Train accuracy: 0.490 ;IOU accuracy: 0.598 ;Time: 0:00:55
#
# VALIDATION, ephoc: 42
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.376 ;B loss: 3.193 ;A loss: 0.434 ;acc: 0.135 ;iou_acc: 0.285 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.445 ;B loss: 1.926 ;A loss: 0.501 ;acc: 0.430 ;iou_acc: 0.520 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.336 ;B loss: 1.687 ;A loss: 0.441 ;acc: 0.675 ;iou_acc: 0.740 ;time: 0:00:15
#
# *B loss: 2.130 ;A loss: 0.465 ;Edit ratio: 0.390 ;Accuracy 0.472 ;IOU accuracy: 0.584 ;Time: 0:00:22
#
# Random choice: True
# batch: 0 ;edits ratio: 0.369 ;B loss: 3.022 ;A loss: 0.572 ;acc: 0.285 ;iou_acc: 0.440 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.378 ;B loss: 1.659 ;A loss: 0.583 ;acc: 0.570 ;iou_acc: 0.685 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.406 ;B loss: 1.398 ;A loss: 0.673 ;acc: 0.675 ;iou_acc: 0.775 ;time: 0:00:13
#
# *B loss: 1.964 ;A loss: 0.607 ;Edit ratio: 0.389 ;Accuracy 0.537 ;IOU accuracy: 0.639 ;Time: 0:00:20
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.166 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:43; Training B:True; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:4753 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:3.758 ;Aloss:0.366 ;edits ratio:0.270 ;acc:0.115 ;iou:0.405 ;time: 0:00:01
# Edit: True ;batch:50 ;gs:4803 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:2.986 ;Aloss:0.424 ;edits ratio:0.352 ;acc:0.215 ;iou:0.405 ;time: 0:00:14
# Edit: True ;batch:100 ;gs:4853 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.603 ;Aloss:0.445 ;edits ratio:0.277 ;acc:0.730 ;iou:0.825 ;time: 0:00:28
# Edit: True ;batch:150 ;gs:4903 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:2.142 ;Aloss:0.542 ;edits ratio:0.432 ;acc:0.470 ;iou:0.595 ;time: 0:00:43
# Edit: True ;batch:200 ;gs:4953 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.982 ;Aloss:0.508 ;edits ratio:0.404 ;acc:0.490 ;iou:0.595 ;time: 0:00:56
# Edit: True ;batch:250 ;gs:5003 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.682 ;Aloss:0.439 ;edits ratio:0.342 ;acc:0.630 ;iou:0.700 ;time: 0:01:09
#
# *B Train loss: 2.073 ;A Train loss: 0.469 ;Edit ratio: 0.385 ;Train accuracy: 0.505 ;IOU accuracy: 0.611 ;Time: 0:01:22
#
# No Edit
# ooooooo
# Edit: False ;batch: 0 ;gs: 5049 ;Blr: 0.010 ;B loss: 3.367 ;acc: 0.310 ;iou: 0.585 ;time: 0:01:22
# Edit: False ;batch: 50 ;gs: 5049 ;Blr: 0.010 ;B loss: 2.541 ;acc: 0.465 ;iou: 0.670 ;time: 0:01:30
# Edit: False ;batch: 100 ;gs: 5049 ;Blr: 0.010 ;B loss: 1.270 ;acc: 0.870 ;iou: 0.935 ;time: 0:01:36
# Edit: False ;batch: 150 ;gs: 5049 ;Blr: 0.010 ;B loss: 1.557 ;acc: 0.755 ;iou: 0.865 ;time: 0:01:43
# Edit: False ;batch: 200 ;gs: 5049 ;Blr: 0.010 ;B loss: 1.462 ;acc: 0.770 ;iou: 0.855 ;time: 0:01:49
# Edit: False ;batch: 250 ;gs: 5049 ;Blr: 0.010 ;B loss: 1.201 ;acc: 0.870 ;iou: 0.905 ;time: 0:01:57
#
# *B Train loss: 1.653 ;Train accuracy: 0.721 ;IOU accuracy: 0.813 ;Time: 0:02:02
#
# TESTING, ephoc: 43
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.356 ;acc: 0.785 ;iou_acc: 0.865 ;time: 0:02:03
# batch: 50 ;B loss: 1.295 ;acc: 0.785 ;iou_acc: 0.830 ;time: 0:02:09
# batch: 100 ;B loss: 1.762 ;acc: 0.630 ;iou_acc: 0.760 ;time: 0:02:15
# batch: 150 ;B loss: 1.233 ;acc: 0.815 ;iou_acc: 0.870 ;time: 0:02:21
# batch: 200 ;B loss: 1.318 ;acc: 0.785 ;iou_acc: 0.840 ;time: 0:02:27
# batch: 250 ;B loss: 1.292 ;acc: 0.800 ;iou_acc: 0.865 ;time: 0:02:32
#
# *Test loss: 1.703 ;Test accuracy 0.693 ;IOU accuracy: 0.790 ;Time: 0:02:38
# ==================================================
#
# ==================================================
# TRAIN, ephoc:44; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:5049 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:2.223 ;Aloss:0.485 ;edits ratio:0.445 ;acc:0.350 ;iou:0.455 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:5049 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:2.615 ;Aloss:0.488 ;edits ratio:0.407 ;acc:0.300 ;iou:0.505 ;time: 0:00:09
# Edit: True ;batch:100 ;gs:5049 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.694 ;Aloss:0.451 ;edits ratio:0.335 ;acc:0.625 ;iou:0.705 ;time: 0:00:20
# Edit: True ;batch:150 ;gs:5049 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:1.813 ;Aloss:0.529 ;edits ratio:0.421 ;acc:0.735 ;iou:0.880 ;time: 0:00:29
# Edit: True ;batch:200 ;gs:5049 ;Blr: 0.010 ;Alr:0.001 ;ERP:0.00 ;Bloss:2.366 ;Aloss:0.514 ;edits ratio:0.421 ;acc:0.355 ;iou:0.455 ;time: 0:00:40
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-d41aac66ccbb> in <module>()
#      33                                     Blr=.01,
#      34                                     Alr=.001,
# ---> 35                                     imScale=1/50)
#      36     edit_rewards_tst.append(tst)
#      37     edit_rewards_trn.append(trn)
#
# <ipython-input-21-2d842de3e10a> in train(self, trn_data, tst_data, val_data, ephocs_num, edit_reward, startA, activation_ephoc, muteBnum, start_ephoc, dropout_in, rnn_editProb, dropout_out, dropout_img, dropout_q, queries_editProb, addNoiseImg, imScale, Alr, Blr)
#     977                                 gs, scores, batch_Alr, batch_Blr, B_loss, batch_edit_ratio, A_loss, _ = sess.run(
#     978                                     [self.global_step, self.scores, self.A_learning_rate, self.learning_rate,
# --> 979                                          self.B_loss, self.edit_ratio, self.A_loss, self.A_optimizer], feed_dict=feed_dict)
#     980
#     981
#
# /home/asi/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/asi/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# /home/asi/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/asi/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# /home/asi/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
num_hidden=200
edit_rewards = [-1., -.9, -.8, -0.7, -0.6]
edit_rewards_tst, edit_rewards_trn, edit_rewards_val, edit_rewards_AGain = [], [], [], []

for edit_reward in edit_rewards:
    params_dir = params_dir_tmp+'RL/edit_rewards_'+str(-1*edit_reward)+'hidden_'+str(num_hidden)
    tf.reset_default_graph()
    m = Model(
        batch_size=200, 
        num_hidden=num_hidden,
        embed_size=embed_vecs.shape[1],
        img_dims=trainset[0][0][1][0].shape[1], 
        bbox_dims=trainset[0][0][1][1].shape[1], 
        vocab=vocab, 
        decay_steps=10000, 
        decay_rate=0.9, 
        bnorm=False,
        toQscale=True
    )

    print('params_dir:', params_dir)
    print('num_hidden:', m.num_hidden)
    print('edit_reward:', edit_reward)
    act_rewards, BCE, bell_val, idx = m.train(trainset, testset, valset,
                                    ephocs_num=200,
                                    start_ephoc=29,
                                    startA=8,
                                    activation_ephoc=12,
                                    muteBnum=3, 
                                    queries_editProb=0.95,
                                    edit_reward=edit_reward,
                                    rnn_editProb=0.2,
                                    Blr=.1,
                                    Alr=.01,
                                    imScale=1/50)
    edit_rewards_tst.append(tst) 
    edit_rewards_trn.append(trn)
    edit_rewards_val.append(val) 
    edit_rewards_AGain.append(AGain)

    print('\n'+'*'*100)
    print('*'*100)
    print('*'*100,'\n')
# Out:
# params_dir: ../data/training/models/All/RL/edit_rewards_1.0hidden_200
# num_hidden: 200
# edit_reward: -1.0
# # Train set size: 59400
# # Training batches: 297
# # Validation set size: 29800
# # Validation batches: 149
# # Test set size: 29600
# # Testing batches: 148
# Loading parameters from ../data/training/models/All/RL/edit_rewards_1.0hidden_200/model.ckpt-28
# INFO:tensorflow:Restoring parameters from ../data/training/models/All/RL/edit_rewards_1.0hidden_200/model.ckpt-28
# ==================================================
# TRAIN, ephoc:29; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:3861 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:2.344 ;Aloss:0.412 ;edits ratio:0.349 ;acc:0.380 ;iou:0.490 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:3861 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:2.237 ;Aloss:0.531 ;edits ratio:0.465 ;acc:0.350 ;iou:0.445 ;time: 0:00:10
# Edit: True ;batch:100 ;gs:3861 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:3.191 ;Aloss:0.402 ;edits ratio:0.337 ;acc:0.180 ;iou:0.375 ;time: 0:00:20
# Edit: True ;batch:150 ;gs:3861 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:2.574 ;Aloss:0.403 ;edits ratio:0.413 ;acc:0.270 ;iou:0.420 ;time: 0:00:29
# Edit: True ;batch:200 ;gs:3861 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:2.763 ;Aloss:0.435 ;edits ratio:0.382 ;acc:0.265 ;iou:0.400 ;time: 0:00:39
# Edit: True ;batch:250 ;gs:3861 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:1.781 ;Aloss:0.533 ;edits ratio:0.467 ;acc:0.770 ;iou:0.915 ;time: 0:00:49
#
# *B Train loss: 2.126 ;A Train loss: 0.479 ;Edit ratio: 0.377 ;Train accuracy: 0.477 ;IOU accuracy: 0.584 ;Time: 0:00:58
#
# VALIDATION, ephoc: 29
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.375 ;B loss: 3.228 ;A loss: 0.412 ;acc: 0.155 ;iou_acc: 0.260 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.402 ;B loss: 1.937 ;A loss: 0.470 ;acc: 0.455 ;iou_acc: 0.560 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.321 ;B loss: 1.650 ;A loss: 0.500 ;acc: 0.690 ;iou_acc: 0.750 ;time: 0:00:15
#
# *B loss: 2.143 ;A loss: 0.473 ;Edit ratio: 0.375 ;Accuracy 0.467 ;IOU accuracy: 0.576 ;Time: 0:00:22
#
# Random choice: True
# batch: 0 ;edits ratio: 0.398 ;B loss: 3.102 ;A loss: 0.532 ;acc: 0.260 ;iou_acc: 0.395 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.364 ;B loss: 1.766 ;A loss: 0.578 ;acc: 0.525 ;iou_acc: 0.635 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.387 ;B loss: 1.422 ;A loss: 0.669 ;acc: 0.690 ;iou_acc: 0.760 ;time: 0:00:15
#
# *B loss: 1.976 ;A loss: 0.586 ;Edit ratio: 0.376 ;Accuracy 0.523 ;IOU accuracy: 0.623 ;Time: 0:00:22
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.166 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:30; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:3861 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:2.163 ;Aloss:0.491 ;edits ratio:0.467 ;acc:0.340 ;iou:0.415 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:3861 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:3.158 ;Aloss:0.341 ;edits ratio:0.388 ;acc:0.220 ;iou:0.360 ;time: 0:00:10
# Edit: True ;batch:100 ;gs:3861 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:2.749 ;Aloss:0.418 ;edits ratio:0.430 ;acc:0.290 ;iou:0.455 ;time: 0:00:19
# Edit: True ;batch:150 ;gs:3861 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:3.050 ;Aloss:0.348 ;edits ratio:0.352 ;acc:0.240 ;iou:0.425 ;time: 0:00:30
# Edit: True ;batch:200 ;gs:3861 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:2.411 ;Aloss:0.429 ;edits ratio:0.452 ;acc:0.335 ;iou:0.460 ;time: 0:00:38
# Edit: True ;batch:250 ;gs:3861 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:2.742 ;Aloss:0.388 ;edits ratio:0.352 ;acc:0.320 ;iou:0.505 ;time: 0:00:48
#
# *B Train loss: 2.132 ;A Train loss: 0.481 ;Edit ratio: 0.382 ;Train accuracy: 0.474 ;IOU accuracy: 0.581 ;Time: 0:00:56
#
# VALIDATION, ephoc: 30
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.398 ;B loss: 3.273 ;A loss: 0.435 ;acc: 0.145 ;iou_acc: 0.245 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.446 ;B loss: 1.949 ;A loss: 0.507 ;acc: 0.420 ;iou_acc: 0.525 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.330 ;B loss: 1.649 ;A loss: 0.509 ;acc: 0.690 ;iou_acc: 0.750 ;time: 0:00:15
#
# *B loss: 2.158 ;A loss: 0.485 ;Edit ratio: 0.394 ;Accuracy 0.455 ;IOU accuracy: 0.565 ;Time: 0:00:22
#
# Random choice: True
# batch: 0 ;edits ratio: 0.413 ;B loss: 3.113 ;A loss: 0.570 ;acc: 0.270 ;iou_acc: 0.385 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.333 ;B loss: 1.777 ;A loss: 0.581 ;acc: 0.555 ;iou_acc: 0.640 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.374 ;B loss: 1.390 ;A loss: 0.612 ;acc: 0.680 ;iou_acc: 0.735 ;time: 0:00:14
#
# *B loss: 1.989 ;A loss: 0.600 ;Edit ratio: 0.390 ;Accuracy 0.520 ;IOU accuracy: 0.621 ;Time: 0:00:21
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.169 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:31; Training B:True; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:3862 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:1.931 ;Aloss:0.490 ;edits ratio:0.415 ;acc:0.495 ;iou:0.585 ;time: 0:00:01
# Edit: True ;batch:50 ;gs:3912 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:1.822 ;Aloss:0.492 ;edits ratio:0.394 ;acc:0.760 ;iou:0.855 ;time: 0:00:15
# Edit: True ;batch:100 ;gs:3962 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:1.733 ;Aloss:0.479 ;edits ratio:0.326 ;acc:0.615 ;iou:0.685 ;time: 0:00:27
# Edit: False ;batch: 150 ;gs: 4012 ;Blr: 0.100 ;B loss: 2.147 ;acc: 0.590 ;iou: 0.730 ;time: 0:00:41
# Edit: True ;batch:200 ;gs:4062 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:1.985 ;Aloss:0.448 ;edits ratio:0.380 ;acc:0.460 ;iou:0.585 ;time: 0:00:55
# Edit: True ;batch:250 ;gs:4112 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:1.745 ;Aloss:0.620 ;edits ratio:0.314 ;acc:0.625 ;iou:0.675 ;time: 0:01:09
#
# *B Train loss: 2.096 ;A Train loss: 0.453 ;Edit ratio: 0.355 ;Train accuracy: 0.488 ;IOU accuracy: 0.598 ;Time: 0:01:21
#
# No Edit
# ooooooo
# Edit: False ;batch: 0 ;gs: 4158 ;Blr: 0.100 ;B loss: 1.344 ;acc: 0.730 ;iou: 0.800 ;time: 0:01:22
# Edit: False ;batch: 50 ;gs: 4158 ;Blr: 0.100 ;B loss: 1.988 ;acc: 0.865 ;iou: 0.905 ;time: 0:01:28
# Edit: False ;batch: 100 ;gs: 4158 ;Blr: 0.100 ;B loss: 1.293 ;acc: 0.825 ;iou: 0.890 ;time: 0:01:35
# Edit: False ;batch: 150 ;gs: 4158 ;Blr: 0.100 ;B loss: 2.183 ;acc: 0.515 ;iou: 0.680 ;time: 0:01:42
# Edit: False ;batch: 200 ;gs: 4158 ;Blr: 0.100 ;B loss: 1.476 ;acc: 0.685 ;iou: 0.750 ;time: 0:01:49
# Edit: False ;batch: 250 ;gs: 4158 ;Blr: 0.100 ;B loss: 1.265 ;acc: 0.820 ;iou: 0.850 ;time: 0:01:56
#
# *B Train loss: 1.690 ;Train accuracy: 0.681 ;IOU accuracy: 0.779 ;Time: 0:02:03
#
# TESTING, ephoc: 31
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.364 ;acc: 0.755 ;iou_acc: 0.815 ;time: 0:02:04
# batch: 50 ;B loss: 1.330 ;acc: 0.755 ;iou_acc: 0.805 ;time: 0:02:10
# batch: 100 ;B loss: 1.810 ;acc: 0.565 ;iou_acc: 0.695 ;time: 0:02:16
# batch: 150 ;B loss: 1.285 ;acc: 0.805 ;iou_acc: 0.870 ;time: 0:02:22
# batch: 200 ;B loss: 1.323 ;acc: 0.780 ;iou_acc: 0.830 ;time: 0:02:28
# batch: 250 ;B loss: 1.316 ;acc: 0.805 ;iou_acc: 0.865 ;time: 0:02:34
#
# *Test loss: 1.737 ;Test accuracy 0.659 ;IOU accuracy: 0.760 ;Time: 0:02:39
# ==================================================
#
# ==================================================
# TRAIN, ephoc:32; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:4158 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:1.708 ;Aloss:0.496 ;edits ratio:0.298 ;acc:0.605 ;iou:0.700 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:4158 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:1.719 ;Aloss:0.439 ;edits ratio:0.350 ;acc:0.655 ;iou:0.735 ;time: 0:00:10
# Edit: True ;batch:100 ;gs:4158 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:1.818 ;Aloss:0.446 ;edits ratio:0.357 ;acc:0.585 ;iou:0.640 ;time: 0:00:19
# Edit: True ;batch:150 ;gs:4158 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:1.805 ;Aloss:0.485 ;edits ratio:0.356 ;acc:0.605 ;iou:0.695 ;time: 0:00:29
# Edit: True ;batch:200 ;gs:4158 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:2.667 ;Aloss:0.357 ;edits ratio:0.371 ;acc:0.300 ;iou:0.425 ;time: 0:00:38
# Edit: True ;batch:250 ;gs:4158 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:1.712 ;Aloss:0.422 ;edits ratio:0.345 ;acc:0.660 ;iou:0.745 ;time: 0:00:47
#
# *B Train loss: 2.161 ;A Train loss: 0.429 ;Edit ratio: 0.367 ;Train accuracy: 0.464 ;IOU accuracy: 0.573 ;Time: 0:00:57
#
# VALIDATION, ephoc: 32
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.323 ;B loss: 3.197 ;A loss: 0.347 ;acc: 0.165 ;iou_acc: 0.325 ;time: 0:00:01
# batch: 50 ;edits ratio: 0.362 ;B loss: 1.972 ;A loss: 0.437 ;acc: 0.450 ;iou_acc: 0.560 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.318 ;B loss: 1.743 ;A loss: 0.447 ;acc: 0.645 ;iou_acc: 0.705 ;time: 0:00:14
#
# *B loss: 2.181 ;A loss: 0.421 ;Edit ratio: 0.362 ;Accuracy 0.458 ;IOU accuracy: 0.570 ;Time: 0:00:21
#
# Random choice: True
# batch: 0 ;edits ratio: 0.323 ;B loss: 3.064 ;A loss: 0.596 ;acc: 0.290 ;iou_acc: 0.430 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.404 ;B loss: 1.872 ;A loss: 0.616 ;acc: 0.505 ;iou_acc: 0.610 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.364 ;B loss: 1.472 ;A loss: 0.666 ;acc: 0.660 ;iou_acc: 0.750 ;time: 0:00:13
#
# *B loss: 1.993 ;A loss: 0.611 ;Edit ratio: 0.360 ;Accuracy 0.516 ;IOU accuracy: 0.616 ;Time: 0:00:20
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.189 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:33; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:4158 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:1.996 ;Aloss:0.493 ;edits ratio:0.441 ;acc:0.785 ;iou:0.875 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:4158 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:1.662 ;Aloss:0.478 ;edits ratio:0.329 ;acc:0.685 ;iou:0.750 ;time: 0:00:10
# Edit: True ;batch:100 ;gs:4158 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:2.913 ;Aloss:0.391 ;edits ratio:0.350 ;acc:0.195 ;iou:0.405 ;time: 0:00:19
# Edit: True ;batch:150 ;gs:4158 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:2.090 ;Aloss:0.493 ;edits ratio:0.415 ;acc:0.420 ;iou:0.540 ;time: 0:00:28
# Edit: True ;batch:200 ;gs:4158 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:1.882 ;Aloss:0.360 ;edits ratio:0.371 ;acc:0.500 ;iou:0.630 ;time: 0:00:39
# Edit: True ;batch:250 ;gs:4158 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:2.564 ;Aloss:0.432 ;edits ratio:0.396 ;acc:0.310 ;iou:0.450 ;time: 0:00:48
#
# *B Train loss: 2.167 ;A Train loss: 0.431 ;Edit ratio: 0.372 ;Train accuracy: 0.459 ;IOU accuracy: 0.569 ;Time: 0:00:56
#
# VALIDATION, ephoc: 33
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.378 ;B loss: 3.272 ;A loss: 0.367 ;acc: 0.140 ;iou_acc: 0.285 ;time: 0:00:01
# batch: 50 ;edits ratio: 0.438 ;B loss: 2.026 ;A loss: 0.495 ;acc: 0.405 ;iou_acc: 0.520 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.352 ;B loss: 1.746 ;A loss: 0.482 ;acc: 0.635 ;iou_acc: 0.700 ;time: 0:00:14
#
# *B loss: 2.216 ;A loss: 0.445 ;Edit ratio: 0.402 ;Accuracy 0.435 ;IOU accuracy: 0.548 ;Time: 0:00:22
#
# Random choice: True
# batch: 0 ;edits ratio: 0.383 ;B loss: 3.002 ;A loss: 0.623 ;acc: 0.305 ;iou_acc: 0.460 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.407 ;B loss: 1.833 ;A loss: 0.649 ;acc: 0.510 ;iou_acc: 0.600 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.421 ;B loss: 1.475 ;A loss: 0.691 ;acc: 0.635 ;iou_acc: 0.715 ;time: 0:00:14
#
# *B loss: 2.020 ;A loss: 0.639 ;Edit ratio: 0.403 ;Accuracy 0.502 ;IOU accuracy: 0.603 ;Time: 0:00:21
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.196 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:34; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:4158 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:3.055 ;Aloss:0.356 ;edits ratio:0.369 ;acc:0.230 ;iou:0.405 ;time: 0:00:01
# Edit: True ;batch:50 ;gs:4158 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:2.344 ;Aloss:0.500 ;edits ratio:0.451 ;acc:0.310 ;iou:0.480 ;time: 0:00:10
# Edit: True ;batch:100 ;gs:4158 ;Blr: 0.100 ;Alr:0.010 ;ERP:0.00 ;Bloss:1.986 ;Aloss:0.395 ;edits ratio:0.389 ;acc:0.465 ;iou:0.550 ;time: 0:00:20
# Edit: True ;batch:150 ;gs:4158 ;Blr: 0.100 ;Alr:0.009 ;ERP:0.00 ;Bloss:1.733 ;Aloss:0.417 ;edits ratio:0.349 ;acc:0.640 ;iou:0.690 ;time: 0:00:29
# Edit: True ;batch:200 ;gs:4158 ;Blr: 0.100 ;Alr:0.009 ;ERP:0.00 ;Bloss:2.344 ;Aloss:0.378 ;edits ratio:0.411 ;acc:0.355 ;iou:0.490 ;time: 0:00:38
# Edit: True ;batch:250 ;gs:4158 ;Blr: 0.100 ;Alr:0.009 ;ERP:0.00 ;Bloss:1.820 ;Aloss:0.525 ;edits ratio:0.343 ;acc:0.590 ;iou:0.680 ;time: 0:00:48
#
# *B Train loss: 2.180 ;A Train loss: 0.436 ;Edit ratio: 0.385 ;Train accuracy: 0.451 ;IOU accuracy: 0.561 ;Time: 0:00:57
#
# VALIDATION, ephoc: 34
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.351 ;B loss: 3.243 ;A loss: 0.351 ;acc: 0.150 ;iou_acc: 0.300 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.390 ;B loss: 2.006 ;A loss: 0.468 ;acc: 0.440 ;iou_acc: 0.560 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.328 ;B loss: 1.741 ;A loss: 0.453 ;acc: 0.635 ;iou_acc: 0.705 ;time: 0:00:15
#
# *B loss: 2.193 ;A loss: 0.426 ;Edit ratio: 0.374 ;Accuracy 0.451 ;IOU accuracy: 0.563 ;Time: 0:00:22
#
# Random choice: True
# batch: 0 ;edits ratio: 0.344 ;B loss: 3.006 ;A loss: 0.628 ;acc: 0.265 ;iou_acc: 0.435 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.390 ;B loss: 1.796 ;A loss: 0.623 ;acc: 0.535 ;iou_acc: 0.640 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.344 ;B loss: 1.413 ;A loss: 0.722 ;acc: 0.675 ;iou_acc: 0.765 ;time: 0:00:15
#
# *B loss: 1.998 ;A loss: 0.627 ;Edit ratio: 0.375 ;Accuracy 0.513 ;IOU accuracy: 0.616 ;Time: 0:00:22
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.196 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:35; Training B:True; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:4159 ;Blr: 0.100 ;Alr:0.009 ;ERP:0.00 ;Bloss:3.012 ;Aloss:0.350 ;edits ratio:0.359 ;acc:0.200 ;iou:0.365 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:4209 ;Blr: 0.100 ;Alr:0.009 ;ERP:0.00 ;Bloss:2.261 ;Aloss:0.457 ;edits ratio:0.460 ;acc:0.360 ;iou:0.505 ;time: 0:00:14
# Edit: True ;batch:100 ;gs:4259 ;Blr: 0.100 ;Alr:0.009 ;ERP:0.00 ;Bloss:1.672 ;Aloss:0.412 ;edits ratio:0.285 ;acc:0.725 ;iou:0.785 ;time: 0:00:27
# Edit: True ;batch:150 ;gs:4309 ;Blr: 0.100 ;Alr:0.009 ;ERP:0.00 ;Bloss:2.382 ;Aloss:0.482 ;edits ratio:0.419 ;acc:0.345 ;iou:0.480 ;time: 0:00:40
# Edit: True ;batch:200 ;gs:4359 ;Blr: 0.100 ;Alr:0.009 ;ERP:0.00 ;Bloss:1.744 ;Aloss:0.492 ;edits ratio:0.346 ;acc:0.600 ;iou:0.690 ;time: 0:00:53
# Edit: True ;batch:250 ;gs:4409 ;Blr: 0.100 ;Alr:0.009 ;ERP:0.00 ;Bloss:2.203 ;Aloss:0.521 ;edits ratio:0.423 ;acc:0.415 ;iou:0.495 ;time: 0:01:06
#
# *B Train loss: 2.099 ;A Train loss: 0.463 ;Edit ratio: 0.381 ;Train accuracy: 0.486 ;IOU accuracy: 0.595 ;Time: 0:01:17
#
# No Edit
# ooooooo
# Edit: False ;batch: 0 ;gs: 4455 ;Blr: 0.100 ;B loss: 2.511 ;acc: 0.475 ;iou: 0.625 ;time: 0:01:17
# Edit: False ;batch: 50 ;gs: 4455 ;Blr: 0.100 ;B loss: 1.821 ;acc: 0.635 ;iou: 0.755 ;time: 0:01:23
# Edit: False ;batch: 100 ;gs: 4455 ;Blr: 0.100 ;B loss: 1.311 ;acc: 0.855 ;iou: 0.885 ;time: 0:01:30
# Edit: False ;batch: 150 ;gs: 4455 ;Blr: 0.100 ;B loss: 1.959 ;acc: 0.555 ;iou: 0.685 ;time: 0:01:36
# Edit: False ;batch: 200 ;gs: 4455 ;Blr: 0.100 ;B loss: 1.300 ;acc: 0.770 ;iou: 0.840 ;time: 0:01:43
# Edit: False ;batch: 250 ;gs: 4455 ;Blr: 0.100 ;B loss: 1.797 ;acc: 0.620 ;iou: 0.730 ;time: 0:01:50
#
# *B Train loss: 1.699 ;Train accuracy: 0.696 ;IOU accuracy: 0.790 ;Time: 0:01:55
#
# TESTING, ephoc: 35
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.382 ;acc: 0.765 ;iou_acc: 0.850 ;time: 0:01:56
# batch: 50 ;B loss: 1.332 ;acc: 0.765 ;iou_acc: 0.815 ;time: 0:02:02
# batch: 100 ;B loss: 1.783 ;acc: 0.590 ;iou_acc: 0.730 ;time: 0:02:07
# batch: 150 ;B loss: 1.237 ;acc: 0.770 ;iou_acc: 0.870 ;time: 0:02:13
# batch: 200 ;B loss: 1.329 ;acc: 0.780 ;iou_acc: 0.830 ;time: 0:02:19
# batch: 250 ;B loss: 1.304 ;acc: 0.805 ;iou_acc: 0.860 ;time: 0:02:25
#
# *Test loss: 1.744 ;Test accuracy 0.671 ;IOU accuracy: 0.770 ;Time: 0:02:30
# ==================================================
#
# ==================================================
# TRAIN, ephoc:36; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:4455 ;Blr: 0.100 ;Alr:0.009 ;ERP:0.00 ;Bloss:1.861 ;Aloss:0.552 ;edits ratio:0.506 ;acc:0.745 ;iou:0.860 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:4455 ;Blr: 0.100 ;Alr:0.009 ;ERP:0.00 ;Bloss:2.273 ;Aloss:0.441 ;edits ratio:0.435 ;acc:0.405 ;iou:0.500 ;time: 0:00:09
# Edit: True ;batch:100 ;gs:4455 ;Blr: 0.100 ;Alr:0.009 ;ERP:0.00 ;Bloss:3.080 ;Aloss:0.311 ;edits ratio:0.333 ;acc:0.230 ;iou:0.375 ;time: 0:00:18
# Edit: True ;batch:150 ;gs:4455 ;Blr: 0.100 ;Alr:0.009 ;ERP:0.00 ;Bloss:2.347 ;Aloss:0.453 ;edits ratio:0.356 ;acc:0.390 ;iou:0.535 ;time: 0:00:27
# Edit: True ;batch:200 ;gs:4455 ;Blr: 0.100 ;Alr:0.009 ;ERP:0.00 ;Bloss:1.742 ;Aloss:0.428 ;edits ratio:0.317 ;acc:0.640 ;iou:0.690 ;time: 0:00:36
# Edit: True ;batch:250 ;gs:4455 ;Blr: 0.100 ;Alr:0.009 ;ERP:0.00 ;Bloss:2.826 ;Aloss:0.360 ;edits ratio:0.354 ;acc:0.250 ;iou:0.375 ;time: 0:00:45
#
# *B Train loss: 2.097 ;A Train loss: 0.439 ;Edit ratio: 0.359 ;Train accuracy: 0.478 ;IOU accuracy: 0.589 ;Time: 0:00:53
#
# VALIDATION, ephoc: 36
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.395 ;B loss: 3.267 ;A loss: 0.424 ;acc: 0.125 ;iou_acc: 0.240 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.434 ;B loss: 1.922 ;A loss: 0.467 ;acc: 0.470 ;iou_acc: 0.570 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.292 ;B loss: 1.655 ;A loss: 0.370 ;acc: 0.650 ;iou_acc: 0.740 ;time: 0:00:13
#
# *B loss: 2.146 ;A loss: 0.454 ;Edit ratio: 0.384 ;Accuracy 0.450 ;IOU accuracy: 0.566 ;Time: 0:00:20
#
# Random choice: True
# batch: 0 ;edits ratio: 0.399 ;B loss: 3.071 ;A loss: 0.542 ;acc: 0.315 ;iou_acc: 0.410 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.382 ;B loss: 1.804 ;A loss: 0.635 ;acc: 0.535 ;iou_acc: 0.615 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.404 ;B loss: 1.399 ;A loss: 0.624 ;acc: 0.695 ;iou_acc: 0.765 ;time: 0:00:14
#
# *B loss: 2.000 ;A loss: 0.581 ;Edit ratio: 0.383 ;Accuracy 0.523 ;IOU accuracy: 0.624 ;Time: 0:00:21
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.146 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:37; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:4455 ;Blr: 0.100 ;Alr:0.009 ;ERP:0.00 ;Bloss:2.094 ;Aloss:0.496 ;edits ratio:0.454 ;acc:0.380 ;iou:0.470 ;time: 0:00:01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-27e310d399f7> in <module>()
#      33                                     Blr=.1,
#      34                                     Alr=.01,
# ---> 35                                     imScale=1/50)
#      36     edit_rewards_tst.append(tst)
#      37     edit_rewards_trn.append(trn)
#
# <ipython-input-21-2d842de3e10a> in train(self, trn_data, tst_data, val_data, ephocs_num, edit_reward, startA, activation_ephoc, muteBnum, start_ephoc, dropout_in, rnn_editProb, dropout_out, dropout_img, dropout_q, queries_editProb, addNoiseImg, imScale, Alr, Blr)
#     914                                                                                             self.batch_size,
#     915                                                                                             addNoiseImg=addNoiseImg,
# --> 916                                                                                             imScale=imScale)
#     917
#     918                         feed_dict = {
#
# <ipython-input-21-2d842de3e10a> in build_data(self, data, start, end, imScale, addNoiseImg)
#     538
#     539             padded_im.append(np.concatenate([data[i][j][0] for j in range(1, len(data[i])-1)] +
# --> 540                                        [np.full((imlen-(len(data[i])-2), im_dim), vocab['<pad>'], dtype=np.float32)], axis=0))
#     541
#     542             padded_bbox.append(np.concatenate([data[i][j][1] for j in range(1, len(data[i])-1)] +
#
# KeyboardInterrupt:

# %%
num_hidden=200
edit_rewards = [-1., -.9, -.8, -0.7, -0.6]
edit_rewards_tst, edit_rewards_trn, edit_rewards_val, edit_rewards_AGain = [], [], [], []

for edit_reward in edit_rewards:
    params_dir = params_dir_tmp+'RL/edit_rewards_'+str(-1*edit_reward)+'hidden_'+str(num_hidden)
    tf.reset_default_graph()
    m = Model(
        batch_size=200, 
        num_hidden=num_hidden,
        embed_size=embed_vecs.shape[1],
        img_dims=trainset[0][0][1][0].shape[1], 
        bbox_dims=trainset[0][0][1][1].shape[1], 
        vocab=vocab, 
        decay_steps=10000, 
        decay_rate=0.9, 
        bnorm=False,
        toQscale=True
    )

    print('params_dir:', params_dir)
    print('num_hidden:', m.num_hidden)
    print('edit_reward:', edit_reward)
    act_rewards, BCE, bell_val, idx = m.train(trainset, testset, valset,
                                    ephocs_num=200,
                                    start_ephoc=25,
                                    startA=8,
                                    activation_ephoc=12,
                                    muteBnum=3, 
                                    queries_editProb=0.95,
                                    edit_reward=edit_reward,
                                    rnn_editProb=0.2,
                                    Blr=.05,
                                    Alr=.5,
                                    imScale=1/50)
    edit_rewards_tst.append(tst) 
    edit_rewards_trn.append(trn)
    edit_rewards_val.append(val) 
    edit_rewards_AGain.append(AGain)

    print('\n'+'*'*100)
    print('*'*100)
    print('*'*100,'\n')
# Out:
# params_dir: ../data/training/models/All/RL/edit_rewards_1.0hidden_200
# num_hidden: 200
# edit_reward: -1.0
# # Train set size: 59400
# # Training batches: 297
# # Validation set size: 29800
# # Validation batches: 149
# # Test set size: 29600
# # Testing batches: 148
# Loading parameters from ../data/training/models/All/RL/edit_rewards_1.0hidden_200/model.ckpt-24
# INFO:tensorflow:Restoring parameters from ../data/training/models/All/RL/edit_rewards_1.0hidden_200/model.ckpt-24
# ==================================================
# TRAIN, ephoc:25; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:3564 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.10 ;Bloss:1.974 ;Aloss:0.493 ;edits ratio:0.347 ;acc:0.555 ;iou:0.665 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:3564 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.10 ;Bloss:3.057 ;Aloss:0.419 ;edits ratio:0.234 ;acc:0.280 ;iou:0.525 ;time: 0:00:10
# Edit: True ;batch:100 ;gs:3564 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.10 ;Bloss:2.196 ;Aloss:0.586 ;edits ratio:0.513 ;acc:0.405 ;iou:0.500 ;time: 0:00:20
# Edit: True ;batch:150 ;gs:3564 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.10 ;Bloss:1.885 ;Aloss:0.485 ;edits ratio:0.179 ;acc:0.590 ;iou:0.745 ;time: 0:00:30
# Edit: True ;batch:200 ;gs:3564 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.10 ;Bloss:2.441 ;Aloss:0.389 ;edits ratio:0.143 ;acc:0.465 ;iou:0.660 ;time: 0:00:39
# Edit: True ;batch:250 ;gs:3564 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.10 ;Bloss:2.145 ;Aloss:0.507 ;edits ratio:0.461 ;acc:0.385 ;iou:0.455 ;time: 0:00:49
#
# *B Train loss: 2.055 ;A Train loss: 0.504 ;Edit ratio: 0.326 ;Train accuracy: 0.513 ;IOU accuracy: 0.620 ;Time: 0:00:57
#
# VALIDATION, ephoc: 25
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.187 ;B loss: 2.924 ;A loss: 0.427 ;acc: 0.325 ;iou_acc: 0.480 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.170 ;B loss: 1.781 ;A loss: 0.455 ;acc: 0.625 ;iou_acc: 0.710 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.230 ;B loss: 1.612 ;A loss: 0.501 ;acc: 0.725 ;iou_acc: 0.790 ;time: 0:00:14
#
# *B loss: 1.966 ;A loss: 0.470 ;Edit ratio: 0.184 ;Accuracy 0.586 ;IOU accuracy: 0.685 ;Time: 0:00:21
#
# Random choice: True
# batch: 0 ;edits ratio: 0.194 ;B loss: 2.870 ;A loss: 0.654 ;acc: 0.330 ;iou_acc: 0.495 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.216 ;B loss: 1.664 ;A loss: 0.597 ;acc: 0.605 ;iou_acc: 0.720 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.209 ;B loss: 1.361 ;A loss: 0.732 ;acc: 0.740 ;iou_acc: 0.805 ;time: 0:00:15
#
# *B loss: 1.830 ;A loss: 0.618 ;Edit ratio: 0.186 ;Accuracy 0.619 ;IOU accuracy: 0.719 ;Time: 0:00:22
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.136 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:26; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:3564 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.10 ;Bloss:1.598 ;Aloss:0.779 ;edits ratio:0.201 ;acc:0.755 ;iou:0.800 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:3564 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.10 ;Bloss:2.666 ;Aloss:0.419 ;edits ratio:0.253 ;acc:0.315 ;iou:0.475 ;time: 0:00:10
# Edit: True ;batch:100 ;gs:3564 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.10 ;Bloss:2.126 ;Aloss:0.382 ;edits ratio:0.283 ;acc:0.430 ;iou:0.580 ;time: 0:00:19
# Edit: True ;batch:150 ;gs:3564 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.10 ;Bloss:2.119 ;Aloss:0.380 ;edits ratio:0.241 ;acc:0.505 ;iou:0.620 ;time: 0:00:29
# Edit: True ;batch:200 ;gs:3564 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.10 ;Bloss:2.860 ;Aloss:0.437 ;edits ratio:0.356 ;acc:0.240 ;iou:0.375 ;time: 0:00:38
# Edit: True ;batch:250 ;gs:3564 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.10 ;Bloss:2.161 ;Aloss:0.470 ;edits ratio:0.331 ;acc:0.415 ;iou:0.545 ;time: 0:00:48
#
# *B Train loss: 2.062 ;A Train loss: 0.497 ;Edit ratio: 0.332 ;Train accuracy: 0.508 ;IOU accuracy: 0.616 ;Time: 0:00:58
#
# VALIDATION, ephoc: 26
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.312 ;B loss: 3.127 ;A loss: 0.418 ;acc: 0.220 ;iou_acc: 0.355 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.316 ;B loss: 1.895 ;A loss: 0.450 ;acc: 0.525 ;iou_acc: 0.615 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.299 ;B loss: 1.671 ;A loss: 0.459 ;acc: 0.695 ;iou_acc: 0.765 ;time: 0:00:14
#
# *B loss: 2.082 ;A loss: 0.455 ;Edit ratio: 0.314 ;Accuracy 0.508 ;IOU accuracy: 0.616 ;Time: 0:00:21
#
# Random choice: True
# batch: 0 ;edits ratio: 0.309 ;B loss: 2.915 ;A loss: 0.533 ;acc: 0.360 ;iou_acc: 0.500 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.330 ;B loss: 1.741 ;A loss: 0.584 ;acc: 0.585 ;iou_acc: 0.720 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.298 ;B loss: 1.386 ;A loss: 0.587 ;acc: 0.700 ;iou_acc: 0.770 ;time: 0:00:14
#
# *B loss: 1.921 ;A loss: 0.571 ;Edit ratio: 0.313 ;Accuracy 0.562 ;IOU accuracy: 0.665 ;Time: 0:00:21
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.161 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:27; Training B:True; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:3565 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.00 ;Bloss:3.754 ;Aloss:0.381 ;edits ratio:0.229 ;acc:0.145 ;iou:0.400 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:3615 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.00 ;Bloss:1.849 ;Aloss:0.328 ;edits ratio:0.167 ;acc:0.610 ;iou:0.710 ;time: 0:00:15
# Edit: True ;batch:100 ;gs:3665 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.00 ;Bloss:2.221 ;Aloss:0.367 ;edits ratio:0.248 ;acc:0.445 ;iou:0.640 ;time: 0:00:27
# Edit: True ;batch:150 ;gs:3715 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.00 ;Bloss:1.597 ;Aloss:0.392 ;edits ratio:0.279 ;acc:0.720 ;iou:0.765 ;time: 0:00:41
# Edit: True ;batch:200 ;gs:3765 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.00 ;Bloss:2.055 ;Aloss:0.403 ;edits ratio:0.131 ;acc:0.510 ;iou:0.625 ;time: 0:00:55
# Edit: True ;batch:250 ;gs:3815 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.00 ;Bloss:1.742 ;Aloss:0.072 ;edits ratio:0.000 ;acc:0.875 ;iou:0.930 ;time: 0:01:08
#
# *B Train loss: 2.066 ;A Train loss: 0.472 ;Edit ratio: 0.337 ;Train accuracy: 0.510 ;IOU accuracy: 0.618 ;Time: 0:01:20
#
# No Edit
# ooooooo
# Edit: False ;batch: 0 ;gs: 3861 ;Blr: 0.050 ;B loss: 3.420 ;acc: 0.265 ;iou: 0.520 ;time: 0:01:21
# Edit: False ;batch: 50 ;gs: 3861 ;Blr: 0.050 ;B loss: 1.568 ;acc: 0.700 ;iou: 0.800 ;time: 0:01:28
# Edit: False ;batch: 100 ;gs: 3861 ;Blr: 0.050 ;B loss: 2.028 ;acc: 0.545 ;iou: 0.730 ;time: 0:01:34
# Edit: False ;batch: 150 ;gs: 3861 ;Blr: 0.050 ;B loss: 1.242 ;acc: 0.850 ;iou: 0.885 ;time: 0:01:40
# Edit: False ;batch: 200 ;gs: 3861 ;Blr: 0.050 ;B loss: 1.844 ;acc: 0.610 ;iou: 0.715 ;time: 0:01:47
# Edit: False ;batch: 250 ;gs: 3861 ;Blr: 0.050 ;B loss: 1.783 ;acc: 0.880 ;iou: 0.940 ;time: 0:01:53
#
# *B Train loss: 1.678 ;Train accuracy: 0.705 ;IOU accuracy: 0.800 ;Time: 0:01:59
#
# TESTING, ephoc: 27
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.369 ;acc: 0.770 ;iou_acc: 0.860 ;time: 0:02:00
# batch: 50 ;B loss: 1.322 ;acc: 0.785 ;iou_acc: 0.830 ;time: 0:02:06
# batch: 100 ;B loss: 1.786 ;acc: 0.590 ;iou_acc: 0.730 ;time: 0:02:12
# batch: 150 ;B loss: 1.248 ;acc: 0.785 ;iou_acc: 0.875 ;time: 0:02:19
# batch: 200 ;B loss: 1.302 ;acc: 0.805 ;iou_acc: 0.870 ;time: 0:02:24
# batch: 250 ;B loss: 1.288 ;acc: 0.790 ;iou_acc: 0.855 ;time: 0:02:30
#
# *Test loss: 1.721 ;Test accuracy 0.680 ;IOU accuracy: 0.779 ;Time: 0:02:36
# ==================================================
#
# ==================================================
# TRAIN, ephoc:28; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:3861 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.10 ;Bloss:2.177 ;Aloss:0.647 ;edits ratio:0.515 ;acc:0.390 ;iou:0.480 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:3861 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.10 ;Bloss:1.606 ;Aloss:0.454 ;edits ratio:0.184 ;acc:0.675 ;iou:0.765 ;time: 0:00:10
# Edit: True ;batch:100 ;gs:3861 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.10 ;Bloss:1.707 ;Aloss:0.458 ;edits ratio:0.327 ;acc:0.645 ;iou:0.720 ;time: 0:00:20
# Edit: True ;batch:150 ;gs:3861 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.10 ;Bloss:1.879 ;Aloss:0.498 ;edits ratio:0.350 ;acc:0.495 ;iou:0.570 ;time: 0:00:29
# Edit: True ;batch:200 ;gs:3861 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.10 ;Bloss:1.570 ;Aloss:0.530 ;edits ratio:0.321 ;acc:0.725 ;iou:0.750 ;time: 0:00:38
# Edit: True ;batch:250 ;gs:3861 ;Blr: 0.050 ;Alr:0.500 ;ERP:0.10 ;Bloss:2.717 ;Aloss:0.369 ;edits ratio:0.109 ;acc:0.375 ;iou:0.565 ;time: 0:00:47
#
# *B Train loss: 2.064 ;A Train loss: 0.496 ;Edit ratio: 0.327 ;Train accuracy: 0.511 ;IOU accuracy: 0.615 ;Time: 0:00:56
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-21ffbd1fdff5> in <module>()
#      33                                     Blr=.05,
#      34                                     Alr=.5,
# ---> 35                                     imScale=1/50)
#      36     edit_rewards_tst.append(tst)
#      37     edit_rewards_trn.append(trn)
#
# <ipython-input-16-b3444027ebb5> in train(self, trn_data, tst_data, val_data, ephocs_num, edit_reward, startA, activation_ephoc, muteBnum, start_ephoc, dropout_in, rnn_editProb, dropout_out, dropout_img, dropout_q, queries_editProb, addNoiseImg, imScale, Alr, Blr)
#    1059                               ';Time:', datetime.now().replace(microsecond=0)-startTime, '\n')
#    1060                         self.train_res.append([trn_acc, trn_iou, B_trn_loss, 0])
# -> 1061                 self.saver.save(sess, params_dir + "/model.ckpt", global_step=ephoc)
#    1062
#    1063 #                 print('GRADS:')
#
# /home/asi/.local/lib/python3.5/site-packages/tensorflow/python/training/saver.py in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state)
#    1492           checkpoint_file, meta_graph_suffix=meta_graph_suffix)
#    1493       with sess.graph.as_default():
# -> 1494         self.export_meta_graph(meta_graph_filename)
#    1495
#    1496     if self._is_empty:
#
# /home/asi/.local/lib/python3.5/site-packages/tensorflow/python/training/saver.py in export_meta_graph(self, filename, collection_list, as_text, export_scope, clear_devices)
#    1520     return export_meta_graph(
#    1521         filename=filename,
# -> 1522         graph_def=ops.get_default_graph().as_graph_def(add_shapes=True),
#    1523         saver_def=self.saver_def,
#    1524         collection_list=collection_list,
#
# /home/asi/.local/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in as_graph_def(self, from_version, add_shapes)
#    2359       ValueError: If the `graph_def` would be too large.
#    2360     """
# -> 2361     result, _ = self._as_graph_def(from_version, add_shapes)
#    2362     return result
#    2363
#
# /home/asi/.local/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in _as_graph_def(self, from_version, add_shapes)
#    2320             graph.node[-1].attr["_output_shapes"].list.shape.extend([
#    2321                 output.get_shape().as_proto() for output in op.outputs])
# -> 2322           bytesize += op.node_def.ByteSize()
#    2323           if bytesize >= (1 << 31) or bytesize < 0:
#    2324             raise ValueError("GraphDef cannot be larger than 2GB.")
#
# KeyboardInterrupt:

# %%
num_hidden=200
edit_rewards = [-1., -.9, -.8, -0.7, -0.6]
edit_rewards_tst, edit_rewards_trn, edit_rewards_val, edit_rewards_AGain = [], [], [], []

for edit_reward in edit_rewards:
    params_dir = params_dir_tmp+'RL/edit_rewards_'+str(-1*edit_reward)+'hidden_'+str(num_hidden)
    tf.reset_default_graph()
    m = Model(
        batch_size=200, 
        num_hidden=num_hidden,
        embed_size=embed_vecs.shape[1],
        img_dims=trainset[0][0][1][0].shape[1], 
        bbox_dims=trainset[0][0][1][1].shape[1], 
        vocab=vocab, 
        decay_steps=10000, 
        decay_rate=0.9, 
        bnorm=False,
        toQscale=True
    )

    print('params_dir:', params_dir)
    print('num_hidden:', m.num_hidden)
    print('edit_reward:', edit_reward)
    act_rewards, BCE, bell_val, idx = m.train(trainset, testset, valset,
                                    ephocs_num=200,
                                    start_ephoc=24,
                                    startA=8,
                                    activation_ephoc=12,
                                    muteBnum=3, 
                                    queries_editProb=0.95,
                                    edit_reward=edit_reward,
                                    rnn_editProb=0.2,
                                    Blr=.05,
                                    Alr=.01,
                                    imScale=1/50)
    edit_rewards_tst.append(tst) 
    edit_rewards_trn.append(trn)
    edit_rewards_val.append(val) 
    edit_rewards_AGain.append(AGain)

    print('\n'+'*'*100)
    print('*'*100)
    print('*'*100,'\n')
# Out:
# params_dir: ../data/training/models/All/RL/edit_rewards_1.0hidden_200
# num_hidden: 200
# edit_reward: -1.0
# # Train set size: 59400
# # Training batches: 297
# # Validation set size: 29800
# # Validation batches: 149
# # Test set size: 29600
# # Testing batches: 148
# Loading parameters from ../data/training/models/All/RL/edit_rewards_1.0hidden_200/model.ckpt-23
# INFO:tensorflow:Restoring parameters from ../data/training/models/All/RL/edit_rewards_1.0hidden_200/model.ckpt-23
# ==================================================
# TRAIN, ephoc:24; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:3564 ;Blr: 0.050 ;Alr:0.010 ;ERP:0.10 ;Bloss:2.395 ;Aloss:0.491 ;edits ratio:0.393 ;acc:0.420 ;iou:0.530 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:3564 ;Blr: 0.050 ;Alr:0.010 ;ERP:0.10 ;Bloss:3.761 ;Aloss:0.412 ;edits ratio:0.226 ;acc:0.135 ;iou:0.400 ;time: 0:00:11
# Edit: True ;batch:100 ;gs:3564 ;Blr: 0.050 ;Alr:0.010 ;ERP:0.10 ;Bloss:1.597 ;Aloss:0.543 ;edits ratio:0.237 ;acc:0.695 ;iou:0.790 ;time: 0:00:20
# Edit: True ;batch:150 ;gs:3564 ;Blr: 0.050 ;Alr:0.010 ;ERP:0.10 ;Bloss:2.255 ;Aloss:0.452 ;edits ratio:0.366 ;acc:0.425 ;iou:0.555 ;time: 0:00:30
# Edit: True ;batch:200 ;gs:3564 ;Blr: 0.050 ;Alr:0.010 ;ERP:0.10 ;Bloss:1.548 ;Aloss:0.663 ;edits ratio:0.274 ;acc:0.690 ;iou:0.780 ;time: 0:00:39
# Edit: True ;batch:250 ;gs:3564 ;Blr: 0.050 ;Alr:0.010 ;ERP:0.10 ;Bloss:1.728 ;Aloss:0.434 ;edits ratio:0.303 ;acc:0.635 ;iou:0.735 ;time: 0:00:48
#
# *B Train loss: 2.056 ;A Train loss: 0.481 ;Edit ratio: 0.319 ;Train accuracy: 0.518 ;IOU accuracy: 0.627 ;Time: 0:00:58
#
# VALIDATION, ephoc: 24
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.333 ;B loss: 3.178 ;A loss: 0.453 ;acc: 0.200 ;iou_acc: 0.330 ;time: 0:00:01
# batch: 50 ;edits ratio: 0.343 ;B loss: 1.912 ;A loss: 0.439 ;acc: 0.500 ;iou_acc: 0.595 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.305 ;B loss: 1.668 ;A loss: 0.436 ;acc: 0.680 ;iou_acc: 0.755 ;time: 0:00:16
#
# *B loss: 2.103 ;A loss: 0.454 ;Edit ratio: 0.336 ;Accuracy 0.493 ;IOU accuracy: 0.604 ;Time: 0:00:23
#
# Random choice: True
# batch: 0 ;edits ratio: 0.322 ;B loss: 2.917 ;A loss: 0.684 ;acc: 0.340 ;iou_acc: 0.495 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.319 ;B loss: 1.712 ;A loss: 0.663 ;acc: 0.570 ;iou_acc: 0.680 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.390 ;B loss: 1.435 ;A loss: 0.645 ;acc: 0.645 ;iou_acc: 0.730 ;time: 0:00:15
#
# *B loss: 1.933 ;A loss: 0.661 ;Edit ratio: 0.333 ;Accuracy 0.551 ;IOU accuracy: 0.654 ;Time: 0:00:21
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.170 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:25; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:3564 ;Blr: 0.050 ;Alr:0.010 ;ERP:0.10 ;Bloss:1.607 ;Aloss:0.441 ;edits ratio:0.254 ;acc:0.640 ;iou:0.735 ;time: 0:00:01
# Edit: True ;batch:50 ;gs:3564 ;Blr: 0.050 ;Alr:0.010 ;ERP:0.10 ;Bloss:2.471 ;Aloss:0.487 ;edits ratio:0.347 ;acc:0.330 ;iou:0.490 ;time: 0:00:11
# Edit: True ;batch:100 ;gs:3564 ;Blr: 0.050 ;Alr:0.010 ;ERP:0.10 ;Bloss:1.634 ;Aloss:0.504 ;edits ratio:0.307 ;acc:0.710 ;iou:0.790 ;time: 0:00:20
# Edit: True ;batch:150 ;gs:3564 ;Blr: 0.050 ;Alr:0.010 ;ERP:0.10 ;Bloss:2.039 ;Aloss:0.476 ;edits ratio:0.365 ;acc:0.470 ;iou:0.580 ;time: 0:00:29
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-07228e70d703> in <module>()
#      33                                     Blr=.05,
#      34                                     Alr=.01,
# ---> 35                                     imScale=1/50)
#      36     edit_rewards_tst.append(tst)
#      37     edit_rewards_trn.append(trn)
#
# <ipython-input-16-b3444027ebb5> in train(self, trn_data, tst_data, val_data, ephocs_num, edit_reward, startA, activation_ephoc, muteBnum, start_ephoc, dropout_in, rnn_editProb, dropout_out, dropout_img, dropout_q, queries_editProb, addNoiseImg, imScale, Alr, Blr)
#     914                                                                                             self.batch_size,
#     915                                                                                             addNoiseImg=addNoiseImg,
# --> 916                                                                                             imScale=imScale)
#     917
#     918                         feed_dict = {
#
# <ipython-input-16-b3444027ebb5> in build_data(self, data, start, end, imScale, addNoiseImg)
#     557             img_scale = (padded_im-img_min)/((img_max-img_min)+halper) # Scale to 0-1
#     558             s = np.std(img_scale, axis=-1, keepdims=True)
# --> 559             padded_im = imScale*img_scale/(s+halper)  #Scale to have imScale std
#     560             padded_im = padded_im - np.mean(padded_im, axis=-1, keepdims=True) # scale to zero mean
#     561
#
# KeyboardInterrupt:

# %%
num_hidden=200
edit_rewards = [-1., -.9, -.8, -0.7, -0.6]
edit_rewards_tst, edit_rewards_trn, edit_rewards_val, edit_rewards_AGain = [], [], [], []

for edit_reward in edit_rewards:
    params_dir = params_dir_tmp+'RL/edit_rewards_'+str(-1*edit_reward)+'hidden_'+str(num_hidden)
    tf.reset_default_graph()
    m = Model(
        batch_size=200, 
        num_hidden=num_hidden,
        embed_size=embed_vecs.shape[1],
        img_dims=trainset[0][0][1][0].shape[1], 
        bbox_dims=trainset[0][0][1][1].shape[1], 
        vocab=vocab, 
        decay_steps=10000, 
        decay_rate=0.9, 
        bnorm=False,
        toQscale=True
    )

    print('params_dir:', params_dir)
    print('num_hidden:', m.num_hidden)
    print('edit_reward:', edit_reward)
    act_rewards, BCE, bell_val, idx = m.train(trainset, testset, valset,
                                    ephocs_num=200,
                                    start_ephoc=23,
                                    startA=8,
                                    activation_ephoc=12,
                                    muteBnum=3, 
                                    queries_editProb=0.95,
                                    edit_reward=edit_reward,
                                    rnn_editProb=0.2,
                                    Blr=.05,
                                    Alr=.1,
                                    imScale=1/50)
    edit_rewards_tst.append(tst) 
    edit_rewards_trn.append(trn)
    edit_rewards_val.append(val) 
    edit_rewards_AGain.append(AGain)

    print('\n'+'*'*100)
    print('*'*100)
    print('*'*100,'\n')
# Out:
# params_dir: ../data/training/models/All/RL/edit_rewards_1.0hidden_200
# num_hidden: 200
# edit_reward: -1.0
# # Train set size: 59400
# # Training batches: 297
# # Validation set size: 29800
# # Validation batches: 149
# # Test set size: 29600
# # Testing batches: 148
# Loading parameters from ../data/training/models/All/RL/edit_rewards_1.0hidden_200/model.ckpt-22
# INFO:tensorflow:Restoring parameters from ../data/training/models/All/RL/edit_rewards_1.0hidden_200/model.ckpt-22
# ==================================================
# TRAIN, ephoc:23; Training B:True; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:3268 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.989 ;Aloss:0.402 ;edits ratio:0.341 ;acc:0.520 ;iou:0.635 ;time: 0:00:01
# Edit: True ;batch:50 ;gs:3318 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.396 ;Aloss:0.449 ;edits ratio:0.415 ;acc:0.320 ;iou:0.480 ;time: 0:00:14
# Edit: True ;batch:100 ;gs:3368 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.105 ;Aloss:0.477 ;edits ratio:0.445 ;acc:0.380 ;iou:0.480 ;time: 0:00:28
# Edit: True ;batch:150 ;gs:3418 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.935 ;Aloss:0.417 ;edits ratio:0.313 ;acc:0.530 ;iou:0.630 ;time: 0:00:42
# Edit: True ;batch:200 ;gs:3468 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.848 ;Aloss:0.417 ;edits ratio:0.374 ;acc:0.515 ;iou:0.585 ;time: 0:00:55
# Edit: True ;batch:250 ;gs:3518 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:3.153 ;Aloss:0.424 ;edits ratio:0.272 ;acc:0.235 ;iou:0.430 ;time: 0:01:11
#
# *B Train loss: 2.070 ;A Train loss: 0.435 ;Edit ratio: 0.323 ;Train accuracy: 0.514 ;IOU accuracy: 0.622 ;Time: 0:01:22
#
# No Edit
# ooooooo
# Edit: False ;batch: 0 ;gs: 3564 ;Blr: 0.050 ;B loss: 1.496 ;acc: 0.715 ;iou: 0.805 ;time: 0:01:22
# Edit: False ;batch: 50 ;gs: 3564 ;Blr: 0.050 ;B loss: 1.903 ;acc: 0.630 ;iou: 0.750 ;time: 0:01:29
# Edit: False ;batch: 100 ;gs: 3564 ;Blr: 0.050 ;B loss: 1.644 ;acc: 0.680 ;iou: 0.770 ;time: 0:01:36
# Edit: False ;batch: 150 ;gs: 3564 ;Blr: 0.050 ;B loss: 1.476 ;acc: 0.750 ;iou: 0.835 ;time: 0:01:43
# Edit: False ;batch: 200 ;gs: 3564 ;Blr: 0.050 ;B loss: 1.407 ;acc: 0.740 ;iou: 0.795 ;time: 0:01:50
# Edit: False ;batch: 250 ;gs: 3564 ;Blr: 0.050 ;B loss: 2.732 ;acc: 0.435 ;iou: 0.625 ;time: 0:01:57
#
# *B Train loss: 1.688 ;Train accuracy: 0.705 ;IOU accuracy: 0.801 ;Time: 0:02:03
#
# TESTING, ephoc: 23
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.371 ;acc: 0.785 ;iou_acc: 0.865 ;time: 0:02:03
# batch: 50 ;B loss: 1.322 ;acc: 0.770 ;iou_acc: 0.825 ;time: 0:02:09
# batch: 100 ;B loss: 1.784 ;acc: 0.620 ;iou_acc: 0.750 ;time: 0:02:16
# batch: 150 ;B loss: 1.245 ;acc: 0.780 ;iou_acc: 0.870 ;time: 0:02:22
# batch: 200 ;B loss: 1.315 ;acc: 0.785 ;iou_acc: 0.840 ;time: 0:02:28
# batch: 250 ;B loss: 1.301 ;acc: 0.805 ;iou_acc: 0.870 ;time: 0:02:34
#
# *Test loss: 1.726 ;Test accuracy 0.684 ;IOU accuracy: 0.782 ;Time: 0:02:39
# ==================================================
#
# ==================================================
# TRAIN, ephoc:24; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:3564 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.10 ;Bloss:2.705 ;Aloss:0.482 ;edits ratio:0.372 ;acc:0.275 ;iou:0.425 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:3564 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.10 ;Bloss:3.058 ;Aloss:0.445 ;edits ratio:0.209 ;acc:0.300 ;iou:0.470 ;time: 0:00:09
# Edit: True ;batch:100 ;gs:3564 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.10 ;Bloss:1.645 ;Aloss:0.568 ;edits ratio:0.326 ;acc:0.605 ;iou:0.685 ;time: 0:00:19
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-73ee898ceae1> in <module>()
#      33                                     Blr=.05,
#      34                                     Alr=.1,
# ---> 35                                     imScale=1/50)
#      36     edit_rewards_tst.append(tst)
#      37     edit_rewards_trn.append(trn)
#
# <ipython-input-16-b3444027ebb5> in train(self, trn_data, tst_data, val_data, ephocs_num, edit_reward, startA, activation_ephoc, muteBnum, start_ephoc, dropout_in, rnn_editProb, dropout_out, dropout_img, dropout_q, queries_editProb, addNoiseImg, imScale, Alr, Blr)
#     977                                 gs, scores, batch_Alr, batch_Blr, B_loss, batch_edit_ratio, A_loss, _ = sess.run(
#     978                                     [self.global_step, self.scores, self.A_learning_rate, self.learning_rate,
# --> 979                                          self.B_loss, self.edit_ratio, self.A_loss, self.A_optimizer], feed_dict=feed_dict)
#     980
#     981
#
# /home/asi/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/asi/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# /home/asi/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/asi/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# /home/asi/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
num_hidden=200
edit_rewards = [-1., -.9, -.8, -0.7, -0.6]
edit_rewards_tst, edit_rewards_trn, edit_rewards_val, edit_rewards_AGain = [], [], [], []

for edit_reward in edit_rewards:
    params_dir = params_dir_tmp+'RL/edit_rewards_'+str(-1*edit_reward)+'hidden_'+str(num_hidden)
    tf.reset_default_graph()
    m = Model(
        batch_size=200, 
        num_hidden=num_hidden,
        embed_size=embed_vecs.shape[1],
        img_dims=trainset[0][0][1][0].shape[1], 
        bbox_dims=trainset[0][0][1][1].shape[1], 
        vocab=vocab, 
        decay_steps=10000, 
        decay_rate=0.9, 
        bnorm=False,
        toQscale=True
    )

    print('params_dir:', params_dir)
    print('num_hidden:', m.num_hidden)
    print('edit_reward:', edit_reward)
    act_rewards, BCE, bell_val, idx = m.train(trainset, testset, valset,
                                    ephocs_num=200,
                                    start_ephoc=19,
                                    startA=8,
                                    activation_ephoc=12,
                                    muteBnum=3, 
                                    queries_editProb=0.95,
                                    edit_reward=edit_reward,
                                    rnn_editProb=0.3,
                                    Blr=.05,
                                    Alr=.1,
                                    imScale=1/50)
    edit_rewards_tst.append(tst) 
    edit_rewards_trn.append(trn)
    edit_rewards_val.append(val) 
    edit_rewards_AGain.append(AGain)

    print('\n'+'*'*100)
    print('*'*100)
    print('*'*100,'\n')
# Out:
# params_dir: ../data/training/models/All/RL/edit_rewards_1.0hidden_200
# num_hidden: 200
# edit_reward: -1.0
# # Train set size: 59400
# # Training batches: 297
# # Validation set size: 29800
# # Validation batches: 149
# # Test set size: 29600
# # Testing batches: 148
# Loading parameters from ../data/training/models/All/RL/edit_rewards_1.0hidden_200/model.ckpt-18
# INFO:tensorflow:Restoring parameters from ../data/training/models/All/RL/edit_rewards_1.0hidden_200/model.ckpt-18
# ==================================================
# TRAIN, ephoc:19; Training B:True; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:2971 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.807 ;Aloss:0.377 ;edits ratio:0.236 ;acc:0.280 ;iou:0.470 ;time: 0:00:01
# Edit: True ;batch:50 ;gs:3021 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.069 ;Aloss:0.318 ;edits ratio:0.211 ;acc:0.465 ;iou:0.600 ;time: 0:00:14
# Edit: True ;batch:100 ;gs:3071 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:3.108 ;Aloss:0.411 ;edits ratio:0.204 ;acc:0.260 ;iou:0.470 ;time: 0:00:27
# Edit: True ;batch:150 ;gs:3121 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.455 ;Aloss:0.423 ;edits ratio:0.289 ;acc:0.400 ;iou:0.610 ;time: 0:00:42
# Edit: True ;batch:200 ;gs:3171 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.555 ;Aloss:0.499 ;edits ratio:0.337 ;acc:0.720 ;iou:0.790 ;time: 0:00:55
# Edit: True ;batch:250 ;gs:3221 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.593 ;Aloss:0.457 ;edits ratio:0.369 ;acc:0.250 ;iou:0.455 ;time: 0:01:09
#
# *B Train loss: 2.085 ;A Train loss: 0.428 ;Edit ratio: 0.320 ;Train accuracy: 0.506 ;IOU accuracy: 0.616 ;Time: 0:01:22
#
# No Edit
# ooooooo
# Edit: False ;batch: 0 ;gs: 3267 ;Blr: 0.050 ;B loss: 2.498 ;acc: 0.400 ;iou: 0.575 ;time: 0:01:22
# Edit: False ;batch: 50 ;gs: 3267 ;Blr: 0.050 ;B loss: 1.748 ;acc: 0.635 ;iou: 0.755 ;time: 0:01:29
# Edit: False ;batch: 100 ;gs: 3267 ;Blr: 0.050 ;B loss: 2.728 ;acc: 0.415 ;iou: 0.615 ;time: 0:01:36
# Edit: False ;batch: 150 ;gs: 3267 ;Blr: 0.050 ;B loss: 2.072 ;acc: 0.590 ;iou: 0.795 ;time: 0:01:43
# Edit: False ;batch: 200 ;gs: 3267 ;Blr: 0.050 ;B loss: 1.155 ;acc: 0.880 ;iou: 0.930 ;time: 0:01:50
# Edit: False ;batch: 250 ;gs: 3267 ;Blr: 0.050 ;B loss: 2.063 ;acc: 0.560 ;iou: 0.725 ;time: 0:01:57
#
# *B Train loss: 1.684 ;Train accuracy: 0.701 ;IOU accuracy: 0.798 ;Time: 0:02:03
#
# TESTING, ephoc: 19
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.355 ;acc: 0.795 ;iou_acc: 0.870 ;time: 0:02:04
# batch: 50 ;B loss: 1.317 ;acc: 0.770 ;iou_acc: 0.815 ;time: 0:02:09
# batch: 100 ;B loss: 1.774 ;acc: 0.565 ;iou_acc: 0.725 ;time: 0:02:16
# batch: 150 ;B loss: 1.259 ;acc: 0.780 ;iou_acc: 0.865 ;time: 0:02:22
# batch: 200 ;B loss: 1.310 ;acc: 0.800 ;iou_acc: 0.860 ;time: 0:02:27
# batch: 250 ;B loss: 1.311 ;acc: 0.775 ;iou_acc: 0.850 ;time: 0:02:33
#
# *Test loss: 1.721 ;Test accuracy 0.681 ;IOU accuracy: 0.780 ;Time: 0:02:39
# ==================================================
#
# ==================================================
# TRAIN, ephoc:20; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:3267 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.693 ;Aloss:0.410 ;edits ratio:0.280 ;acc:0.565 ;iou:0.655 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:3267 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.030 ;Aloss:0.477 ;edits ratio:0.440 ;acc:0.475 ;iou:0.575 ;time: 0:00:09
# Edit: True ;batch:100 ;gs:3267 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.707 ;Aloss:0.378 ;edits ratio:0.295 ;acc:0.320 ;iou:0.480 ;time: 0:00:18
# Edit: True ;batch:150 ;gs:3267 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.684 ;Aloss:0.571 ;edits ratio:0.290 ;acc:0.745 ;iou:0.825 ;time: 0:00:29
# Edit: True ;batch:200 ;gs:3267 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.621 ;Aloss:0.484 ;edits ratio:0.280 ;acc:0.695 ;iou:0.765 ;time: 0:00:38
# Edit: True ;batch:250 ;gs:3267 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.768 ;Aloss:0.483 ;edits ratio:0.308 ;acc:0.640 ;iou:0.705 ;time: 0:00:47
#
# *B Train loss: 2.094 ;A Train loss: 0.442 ;Edit ratio: 0.331 ;Train accuracy: 0.503 ;IOU accuracy: 0.614 ;Time: 0:00:55
#
# VALIDATION, ephoc: 20
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.311 ;B loss: 3.156 ;A loss: 0.437 ;acc: 0.185 ;iou_acc: 0.340 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.332 ;B loss: 1.924 ;A loss: 0.428 ;acc: 0.520 ;iou_acc: 0.625 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.304 ;B loss: 1.664 ;A loss: 0.435 ;acc: 0.665 ;iou_acc: 0.745 ;time: 0:00:14
#
# *B loss: 2.113 ;A loss: 0.433 ;Edit ratio: 0.334 ;Accuracy 0.491 ;IOU accuracy: 0.604 ;Time: 0:00:21
#
# Random choice: True
# batch: 0 ;edits ratio: 0.354 ;B loss: 2.955 ;A loss: 0.830 ;acc: 0.310 ;iou_acc: 0.435 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.347 ;B loss: 1.728 ;A loss: 0.745 ;acc: 0.560 ;iou_acc: 0.665 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.319 ;B loss: 1.380 ;A loss: 0.711 ;acc: 0.660 ;iou_acc: 0.725 ;time: 0:00:15
#
# *B loss: 1.936 ;A loss: 0.774 ;Edit ratio: 0.334 ;Accuracy 0.549 ;IOU accuracy: 0.652 ;Time: 0:00:22
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.177 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:21; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:3267 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.788 ;Aloss:0.462 ;edits ratio:0.327 ;acc:0.635 ;iou:0.715 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:3267 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.962 ;Aloss:0.391 ;edits ratio:0.368 ;acc:0.525 ;iou:0.615 ;time: 0:00:10
# Edit: True ;batch:100 ;gs:3267 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.496 ;Aloss:0.445 ;edits ratio:0.393 ;acc:0.335 ;iou:0.465 ;time: 0:00:20
# Edit: True ;batch:150 ;gs:3267 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.705 ;Aloss:0.492 ;edits ratio:0.293 ;acc:0.625 ;iou:0.690 ;time: 0:00:31
# Edit: True ;batch:200 ;gs:3267 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.798 ;Aloss:0.392 ;edits ratio:0.257 ;acc:0.810 ;iou:0.920 ;time: 0:00:41
# Edit: True ;batch:250 ;gs:3267 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.197 ;Aloss:0.392 ;edits ratio:0.392 ;acc:0.410 ;iou:0.525 ;time: 0:00:51
#
# *B Train loss: 2.095 ;A Train loss: 0.441 ;Edit ratio: 0.331 ;Train accuracy: 0.504 ;IOU accuracy: 0.615 ;Time: 0:01:00
#
# VALIDATION, ephoc: 21
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.233 ;B loss: 3.012 ;A loss: 0.382 ;acc: 0.260 ;iou_acc: 0.415 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.243 ;B loss: 1.858 ;A loss: 0.343 ;acc: 0.600 ;iou_acc: 0.690 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.275 ;B loss: 1.645 ;A loss: 0.421 ;acc: 0.675 ;iou_acc: 0.755 ;time: 0:00:15
#
# *B loss: 2.053 ;A loss: 0.390 ;Edit ratio: 0.265 ;Accuracy 0.536 ;IOU accuracy: 0.643 ;Time: 0:00:22
#
# Random choice: True
# batch: 0 ;edits ratio: 0.278 ;B loss: 2.884 ;A loss: 0.841 ;acc: 0.350 ;iou_acc: 0.475 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.220 ;B loss: 1.670 ;A loss: 0.720 ;acc: 0.630 ;iou_acc: 0.730 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.269 ;B loss: 1.389 ;A loss: 0.731 ;acc: 0.665 ;iou_acc: 0.760 ;time: 0:00:15
#
# *B loss: 1.884 ;A loss: 0.789 ;Edit ratio: 0.262 ;Accuracy 0.579 ;IOU accuracy: 0.682 ;Time: 0:00:22
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.169 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:22; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:3267 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.808 ;Aloss:0.382 ;edits ratio:0.214 ;acc:0.605 ;iou:0.690 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:3267 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.557 ;Aloss:0.454 ;edits ratio:0.276 ;acc:0.750 ;iou:0.775 ;time: 0:00:09
# Edit: True ;batch:100 ;gs:3267 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.675 ;Aloss:0.412 ;edits ratio:0.272 ;acc:0.660 ;iou:0.735 ;time: 0:00:19
# Edit: True ;batch:150 ;gs:3267 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.523 ;Aloss:0.478 ;edits ratio:0.442 ;acc:0.270 ;iou:0.400 ;time: 0:00:29
# Edit: True ;batch:200 ;gs:3267 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.270 ;Aloss:0.490 ;edits ratio:0.420 ;acc:0.360 ;iou:0.500 ;time: 0:00:39
# Edit: True ;batch:250 ;gs:3267 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.639 ;Aloss:0.414 ;edits ratio:0.289 ;acc:0.365 ;iou:0.475 ;time: 0:00:48
#
# *B Train loss: 2.091 ;A Train loss: 0.433 ;Edit ratio: 0.326 ;Train accuracy: 0.506 ;IOU accuracy: 0.616 ;Time: 0:00:57
#
# VALIDATION, ephoc: 22
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.311 ;B loss: 3.153 ;A loss: 0.432 ;acc: 0.185 ;iou_acc: 0.345 ;time: 0:00:01
# batch: 50 ;edits ratio: 0.342 ;B loss: 1.929 ;A loss: 0.434 ;acc: 0.520 ;iou_acc: 0.620 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.305 ;B loss: 1.663 ;A loss: 0.437 ;acc: 0.665 ;iou_acc: 0.745 ;time: 0:00:15
#
# *B loss: 2.115 ;A loss: 0.435 ;Edit ratio: 0.335 ;Accuracy 0.489 ;IOU accuracy: 0.603 ;Time: 0:00:22
#
# Random choice: True
# batch: 0 ;edits ratio: 0.356 ;B loss: 2.993 ;A loss: 0.780 ;acc: 0.300 ;iou_acc: 0.430 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.377 ;B loss: 1.762 ;A loss: 0.732 ;acc: 0.530 ;iou_acc: 0.620 ;time: 0:00:06
# batch: 100 ;edits ratio: 0.310 ;B loss: 1.376 ;A loss: 0.697 ;acc: 0.725 ;iou_acc: 0.830 ;time: 0:00:13
#
# *B loss: 1.937 ;A loss: 0.756 ;Edit ratio: 0.336 ;Accuracy 0.544 ;IOU accuracy: 0.648 ;Time: 0:00:20
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.178 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:23; Training B:True; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:3268 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.282 ;Aloss:0.458 ;edits ratio:0.382 ;acc:0.405 ;iou:0.550 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:3318 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:3.863 ;Aloss:0.419 ;edits ratio:0.277 ;acc:0.095 ;iou:0.305 ;time: 0:00:13
# Edit: True ;batch:100 ;gs:3368 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.717 ;Aloss:0.463 ;edits ratio:0.315 ;acc:0.615 ;iou:0.705 ;time: 0:00:26
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-1dcc8a9c2cd8> in <module>()
#      33                                     Blr=.05,
#      34                                     Alr=.1,
# ---> 35                                     imScale=1/50)
#      36     edit_rewards_tst.append(tst)
#      37     edit_rewards_trn.append(trn)
#
# <ipython-input-12-0079cfd91450> in train(self, trn_data, tst_data, val_data, ephocs_num, edit_reward, startA, activation_ephoc, muteBnum, start_ephoc, dropout_in, rnn_editProb, dropout_out, dropout_img, dropout_q, queries_editProb, addNoiseImg, imScale, Alr, Blr)
#    1011                                 batch_Blr, gs, _ = sess.run(
#    1012                                     [self.learning_rate, self.global_step, self.B_optimizer],
# -> 1013                                     feed_dict=feed_dict)
#    1014                             if b%50==0:
#    1015                                 if toTrainA==0:
#
# /home/asi/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/asi/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# /home/asi/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/asi/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# /home/asi/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
num_hidden=200
edit_rewards = [-1., -.9, -.8, -0.7, -0.6]
edit_rewards_tst, edit_rewards_trn, edit_rewards_val, edit_rewards_AGain = [], [], [], []

for edit_reward in edit_rewards:
    params_dir = params_dir_tmp+'RL/edit_rewards_'+str(-1*edit_reward)+'hidden_'+str(num_hidden)
    tf.reset_default_graph()
    m = Model(
        batch_size=200, 
        num_hidden=num_hidden,
        embed_size=embed_vecs.shape[1],
        img_dims=trainset[0][0][1][0].shape[1], 
        bbox_dims=trainset[0][0][1][1].shape[1], 
        vocab=vocab, 
        decay_steps=10000, 
        decay_rate=0.9, 
        bnorm=False,
        toQscale=True
    )

    print('params_dir:', params_dir)
    print('num_hidden:', m.num_hidden)
    print('edit_reward:', edit_reward)
    act_rewards, BCE, bell_val, idx = m.train(trainset, testset, valset,
                                    ephocs_num=200,
                                    start_ephoc=0,
                                    startA=8,
                                    activation_ephoc=12,
                                    muteBnum=3, 
                                    queries_editProb=0.95,
                                    edit_reward=edit_reward,
                                    rnn_editProb=0.3,
                                    Blr=.05,
                                    Alr=.1,
                                    imScale=1/50)
    edit_rewards_tst.append(tst) 
    edit_rewards_trn.append(trn)
    edit_rewards_val.append(val) 
    edit_rewards_AGain.append(AGain)

    print('\n'+'*'*100)
    print('*'*100)
    print('*'*100,'\n')
# Out:
# params_dir: ../data/training/models/All/RL/edit_rewards_1.0hidden_200
# num_hidden: 200
# edit_reward: -1.0
# # Train set size: 59400
# # Training batches: 297
# # Validation set size: 29800
# # Validation batches: 149
# # Test set size: 29600
# # Testing batches: 148
# Initializing variables
# ==================================================
# TRAIN, ephoc:0; Training B:True; A is a know-it-all:False; ActivateA:False
# Edit: False ;batch:0 ;gs:1 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:2.808 ;Aloss:1.339 ;edits ratio:0.000 ;acc:0.120 ;iou:0.210 ;time: 0:00:01
# Edit: False ;batch:50 ;gs:51 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.551 ;Aloss:0.288 ;edits ratio:0.000 ;acc:0.565 ;iou:0.690 ;time: 0:00:12
# Edit: False ;batch:100 ;gs:101 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:2.565 ;Aloss:0.224 ;edits ratio:0.000 ;acc:0.300 ;iou:0.380 ;time: 0:00:24
# Edit: False ;batch:150 ;gs:151 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.390 ;Aloss:0.213 ;edits ratio:0.000 ;acc:0.705 ;iou:0.800 ;time: 0:00:34
# Edit: False ;batch:200 ;gs:201 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:2.285 ;Aloss:0.173 ;edits ratio:0.000 ;acc:0.435 ;iou:0.560 ;time: 0:00:45
# Edit: False ;batch:250 ;gs:251 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.754 ;Aloss:0.206 ;edits ratio:0.000 ;acc:0.545 ;iou:0.650 ;time: 0:00:55
#
# *B Train loss: 2.375 ;A Train loss: 0.250 ;Edit ratio: 0.000 ;Train accuracy: 0.385 ;IOU accuracy: 0.498 ;Time: 0:01:06
#
# TESTING, ephoc: 0
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.959 ;acc: 0.565 ;iou_acc: 0.675 ;time: 0:01:07
# batch: 50 ;B loss: 1.715 ;acc: 0.580 ;iou_acc: 0.680 ;time: 0:01:13
# batch: 100 ;B loss: 2.523 ;acc: 0.340 ;iou_acc: 0.470 ;time: 0:01:19
# batch: 150 ;B loss: 1.630 ;acc: 0.630 ;iou_acc: 0.740 ;time: 0:01:25
# batch: 200 ;B loss: 1.686 ;acc: 0.590 ;iou_acc: 0.710 ;time: 0:01:31
# batch: 250 ;B loss: 1.679 ;acc: 0.615 ;iou_acc: 0.740 ;time: 0:01:37
#
# *Test loss: 2.271 ;Test accuracy 0.479 ;IOU accuracy: 0.607 ;Time: 0:01:43
# ==================================================
#
# ==================================================
# TRAIN, ephoc:1; Training B:True; A is a know-it-all:False; ActivateA:False
# Edit: False ;batch:0 ;gs:298 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.975 ;Aloss:0.219 ;edits ratio:0.000 ;acc:0.550 ;iou:0.665 ;time: 0:00:00
# Edit: False ;batch:50 ;gs:348 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:2.570 ;Aloss:0.150 ;edits ratio:0.000 ;acc:0.420 ;iou:0.550 ;time: 0:00:11
# Edit: False ;batch: 100 ;gs: 398 ;Blr: 0.050 ;B loss: 2.218 ;acc: 0.490 ;iou: 0.600 ;time: 0:00:22
# Edit: False ;batch:150 ;gs:448 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.522 ;Aloss:0.165 ;edits ratio:0.000 ;acc:0.710 ;iou:0.785 ;time: 0:00:32
# Edit: False ;batch:200 ;gs:498 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:2.319 ;Aloss:0.153 ;edits ratio:0.000 ;acc:0.470 ;iou:0.570 ;time: 0:00:43
# Edit: False ;batch: 250 ;gs: 548 ;Blr: 0.050 ;B loss: 1.406 ;acc: 0.720 ;iou: 0.825 ;time: 0:00:55
#
# *B Train loss: 2.079 ;A Train loss: 0.154 ;Edit ratio: 0.000 ;Train accuracy: 0.539 ;IOU accuracy: 0.655 ;Time: 0:01:05
#
# TESTING, ephoc: 1
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.509 ;acc: 0.675 ;iou_acc: 0.760 ;time: 0:01:06
# batch: 50 ;B loss: 1.428 ;acc: 0.685 ;iou_acc: 0.775 ;time: 0:01:12
# batch: 100 ;B loss: 2.049 ;acc: 0.540 ;iou_acc: 0.630 ;time: 0:01:18
# batch: 150 ;B loss: 1.375 ;acc: 0.720 ;iou_acc: 0.805 ;time: 0:01:25
# batch: 200 ;B loss: 1.390 ;acc: 0.680 ;iou_acc: 0.775 ;time: 0:01:31
# batch: 250 ;B loss: 1.433 ;acc: 0.785 ;iou_acc: 0.860 ;time: 0:01:37
#
# *Test loss: 1.918 ;Test accuracy 0.583 ;IOU accuracy: 0.697 ;Time: 0:01:43
# ==================================================
#
# ==================================================
# TRAIN, ephoc:2; Training B:True; A is a know-it-all:False; ActivateA:False
# Edit: False ;batch:0 ;gs:595 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.767 ;Aloss:0.152 ;edits ratio:0.000 ;acc:0.560 ;iou:0.680 ;time: 0:00:00
# Edit: False ;batch:50 ;gs:645 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.549 ;Aloss:0.123 ;edits ratio:0.000 ;acc:0.650 ;iou:0.770 ;time: 0:00:12
# Edit: False ;batch:100 ;gs:695 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.330 ;Aloss:0.137 ;edits ratio:0.000 ;acc:0.750 ;iou:0.825 ;time: 0:00:23
# Edit: False ;batch:150 ;gs:745 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:2.009 ;Aloss:0.120 ;edits ratio:0.000 ;acc:0.875 ;iou:0.930 ;time: 0:00:34
# Edit: False ;batch:200 ;gs:795 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.979 ;Aloss:0.121 ;edits ratio:0.000 ;acc:0.465 ;iou:0.605 ;time: 0:00:44
# Edit: False ;batch:250 ;gs:845 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:2.081 ;Aloss:0.115 ;edits ratio:0.000 ;acc:0.870 ;iou:0.935 ;time: 0:00:55
#
# *B Train loss: 1.850 ;A Train loss: 0.131 ;Edit ratio: 0.000 ;Train accuracy: 0.602 ;IOU accuracy: 0.711 ;Time: 0:01:04
#
# TESTING, ephoc: 2
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.383 ;acc: 0.710 ;iou_acc: 0.785 ;time: 0:01:05
# batch: 50 ;B loss: 1.375 ;acc: 0.740 ;iou_acc: 0.790 ;time: 0:01:10
# batch: 100 ;B loss: 1.861 ;acc: 0.545 ;iou_acc: 0.660 ;time: 0:01:16
# batch: 150 ;B loss: 1.339 ;acc: 0.755 ;iou_acc: 0.845 ;time: 0:01:22
# batch: 200 ;B loss: 1.353 ;acc: 0.745 ;iou_acc: 0.815 ;time: 0:01:28
# batch: 250 ;B loss: 1.393 ;acc: 0.810 ;iou_acc: 0.870 ;time: 0:01:33
#
# *Test loss: 1.807 ;Test accuracy 0.617 ;IOU accuracy: 0.728 ;Time: 0:01:39
# ==================================================
#
# ==================================================
# TRAIN, ephoc:3; Training B:True; A is a know-it-all:False; ActivateA:False
# Edit: False ;batch:0 ;gs:892 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.363 ;Aloss:0.114 ;edits ratio:0.000 ;acc:0.745 ;iou:0.825 ;time: 0:00:00
# Edit: False ;batch:50 ;gs:942 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.327 ;Aloss:0.101 ;edits ratio:0.000 ;acc:0.735 ;iou:0.815 ;time: 0:00:11
# Edit: False ;batch:100 ;gs:992 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.385 ;Aloss:0.121 ;edits ratio:0.000 ;acc:0.800 ;iou:0.855 ;time: 0:00:23
# Edit: False ;batch:150 ;gs:1042 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:2.140 ;Aloss:0.145 ;edits ratio:0.000 ;acc:0.530 ;iou:0.640 ;time: 0:00:34
# Edit: False ;batch:200 ;gs:1092 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.638 ;Aloss:0.121 ;edits ratio:0.000 ;acc:0.720 ;iou:0.795 ;time: 0:00:46
# Edit: False ;batch:250 ;gs:1142 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:2.027 ;Aloss:0.128 ;edits ratio:0.000 ;acc:0.490 ;iou:0.665 ;time: 0:00:58
#
# *B Train loss: 1.788 ;A Train loss: 0.120 ;Edit ratio: 0.000 ;Train accuracy: 0.626 ;IOU accuracy: 0.733 ;Time: 0:01:09
#
# TESTING, ephoc: 3
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.347 ;acc: 0.735 ;iou_acc: 0.805 ;time: 0:01:10
# batch: 50 ;B loss: 1.349 ;acc: 0.745 ;iou_acc: 0.790 ;time: 0:01:16
# batch: 100 ;B loss: 1.809 ;acc: 0.565 ;iou_acc: 0.675 ;time: 0:01:23
# batch: 150 ;B loss: 1.285 ;acc: 0.770 ;iou_acc: 0.855 ;time: 0:01:29
# batch: 200 ;B loss: 1.365 ;acc: 0.750 ;iou_acc: 0.820 ;time: 0:01:36
# batch: 250 ;B loss: 1.385 ;acc: 0.800 ;iou_acc: 0.855 ;time: 0:01:42
#
# *Test loss: 1.773 ;Test accuracy 0.634 ;IOU accuracy: 0.741 ;Time: 0:01:48
# ==================================================
#
# ==================================================
# TRAIN, ephoc:4; Training B:True; A is a know-it-all:False; ActivateA:False
# Edit: False ;batch:0 ;gs:1189 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.659 ;Aloss:0.151 ;edits ratio:0.000 ;acc:0.645 ;iou:0.705 ;time: 0:00:00
# Edit: False ;batch:50 ;gs:1239 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:2.347 ;Aloss:0.118 ;edits ratio:0.000 ;acc:0.455 ;iou:0.630 ;time: 0:00:12
# Edit: False ;batch:100 ;gs:1289 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.805 ;Aloss:0.089 ;edits ratio:0.000 ;acc:0.590 ;iou:0.695 ;time: 0:00:23
# Edit: False ;batch:150 ;gs:1339 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:2.050 ;Aloss:0.069 ;edits ratio:0.000 ;acc:0.845 ;iou:0.930 ;time: 0:00:35
# Edit: False ;batch:200 ;gs:1389 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.587 ;Aloss:0.150 ;edits ratio:0.000 ;acc:0.735 ;iou:0.795 ;time: 0:00:47
# Edit: False ;batch:250 ;gs:1439 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.388 ;Aloss:0.124 ;edits ratio:0.000 ;acc:0.815 ;iou:0.870 ;time: 0:00:59
#
# *B Train loss: 1.755 ;A Train loss: 0.115 ;Edit ratio: 0.000 ;Train accuracy: 0.641 ;IOU accuracy: 0.747 ;Time: 0:01:09
#
# TESTING, ephoc: 4
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.326 ;acc: 0.755 ;iou_acc: 0.830 ;time: 0:01:09
# batch: 50 ;B loss: 1.337 ;acc: 0.750 ;iou_acc: 0.790 ;time: 0:01:15
# batch: 100 ;B loss: 1.769 ;acc: 0.555 ;iou_acc: 0.660 ;time: 0:01:22
# batch: 150 ;B loss: 1.276 ;acc: 0.780 ;iou_acc: 0.865 ;time: 0:01:28
# batch: 200 ;B loss: 1.356 ;acc: 0.745 ;iou_acc: 0.815 ;time: 0:01:34
# batch: 250 ;B loss: 1.372 ;acc: 0.805 ;iou_acc: 0.865 ;time: 0:01:40
#
# *Test loss: 1.750 ;Test accuracy 0.646 ;IOU accuracy: 0.750 ;Time: 0:01:46
# ==================================================
#
# ==================================================
# TRAIN, ephoc:5; Training B:True; A is a know-it-all:False; ActivateA:False
# Edit: False ;batch:0 ;gs:1486 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.281 ;Aloss:0.141 ;edits ratio:0.000 ;acc:0.845 ;iou:0.890 ;time: 0:00:00
# Edit: False ;batch:50 ;gs:1536 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.552 ;Aloss:0.144 ;edits ratio:0.000 ;acc:0.665 ;iou:0.760 ;time: 0:00:11
# Edit: False ;batch:100 ;gs:1586 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.303 ;Aloss:0.148 ;edits ratio:0.000 ;acc:0.795 ;iou:0.830 ;time: 0:00:23
# Edit: False ;batch:150 ;gs:1636 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:2.001 ;Aloss:0.065 ;edits ratio:0.000 ;acc:0.525 ;iou:0.640 ;time: 0:00:34
# Edit: False ;batch:200 ;gs:1686 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:2.137 ;Aloss:0.053 ;edits ratio:0.000 ;acc:0.515 ;iou:0.680 ;time: 0:00:46
# Edit: False ;batch:250 ;gs:1736 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.851 ;Aloss:0.062 ;edits ratio:0.000 ;acc:0.550 ;iou:0.665 ;time: 0:00:58
#
# *B Train loss: 1.728 ;A Train loss: 0.111 ;Edit ratio: 0.000 ;Train accuracy: 0.655 ;IOU accuracy: 0.758 ;Time: 0:01:09
#
# TESTING, ephoc: 5
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.320 ;acc: 0.755 ;iou_acc: 0.815 ;time: 0:01:10
# batch: 50 ;B loss: 1.330 ;acc: 0.765 ;iou_acc: 0.805 ;time: 0:01:16
# batch: 100 ;B loss: 1.779 ;acc: 0.540 ;iou_acc: 0.660 ;time: 0:01:22
# batch: 150 ;B loss: 1.289 ;acc: 0.820 ;iou_acc: 0.905 ;time: 0:01:28
# batch: 200 ;B loss: 1.323 ;acc: 0.775 ;iou_acc: 0.850 ;time: 0:01:34
# batch: 250 ;B loss: 1.357 ;acc: 0.800 ;iou_acc: 0.865 ;time: 0:01:40
#
# *Test loss: 1.737 ;Test accuracy 0.649 ;IOU accuracy: 0.753 ;Time: 0:01:46
# ==================================================
#
# ==================================================
# TRAIN, ephoc:6; Training B:True; A is a know-it-all:False; ActivateA:False
# Edit: False ;batch:0 ;gs:1783 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.352 ;Aloss:0.146 ;edits ratio:0.000 ;acc:0.745 ;iou:0.830 ;time: 0:00:01
# Edit: False ;batch:50 ;gs:1833 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.854 ;Aloss:0.088 ;edits ratio:0.000 ;acc:0.605 ;iou:0.685 ;time: 0:00:12
# Edit: False ;batch:100 ;gs:1883 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.807 ;Aloss:0.073 ;edits ratio:0.000 ;acc:0.530 ;iou:0.680 ;time: 0:00:24
# Edit: False ;batch:150 ;gs:1933 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:2.565 ;Aloss:0.072 ;edits ratio:0.000 ;acc:0.415 ;iou:0.580 ;time: 0:00:36
# Edit: False ;batch:200 ;gs:1983 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.934 ;Aloss:0.131 ;edits ratio:0.000 ;acc:0.530 ;iou:0.685 ;time: 0:00:49
# Edit: False ;batch:250 ;gs:2033 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:2.073 ;Aloss:0.063 ;edits ratio:0.000 ;acc:0.545 ;iou:0.680 ;time: 0:01:00
#
# *B Train loss: 1.710 ;A Train loss: 0.109 ;Edit ratio: 0.000 ;Train accuracy: 0.663 ;IOU accuracy: 0.765 ;Time: 0:01:11
#
# TESTING, ephoc: 6
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.311 ;acc: 0.735 ;iou_acc: 0.815 ;time: 0:01:11
# batch: 50 ;B loss: 1.332 ;acc: 0.785 ;iou_acc: 0.830 ;time: 0:01:18
# batch: 100 ;B loss: 1.738 ;acc: 0.565 ;iou_acc: 0.700 ;time: 0:01:24
# batch: 150 ;B loss: 1.321 ;acc: 0.755 ;iou_acc: 0.850 ;time: 0:01:30
# batch: 200 ;B loss: 1.316 ;acc: 0.805 ;iou_acc: 0.860 ;time: 0:01:36
# batch: 250 ;B loss: 1.356 ;acc: 0.790 ;iou_acc: 0.860 ;time: 0:01:43
#
# *Test loss: 1.740 ;Test accuracy 0.648 ;IOU accuracy: 0.750 ;Time: 0:01:49
# ==================================================
#
# ==================================================
# TRAIN, ephoc:7; Training B:True; A is a know-it-all:False; ActivateA:False
# Edit: False ;batch:0 ;gs:2080 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:2.153 ;Aloss:0.158 ;edits ratio:0.000 ;acc:0.480 ;iou:0.635 ;time: 0:00:00
# Edit: False ;batch:50 ;gs:2130 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.227 ;Aloss:0.146 ;edits ratio:0.000 ;acc:0.870 ;iou:0.885 ;time: 0:00:12
# Edit: False ;batch:100 ;gs:2180 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:1.303 ;Aloss:0.120 ;edits ratio:0.000 ;acc:0.885 ;iou:0.930 ;time: 0:00:23
# Edit: False ;batch:150 ;gs:2230 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:2.640 ;Aloss:0.101 ;edits ratio:0.000 ;acc:0.370 ;iou:0.595 ;time: 0:00:35
# Edit: False ;batch:200 ;gs:2280 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:2.216 ;Aloss:0.125 ;edits ratio:0.000 ;acc:0.855 ;iou:0.940 ;time: 0:00:47
# Edit: False ;batch:250 ;gs:2330 ;Blr: 0.050 ;Alr:0.100 ;ERP:1.00 ;Bloss:2.235 ;Aloss:0.139 ;edits ratio:0.000 ;acc:0.895 ;iou:0.950 ;time: 0:01:00
#
# *B Train loss: 1.688 ;A Train loss: 0.107 ;Edit ratio: 0.000 ;Train accuracy: 0.673 ;IOU accuracy: 0.774 ;Time: 0:01:10
#
# TESTING, ephoc: 7
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.287 ;acc: 0.775 ;iou_acc: 0.845 ;time: 0:01:11
# batch: 50 ;B loss: 1.320 ;acc: 0.755 ;iou_acc: 0.795 ;time: 0:01:18
# batch: 100 ;B loss: 1.720 ;acc: 0.555 ;iou_acc: 0.675 ;time: 0:01:24
# batch: 150 ;B loss: 1.285 ;acc: 0.790 ;iou_acc: 0.860 ;time: 0:01:31
# batch: 200 ;B loss: 1.361 ;acc: 0.735 ;iou_acc: 0.800 ;time: 0:01:37
# batch: 250 ;B loss: 1.379 ;acc: 0.795 ;iou_acc: 0.875 ;time: 0:01:42
#
# *Test loss: 1.737 ;Test accuracy 0.650 ;IOU accuracy: 0.751 ;Time: 0:01:47
# ==================================================
#
# ==================================================
# TRAIN, ephoc:8; Training B:False; A is a know-it-all:False; ActivateA:False
# Edit: True ;batch:0 ;gs:2376 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.349 ;Aloss:0.181 ;edits ratio:0.022 ;acc:0.455 ;iou:0.610 ;time: 0:00:01
# Edit: True ;batch:50 ;gs:2376 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:4.122 ;Aloss:0.554 ;edits ratio:0.588 ;acc:0.035 ;iou:0.130 ;time: 0:00:11
# Edit: True ;batch:100 ;gs:2376 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.130 ;Aloss:0.546 ;edits ratio:0.464 ;acc:0.540 ;iou:0.650 ;time: 0:00:20
# Edit: True ;batch:150 ;gs:2376 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.861 ;Aloss:0.475 ;edits ratio:0.459 ;acc:0.170 ;iou:0.310 ;time: 0:00:29
# Edit: True ;batch:200 ;gs:2376 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.544 ;Aloss:0.469 ;edits ratio:0.458 ;acc:0.360 ;iou:0.460 ;time: 0:00:40
# Edit: True ;batch:250 ;gs:2376 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.957 ;Aloss:0.561 ;edits ratio:0.455 ;acc:0.215 ;iou:0.370 ;time: 0:00:50
#
# *B Train loss: 2.626 ;A Train loss: 0.547 ;Edit ratio: 0.449 ;Train accuracy: 0.352 ;IOU accuracy: 0.474 ;Time: 0:00:59
#
# VALIDATION, ephoc: 8
# --------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.345 ;B loss: 3.672 ;A loss: 0.420 ;acc: 0.095 ;iou_acc: 0.200 ;time: 0:00:01
# batch: 50 ;edits ratio: 0.349 ;B loss: 2.313 ;A loss: 0.512 ;acc: 0.400 ;iou_acc: 0.495 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.296 ;B loss: 1.903 ;A loss: 0.479 ;acc: 0.635 ;iou_acc: 0.705 ;time: 0:00:16
#
# *B loss: 2.553 ;A loss: 0.478 ;Edit ratio: 0.353 ;Accuracy 0.405 ;IOU accuracy: 0.522 ;Time: 0:00:23
#
# Random choice: True
# batch: 0 ;edits ratio: 0.354 ;B loss: 3.169 ;A loss: 0.835 ;acc: 0.245 ;iou_acc: 0.360 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.357 ;B loss: 1.931 ;A loss: 0.800 ;acc: 0.460 ;iou_acc: 0.590 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.322 ;B loss: 1.487 ;A loss: 0.750 ;acc: 0.675 ;iou_acc: 0.770 ;time: 0:00:15
#
# *B loss: 2.081 ;A loss: 0.806 ;Edit ratio: 0.353 ;Accuracy 0.508 ;IOU accuracy: 0.611 ;Time: 0:00:22
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.471 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:9; Training B:False; A is a know-it-all:False; ActivateA:False
# Edit: True ;batch:0 ;gs:2376 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.391 ;Aloss:0.436 ;edits ratio:0.341 ;acc:0.425 ;iou:0.520 ;time: 0:00:01
# Edit: True ;batch:50 ;gs:2376 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.102 ;Aloss:0.440 ;edits ratio:0.339 ;acc:0.525 ;iou:0.645 ;time: 0:00:11
# Edit: True ;batch:100 ;gs:2376 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.229 ;Aloss:0.454 ;edits ratio:0.354 ;acc:0.500 ;iou:0.600 ;time: 0:00:21
# Edit: True ;batch:150 ;gs:2376 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.529 ;Aloss:0.397 ;edits ratio:0.237 ;acc:0.320 ;iou:0.490 ;time: 0:00:32
# Edit: True ;batch:200 ;gs:2376 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.502 ;Aloss:0.407 ;edits ratio:0.374 ;acc:0.325 ;iou:0.385 ;time: 0:00:41
# Edit: True ;batch:250 ;gs:2376 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:3.693 ;Aloss:0.649 ;edits ratio:0.465 ;acc:0.075 ;iou:0.250 ;time: 0:00:51
#
# *B Train loss: 2.595 ;A Train loss: 0.481 ;Edit ratio: 0.383 ;Train accuracy: 0.381 ;IOU accuracy: 0.499 ;Time: 0:01:00
#
# VALIDATION, ephoc: 9
# --------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.403 ;B loss: 3.773 ;A loss: 0.443 ;acc: 0.065 ;iou_acc: 0.170 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.435 ;B loss: 2.437 ;A loss: 0.540 ;acc: 0.320 ;iou_acc: 0.425 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.314 ;B loss: 1.896 ;A loss: 0.507 ;acc: 0.635 ;iou_acc: 0.710 ;time: 0:00:16
#
# *B loss: 2.644 ;A loss: 0.508 ;Edit ratio: 0.415 ;Accuracy 0.371 ;IOU accuracy: 0.489 ;Time: 0:00:23
#
# Random choice: True
# batch: 0 ;edits ratio: 0.422 ;B loss: 3.247 ;A loss: 0.967 ;acc: 0.250 ;iou_acc: 0.370 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.434 ;B loss: 1.941 ;A loss: 0.884 ;acc: 0.455 ;iou_acc: 0.565 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.417 ;B loss: 1.472 ;A loss: 0.791 ;acc: 0.640 ;iou_acc: 0.710 ;time: 0:00:14
#
# *B loss: 2.154 ;A loss: 0.888 ;Edit ratio: 0.415 ;Accuracy 0.476 ;IOU accuracy: 0.580 ;Time: 0:00:21
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.490 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:10; Training B:False; A is a know-it-all:False; ActivateA:False
# Edit: True ;batch:0 ;gs:2376 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.635 ;Aloss:0.528 ;edits ratio:0.465 ;acc:0.235 ;iou:0.380 ;time: 0:00:01
# Edit: True ;batch:50 ;gs:2376 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.341 ;Aloss:0.448 ;edits ratio:0.308 ;acc:0.340 ;iou:0.485 ;time: 0:00:11
# Edit: True ;batch:100 ;gs:2376 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.916 ;Aloss:0.445 ;edits ratio:0.410 ;acc:0.250 ;iou:0.395 ;time: 0:00:21
# Edit: True ;batch:150 ;gs:2376 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.323 ;Aloss:0.471 ;edits ratio:0.321 ;acc:0.425 ;iou:0.535 ;time: 0:00:31
# Edit: True ;batch:200 ;gs:2376 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:3.030 ;Aloss:0.483 ;edits ratio:0.388 ;acc:0.210 ;iou:0.400 ;time: 0:00:40
# Edit: True ;batch:250 ;gs:2376 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.953 ;Aloss:0.449 ;edits ratio:0.343 ;acc:0.590 ;iou:0.685 ;time: 0:00:50
#
# *B Train loss: 2.568 ;A Train loss: 0.464 ;Edit ratio: 0.361 ;Train accuracy: 0.393 ;IOU accuracy: 0.510 ;Time: 0:01:00
#
# VALIDATION, ephoc: 10
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.262 ;B loss: 3.464 ;A loss: 0.388 ;acc: 0.130 ;iou_acc: 0.260 ;time: 0:00:01
# batch: 50 ;edits ratio: 0.258 ;B loss: 2.190 ;A loss: 0.483 ;acc: 0.445 ;iou_acc: 0.555 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.230 ;B loss: 1.846 ;A loss: 0.411 ;acc: 0.650 ;iou_acc: 0.725 ;time: 0:00:15
#
# *B loss: 2.395 ;A loss: 0.424 ;Edit ratio: 0.241 ;Accuracy 0.469 ;IOU accuracy: 0.579 ;Time: 0:00:22
#
# Random choice: True
# batch: 0 ;edits ratio: 0.243 ;B loss: 3.059 ;A loss: 0.900 ;acc: 0.250 ;iou_acc: 0.390 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.220 ;B loss: 1.651 ;A loss: 0.724 ;acc: 0.570 ;iou_acc: 0.670 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.183 ;B loss: 1.426 ;A loss: 0.797 ;acc: 0.750 ;iou_acc: 0.830 ;time: 0:00:15
#
# *B loss: 1.968 ;A loss: 0.843 ;Edit ratio: 0.240 ;Accuracy 0.557 ;IOU accuracy: 0.659 ;Time: 0:00:22
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.428 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:11; Training B:True; A is a know-it-all:False; ActivateA:False
# Edit: False ;batch:0 ;gs:2377 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.459 ;Aloss:0.403 ;edits ratio:0.244 ;acc:0.365 ;iou:0.510 ;time: 0:00:00
# Edit: False ;batch:50 ;gs:2427 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.754 ;Aloss:0.536 ;edits ratio:0.405 ;acc:0.235 ;iou:0.390 ;time: 0:00:12
# Edit: False ;batch:100 ;gs:2477 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.546 ;Aloss:0.430 ;edits ratio:0.334 ;acc:0.350 ;iou:0.480 ;time: 0:00:24
# Edit: False ;batch:150 ;gs:2527 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.813 ;Aloss:0.412 ;edits ratio:0.403 ;acc:0.330 ;iou:0.450 ;time: 0:00:37
# Edit: False ;batch:200 ;gs:2577 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.859 ;Aloss:0.470 ;edits ratio:0.389 ;acc:0.235 ;iou:0.380 ;time: 0:00:48
# Edit: False ;batch:250 ;gs:2627 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.432 ;Aloss:0.408 ;edits ratio:0.335 ;acc:0.410 ;iou:0.525 ;time: 0:01:00
#
# *B Train loss: 2.515 ;A Train loss: 0.444 ;Edit ratio: 0.350 ;Train accuracy: 0.428 ;IOU accuracy: 0.540 ;Time: 0:01:12
#
# No Edit
# ooooooo
# Edit: False ;batch: 0 ;gs: 2673 ;Blr: 0.050 ;B loss: 1.697 ;acc: 0.605 ;iou: 0.740 ;time: 0:01:12
# Edit: False ;batch: 50 ;gs: 2673 ;Blr: 0.050 ;B loss: 1.924 ;acc: 0.545 ;iou: 0.660 ;time: 0:01:19
# Edit: False ;batch: 100 ;gs: 2673 ;Blr: 0.050 ;B loss: 1.662 ;acc: 0.615 ;iou: 0.710 ;time: 0:01:27
# Edit: False ;batch: 150 ;gs: 2673 ;Blr: 0.050 ;B loss: 1.793 ;acc: 0.610 ;iou: 0.700 ;time: 0:01:34
# Edit: False ;batch: 200 ;gs: 2673 ;Blr: 0.050 ;B loss: 1.910 ;acc: 0.520 ;iou: 0.650 ;time: 0:01:41
# Edit: False ;batch: 250 ;gs: 2673 ;Blr: 0.050 ;B loss: 1.543 ;acc: 0.655 ;iou: 0.745 ;time: 0:01:48
#
# *B Train loss: 1.708 ;Train accuracy: 0.655 ;IOU accuracy: 0.756 ;Time: 0:01:54
#
# TESTING, ephoc: 11
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.312 ;acc: 0.745 ;iou_acc: 0.820 ;time: 0:01:55
# batch: 50 ;B loss: 1.326 ;acc: 0.765 ;iou_acc: 0.810 ;time: 0:02:01
# batch: 100 ;B loss: 1.755 ;acc: 0.525 ;iou_acc: 0.670 ;time: 0:02:08
# batch: 150 ;B loss: 1.301 ;acc: 0.810 ;iou_acc: 0.865 ;time: 0:02:14
# batch: 200 ;B loss: 1.356 ;acc: 0.765 ;iou_acc: 0.840 ;time: 0:02:20
# batch: 250 ;B loss: 1.363 ;acc: 0.775 ;iou_acc: 0.860 ;time: 0:02:26
#
# *Test loss: 1.741 ;Test accuracy 0.645 ;IOU accuracy: 0.745 ;Time: 0:02:31
# ==================================================
#
# ==================================================
# TRAIN, ephoc:12; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:2673 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.914 ;Aloss:0.602 ;edits ratio:0.234 ;acc:0.595 ;iou:0.680 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:2673 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.859 ;Aloss:0.479 ;edits ratio:0.255 ;acc:0.670 ;iou:0.765 ;time: 0:00:09
# Edit: True ;batch:100 ;gs:2673 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.512 ;Aloss:0.383 ;edits ratio:0.246 ;acc:0.380 ;iou:0.535 ;time: 0:00:18
# Edit: True ;batch:150 ;gs:2673 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.963 ;Aloss:0.395 ;edits ratio:0.304 ;acc:0.585 ;iou:0.665 ;time: 0:00:29
# Edit: True ;batch:200 ;gs:2673 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.179 ;Aloss:0.359 ;edits ratio:0.306 ;acc:0.480 ;iou:0.580 ;time: 0:00:38
# Edit: True ;batch:250 ;gs:2673 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.681 ;Aloss:0.479 ;edits ratio:0.365 ;acc:0.305 ;iou:0.400 ;time: 0:00:48
#
# *B Train loss: 2.508 ;A Train loss: 0.433 ;Edit ratio: 0.315 ;Train accuracy: 0.421 ;IOU accuracy: 0.530 ;Time: 0:00:57
#
# VALIDATION, ephoc: 12
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.279 ;B loss: 3.581 ;A loss: 0.359 ;acc: 0.185 ;iou_acc: 0.320 ;time: 0:00:01
# batch: 50 ;edits ratio: 0.314 ;B loss: 2.302 ;A loss: 0.447 ;acc: 0.410 ;iou_acc: 0.515 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.258 ;B loss: 1.826 ;A loss: 0.407 ;acc: 0.665 ;iou_acc: 0.715 ;time: 0:00:15
#
# *B loss: 2.501 ;A loss: 0.427 ;Edit ratio: 0.304 ;Accuracy 0.432 ;IOU accuracy: 0.536 ;Time: 0:00:21
#
# Random choice: True
# batch: 0 ;edits ratio: 0.307 ;B loss: 3.140 ;A loss: 0.996 ;acc: 0.245 ;iou_acc: 0.375 ;time: 0:00:01
# batch: 50 ;edits ratio: 0.304 ;B loss: 1.803 ;A loss: 0.835 ;acc: 0.505 ;iou_acc: 0.610 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.304 ;B loss: 1.482 ;A loss: 0.768 ;acc: 0.735 ;iou_acc: 0.790 ;time: 0:00:15
#
# *B loss: 2.038 ;A loss: 0.862 ;Edit ratio: 0.300 ;Accuracy 0.526 ;IOU accuracy: 0.625 ;Time: 0:00:22
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.463 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:13; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:2673 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.148 ;Aloss:0.369 ;edits ratio:0.288 ;acc:0.460 ;iou:0.565 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:2673 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:3.803 ;Aloss:0.417 ;edits ratio:0.325 ;acc:0.100 ;iou:0.275 ;time: 0:00:09
# Edit: True ;batch:100 ;gs:2673 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.113 ;Aloss:0.491 ;edits ratio:0.274 ;acc:0.825 ;iou:0.905 ;time: 0:00:19
# Edit: True ;batch:150 ;gs:2673 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.164 ;Aloss:0.471 ;edits ratio:0.340 ;acc:0.490 ;iou:0.575 ;time: 0:00:28
# Edit: True ;batch:200 ;gs:2673 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.208 ;Aloss:0.448 ;edits ratio:0.326 ;acc:0.505 ;iou:0.635 ;time: 0:00:39
# Edit: True ;batch:250 ;gs:2673 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.243 ;Aloss:0.381 ;edits ratio:0.345 ;acc:0.450 ;iou:0.515 ;time: 0:00:49
#
# *B Train loss: 2.511 ;A Train loss: 0.429 ;Edit ratio: 0.311 ;Train accuracy: 0.422 ;IOU accuracy: 0.530 ;Time: 0:00:58
#
# VALIDATION, ephoc: 13
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.283 ;B loss: 3.612 ;A loss: 0.368 ;acc: 0.165 ;iou_acc: 0.305 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.322 ;B loss: 2.309 ;A loss: 0.443 ;acc: 0.405 ;iou_acc: 0.510 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.258 ;B loss: 1.826 ;A loss: 0.406 ;acc: 0.665 ;iou_acc: 0.715 ;time: 0:00:15
#
# *B loss: 2.502 ;A loss: 0.425 ;Edit ratio: 0.302 ;Accuracy 0.432 ;IOU accuracy: 0.536 ;Time: 0:00:23
#
# Random choice: True
# batch: 0 ;edits ratio: 0.303 ;B loss: 3.155 ;A loss: 0.942 ;acc: 0.225 ;iou_acc: 0.380 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.279 ;B loss: 1.802 ;A loss: 0.883 ;acc: 0.525 ;iou_acc: 0.635 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.285 ;B loss: 1.473 ;A loss: 0.746 ;acc: 0.695 ;iou_acc: 0.785 ;time: 0:00:15
#
# *B loss: 2.045 ;A loss: 0.860 ;Edit ratio: 0.301 ;Accuracy 0.524 ;IOU accuracy: 0.624 ;Time: 0:00:23
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.457 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:14; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:2673 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.853 ;Aloss:0.440 ;edits ratio:0.327 ;acc:0.280 ;iou:0.410 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:2673 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.447 ;Aloss:0.428 ;edits ratio:0.335 ;acc:0.410 ;iou:0.490 ;time: 0:00:11
# Edit: True ;batch:100 ;gs:2673 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.764 ;Aloss:0.389 ;edits ratio:0.270 ;acc:0.720 ;iou:0.770 ;time: 0:00:21
# Edit: True ;batch:150 ;gs:2673 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.714 ;Aloss:0.468 ;edits ratio:0.356 ;acc:0.305 ;iou:0.420 ;time: 0:00:31
# Edit: True ;batch:200 ;gs:2673 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.021 ;Aloss:0.397 ;edits ratio:0.282 ;acc:0.540 ;iou:0.625 ;time: 0:00:40
# Edit: True ;batch:250 ;gs:2673 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.242 ;Aloss:0.315 ;edits ratio:0.286 ;acc:0.515 ;iou:0.595 ;time: 0:00:50
#
# *B Train loss: 2.505 ;A Train loss: 0.423 ;Edit ratio: 0.304 ;Train accuracy: 0.425 ;IOU accuracy: 0.533 ;Time: 0:01:00
#
# VALIDATION, ephoc: 14
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.296 ;B loss: 3.634 ;A loss: 0.373 ;acc: 0.165 ;iou_acc: 0.290 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.329 ;B loss: 2.334 ;A loss: 0.456 ;acc: 0.390 ;iou_acc: 0.500 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.261 ;B loss: 1.823 ;A loss: 0.420 ;acc: 0.665 ;iou_acc: 0.715 ;time: 0:00:14
#
# *B loss: 2.520 ;A loss: 0.430 ;Edit ratio: 0.312 ;Accuracy 0.426 ;IOU accuracy: 0.530 ;Time: 0:00:21
#
# Random choice: True
# batch: 0 ;edits ratio: 0.271 ;B loss: 3.124 ;A loss: 0.891 ;acc: 0.270 ;iou_acc: 0.385 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.313 ;B loss: 1.871 ;A loss: 0.812 ;acc: 0.500 ;iou_acc: 0.615 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.318 ;B loss: 1.481 ;A loss: 0.831 ;acc: 0.660 ;iou_acc: 0.750 ;time: 0:00:14
#
# *B loss: 2.045 ;A loss: 0.860 ;Edit ratio: 0.308 ;Accuracy 0.522 ;IOU accuracy: 0.621 ;Time: 0:00:22
#
# *AlrDecreaseNum: 0 ; maxDecreaseNum: 6 ;AGain: 0.475 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:15; Training B:True; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:2674 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.677 ;Aloss:0.468 ;edits ratio:0.320 ;acc:0.300 ;iou:0.425 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:2724 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.730 ;Aloss:0.400 ;edits ratio:0.255 ;acc:0.650 ;iou:0.695 ;time: 0:00:14
# Edit: True ;batch:100 ;gs:2774 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.632 ;Aloss:0.390 ;edits ratio:0.271 ;acc:0.650 ;iou:0.750 ;time: 0:00:26
# Edit: False ;batch: 150 ;gs: 2824 ;Blr: 0.050 ;B loss: 1.437 ;acc: 0.735 ;iou: 0.805 ;time: 0:00:41
# Edit: True ;batch:200 ;gs:2874 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.333 ;Aloss:0.431 ;edits ratio:0.379 ;acc:0.405 ;iou:0.500 ;time: 0:00:55
# Edit: True ;batch:250 ;gs:2924 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.299 ;Aloss:0.463 ;edits ratio:0.418 ;acc:0.340 ;iou:0.515 ;time: 0:01:09
#
# *B Train loss: 2.119 ;A Train loss: 0.440 ;Edit ratio: 0.320 ;Train accuracy: 0.494 ;IOU accuracy: 0.606 ;Time: 0:01:21
#
# No Edit
# ooooooo
# Edit: False ;batch: 0 ;gs: 2970 ;Blr: 0.050 ;B loss: 1.774 ;acc: 0.620 ;iou: 0.745 ;time: 0:01:21
# Edit: False ;batch: 50 ;gs: 2970 ;Blr: 0.050 ;B loss: 1.272 ;acc: 0.825 ;iou: 0.860 ;time: 0:01:29
# Edit: False ;batch: 100 ;gs: 2970 ;Blr: 0.050 ;B loss: 1.253 ;acc: 0.840 ;iou: 0.895 ;time: 0:01:36
# Edit: False ;batch: 150 ;gs: 2970 ;Blr: 0.050 ;B loss: 1.460 ;acc: 0.740 ;iou: 0.810 ;time: 0:01:43
# Edit: False ;batch: 200 ;gs: 2970 ;Blr: 0.050 ;B loss: 1.911 ;acc: 0.660 ;iou: 0.750 ;time: 0:01:50
# Edit: False ;batch: 250 ;gs: 2970 ;Blr: 0.050 ;B loss: 1.864 ;acc: 0.620 ;iou: 0.755 ;time: 0:01:58
#
# *B Train loss: 1.722 ;Train accuracy: 0.693 ;IOU accuracy: 0.790 ;Time: 0:02:04
#
# TESTING, ephoc: 15
# # t_data size: 59400
# # t_data batches: 297
# batch: 0 ;B loss: 1.391 ;acc: 0.760 ;iou_acc: 0.855 ;time: 0:02:04
# batch: 50 ;B loss: 1.353 ;acc: 0.760 ;iou_acc: 0.810 ;time: 0:02:10
# batch: 100 ;B loss: 1.813 ;acc: 0.605 ;iou_acc: 0.730 ;time: 0:02:17
# batch: 150 ;B loss: 1.249 ;acc: 0.775 ;iou_acc: 0.860 ;time: 0:02:23
# batch: 200 ;B loss: 1.336 ;acc: 0.780 ;iou_acc: 0.840 ;time: 0:02:29
# batch: 250 ;B loss: 1.326 ;acc: 0.785 ;iou_acc: 0.855 ;time: 0:02:34
#
# *Test loss: 1.753 ;Test accuracy 0.672 ;IOU accuracy: 0.772 ;Time: 0:02:40
# ==================================================
#
# ==================================================
# TRAIN, ephoc:16; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:2970 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.738 ;Aloss:0.351 ;edits ratio:0.324 ;acc:0.630 ;iou:0.710 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:2970 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.690 ;Aloss:0.403 ;edits ratio:0.295 ;acc:0.620 ;iou:0.725 ;time: 0:00:09
# Edit: True ;batch:100 ;gs:2970 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.560 ;Aloss:0.453 ;edits ratio:0.311 ;acc:0.690 ;iou:0.745 ;time: 0:00:20
# Edit: True ;batch:150 ;gs:2970 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.654 ;Aloss:0.375 ;edits ratio:0.280 ;acc:0.690 ;iou:0.750 ;time: 0:00:29
# Edit: True ;batch:200 ;gs:2970 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:2.231 ;Aloss:0.472 ;edits ratio:0.415 ;acc:0.405 ;iou:0.500 ;time: 0:00:38
# Edit: True ;batch:250 ;gs:2970 ;Blr: 0.050 ;Alr:0.100 ;ERP:0.00 ;Bloss:1.840 ;Aloss:0.446 ;edits ratio:0.159 ;acc:0.585 ;iou:0.680 ;time: 0:00:48
#
# *B Train loss: 2.111 ;A Train loss: 0.443 ;Edit ratio: 0.340 ;Train accuracy: 0.489 ;IOU accuracy: 0.602 ;Time: 0:00:57
#
# VALIDATION, ephoc: 16
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.328 ;B loss: 3.181 ;A loss: 0.451 ;acc: 0.210 ;iou_acc: 0.340 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.399 ;B loss: 1.948 ;A loss: 0.433 ;acc: 0.475 ;iou_acc: 0.595 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.285 ;B loss: 1.644 ;A loss: 0.371 ;acc: 0.665 ;iou_acc: 0.745 ;time: 0:00:14
#
# *B loss: 2.123 ;A loss: 0.432 ;Edit ratio: 0.345 ;Accuracy 0.476 ;IOU accuracy: 0.592 ;Time: 0:00:21
#
# Random choice: True
# batch: 0 ;edits ratio: 0.375 ;B loss: 3.051 ;A loss: 0.755 ;acc: 0.315 ;iou_acc: 0.425 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.377 ;B loss: 1.792 ;A loss: 0.705 ;acc: 0.530 ;iou_acc: 0.645 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.323 ;B loss: 1.374 ;A loss: 0.738 ;acc: 0.720 ;iou_acc: 0.805 ;time: 0:00:15
#
# *B loss: 1.953 ;A loss: 0.732 ;Edit ratio: 0.347 ;Accuracy 0.538 ;IOU accuracy: 0.645 ;Time: 0:00:22
#
# *AlrDecreaseNum: 1 ; maxDecreaseNum: 6 ;AGain: 0.170 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:17; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:2970 ;Blr: 0.050 ;Alr:0.080 ;ERP:0.00 ;Bloss:2.410 ;Aloss:0.394 ;edits ratio:0.379 ;acc:0.400 ;iou:0.560 ;time: 0:00:01
# Edit: True ;batch:50 ;gs:2970 ;Blr: 0.050 ;Alr:0.080 ;ERP:0.00 ;Bloss:2.332 ;Aloss:0.403 ;edits ratio:0.341 ;acc:0.365 ;iou:0.525 ;time: 0:00:11
# Edit: True ;batch:100 ;gs:2970 ;Blr: 0.050 ;Alr:0.080 ;ERP:0.00 ;Bloss:2.554 ;Aloss:0.441 ;edits ratio:0.315 ;acc:0.340 ;iou:0.595 ;time: 0:00:22
# Edit: True ;batch:150 ;gs:2970 ;Blr: 0.050 ;Alr:0.080 ;ERP:0.00 ;Bloss:1.731 ;Aloss:0.411 ;edits ratio:0.283 ;acc:0.650 ;iou:0.735 ;time: 0:00:32
# Edit: True ;batch:200 ;gs:2970 ;Blr: 0.050 ;Alr:0.080 ;ERP:0.00 ;Bloss:1.818 ;Aloss:0.392 ;edits ratio:0.278 ;acc:0.575 ;iou:0.655 ;time: 0:00:42
# Edit: True ;batch:250 ;gs:2970 ;Blr: 0.050 ;Alr:0.080 ;ERP:0.00 ;Bloss:1.879 ;Aloss:0.389 ;edits ratio:0.312 ;acc:0.565 ;iou:0.665 ;time: 0:00:51
#
# *B Train loss: 2.110 ;A Train loss: 0.425 ;Edit ratio: 0.335 ;Train accuracy: 0.491 ;IOU accuracy: 0.603 ;Time: 0:01:01
#
# VALIDATION, ephoc: 17
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.352 ;B loss: 3.226 ;A loss: 0.477 ;acc: 0.205 ;iou_acc: 0.325 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.457 ;B loss: 1.962 ;A loss: 0.443 ;acc: 0.445 ;iou_acc: 0.565 ;time: 0:00:08
# batch: 100 ;edits ratio: 0.307 ;B loss: 1.655 ;A loss: 0.371 ;acc: 0.660 ;iou_acc: 0.745 ;time: 0:00:15
#
# *B loss: 2.148 ;A loss: 0.450 ;Edit ratio: 0.379 ;Accuracy 0.454 ;IOU accuracy: 0.573 ;Time: 0:00:22
#
# Random choice: True
# batch: 0 ;edits ratio: 0.373 ;B loss: 3.085 ;A loss: 0.780 ;acc: 0.265 ;iou_acc: 0.400 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.366 ;B loss: 1.821 ;A loss: 0.779 ;acc: 0.525 ;iou_acc: 0.645 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.370 ;B loss: 1.395 ;A loss: 0.785 ;acc: 0.700 ;iou_acc: 0.785 ;time: 0:00:14
#
# *B loss: 1.977 ;A loss: 0.778 ;Edit ratio: 0.378 ;Accuracy 0.521 ;IOU accuracy: 0.629 ;Time: 0:00:21
#
# *AlrDecreaseNum: 1 ; maxDecreaseNum: 6 ;AGain: 0.171 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:18; Training B:False; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:2970 ;Blr: 0.050 ;Alr:0.080 ;ERP:0.00 ;Bloss:2.324 ;Aloss:0.484 ;edits ratio:0.422 ;acc:0.340 ;iou:0.450 ;time: 0:00:01
# Edit: True ;batch:50 ;gs:2970 ;Blr: 0.050 ;Alr:0.080 ;ERP:0.00 ;Bloss:1.574 ;Aloss:0.351 ;edits ratio:0.285 ;acc:0.705 ;iou:0.760 ;time: 0:00:09
# Edit: True ;batch:100 ;gs:2970 ;Blr: 0.050 ;Alr:0.080 ;ERP:0.00 ;Bloss:1.587 ;Aloss:0.405 ;edits ratio:0.280 ;acc:0.670 ;iou:0.760 ;time: 0:00:18
# Edit: True ;batch:150 ;gs:2970 ;Blr: 0.050 ;Alr:0.080 ;ERP:0.00 ;Bloss:1.674 ;Aloss:0.361 ;edits ratio:0.296 ;acc:0.620 ;iou:0.725 ;time: 0:00:27
# Edit: True ;batch:200 ;gs:2970 ;Blr: 0.050 ;Alr:0.080 ;ERP:0.00 ;Bloss:1.889 ;Aloss:0.362 ;edits ratio:0.312 ;acc:0.535 ;iou:0.645 ;time: 0:00:37
# Edit: True ;batch:250 ;gs:2970 ;Blr: 0.050 ;Alr:0.080 ;ERP:0.00 ;Bloss:2.259 ;Aloss:0.460 ;edits ratio:0.395 ;acc:0.375 ;iou:0.470 ;time: 0:00:47
#
# *B Train loss: 2.110 ;A Train loss: 0.419 ;Edit ratio: 0.330 ;Train accuracy: 0.490 ;IOU accuracy: 0.603 ;Time: 0:00:56
#
# VALIDATION, ephoc: 18
# ---------------------
#
# Random choice: False
# batch: 0 ;edits ratio: 0.253 ;B loss: 3.069 ;A loss: 0.384 ;acc: 0.285 ;iou_acc: 0.420 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.253 ;B loss: 1.882 ;A loss: 0.363 ;acc: 0.545 ;iou_acc: 0.665 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.249 ;B loss: 1.624 ;A loss: 0.338 ;acc: 0.685 ;iou_acc: 0.760 ;time: 0:00:15
#
# *B loss: 2.068 ;A loss: 0.376 ;Edit ratio: 0.271 ;Accuracy 0.519 ;IOU accuracy: 0.629 ;Time: 0:00:22
#
# Random choice: True
# batch: 0 ;edits ratio: 0.263 ;B loss: 2.941 ;A loss: 0.793 ;acc: 0.345 ;iou_acc: 0.465 ;time: 0:00:00
# batch: 50 ;edits ratio: 0.224 ;B loss: 1.645 ;A loss: 0.720 ;acc: 0.600 ;iou_acc: 0.715 ;time: 0:00:07
# batch: 100 ;edits ratio: 0.268 ;B loss: 1.375 ;A loss: 0.683 ;acc: 0.715 ;iou_acc: 0.800 ;time: 0:00:14
#
# *B loss: 1.909 ;A loss: 0.750 ;Edit ratio: 0.271 ;Accuracy 0.567 ;IOU accuracy: 0.672 ;Time: 0:00:21
#
# *AlrDecreaseNum: 2 ; maxDecreaseNum: 6 ;AGain: 0.158 ;toTrainA: True
# --------------------------------------------------------------------
#
# ==================================================
#
# ==================================================
# TRAIN, ephoc:19; Training B:True; A is a know-it-all:False; ActivateA:True
# Edit: True ;batch:0 ;gs:2971 ;Blr: 0.050 ;Alr:0.064 ;ERP:0.00 ;Bloss:1.656 ;Aloss:0.319 ;edits ratio:0.234 ;acc:0.630 ;iou:0.730 ;time: 0:00:00
# Edit: True ;batch:50 ;gs:3021 ;Blr: 0.050 ;Alr:0.064 ;ERP:0.00 ;Bloss:2.826 ;Aloss:0.418 ;edits ratio:0.321 ;acc:0.250 ;iou:0.410 ;time: 0:00:14
# Edit: True ;batch:100 ;gs:3071 ;Blr: 0.050 ;Alr:0.064 ;ERP:0.00 ;Bloss:2.167 ;Aloss:0.445 ;edits ratio:0.394 ;acc:0.420 ;iou:0.535 ;time: 0:00:27
# Edit: True ;batch:150 ;gs:3121 ;Blr: 0.050 ;Alr:0.064 ;ERP:0.00 ;Bloss:1.718 ;Aloss:0.682 ;edits ratio:0.289 ;acc:0.695 ;iou:0.755 ;time: 0:00:41
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-ecc2b44354f7> in <module>()
#      33                                     Blr=.05,
#      34                                     Alr=.1,
# ---> 35                                     imScale=1/50)
#      36     edit_rewards_tst.append(tst)
#      37     edit_rewards_trn.append(trn)
#
# <ipython-input-10-1b3b3cd0366c> in train(self, trn_data, tst_data, val_data, ephocs_num, edit_reward, startA, activation_ephoc, muteBnum, start_ephoc, dropout_in, rnn_editProb, dropout_out, dropout_img, dropout_q, queries_editProb, addNoiseImg, imScale, Alr, Blr)
#     914                                                                                             self.batch_size,
#     915                                                                                             addNoiseImg=addNoiseImg,
# --> 916                                                                                             imScale=imScale)
#     917
#     918                         feed_dict = {
#
# <ipython-input-10-1b3b3cd0366c> in build_data(self, data, start, end, imScale, addNoiseImg)
#     558             s = np.std(img_scale, axis=-1, keepdims=True)
#     559             padded_im = imScale*img_scale/(s+halper)  #Scale to have imScale std
# --> 560             padded_im = padded_im - np.mean(padded_im, axis=-1, keepdims=True) # scale to zero mean
#     561
#     562         return qlen, np.array(attn_idx), np.array(padded_queries, dtype=np.int32), padded_im, np.array(padded_bbox), np.array(dist_labels)
#
# KeyboardInterrupt:
