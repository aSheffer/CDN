# %%
import numpy as np
import tensorflow as tf
import json
from datetime import datetime
import os
import sys
sys.path.append('../')
import retriever
from tabulate import tabulate

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
trainset_file = '../data/training/order_train_data.bin'
testset_file = '../data/training/order_test_data.bin'
vocab_file =  '../data/metadata/w2v_vocab.json'
params_dir_tmp = '../data/training/models/All/'
embed_path =  '../data/metadata/w2v.bin'

# %% [markdown]
# <h3>Each entry in this list has the following structure:</h3>
# <ul>
# <li>entry[0]: query indexes </li>
# <li>entry[1:n]: n items where each item is [bounding box vector, bounding box spaital features]. Note that different enteries might have different number of possible  bounding boxes (i.e. different n) </li>
# <li>entry[n+1]: integer, entry[ 1 + entry[n+1]] is the ture bbox </li>
# </ul>

# %%
trainset = np.load(open(trainset_file, 'rb'))
print('Train set batches #:', len(trainset))
print('Train batch size:', len(trainset[0]))
print('Train set data size:', len(trainset)*len(trainset[0]))

testset = np.load(open(testset_file, 'rb'))
print('Test set batches #:', len(trainset))
print('Test Batch size:', len(trainset[0]))
print('Test set data size:', len(trainset)*len(trainset[0]))


with open(vocab_file, 'r') as f:
    vocab = json.loads(f.read())
vocab['<unk>'] = len(vocab)

print("Number of words:", len(vocab))
# Out:
# Train set batches #: 297
# Train batch size: 200
# Train set data size: 59400
# Test set batches #: 297
# Test Batch size: 200
# Test set data size: 59400
# Number of words: 8242

# %%
# w2c words vectors
embed_vecs = np.load(open(embed_path, 'rb')).astype(np.float32)

# %% [markdown]
# <h3> augment_data function </h3>
# <br>We try sevral regularization methods. One of the things I've tried is to add data points where for each data I pick a query from a random data point and a set of bbox from a different random point. We build the labels (bboxes) distribution by giving an equal probability to each label. <br><br>
# The augment_data function does just that but the label of each added poind is writen as -1*number of bboxes. When we build the batch it self (function build_data in class Model), if we see a negative label index, we know its an added point and we know the number of bboxes so we can build the correct distribution.

# %%
def augment_data(data, ratio=0.5, addNoise=False):
        '''
        The function add data points. 
        We pick a query from a random data point,
        and a set of bbox from a different random point and we join them
        to build a new data point. The label distribution of the new data point will 
        uniform, that is, all labels will have equal probability. 
        
        
        Params:
            data: a list of data entries
                                                
        Returns: a list of augmented data
            
                        
        '''
                          
        q_idx = np.random.choice(range(len(data)), int(len(data)*ratio), replace=False)
        im_idx = np.random.choice([i for i in range(len(data)) if i not in q_idx], int(len(data)*ratio))
        for i in range(len(q_idx)):
            q, im = data[q_idx[i]][0], data[im_idx[i]][1:-1]
            item = [q]
            for im_tmp in im:
                item.append(im_tmp)
            item.append(-len(im))
            data.append(item)

# %%
def stats(test, train, ephocs=100, title=None, params=[50, 100, 150, 200]):
    '''
    Plot metrics graphs and print some stats.
    
    Params:
        test: list. 
              Each item is a tuple, [test accuracy, test IOU, test loss]
        
        train: list. 
               Each item is a tuple, [train accuracy, train IOU, train loss, 0]
               For now we can ignore the last part in the tuple (zero)
               
        params: The hyper-parameters to iterate over, defult to number of rnn's hidden units.
    '''
    
    ephocs = range(ephocs)
    test_res = np.array(test)
    train_res = np.array(train)
    test_Glabels = ['test accuracy', 'test IOU', 'test loss']
    train_Glabels = ['train accuracy', 'train IOU', 'train loss']

    for j, param in enumerate(params):
        for i in range(len(train_Glabels)):
            plt.plot(ephocs, test_res[j][:,i])
            plt.plot(ephocs, train_res[j][:,i])
            plt.legend([test_Glabels[i], train_Glabels[i]], loc='upper left')
            if title is not None:
                plt.title('%s: %0.3f'%(title, param))
            plt.show()

            metric = ''.join(train_Glabels[i][len('train')+1:])
            if metric=='loss':
                print('Train min %s:%.3f'%(metric, min(train_res[j][:,i])))
                print('Test min %s:%.3f'%(metric, min(test_res[j][:,i])))
            else:
                print('Train max %s:%.3f'%(metric, max(train_res[j][:,i])))
                print('Test max %s:%.3f'%(metric, max(test_res[j][:,i])))
        print('-'*100,'\n')

# %% [markdown]
# # ALSTM
#
# After running B with no edited words we use this RNN cell which has two LSTM cells, Bcell (for player B) and Acell (for Player A). If is Edit is False, we just run B's cell else it works as follow:
# <ol>
# <li>We run B's cells with the true query input word, getting the un-edited state. If use_worsAttn=True we add attention on the images vectors for each word.</li>
# <li>We run B's cells with the edited input word - 'unk', getting the edited state. If use_worsAttn=True we add attention on the images vectors for each word.</li>
# <li>A uses attention mechanism over all B's outputs on the unedited words (which we got before using this cell).</li>
# <li>A's input are:
# <ul><li>B's unedited state</li><li>The reward for editing a word</li><li>B's loss having no edited words.</li></ul></li>
# <br><li>A's output is then goes throw a transformation which yields two values, one for editing a word and another for not:
# <ul>
#     <li>With probability of editRandomlyProb we ignore A and decide whether to edit or not with probability of rnn_editProb</li>
#     <li>With probability of 1-editRandomlyProb A chooses an action: edit only if the value for edit the word is higher (i.e. we pass B's edited state to the next time step), else we pass B's unedited state.</li></ul>.</li>
# </ol>

# %%
class ALSTM(tf.nn.rnn_cell.LSTMCell):
    def __init__(self, 
                 batch_size, 
                 num_units, 
                 
                 # Size of A's attention vector.
                 words_attn_dim, 
                 # B's outputs (for each time step).
                 words_attn_states, 
                 # Inicates whether attentionvec is a padding (0) or not (1).
                 words_attn_idx, 
                 
                 # Size of B's attention vector ([image vector, spital features] size) .
                 img_attn_dim, 
                 # B's outputs (for each time step).
                 img_attn_states, 
                 
                 
                 # Inicates whether attentionvec is a padding (0) or not (1).
                 img_attn_idx, 
                 
                 unk, #'unk' word vector
                 
                 # Probabilty for choosing an action (edit or not) randomly, 
                 editRandomlyProb, 
                 # Probabilty for edit a word in rnn, when decision are taken randomly.
                 rnn_editProb, 
                 
                 # qeuries_length[i]=length of the i'th query in the batch
                 qeuries_length,
                 
                 # If (qeuries_length[i]-1)-current_timestamp>MIXER_delta
                 # don't edit.
                 MIXER_delta,
                 
                 
                 # Whehter to edit the query or not.
                 isEdit, 
                 
                 # Whether B uses words levlel attention or not.
                 use_wordAttn,
                 
                 # If isIDX is True then use the decisions in set_actions.
                 isIDX,
                 set_actions=None,
                 
                 
                 # Word vector size 
                 word_size=100,
                 
                 # If True add noise instead of using 'unk'
                 useNoise=False,
                 
                 # If useNoise is true word vec = alpha*word_vector+(1-alpha)*noise
                 alpha=.3,
                 
                 # Dropout ratio for rnn's inputs and outpouts
                 dropout_in=1.,
                 dropout_out=1.,
                 
                 #this holds A's rewards and B's losses to
                 # be add to A's feature vectors.
                 reward_loss=None,
                 state_is_tuple=True,):
        
        
        # When useing A, the cell state will contain the concatenation 
        # of both B and A states. Therefore we set the unit number to be
        # 2*(A and B unit size).
        super().__init__(2*num_units+1, state_is_tuple=state_is_tuple)
    
        self.words_attn_states = words_attn_states
        self.words_attn_idx = words_attn_idx
        self.words_attn_dim = words_attn_dim
        
        self.img_attn_states = img_attn_states
        self.img_attn_idx = img_attn_idx
        self.img_attn_dim = img_attn_dim
        
        self.num_units = num_units
        self.batch_size = batch_size
        self.unk = unk 
        self.isEdit = isEdit
        self.use_wordAttn=use_wordAttn
        
        # To avoide using dropout twice on the same input, if isEdit is true
        # Bcell will only use dropout for its inputs. We'll add dropout to B's outputs
        # only after A's action was taken.
        self.Acell = tf.contrib.rnn.DropoutWrapper(
            tf.nn.rnn_cell.LSTMCell(self.num_units, state_is_tuple=True), 
            input_keep_prob=dropout_in, 
            output_keep_prob=dropout_out
        )
      
        self.Bcell_tmp = tf.nn.rnn_cell.LSTMCell(self.num_units, state_is_tuple=True)
            
        
        self.rnn_editProb = rnn_editProb
        self.reward_loss = reward_loss
        self.useNoise=useNoise
        self.alpha=alpha
        self.MIXER_delta=MIXER_delta
        
        self.isIDX=isIDX
        self.set_actions=set_actions
        self.editRandomlyProb = editRandomlyProb
        self.dropout_in = dropout_in
        self.dropout_out = dropout_out
        self.word_size=word_size
        self.qeuries_length = qeuries_length
        

    def call(self, inputs, state):
        '''
        Params:
            inputs: word embadding.
            state:  [B's state form privious state, A's state form privious state]
        '''
        # takse B's state from state[:self.num_units]
        Bstate_c = tf.slice(state[0], [0, 0], [-1, self.num_units])
        Bstate_h = tf.slice(state[1], [0, 0], [-1, self.num_units])
        self.Bstate =  tf.nn.rnn_cell.LSTMStateTuple(c=Bstate_c, h=Bstate_h)
        
        if self.use_wordAttn:
            words_attn = self.attention(Bstate_h, self.img_attn_states, self.img_attn_dim, self.img_attn_idx)

        
        # If isEdit==True 
        def f1(): 
            # If B's cell uses attention
            self.Bcell = tf.contrib.rnn.DropoutWrapper(
                    self.Bcell_tmp, input_keep_prob=self.dropout_in)
            
            # If B uses words level attention over BBOXes.
            if self.use_wordAttn:
                new_input = tf.concat([inputs, words_attn], -1)
                Boutputs, Bnew_state =  self.Bcell(new_input, self.Bstate, 'Bcell')
            else:
                Boutputs, Bnew_state =  self.Bcell(inputs, self.Bstate, 'Bcell')
            
            # takse A's state from state[self.num_units: 2*self.num_units]
            Astate_c = tf.slice(state[0], [0, self.num_units], [-1, self.num_units])
            Astate_h = tf.slice(state[1], [0, self.num_units], [-1, self.num_units])
            self.Astate =  tf.nn.rnn_cell.LSTMStateTuple(c=Astate_c, h=Astate_h)
            
            # Current time step is in the state[-1]
            self.timesteps = tf.slice(state[1], [0, 2*self.num_units], [-1, 1])
            self.timestep = tf.cast(self.timesteps[0][0], tf.int32)
            
            # If timestep_delta[i]=0, don't edit the i'th word in the batch
            self.timestep_delta = tf.cast(tf.less_equal(
                tf.expand_dims(self.qeuries_length-1, 1)-tf.cast(self.timesteps, tf.int32), self.MIXER_delta), tf.float32)
            
            
            if self.useNoise: # just add noise to the edited words
                new_unk_vecs = self.alpha*inputs + (1-alpha)*tf.random_normal(shape=inputs.get_shape(), stddev=0.1)
            else: # change the edited words by 'unk'
                '''
                We build Wnoise so that when A decides to edit, the edited word's vector
                will be Wnoise[i], which is sampled from normal distribution, N(Qmean[i], Qstd[i]),
                where Qmean[i] and Qstd[i] are the same as the mean and std of the i'th 
                input's word.
                '''
                Qmean = tf.reduce_mean(inputs, axis=-1, keep_dims=True) # Qmean[i] = i'th input's word mean
                Qstd = tf.contrib.keras.backend.std(inputs, axis=-1, keepdims=True) # Qstd[i]= i'th input's word std
                Wnoise = tf.random_normal(shape=[self.batch_size, self.word_size], mean=Qmean, stddev=Qstd) 
            
            # run B's cell with unk_batch
            if self.use_wordAttn:
                new_unk = tf.concat([Wnoise, words_attn], -1)
            else:
                new_unk = Wnoise
            edit_output, edit_new_state = self.Bcell(new_unk, self.Bstate, 'Bcell')  
            out1, state1 = self.runCell(Boutputs, Bnew_state, edit_new_state)
            return out1, state1
        
        def f2(): #If we don't edit
            # If B's cell uses attention
            self.Bcell = tf.contrib.rnn.DropoutWrapper(
                    self.Bcell_tmp, output_keep_prob=self.dropout_out, input_keep_prob=self.dropout_in)
            
            if self.use_wordAttn:
                new_input = tf.concat([inputs, words_attn], -1)
                Boutputs, Bnew_state =  self.Bcell(new_input, self.Bstate, 'Bcell')
            else:
                Boutputs, Bnew_state =  self.Bcell(inputs, self.Bstate, 'Bcell')
                
            outs = tf.concat([Boutputs, tf.zeros((self.batch_size, self.num_units+1))], 1)
            new_state_c = tf.concat([Bnew_state[0], tf.zeros((self.batch_size, self.num_units+1))], 1)
            new_state_h = tf.concat([Bnew_state[1], tf.zeros((self.batch_size, self.num_units+1))], 1)
            return outs, tf.nn.rnn_cell.LSTMStateTuple(c=new_state_c, h=new_state_h)
        
        new_output, new_state = tf.cond(self.isEdit, f1, f2)
        
        return new_output, new_state
    
    def runCell(self, Boutputs, Bnew_state, edit_new_state):
        '''
        Run B's cell after editing.
        
        params:
            Boutputs: output vector without editing.
            Bnew_state: state vector without editing.
            edit_new_state: state vector after editing the input word to 'unk'. 
        '''
        
        with tf.variable_scope('runcell'):
            # get action values according to B's hidden state
            Aout, Anew_state, actions_vals = self.action_vals(Boutputs) 
            
            def g1():
                '''
                If isIDX use the decisions in self.action_idx
                '''
                return tf.slice(self.set_actions, [0,self.timestep], [-1, 1])
            
            def g2():
                # A choose to edit a word if actions_vals[0]<actions_vals[1].
                # Note: if we edit the word cond=1, else cond=0.
                a1, a2 = tf.split(value=actions_vals, num_or_size_splits=2, axis=1)
                A_choice = tf.cast(tf.less(a1, a2), tf.float32)

                # If action is chosen randomly, edit word with probability self.rnn_editProb
                # Note: if we edit the word cond=1, else cond=0.
                rand = tf.multinomial(tf.log([[self.rnn_editProb, 1-self.rnn_editProb]]), self.batch_size)
                rand_choice = tf.cast(tf.less(tf.transpose(rand), 1), tf.float32) 

                # Choose whether to edit a word randomly with probability of editRandomlyProb
                editRandomly = tf.multinomial(tf.log([[self.editRandomlyProb, 1-self.editRandomlyProb]]), self.batch_size)
                editRandomly_choice = tf.cast(tf.less(tf.transpose(editRandomly), 1), tf.float32)

                # A list of decisions for each word in the batch. actions_idx[i] = 1->edit word in query i (at this time step), 0->do not edit.
                return self.timestep_delta*(editRandomly_choice*rand_choice + (1-editRandomly_choice)*A_choice)

            
            # a list of A's decisions for each batch.  1->edit, 0-> do not edit.
            cond = tf.cast(tf.cond(self.isIDX, g1, g2), tf.float32)

            # We'd like to know the action values and decision for each word,
            # therefore theses info are placed on the first 3 dimensions of the 
            # output vector. Note that this vector is not passed to the 
            # next tiee step so it won't affect the model. 
            outs = tf.concat([actions_vals, cond], 1)

            # B's i state is replaced by the edited state if cond[i]=1 (i =1, 2, ..., batch_size)
            new_edit_state_c = (1-cond)*Bnew_state[0] + cond*edit_new_state[0]
            new_edit_state_h = (1-cond)*Bnew_state[1] + cond*edit_new_state[1]


            new_outs = tf.concat([outs, tf.zeros((self.batch_size, 2*self.num_units-3)), self.timesteps+1], 1)
            new_state_c = tf.concat([new_edit_state_c, Anew_state[0], self.timesteps+1], 1)
            new_state_h = tf.concat([new_edit_state_h, Anew_state[1], self.timesteps+1], 1)
            return new_outs, tf.nn.rnn_cell.LSTMStateTuple(c=new_state_c, h=new_state_h)
    
    
    def action_vals(self, Boutputs):
        '''
        Get values for editing/not editing the input word.
        
        Params:
            Boutputs: output vector without editing.
            
        Returns vals where:
            Aout: A's cell output
            Anew_state: A's cell state
            vals: Tensor where vals[0] is the value for not editing the word 
                    and vals[1] is the value for editing the word.
        '''
        
        with tf.variable_scope('action_vals') as scope:
            Aattn = self.attention(self.Astate[1], self.words_attn_states, self.words_attn_dim, self.words_attn_idx)
            
            # A's input: [input, B's output, attntion state, reward, B's loss with no edits]
            Anew_inputs = tf.concat([Boutputs, Aattn, self.reward_loss], 1)
            
            Aout, Anew_state = self.Acell(Anew_inputs, self.Astate, 'Acell')
            vals = tf.nn.relu(self.linear(Aout, 2))

            # Save the variables that only A uses. 
            # These variables will be trained separately from B's model.
            self.Avars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=scope.name)
            
            return Aout, Anew_state, vals
            
        
    def linear(self, inputs, output_dim, scope='linear', bias=True, reuse=False):
        with tf.variable_scope(scope, reuse=False):
            W = tf.get_variable('W', initializer=tf.random_uniform_initializer(maxval=1., minval=-1.),
                                shape=(inputs.get_shape()[-1], output_dim))
            if bias:
                b = tf.get_variable('b', initializer=tf.constant_initializer(0.1),
                               shape=[1, output_dim])
                return tf.matmul(inputs, W) + b

        return tf.matmul(inputs, W)
    
    
    def attention(self, state, attn_states, attn_dim, attn_idx, relu=False):
        '''
        Attention mechanism (see https://arxiv.org/pdf/1409.0473.pdf)
        
        state: State from previous time step.
        attn_states: Attetntion states. 
                     Tensor of shape (batch_size x max([len(attention_vectors[i]) for i in range(bach_size)]) x attn_dim)
        attn_dim: Attention vector size.
        attn_idx,: Tensor used for masking of shape (batch_size x max([len(attention_vectors[i]) for i in range(bach_size)]). 
                   attn_idx[i, j]=1 if the j's attention vcctior of sample i  is not padding, else its equat to 0.
        '''
        with tf.variable_scope('attn'):
            self.attn_length = tf.shape(attn_states)[1]  

            # Computing... hidden_attn = W*v_att (use tf.nn.conv2d for efficiency)
            attn_vecs = tf.reshape(attn_states, [self.batch_size, self.attn_length, 1, attn_dim])
            W = tf.get_variable("attn_W", [1, 1, attn_dim, self.num_units])
            hidden_attn = tf.nn.conv2d(attn_vecs, W, [1, 1, 1, 1], "SAME")

            # Computing... hidden_s = U*v_state
            hidden_s = tf.reshape(
                self.linear(
                    tf.cast(state, tf.float32), output_dim=self.num_units, scope='hidden_s_linear'), [-1, 1, 1,  self.num_units], name='hidden_s')

            # Computing alpha
            v = tf.get_variable("attn_v", [self.num_units])
            if relu:
                logits = tf.reduce_sum(v * tf.nn.relu(hidden_attn + hidden_s), [2, 3])
            else:
                logits = tf.reduce_sum(v * tf.nn.tanh(hidden_attn + hidden_s), [2, 3])

            # Masked softmax
            max_logits = tf.reduce_max(logits, axis=-1)
            masked_logits = tf.exp(logits-tf.expand_dims(max_logits, axis=1))*attn_idx
            alpha = masked_logits/tf.reduce_sum(masked_logits, axis=-1, keep_dims=True)

            a = tf.reduce_sum(tf.reshape(alpha, [-1, self.attn_length, 1, 1]) * attn_vecs, [1, 2])
            b = tf.contrib.layers.fully_connected(a, num_outputs=self.num_units)


            return b

# %% [markdown]
# # Training
# When A joins the game, each iteration is completed via three steps:
# <ul>
# <li>We feed the query as it is to B and run it alone (no optimization nor training is done at this step)</li>
# <li>We calculate B's loss per query and use it to calculate the reward for query i as follow: <br> <br><b>edit_reard*Bloss_i/length_of_query_i</b><br>
# <li>We run A and B together (no optimization nor training is done at this step). At this step we get A's decition and B's loss on the edited query. We use B's loss to calculate the Bellman's value for each time step. </li>
# <li>We again run A and B together, forcing A to make the same actions it did as in the previous run. Since now we know the real value, action and reward for each time step (these will be the same as in the previous step since we did not train optimize the parameters yet), we finaly train the model</li>
# </ul>
# <br>
# But first we check the model's performance with out A. Class Model has a set of conditioning variables that set a different ragularization methods in the model. We start by checking them with out A's interference. We can also make the model RNN become bidirectional (by setting useBidirectionalRnn to True) and use words level attention (by setting use_wordAttn to True).

# %%
class Model():
    def __init__(self,
                 batch_size, 
                 num_hidden, 
                 
                 #Image's vector size.
                 img_dims, 
                 
                 #Spaital features length.
                 bbox_dims, 
                 vocab, 
                 lr, #  B's learning rate.
                 decay_steps, 
                 decay_rate, 
                 
                 # A's leanring rate = B's learning rate x coefAlr.
                 coefAlr,
                 
                 # whether to use bach normaliztion for the last attention layer
                 bnorm,
                 embed_size=embed_vecs.shape[1],
                 
                 # Whether B uses words levlel attention or not.
                 use_wordAttn=False,
                 
                 # Whther to use bidirectional rnn
                 useBidirectionalRnn=False,
                 
                 # Urnn_norm: Whether to use batch normalization for the queries.
                 # Uatt_norm: Whether to use batch normalization for the VGG outputs.
                 Urnn_norm=True, 
                 Uatt_norm=True,
                 
                 # If useNoise, A add Normal noise to a word 
                 # instead of editing it: word_vec = alpha*word_vec+(1-alpha)*noise
                 useNoise=False,
                 alpha=.5,
                
                 # Whether to scale and normelize queries 
                 # embedding to have zero mean and QSTD std
                 toQscale = False,
                 Qstd = 0.1):
        
        self.batch_size = batch_size
        self.img_dims = img_dims
        self.bbox_dims = bbox_dims 
        self.num_hidden = num_hidden
        self.embed_size = embed_size
        self.vocab = vocab
        self.lr = lr
        self.toQscale=toQscale
        self.Qstd=Qstd

        # Probabilty for choosing an action (edit or not) randomly, 
        self.editRandomlyProb = tf.placeholder(tf.float32, name='editRandomlyProb_holder')
        # If the action is chosen randomly. edit with probability of rnn_editProb
        self.rnn_editProb = tf.placeholder(tf.float32, name='rnn_editProb_holder')

        self.queries = tf.placeholder(tf.int32, [None, None], name='queries')
        self.img  = tf.placeholder(tf.float32, [None, None, self.img_dims], name='img')# VGG output vectors
        self.bboxes = tf.placeholder(tf.float32, [None, None, self.bbox_dims], name='bboxes')# spatial bbox's features.

        # attn_idx: inicates whether attention box is a dummy (0) or not (1).
        self.attn_idx = tf.placeholder(tf.float32, [None, None], name='attn_idx')
        
        # If isIDX is True then use the decisions in set_actions instead of A's decisions.
        # We use it to force A to take the decitions it made while we calculated the bellman values.
        self.isIDX = tf.placeholder(tf.bool, name='isIDX_holder')
        self.set_actions = tf.placeholder(tf.float32, [None, None], name='actions_idx_holder')

        self.labels = tf.placeholder(tf.float32, [None, None], name='labels')
        self.isEdit = tf.placeholder(tf.bool, name='isEdit') # whehter to edit the query or not.
        
        self.MIXER_delta = tf.placeholder(tf.int32, name='mixer_delta_place_holder')


        # this holds A's rewards and B losses per query, to be add to A's feature vectors.
        self.reward_loss = tf.placeholder(tf.float32, [None,2], name='rewards_loss')

        # Dropout ratio for rnn's inputs and outpouts
        self.dropout_in = tf.placeholder(tf.float32, name='dropoutIn_holder')
        self.dropout_out = tf.placeholder(tf.float32, name='dropoutOut_holder')

        # Dropout ratio for attention vector (for the final attention layer before the loss function)
        self.dropout_img = tf.placeholder(tf.float32, name='dropoutImg_holder')
        # Dropout ratio for query vector (for the final attention layer before the loss function)
        self.dropout_q = tf.placeholder(tf.float32, name='dropoutImg_holder')

        # B outputs vectors (with no words edits), These are A's attention vectors
        # which it uses to decide whter to edit a word.
        self.Aattn_vecs = tf.placeholder(tf.float32, [None, None, None], name='Aattn_vecs_holder')    
        self.unk = tf.constant([[vocab['<unk>']]], tf.int32)

        self.isTrain = tf.placeholder(tf.bool, name='isTrain_holder') 
        self.queries_lens = self.length(self.queries) # list of all the lengths of the batch's queriey 

        # Concatinate images vectors and their spaital features. 
        # These vectors wlll be used for attenionn when 
        # we calculate the loss function.
        attn_vecs = tf.concat([self.img, self.bboxes], 2) 
        voc_size = len(self.vocab)

        # Load pre-trained word imaddings.
        # w2v_embed is not trainable.
        with tf.variable_scope('w2v'):
            w2v_embed = tf.get_variable('w2v_embed', initializer=embed_vecs, trainable=False)
            w2v_queries = tf.nn.embedding_lookup(w2v_embed, self.queries, name='w2v_queries')

        with tf.variable_scope('embed'):
            embed = tf.get_variable('embed', shape=[voc_size, self.embed_size], 
                                    initializer=tf.random_uniform_initializer(minval=-0.1, maxval=0.1))
            embed_queries_tmp = tf.nn.embedding_lookup(embed, self.queries, name='embed_queries')

        embed_queries = embed_queries_tmp+w2v_queries

        with tf.variable_scope('rnn'):
            Aattn_idx = tf.cast(tf.abs(tf.sign(self.queries)), tf.float32)


            cell = ALSTM(num_units=self.num_hidden, 
                            words_attn_dim=self.num_hidden, 
                            words_attn_states=self.Aattn_vecs, 
                            words_attn_idx=Aattn_idx,
                            img_attn_dim=self.img_dims+self.bbox_dims,
                            img_attn_states=attn_vecs,
                            img_attn_idx=self.attn_idx,
                            batch_size=self.batch_size, 
                            unk=tf.nn.embedding_lookup(embed, self.unk), rnn_editProb=self.rnn_editProb,
                            isEdit=self.isEdit, dropout_in=self.dropout_in, dropout_out=self.dropout_out,
                            reward_loss=self.reward_loss, use_wordAttn=use_wordAttn,
                            isIDX=self.isIDX, set_actions=self.set_actions, editRandomlyProb=self.editRandomlyProb,
                            useNoise=useNoise, alpha=alpha, MIXER_delta=self.MIXER_delta, qeuries_length=self.queries_lens)

            if useBidirectionalRnn:
                self.outputs, self.last_states = tf.nn.bidirectional_dynamic_rnn(
                    cell_fw=cell,
                    cell_bw=cell,
                    dtype=tf.float32,
                    sequence_length=self.queries_lens,
                    inputs=embed_queries)

                # self.last_states contain both forward state
                # and backward state.
                # We don't use A with bidirectional rnn
                # so no need for self.values (action values as calculated by A)
                Bstate = tf.concat(
                    [tf.slice(self.last_states[0][1], [0,0], [-1, self.num_hidden]), 
                     tf.slice(self.last_states[1][1], [0,0], [-1, self.num_hidden])], -1)
            else:
                self.outputs, self.last_states = tf.nn.dynamic_rnn(
                    cell=cell,
                    dtype=tf.float32,
                    sequence_length=self.queries_lens,
                    inputs=embed_queries)

                # self.values[0]=value for not editing, self.values[1]=value for editing
                self.values = tf.slice(self.outputs, [0,0,0], [-1,-1,2])
                Bstate = tf.slice(self.last_states[1], [0,0], [-1, self.num_hidden])  


        # The variable A uses
        Avars = cell.Avars

        if bnorm: # If using batch normalization 
            self.scores = self.bnorm_attention(Bstate, Urnn_norm=Urnn_norm, Uatt_norm=Uatt_norm) 
        else:
            self.scores = self.attention(Bstate) 


        # Cross entophy loss for each of the queries in the batch.
        self.B_ce = -tf.reduce_sum(
                        self.labels*tf.log(self.scores+0.00000001)+
                            (1-self.labels)*tf.log((1-self.scores)+0.00000001), 
                            axis=-1)


        # We don't use A with bidirectional rnn
        if not useBidirectionalRnn:
            # A's decision for each word.
            self.idx = tf.squeeze(tf.slice(self.outputs, [0,0,2], [-1,-1,1]))

            self.edit_num = tf.reduce_mean(tf.reduce_sum(
                tf.cast(self.idx, tf.float32)*tf.expand_dims(
                        1/tf.cast(self.queries_lens, tf.float32), axis=1), axis=1))

            # After running A for the first time, we get A's decisions and their values.
            # we then calulate the following tensors:
            # actions_idx[j,i] = 1 if the word i in query j was edited or 0 otherwise.     
            # bell_vall holds the values for each decision by the bellman function. 

            # self.actions_idx will be used to get the values of the action that were taken by A.                 
            self.actions_idx = tf.placeholder(shape=[None, None], dtype=tf.int32, name="actions_idx")
            self.bell_val = tf.placeholder(shape=[None, None], dtype=tf.float32, name="bell_val")

            # pyrite_val: holds the values for each of A's decisions, claculated by A. 
            # see https://en.wikipedia.org/wiki/Pyrite.
            self.pyrite_val = tf.reshape(tf.gather_nd(tf.reshape(self.values, (-1,2)), self.actions_idx), (self.batch_size, -1))

            # RMSE loss (adding smoothing factor so the gradient won't divide by zero)
            self.A_loss = tf.reduce_mean(tf.reduce_sum(
                tf.sqrt(tf.square((self.bell_val-self.pyrite_val+0.000001)*tf.cast(
                    tf.sign(tf.abs(self.queries)), tf.float32)))/tf.expand_dims(
                                                    tf.cast(self.queries_lens, tf.float32), axis=1), axis=-1))

        self.B_loss = tf.reduce_mean(self.B_ce)

        ##############
        # Optimizers #
        ##############

        starter_learning_rate = self.lr
        self.global_step = tf.Variable(0, name='global_step', trainable=False)
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,
                                                       decay_steps=decay_steps, decay_rate=decay_rate, staircase=True)

        if not useBidirectionalRnn:
            # Train only A variables 
            self.A_optimizer =  tf.train.GradientDescentOptimizer(
                    learning_rate=coefAlr*self.learning_rate).minimize(self.A_loss, var_list=Avars)  

        # Train only B variables 
        Bvars = [var for var in tf.trainable_variables() if var not in Avars]
        self.B_optimizer =  tf.train.GradientDescentOptimizer(
                    learning_rate=self.learning_rate).minimize(self.B_loss, global_step=self.global_step, var_list=Bvars)  

        if not os.path.exists(params_dir):
                os.makedirs(params_dir)
        self.saver = tf.train.Saver()

        
    def length(self, seq):
        '''
        Retruns real lengths (before addings) of all queries in seq  .
        '''
        return tf.cast(tf.reduce_sum(tf.sign(tf.abs(seq)), reduction_indices=1), tf.int32)
       

    def linear(self, inputs, output_dim, scope='linear', bias=True, reuse=False):

        with tf.variable_scope(scope, reuse=reuse):
            W1 = tf.get_variable('W1', initializer=tf.contrib.layers.xavier_initializer(),
                                shape=(inputs.get_shape()[-1], output_dim))
            if bias:
                b = tf.get_variable('b', initializer=tf.constant_initializer(0.1),
                               shape=[1, output_dim])
                return tf.matmul(inputs, W1) + b
            
            return tf.matmul(inputs, W1)

            
    def Qscale(self, qVecs):
        '''
        Scale queries embedding vectors to have zero mean and std STD.
        
        Params:
            qVecs: Tensor (shape: batch_size x number_of_hidden_units) 
                   holding the queries vectors, 
        '''
        qVecs_min = tf.reduce_min(qVecs, axis=-1, keep_dims=True)
        qVecs_max = tf.reduce_max(qVecs, axis=-1, keep_dims=True)
        qVecs_scale = (qVecs-qVecs_min)/(qVecs_max-qVecs_min) # Scale to 0-1
        s = tf.contrib.keras.backend.std(qVecs_scale, axis=-1, keepdims=True)
        tmp = self.Qstd * qVecs_scale/s #Scale to have self.Qstd std
        new_qVecs = tmp - tf.reduce_mean(tmp, axis=-1, keep_dims=True) # zero mean
        
        return new_qVecs
    
    def attention(self, q_embed):
        '''
        Given B's output vector, calculate the attention over 
        all the query's bounding boxes vectors, That is, calculate:
        
        probs = softmax(relu(context(Sq+Satt+b)))
        
        Where:
        Sq = <Wq, queries_states>
        Sattn = <Wattn, attention_bboxes_vectors>
        
        The  bounding box with the highest attention score will be chosen as the correct bounding box.
        
        Params:
            q_embed: Tensor of shape (batch size x num_hidden)B's outputs. 
            
        Returns:
            probs: Tensor of shape (batch_size x max bbox number for query).
                   Attention score for each bbox.
        '''
        # concatenate img vectors with spaical features
        attn_vecs = tf.concat([self.img, self.bboxes], 2)
        
        # B's outputs, shape: (batch size x num_hidden)
        if self.toQscale:
            Urnn = self.Qscale(q_embed)
        else:
            Urnn = q_embed
        
        # Attention vectors, 
        # shape: (batch size x max bbox number for query x attention vector size)
        Uatt = attn_vecs
           
        with tf.variable_scope('l1'):
            b = tf.get_variable(
                    'b', 
                    initializer=tf.constant_initializer(0.1), 
                    shape=[1, self.num_hidden])

            context = tf.get_variable(
                    'context', 
                    initializer=tf.random_uniform_initializer(minval=-0.1, maxval=0.1), 
                    shape=[self.num_hidden, 1])


            Sq = tf.nn.dropout(
                self.linear(Urnn, self.num_hidden, bias=False, scope='Sq'), 
                self.dropout_q)
            
            Sattn = tf.nn.dropout(
                tf.reshape(
                    self.linear(
                        tf.reshape(Uatt, (-1, self.img_dims+self.bbox_dims)), 
                        self.num_hidden, 
                        bias=False, scope='Sattn'), 
                    [self.batch_size, -1, self.num_hidden]),
                self.dropout_img)

        out = tf.nn.relu(tf.expand_dims(Sq, 1) + Sattn + b)
        logits = tf.reshape(tf.matmul(tf.reshape(out, (-1, tf.shape(out)[-1])),  context), (tf.shape(out)[0], -1))

        # Calculate logits's masked softmax (we use self.attn_idx to mas
        max_logits = tf.reduce_max(logits, axis=-1)
        masked_logits = tf.exp(logits-tf.expand_dims(max_logits, axis=1))*self.attn_idx
        probs = self.attn_idx*masked_logits/tf.reduce_sum(masked_logits, axis=-1, keep_dims=True)

        return probs

    
    def bnorm_attention(self, q_embed, Urnn_norm=True, Uatt_norm=True):
        '''
        Given B's output vector, calculate the attention over 
        all the query's bounding boxes vectors using batch normalization. , That is, calculate:
        
        probs = softmax(relu(context(Sq+Satt+b)))
        
        Where:
        Sq = <Wq, queries_states>
        Sattn = <Wattn, attention_bboxes_vectors>
        
        The  bounding box with the highest attention score will be chosen as the correct bounding box.
        This function uses batch normalization. 
        
        Params:
            q_embed: Tensor of shape (batch size x num_hidden)B's outputs. 
            Urnn_norm: Whether to use batch normalization for the queries.
            Uatt_norm: Whether to use batch normalization for the VGG outputs.
            
        Returns:
            probs: Tensor of shape (batch_size x max bbox number for query).
                   Attention score for each bbox.
        '''
        # concatenate img vectors with with spaical features
        attn_vecs = tf.concat([self.img, self.bboxes], 2)
        
        if Urnn_norm:
            # B's outputs with bath normalization. 
            # shape: (batch size x num_hidden)
            Urnn = tf.contrib.layers.batch_norm(
                q_embed, center=True, scale=True, is_training=self.isTrain) 
        else:
            Urnn = q_embed
        
        if Uatt_norm:
            # Attention vectors with bath normalization. 
            # shape: (batch size x max bbox number for query x attention vector size)
            Uatt = tf.contrib.layers.batch_norm(
                attn_vecs, center=True, scale=True, is_training=self.isTrain)
        else:
            Uatt = attn_vecs
        
           
        update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
        with tf.control_dependencies(update_ops):
            with tf.variable_scope('bnorm_l1'):
                b = tf.get_variable(
                        'b', 
                        initializer=tf.constant_initializer(0.1), 
                        shape=[1, self.num_hidden])

                context = tf.get_variable(
                        'context', 
                        initializer=tf.random_uniform_initializer(minval=-0.1, maxval=0.1), 
                        shape=[self.num_hidden, 1])


                Sq = tf.nn.dropout(
                    self.linear(Urnn, self.num_hidden, bias=False, scope='Sq'), 
                    self.dropout_q)
                
                Sattn = tf.nn.dropout(
                            tf.reshape(
                                self.linear(
                                    tf.reshape(Uatt, (-1, self.img_dims+self.bbox_dims)), 
                                    self.num_hidden, 
                                    bias=False, scope='Sattn'), 
                                 [self.batch_size, -1, self.num_hidden]),
                            self.dropout_img)
                    
                   
            out = tf.nn.relu(tf.expand_dims(Sq, 1) + Sattn + b)
            logits = tf.reshape(tf.matmul(tf.reshape(out, (-1, tf.shape(out)[-1])),  context), (tf.shape(out)[0], -1))

            # Calculate logits's masked softmax (we use self.attn_idx to mas
            max_logits = tf.reduce_max(logits, axis=-1)
            masked_logits = tf.exp(logits-tf.expand_dims(max_logits, axis=1))*self.attn_idx
            probs = self.attn_idx*masked_logits/tf.reduce_sum(masked_logits, axis=-1, keep_dims=True)

            return probs
  
        
    def q_padding(self, seq, max_length):
        '''
        Pad  seq with vocab['<pad>'] (0) to max_length length.
        '''                  
        return seq + [self.vocab['<pad>']]*(max_length-len(seq))

    
    def build_data(self, data, start, end, imScale, addNoise=False):
        '''
        Build batch.
        ------------
        
        Params:
            data: each entry in this list has the following structure:
                  [query indexes, [bounding box vector (VGG), bounding box spaital features], ..., 
                  [bounding box vector (VGG), bounding box spaital features], index of the true label]
                  
            start/end: batch data is built from data[start:end]
            
        Returns:
            attn_idx: attn_idx[i, j]=1 if the j'th bbox in the i'th query is not padding, else equals to 0. 
            
            padded_queries: list of queries, padded to the length of the longest query in the batch.
                            Note: vocab['pad']=0
                            
            padded_im: list of bounding boxes vectors, padded to the maximum number of bbox per query.
                       Note: padded vector is vector of zeros. 
                            
            padded_bbox: list of bounding boxes spatial features, padded to the maximum number of bbox per query.
                         Note: padded vector is vector of zeros.  
        
            onehot_labels: onehot_labels[i][j]=1 if j is the true bbox for query i, else  onehot_labels[i][j]=0
            
            addNoise: Boolean. Whether to add normal noise to the images.
            
            imScale: If not None, scale the image vectors (VGG16 outputs) to have 0 mean and 1imScale std
                        
        '''
                          
        qlen = max([len(data[i][0]) for i in range(start, end)]) # Length fo the longest query
        imlen = max([len(data[i]) for i in range(start, end)])-2 # Maximum number of bbox per query.
        padded_queries, padded_im, padded_bbox, attn_idx = [], [], [], []
        
        # Build one hot labels from the labels index, given in the data.                  
        labels = [item[-1] for item in data[start:end]] #data[i][-1]=index of the true bbox of query i
        dist_labels = np.zeros((end-start, imlen)) #label distribution
        
        # Real data points
        dist_labels[[i for i in np.arange(end-start) if labels[i]>=0], [l for l in labels if l>=0]]=1
        
        # augmented data points
        # the label of each added poind is writen as -1*number of bboxes. 
        # When we build the batch it self (function build_data in class Model), 
        # if we see a negative label index, we know its an added point and we know the 
        # number of bboxes so we can build the correct distribution.
        for i in np.arange(end-start):
            if labels[i]<0:
                dist_labels[i] = [-1/labels[i] for _ in range(-labels[i])]+[0. for _ in range(imlen+labels[i])]
                          
        im_dim, bbox_dim = data[0][1][0].shape[1], data[0][1][1].shape[1]
        for i in range(start, end):
            padded_queries.append(self.q_padding(data[i][0], qlen))
            
            attn_idx.append([1 for _ in range(len(data[i])-2)]+[0 for _ in range(imlen-(len(data[i])-2))])
            
            padded_im.append(np.concatenate([data[i][j][0] for j in range(1, len(data[i])-1)] + 
                                       [np.full((imlen-(len(data[i])-2), im_dim), vocab['<pad>'], dtype=np.float32)], axis=0))
            
            padded_bbox.append(np.concatenate([data[i][j][1] for j in range(1, len(data[i])-1)] + 
                                       [np.full((imlen-(len(data[i])-2),bbox_dim), vocab['<pad>'], dtype=np.float32)], axis=0))
           
        
        
        if addNoise:
            padded_im+=(padded_im+np.random.normal(0, .1, np.array(padded_im).shape))*np.expand_dims(attn_idx, 2)
        else:
            padded_im=np.array(padded_im)
            
        if imScale is not None:
            # Smoothing factor
            halper = (1-np.expand_dims(np.array(attn_idx).astype(np.float32), 2))
            img_min = np.min(padded_im, axis=-1, keepdims=True)
            img_max = np.max(padded_im, axis=-1, keepdims=True)
            img_scale = (padded_im-img_min)/((img_max-img_min)+halper) # Scale to 0-1
            s = np.std(img_scale, axis=-1, keepdims=True)
            padded_im = imScale*img_scale/(s+halper)  #Scale to have 1/imScale std
            padded_im = padded_im - np.mean(padded_im, axis=-1, keepdims=True) # scale to zero mean
            
        return np.array(attn_idx), np.array(padded_queries, dtype=np.int32), padded_im, np.array(padded_bbox), np.array(dist_labels)
            
   
    def ground(self, data=None, start=None, end=None, 
               sess=None, feed_dict = None, isEdit=True, 
               imScale=False, MIXER_delta=None):
        '''
        Given a query and a list of bboxes, the function returns the index of the chosen bbox and the ground truth bbox.
        
        Params:
            data: A numpy array with datasat's data points
            start/end: The function only take data points from data[start:end]
            imScale: whether to scale the images vectors
        '''
        isSess = (sess==None)
        if isSess:
            sess = tf.Session()
        with sess.as_default():
            if isSess:
                tf.global_variables_initializer().run()
                ckpt = tf.train.get_checkpoint_state(params_dir)
                if ckpt and ckpt.model_checkpoint_path:
                    self.saver.restore(sess, ckpt.model_checkpoint_path) # restore all variables
                else:
                    print('Initializing variables')
            if feed_dict is None:
                attn_idx, padded_queries, padded_im, padded_bbox, labels = self.build_data(data, start, end, imScale=imScale)
                feed_dict = {
                        self.queries:padded_queries,
                        self.img:padded_im,
                        self.bboxes:padded_bbox,
                        self.labels:labels,
                        self.attn_idx:attn_idx,
                        self.MIXER_delta:MIXER_delta
                    }
            feed_dict[self.isTrain]=False
            feed_dict[self.isEdit] = isEdit
            feed_dict[self.dropout_in]=1.
            feed_dict[self.dropout_out]=1.
            feed_dict[self.dropout_img]=1.
            feed_dict[self.dropout_q]=1.
            scores = sess.run(self.scores, feed_dict=feed_dict) # get score for each bbox

        return np.argmax(scores, axis=1), np.argmax(feed_dict[self.labels], axis=1)
        
        
    def iou_accuracy(self, data, start, end, imScale, 
                     sess=None, feed_dict = None, 
                     threshold=0.5, test=False, isEdit=True,
                     MIXER_delta=None):
        '''
        Calculate the IOU score between the Model bbox and the true bbox.
        
         Params:
            data: A numpy array with datasat's data points
            start/end: The function only take data points from data[start:end]
            imScale: whether to scale the images vectors
            threshold: If IOU>0.5 this is a true positive
        ''' 
                          
        # Get score for each bbox (labels) and th true bbox index (gt_idx)                  
        if feed_dict is None:
            labels, gt_idx = self.ground(data, start, end, sess=sess, feed_dict=feed_dict, 
                                         isEdit=isEdit, imScale=imScale, MIXER_delta=MIXER_delta)
        else: labels, gt_idx = self.ground(sess=sess, feed_dict=feed_dict, 
                                           isEdit=isEdit, imScale=imScale, MIXER_delta=MIXER_delta)
        acc = 0
        
        for i in range(start, end):
            gt = data[i][gt_idx[i-start]+1][1][0] # ground truth bbox. Note that len(data)!=len(gt_idx)=batch_size
            crops = np.expand_dims(data[i][labels[i-start]+1][1][0], axis=0) #Model chosen bbox. Note that len(data)!=len(labels)=batch_size
            acc += (retriever.compute_iou(crops, gt)[0]>threshold) #IOU for the i sample.
            
        return acc/(end-start)
        
    def accuracy(self, imScale, data=None, start=None, 
                 end=None, sess=None, feed_dict = None, 
                 isEdit=True, MIXER_delta=None):
        
        isSess = (sess==None)
        if isSess:
            print('Building sess')
            sess = tf.Session()
        with sess.as_default():
            if isSess:
                print('Building sess used')
                tf.global_variables_initializer().run()
                ckpt = tf.train.get_checkpoint_state(params_dir)
                if ckpt and ckpt.model_checkpoint_path:
                    print('3')
                    self.saver.restore(sess, ckpt.model_checkpoint_path) # restore all variables
                else:
                    print('Initializing variables')
            if feed_dict is None:
                print('Building feed_dict')
                attn_idx, padded_queries, padded_im, padded_bbox, labels = self.build_data(data, start, end, imScale=imScale)
                feed_dict = {
                        self.queries:padded_queries,
                        self.img:padded_im,
                        self.bboxes:padded_bbox,
                        self.attn_idx:attn_idx,
                        self.labels:labels,
                        self.MIXER_delta:MIXER_delta
                    }
                
            feed_dict[self.isTrain]=False
            feed_dict[self.isEdit] = isEdit
            feed_dict[self.dropout_in]=1.
            feed_dict[self.dropout_out]=1.
            feed_dict[self.dropout_img]=1.
            feed_dict[self.dropout_q]=1.
            scores = sess.run(self.scores, feed_dict=feed_dict)
            acc = sum(np.equal(np.argmax(scores, axis=1), np.argmax(feed_dict[self.labels], axis=1))/len(feed_dict[self.labels]))

                    
        return acc
    
    def discount_rewards(self, r, last_r, gamma=1.0):
        """ 
        take 1D float array of rewards and compute discounted reward 
        using bellman function.
        
        params:
            r: r[i,j]=1 reward of action A did on word j at query i.
            last_r: B's loss for query i with no edits. This is the final reward.
            gamma: discount factor.
        """
                          
        discounted_r = np.zeros(r.shape)
        running_add = last_r # B loss
        discounted_r = [i for i in range(r.shape[-1])]
        for t in reversed(range(0, r.shape[-1])):
            running_add = running_add * gamma + r[:,t]
            discounted_r[t] = running_add
        return np.array(discounted_r).T
        
    def train(self, trn_data, tst_data, ephocs_num, edit_reward, rnn_editProb, startA=3, 
              activation_ephoc=10, muteB=3, start_ephoc=0, dropout_in=1., onlyB=False,
              dropout_out=1., dropout_img=1., dropout_q=1., editProb=0.5, delta=1,
              addNoise=False, imScale=None):
                          
        '''
        Params:
             trn_data: list, train set. 
             
             tst_data: list, test set. 
             
             ephocs_num: number of ephocs
             
             start_ephoc: number of first ephoc.
             
             edit_reward: int, coefficient to multiply the reward by when editing a word.
             
             startA: int, Start competition only at ephoc # startA.
             
             activation_ephoc: at ephoc numer "activation_ephoc", A will be activate.
                               That is, for (activation_ephoc-startA) number of ephocs, 
                               A will chooce an action randomly.
             
            muteB: After A starts, for each ephoc which A & B trains, 
                   only A will be trained for this amount of ephocs.
                   
            editProb: robabilty for editing a query.
            
            rnn_editProb: Probabilty for edit a word in rnn, when decision are taken randomly.  
            
            dropout_in: dropout ratio of B's rnn inputs.
            
            dropout_output: dropout ratio of B's rnn output.
            
            dropout_img: dropout ratio of images vectors before the last attention layer .
            
            addNoise: Boolean. Whether to add normal noise to the images (see build_data).
            
            imScale: If not None, scale the image vectors (VGG16 outputs) to have 0 mean and 1imScale std
            
            onlyB: boolean, Wheter to train only B. By setting startA and acctivation_ephoc larger than ephocs_num
                   and setting onlyB to True, we get A out of the game 
                   
            delta: The probablility to etid a word randomly is 1/delta (dleta increase during training)
                               
        '''                  
        
        trn_nbatch = len(trn_data)
        tst_nbatch = len(tst_data)
        print('# Train set size:', len([len(batch) for batch in trn_data]))
        print('# Training batches:', trn_nbatch)
        print('# Test set size:', len([len(batch) for batch in tst_data]))
        print('# Testing batches:', tst_nbatch)
        self.test_res, self.train_res,  self.unedited_train_res, self.Atst_res, self.Arand_res  = [], [], [], [], [] #list to hold accuracy of test and train sets
        
        # After activation_ephoc number of ephocs, A may only edit the last word (mixer_delta=1). 
        MIXER_delta = 1
        
        sess = tf.Session()
        with sess.as_default():
            tf.global_variables_initializer().run()
            ckpt = tf.train.get_checkpoint_state(params_dir)
            if ckpt and ckpt.model_checkpoint_path:
                print('Loading parameters from', ckpt.model_checkpoint_path)
                self.saver.restore(sess, ckpt.model_checkpoint_path) # restore all variables
            else:
                print('Initializing variables')
                
            for ephoc in range(start_ephoc, ephocs_num):
                startTime = datetime.now().replace(microsecond=0)
                          
                # Train B only after competition start (ephoc<startA). 
                # Each time we train B, we train only B for muteB ephocs.
                toTrainB = ephoc<startA or (ephoc-(startA-1))%(muteB+1)==0 # Whether to train only B 
                
                # Every 2 times we train B and A (+ only A for muteB ephocs), we increase
                # delta and MIXER_delta by one
                if (ephoc-activation_ephoc)%((muteB+1)*2)==0 and ephoc>=activation_ephoc:
                    delta+=1
                    MIXER_delta+=1
                
                # * If ephoc<startA, train A with no word edits
                #   by setting editRandomlyProb to one and rnn_editProb to 0 (always 
                #   choose an action randomly with zero probability for edit). 
                # * If we train B in this ephoc, set editRandomlyProb to zero.
                if ephoc<startA:
                    rnn_editProb_holder = 0.
                    editRandomlyProb=1.
                elif toTrainB==False:
                    rnn_editProb_holder = rnn_editProb
                    editRandomlyProb=1/delta
                else:
                    rnn_editProb_holder= 0.
                    editRandomlyProb=0.
                        
                # When we train B with edited words (itrInEphoc=2), we show B results without editing (on train set).
                # Note the we train B with edited words only if delta>2.
                itrInEphoc=1
                if onlyB==False and delta>2 and toTrainB:
                    itrInEphoc=2
                    
                print('='*50,'\nTrain, ephoc:',ephoc, '; Training B:', toTrainB)
                np.random.shuffle(trn_data)
                for ep in range(itrInEphoc):
                    trn_ce_loss, A_trn_loss, B_trn_loss = 0, 0, 0
                    trn_acc, trn_iou, edits_count = 0, 0, 0
                    tst_ce_loss, tst_loss, tst_acc, tst_iou = 0, 0, 0, 0
                    if ep==1:
                        print('No Edit')
                        print('ooooooo')
                    edit_num = 0 # average number of edited words per query
                    editRount_count = 0 # number of iterations with competition.
                    
                    for b in range(trn_nbatch):
                        if ep==1:
                            '''
                            If ep=1, we're in round 2 in which we only show B's 
                            results with out editing (on the train set).
                            '''
                            isEdit=False
                        else:
                            # If ephoc<startA we train B and A with no edits
                            # then, if B is trained, only if delta>2 (which mean A was trained with un-random choices)
                            # we can train B with A edits.
                            isEdit = onlyB==False and ephoc<startA or toTrainB==False or (delta>2 and np.random.rand(1)[0]<editProb)
                            
                        attn_idx, padded_queries, padded_im, padded_bbox, labels = self.build_data(trn_data[b], 
                                                                                            0, 
                                                                                            self.batch_size, 
                                                                                            addNoise=addNoise,
                                                                                            imScale=imScale)
                
                        reward_loss = np.array([[0., 0.] for _ in range(self.batch_size)]) # dummy holder 
                    

                        feed_dict = {
                            self.queries:padded_queries,
                            self.img:padded_im,
                            self.bboxes:padded_bbox,
                            self.attn_idx:attn_idx,
                            self.labels: labels,
                            self.unk:np.array([[vocab['<unk>']]]),
                            self.isEdit:isEdit,
                            self.reward_loss:reward_loss,
                            self.Aattn_vecs:[[[]]],# dummy holder 
                            self.dropout_in:dropout_in,
                            self.dropout_out:dropout_out,
                            self.dropout_img:dropout_img,
                            self.dropout_q:dropout_q,
                            self.isTrain:True,
                            self.isIDX:False,
                            self.set_actions:[[]],# dummy holder 
                            self.rnn_editProb:rnn_editProb_holder,
                            self.editRandomlyProb:editRandomlyProb,
                            self.MIXER_delta:MIXER_delta
                        }
                        
                   tf.nn.dynamic_rnn     
                        if isEdit==True:
                            editRount_count+=1
                          
                            #We first run B with no edit in order to get it's loss and outputs.
                            feed_dict[self.isEdit] = False
                            queries_lens, B_ce, outputs = sess.run([self.queries_lens, self.B_ce, self.outputs], feed_dict=feed_dict)
                            feed_dict[self.isEdit] = True
                            # B_ce contain the loss for each query.
                            # We scale all the losses to have mean 1 and std 0.3.
                            Bce_min = min(B_ce)
                            Bce_max = max(B_ce)
                            Bce_scale = (B_ce-Bce_min)/(Bce_max-Bce_min)
                            s = np.std(Bce_scale)
                            BCE = 0.5*Bce_scale/s
                            BCE = 1 + BCE - np.mean(BCE)
                          
                            # reward for edit a word = edit_reward*BCE/queries_lens.
                            # A's get the reward and loss per query  as 2 of its features.
                            rewards_loss = np.concatenate(
                                [np.expand_dims(edit_reward*BCE/queries_lens, 1), np.expand_dims(BCE, 1)], 1)
                            
                            feed_dict[self.reward_loss]=rewards_loss
                            
                            # A's attention vectors are B's outputs with no edited words.
                            Aattn_vecs = outputs[:,:,:self.num_hidden]
                            feed_dict[self.Aattn_vecs]=Aattn_vecs
                           
                            '''
                            We then run B with A's edits. 
                            We get idx (A's decision [0,1] for each words).
                            edit_num: the ratio of edited words per query 
                            B_ce, B_loss: B's loss per query and B overall mean.
                            '''
                           
                            idx, B_ce1, B_loss, edit_num = sess.run(
                                [self.idx, self.B_ce, self.B_loss, self.edit_num], 
                                 feed_dict=feed_dict)

                            # Get reward per word.
                            # If word i in query j was edited idx[j,i]=1 --> rewards[i,j] = 1*reward
                            # If word i in query j was not edited idx[j,i]=0 --> rewards[i,j] = 0*reward
                            rewards = idx*np.expand_dims(
                                edit_reward*BCE/queries_lens, axis=1)
                            
                            # Scale new losses
                            Bce_min = min(B_ce1)
                            Bce_max = max(B_ce1)
                            Bce_scale = (B_ce1-Bce_min)/(Bce_max-Bce_min)
                            s = np.std(Bce_scale)
                            BCE1 = .5*Bce_scale/s
                            BCE1 = 1 + BCE1 - np.mean(BCE1)
                            
                            feed_dict[self.actions_idx] = np.abs(list(zip(range(
                                        self.batch_size*idx.shape[-1]), idx.reshape(-1))))
                            feed_dict[self.bell_val] = self.discount_rewards(rewards, BCE1)
                            feed_dict[self.set_actions] = idx
                            feed_dict[self.isIDX]=True
                                                         
                            A_loss, _ = sess.run(
                                [self.A_loss, self.A_optimizer], feed_dict=feed_dict)
                                                        
                            if toTrainB:
                                feed_dict[self.isIDX]=False
                                lr, gs, B_loss, edit_num, _ = sess.run(
                                    [self.learning_rate, self.global_step, self.B_loss, self.edit_num, self.B_optimizer], 
                                    feed_dict=feed_dict)
                
                    
                            acc = self.accuracy(sess=sess, feed_dict=feed_dict, isEdit=isEdit, 
                                                imScale=imScale, MIXER_delta=MIXER_delta)  
                            iou_acc = self.iou_accuracy(
                                trn_data[b], 0, self.batch_size, imScale=imScale,
                                sess=sess, feed_dict=feed_dict, isEdit=isEdit, MIXER_delta=MIXER_delta)

                            trn_acc += acc/trn_nbatch
                            A_trn_loss += A_loss
                            B_trn_loss += B_loss/trn_nbatch
                            trn_iou += iou_acc/trn_nbatch
                            edits_count += edit_num
                            
                            if b%50==0:
                                if toTrainB: 
                                    print('Edit:%s'%(isEdit), 
                                          ';batch:%d'%(b), 
                                          ';gs:%d'%(gs), ';lr:%.3f'%(lr), ';Bloss:%.3f'%(B_loss), 
                                          ';Aloss:%.3f'%(A_loss), ';edits:%.2f'%(edit_num),  ';editRandomlyProb:%.2f'%(editRandomlyProb),
                                          ';acc:%.3f'%(acc), ';iou:%.3f'%(iou_acc), ';time:', datetime.now().replace(microsecond=0)-startTime)    
                                else:
                                    print('Edit:%s'%(isEdit),
                                          ';batch:%d'%(b), 
                                          ';Bloss:%.3f'%(B_loss), ';Aloss:%.3f'%(A_loss), 
                                          ';edits:%.2f'%(edit_num), ';editRandomlyProb:%.2f'%(editRandomlyProb), ';acc:%.3f'%(acc),
                                          ';iou:%.3f'%(iou_acc), ';time:', datetime.now().replace(microsecond=0)-startTime)  
                                

                               
                        else: # isEdit=False
                            if ep==0:
                                B_loss, lr, gs, _ = sess.run([self.B_loss, self.learning_rate, 
                                                                self.global_step, self.B_optimizer], feed_dict=feed_dict)
                            else: 
                                # just show results of B with no edits
                                B_loss, lr, gs = sess.run([self.B_loss, self.learning_rate, self.global_step], feed_dict=feed_dict)

                            acc = self.accuracy(sess=sess, feed_dict=feed_dict, isEdit=isEdit, imScale=imScale, MIXER_delta=MIXER_delta)  
                            iou_acc = self.iou_accuracy(trn_data[b], 0, self.batch_size, imScale=imScale,
                                                        sess=sess, feed_dict=feed_dict, isEdit=isEdit, MIXER_delta=MIXER_delta)

                            trn_acc += acc/trn_nbatch
                            B_trn_loss += B_loss/trn_nbatch
                            trn_iou += iou_acc/trn_nbatch

                            if b%50==0:
                                print('Edit:%s'%(isEdit), 
                                      ';batch:%d'%(b),  
                                      ';gs:%d'%(gs), ';lr:%.3f'%(lr),
                                      ';Bloss:%.3f'%(B_loss),  ';acc:%.3f'%(acc), 
                                      ';iou:%.3f'%(iou_acc),
                                      ';time:', datetime.now().replace(microsecond=0)-startTime)

                    if editRount_count>0:
                        assert ep==0, "ep!=0 and editRount_count>0"
                        print('\n*Training B:', ephoc%3==0, ';B Train loss: %.3f'%(B_trn_loss), ';A Train loss: %.3f'%(A_trn_loss/editRount_count),                                                                                             
                          ';Edit num: %.3f'%(edits_count/editRount_count), 'MIXER delta:%0.3f'%(MIXER_delta),
                          ';Train accuracy: %.3f'%(trn_acc),  ';IOU accuracy: %.3f'%(trn_iou), 
                          ';Time:', datetime.now().replace(microsecond=0)-startTime, '\n')
                        self.train_res.append([trn_acc, trn_iou, B_trn_loss, A_trn_loss/editRount_count, edits_count/editRount_count])
                    else:
                        print('\n*Training B:', ephoc%3==0, ';B Train loss: %.3f'%(B_trn_loss),';Train accuracy: %.3f'%(trn_acc), 
                          ';IOU accuracy: %.3f'%(trn_iou),  
                          ';Time:', datetime.now().replace(microsecond=0)-startTime, '\n')
                        if ep==0:
                            self.train_res.append([trn_acc, trn_iou, B_trn_loss, 0, 0, MIXER_delta])
                        else:
                            self.unedited_train_res.append([trn_acc, trn_iou, B_trn_loss, MIXER_delta])
                          
                    self.saver.save(sess, params_dir + "/model.ckpt", global_step=ephoc)
                
                
                if ephoc>=startA and toTrainB==False:
                    for Aidx in range(2):
                        print('A testing, ephoc:',ephoc, ';Random:', Aidx==1)
                        tstTime = datetime.now().replace(microsecond=0)
                        Atst_loss, Atst_acc, Atst_iou = 0, 0, 0
                        
                        # On the first iteration we (Aidx=0) we never choose 
                        # an action randomly. On the secound one (Aidx=1) we allways choose an 
                        # action randomly with probability to edit = edits_count/tst_nbatch (the ration of words per q A edited)
                        if Aidx==0:
                                tst_rnn_editProb=0
                                tst_editRandomlyProb=0
                        else:
                            tst_rnn_editProb=edits_count/tst_nbatch
                            tst_editRandomlyProb=1.
                            
                        edits_count=0
                                
                                
                        for b in range(tst_nbatch):
                            attn_idx, padded_queries, padded_im, padded_bbox, labels = self.build_data(tst_data[b],
                                                                                        0, self.batch_size, imScale=imScale)
                            
                            rewards_loss = np.array([[0., 0.] for _ in range(self.batch_size)])
                            feed_dict = {
                                self.queries:padded_queries,
                                self.img:padded_im,
                                self.bboxes:padded_bbox,
                                self.attn_idx:attn_idx,
                                self.labels: labels,
                                self.unk:np.array([[vocab['<unk>']]]),
                                self.reward_loss:reward_loss,
                                self.isEdit:True,
                                self.Aattn_vecs:[[[]]],
                                self.dropout_in:1.,
                                self.dropout_out:1.,
                                self.dropout_img:1.,
                                self.dropout_q:1.,
                                self.isTrain:False,
                                self.isIDX:False,
                                self.set_actions:[[]],# dummy holder 
                                self.rnn_editProb:tst_rnn_editProb,
                                self.editRandomlyProb:tst_editRandomlyProb,
                                self.MIXER_delta:500
                            }

                            # We first run B with no edit in order to get it's loss and outputs.
                            feed_dict[self.isEdit] = False
                            queries_lens, B_ce, outputs = sess.run([self.queries_lens, self.B_ce, self.outputs], feed_dict=feed_dict)
                            feed_dict[self.isEdit] = True
                            # B_ce contain the loss for each query.
                            # We scale all the losses to have mean 1 and std 0.3.
                            Bce_min = min(B_ce)
                            Bce_max = max(B_ce)
                            Bce_scale = (B_ce-Bce_min)/(Bce_max-Bce_min)
                            s = np.std(Bce_scale)
                            BCE = 0.5*Bce_scale/s
                            BCE = 1 + BCE - np.mean(BCE)

                            # reward for edit a word = edit_reward*BCE/queries_lens.
                            # A's get the reward and loss per query  as 2 of its features.
                            rewards_loss = np.concatenate(
                                [np.expand_dims(edit_reward*BCE/queries_lens, 1), np.expand_dims(BCE, 1)], 1)

                            feed_dict[self.reward_loss]=rewards_loss

                            # A's attention vectors are B's outputs with no edited words.
                            Aattn_vecs = outputs[:,:,:self.num_hidden]
                            feed_dict[self.Aattn_vecs]=Aattn_vecs

                            '''
                            We then run B with A's edits. 
                            We get idx (A's decision [0,1] for each words).
                            edit_num: the ratio of edited words per query 
                            B_ce, B_loss: B's loss per query and B overall mean.
                            '''

                            B_loss, edit_num = sess.run(
                                [self.B_loss, self.edit_num], 
                                 feed_dict=feed_dict)

                            acc = self.accuracy(sess=sess, feed_dict=feed_dict, isEdit=isEdit, imScale=imScale)  
                            iou_acc = self.iou_accuracy(tst_data[b], 0, self.batch_size, imScale=imScale,
                                                        sess=sess, feed_dict=feed_dict, isEdit=isEdit)
                            Atst_acc += acc/tst_nbatch
                            Atst_loss += B_loss/tst_nbatch
                            Atst_iou += iou_acc/tst_nbatch
                            edits_count+=edit_num
                            if b%50==0:
                                print('batch:', b, 
                                      ';B loss: %.3f'%(B_loss), 
                                      ';acc: %.3f'%(acc), 
                                      ';iou_acc: %.3f'%(iou_acc), 
                                      ';edits:%.2f'%(edit_num),
                                      ';time:', datetime.now().replace(microsecond=0)-startTime)
                                
                        print('\n*B test loss: %.3f'%(Atst_loss),
                              ';Test accuracy %.3f'%(Atst_acc), 
                              ';IOU accuracy: %.3f'%(Atst_iou), 
                              ';Edit num: %.3f'%(edits_count/tst_nbatch), 
                              ';Time:', datetime.now().replace(microsecond=0)-startTime,'\n')
                        if Aidx==0:
                            self.Atst_res.append([Atst_acc, Atst_iou, Atst_loss, edits_count/tst_nbatch])
                        else:
                            self.Arand_res.append([Atst_acc, Atst_iou, Atst_loss, edits_count/tst_nbatch])
                
                if ephoc<startA or toTrainB:
                    print('Testing, ephoc:',ephoc)
                    tstTime = datetime.now().replace(microsecond=0)
                    tst_loss, tst_acc, tst_iou = 0, 0, 0
                    for b in range(tst_nbatch):
                        attn_idx, padded_queries, padded_im, padded_bbox, labels = self.build_data(tst_data[b],
                                                                                    0, self.batch_size, imScale=imScale)
                        rewards_loss = np.array([[0., 0.] for _ in range(self.batch_size)])
                        feed_dict = {
                            self.queries:padded_queries,
                            self.img:padded_im,
                            self.bboxes:padded_bbox,
                            self.attn_idx:attn_idx,
                            self.labels: labels,
                            self.unk:np.array([[vocab['<unk>']]]),
                            self.reward_loss:reward_loss,
                            self.isEdit:False,
                            self.Aattn_vecs:[[[]]],
                            self.dropout_in:1.,
                            self.dropout_out:1.,
                            self.dropout_img:1.,
                            self.dropout_q:1.,
                            self.isTrain:False,
                            self.isIDX:False,
                            self.set_actions:[[]],# dummy holder 
                            self.rnn_editProb:0.,
                            self.editRandomlyProb:0.,
                            self.MIXER_delta:500
                        }
                        B_loss = sess.run(self.B_loss, feed_dict=feed_dict)

                        acc = self.accuracy(sess=sess, feed_dict=feed_dict, isEdit=False, imScale=imScale)
                        iou_acc = self.iou_accuracy(
                            tst_data[b], 0, self.batch_size, sess=sess, 
                            feed_dict=feed_dict, isEdit=False, imScale=imScale)
                        
                        tst_acc += acc/tst_nbatch
                        tst_loss += B_loss/tst_nbatch
                        tst_iou += iou_acc/tst_nbatch
                        if b%50==0:
                            print('batch:', b, ';B loss: %.3f'%(B_loss), ';acc: %.3f'%(acc), 
                                   ';iou_acc: %.3f'%(iou_acc), ';time:', datetime.now().replace(microsecond=0)-startTime)
                    print('\n*BTrain:', ephoc%3==0, ';Test loss: %.3f'%(tst_loss), ';Test accuracy %.3f'%(tst_acc), 
                          ';IOU accuracy: %.3f'%(tst_iou), ';Time:', datetime.now().replace(microsecond=0)-startTime)
                    self.test_res.append([tst_acc, tst_iou, tst_loss])
                print('='*50,'\n')
            return self.test_res, self.train_res, self.unedited_train_res, self.Atst_res, self.Arand_res

# %% [markdown]
# # RL

# %%
num_hidden = 200
rl_tst, rl_trn, rl_uetst, rl_AtstVal, rl_AtstRand = [], [], [], [], []
rewards = [-1., -0.8, -0.5]

for reward in rewards:
    params_dir = params_dir_tmp+'RL/EXP/MIXER1_reward_'+str(reward)+'_hidden:'+str(num_hidden)
    tf.reset_default_graph()
    m = Model(
        batch_size=200, 
        num_hidden=num_hidden,
        embed_size=embed_vecs.shape[1],
        img_dims=trainset[0][0][1][0].shape[1], 
        bbox_dims=trainset[0][0][1][1].shape[1], 
        lr=.05,
        vocab=vocab, 
        decay_steps=10000, 
        decay_rate=0.9, 
        coefAlr=1,
        bnorm=False,
        toQscale=0.5,
    )

    print('reward:', reward)
    print('params_dir:', params_dir)
    print('num_hidden:', m.num_hidden)
    print('learning rate:', m.lr)
    tst, trn, ue_tst, tstVal, randVal = m.train(trainset, testset,
            ephocs_num=300,
            start_ephoc=0,
            startA=3,
            activation_ephoc=8,
            muteB=2, 
            editProb=0.95,
            edit_reward=reward,
            dropout_in=0.5,
            dropout_out=1.,
            rnn_editProb=0.2,
            onlyB=False,
            imScale=0.02,
            delta=1)

    rl_tst.append(tst)
    rl_trn.append(trn)
    rl_uetst.append(ue_tst)
    rl_AtstVal.append(tstVal)
    rl_AtstRand.append(randVal)

    print('\n'+'*'*100)
    print('*'*100)
    print('*'*100,'\n')
# Out:
# reward: -1.0
# params_dir: ../data/training/models/All/RL/EXP/MIXER1_reward_-1.0_hidden:200
# num_hidden: 200
# learning rate: 0.05
# # Train set size: 297
# # Training batches: 297
# # Test set size: 297
# # Testing batches: 297
# Initializing variables
# ==================================================
# Train, ephoc: 0 ; Training B: True
# Edit:True ;batch:0 ;gs:1 ;lr:0.050 ;Bloss:3.247 ;Aloss:0.692 ;edits:0.00 ;editRandomlyProb:1.00 ;acc:0.070 ;iou:0.150 ;time: 0:00:01
# Edit:True ;batch:50 ;gs:51 ;lr:0.050 ;Bloss:2.695 ;Aloss:0.322 ;edits:0.00 ;editRandomlyProb:1.00 ;acc:0.205 ;iou:0.290 ;time: 0:00:22
# Edit:True ;batch:100 ;gs:101 ;lr:0.050 ;Bloss:2.484 ;Aloss:0.452 ;edits:0.00 ;editRandomlyProb:1.00 ;acc:0.340 ;iou:0.430 ;time: 0:00:44
# Edit:True ;batch:150 ;gs:151 ;lr:0.050 ;Bloss:3.329 ;Aloss:0.478 ;edits:0.00 ;editRandomlyProb:1.00 ;acc:0.110 ;iou:0.200 ;time: 0:01:05
# Edit:True ;batch:200 ;gs:201 ;lr:0.050 ;Bloss:3.640 ;Aloss:0.387 ;edits:0.00 ;editRandomlyProb:1.00 ;acc:0.155 ;iou:0.270 ;time: 0:01:26
# Edit:True ;batch:250 ;gs:251 ;lr:0.050 ;Bloss:3.045 ;Aloss:0.301 ;edits:0.00 ;editRandomlyProb:1.00 ;acc:0.275 ;iou:0.365 ;time: 0:01:46
#
# *Training B: True ;B Train loss: 2.659 ;A Train loss: 0.416 ;Edit num: 0.000 MIXER delta:1.000 ;Train accuracy: 0.331 ;IOU accuracy: 0.428 ;Time: 0:02:04
#
# Testing, ephoc: 0
# batch: 0 ;B loss: 1.207 ;acc: 0.725 ;iou_acc: 0.815 ;time: 0:02:04
# batch: 50 ;B loss: 1.947 ;acc: 0.650 ;iou_acc: 0.730 ;time: 0:02:09
# batch: 100 ;B loss: 2.247 ;acc: 0.525 ;iou_acc: 0.630 ;time: 0:02:14
# batch: 150 ;B loss: 2.466 ;acc: 0.430 ;iou_acc: 0.520 ;time: 0:02:20
# batch: 200 ;B loss: 2.782 ;acc: 0.385 ;iou_acc: 0.530 ;time: 0:02:27
# batch: 250 ;B loss: 3.200 ;acc: 0.245 ;iou_acc: 0.335 ;time: 0:02:36
#
# *BTrain: True ;Test loss: 2.497 ;Test accuracy 0.432 ;IOU accuracy: 0.550 ;Time: 0:02:46
# ==================================================
#
# ==================================================
# Train, ephoc: 1 ; Training B: True
# Edit:True ;batch:0 ;gs:298 ;lr:0.050 ;Bloss:2.063 ;Aloss:0.341 ;edits:0.00 ;editRandomlyProb:1.00 ;acc:0.515 ;iou:0.660 ;time: 0:00:01
# Edit:True ;batch:50 ;gs:348 ;lr:0.050 ;Bloss:2.208 ;Aloss:0.383 ;edits:0.00 ;editRandomlyProb:1.00 ;acc:0.490 ;iou:0.550 ;time: 0:00:20
# Edit:True ;batch:100 ;gs:398 ;lr:0.050 ;Bloss:2.832 ;Aloss:0.278 ;edits:0.00 ;editRandomlyProb:1.00 ;acc:0.325 ;iou:0.480 ;time: 0:00:42
# Edit:True ;batch:150 ;gs:448 ;lr:0.050 ;Bloss:2.943 ;Aloss:0.352 ;edits:0.00 ;editRandomlyProb:1.00 ;acc:0.345 ;iou:0.535 ;time: 0:01:03
# Edit:True ;batch:200 ;gs:498 ;lr:0.050 ;Bloss:3.175 ;Aloss:0.226 ;edits:0.00 ;editRandomlyProb:1.00 ;acc:0.285 ;iou:0.435 ;time: 0:01:23
# Edit:True ;batch:250 ;gs:548 ;lr:0.050 ;Bloss:1.873 ;Aloss:0.207 ;edits:0.00 ;editRandomlyProb:1.00 ;acc:0.590 ;iou:0.710 ;time: 0:01:43
#
# *Training B: False ;B Train loss: 2.267 ;A Train loss: 0.270 ;Edit num: 0.000 MIXER delta:1.000 ;Train accuracy: 0.494 ;IOU accuracy: 0.615 ;Time: 0:02:01
#
# Testing, ephoc: 1
# batch: 0 ;B loss: 0.930 ;acc: 0.780 ;iou_acc: 0.880 ;time: 0:02:02
# batch: 50 ;B loss: 1.275 ;acc: 0.745 ;iou_acc: 0.810 ;time: 0:02:06
# batch: 100 ;B loss: 1.698 ;acc: 0.625 ;iou_acc: 0.710 ;time: 0:02:11
# batch: 150 ;B loss: 1.831 ;acc: 0.610 ;iou_acc: 0.705 ;time: 0:02:17
# batch: 200 ;B loss: 2.174 ;acc: 0.515 ;iou_acc: 0.640 ;time: 0:02:25
# batch: 250 ;B loss: 2.720 ;acc: 0.380 ;iou_acc: 0.535 ;time: 0:02:33
#
# *BTrain: False ;Test loss: 1.957 ;Test accuracy 0.554 ;IOU accuracy: 0.672 ;Time: 0:02:44
# ==================================================
#
# ==================================================
# Train, ephoc: 2 ; Training B: True
# Edit:True ;batch:0 ;gs:595 ;lr:0.050 ;Bloss:1.079 ;Aloss:0.198 ;edits:0.00 ;editRandomlyProb:1.00 ;acc:0.785 ;iou:0.860 ;time: 0:00:00
# Edit:True ;batch:50 ;gs:645 ;lr:0.050 ;Bloss:1.514 ;Aloss:0.188 ;edits:0.00 ;editRandomlyProb:1.00 ;acc:0.710 ;iou:0.780 ;time: 0:00:21
# Edit:True ;batch:100 ;gs:695 ;lr:0.050 ;Bloss:2.328 ;Aloss:0.217 ;edits:0.00 ;editRandomlyProb:1.00 ;acc:0.460 ;iou:0.670 ;time: 0:00:43
# Edit:True ;batch:150 ;gs:745 ;lr:0.050 ;Bloss:1.511 ;Aloss:0.192 ;edits:0.00 ;editRandomlyProb:1.00 ;acc:0.710 ;iou:0.775 ;time: 0:01:04
# Edit:True ;batch:200 ;gs:795 ;lr:0.050 ;Bloss:1.986 ;Aloss:0.251 ;edits:0.00 ;editRandomlyProb:1.00 ;acc:0.545 ;iou:0.625 ;time: 0:01:26
# Edit:True ;batch:250 ;gs:845 ;lr:0.050 ;Bloss:1.019 ;Aloss:0.215 ;edits:0.00 ;editRandomlyProb:1.00 ;acc:0.765 ;iou:0.840 ;time: 0:01:47
#
# *Training B: False ;B Train loss: 1.857 ;A Train loss: 0.217 ;Edit num: 0.000 MIXER delta:1.000 ;Train accuracy: 0.602 ;IOU accuracy: 0.713 ;Time: 0:02:07
#
# Testing, ephoc: 2
# batch: 0 ;B loss: 0.748 ;acc: 0.845 ;iou_acc: 0.910 ;time: 0:02:07
# batch: 50 ;B loss: 1.035 ;acc: 0.785 ;iou_acc: 0.860 ;time: 0:02:11
# batch: 100 ;B loss: 1.468 ;acc: 0.665 ;iou_acc: 0.755 ;time: 0:02:16
# batch: 150 ;B loss: 1.481 ;acc: 0.660 ;iou_acc: 0.740 ;time: 0:02:22
# batch: 200 ;B loss: 1.903 ;acc: 0.530 ;iou_acc: 0.655 ;time: 0:02:29
# batch: 250 ;B loss: 2.460 ;acc: 0.435 ;iou_acc: 0.585 ;time: 0:02:37
#
# *BTrain: False ;Test loss: 1.674 ;Test accuracy 0.611 ;IOU accuracy: 0.722 ;Time: 0:02:47
# ==================================================
#
# ==================================================
# Train, ephoc: 3 ; Training B: False
# Edit:True ;batch:0 ;Bloss:2.380 ;Aloss:0.214 ;edits:0.12 ;editRandomlyProb:1.00 ;acc:0.470 ;iou:0.610 ;time: 0:00:01
# Edit:True ;batch:50 ;Bloss:2.745 ;Aloss:0.222 ;edits:0.12 ;editRandomlyProb:1.00 ;acc:0.410 ;iou:0.540 ;time: 0:00:17
# Edit:True ;batch:100 ;Bloss:2.558 ;Aloss:0.206 ;edits:0.11 ;editRandomlyProb:1.00 ;acc:0.420 ;iou:0.635 ;time: 0:00:31
# Edit:True ;batch:150 ;Bloss:1.959 ;Aloss:0.202 ;edits:0.16 ;editRandomlyProb:1.00 ;acc:0.575 ;iou:0.675 ;time: 0:00:47
# Edit:True ;batch:200 ;Bloss:2.862 ;Aloss:0.218 ;edits:0.13 ;editRandomlyProb:1.00 ;acc:0.320 ;iou:0.485 ;time: 0:01:03
# Edit:True ;batch:250 ;Bloss:2.293 ;Aloss:0.213 ;edits:0.13 ;editRandomlyProb:1.00 ;acc:0.475 ;iou:0.600 ;time: 0:01:18
#
# *Training B: True ;B Train loss: 1.932 ;A Train loss: 0.204 ;Edit num: 0.138 MIXER delta:1.000 ;Train accuracy: 0.562 ;IOU accuracy: 0.675 ;Time: 0:01:32
#
# A testing, ephoc: 3 ;Random: False
# batch: 0 ;B loss: 0.863 ;acc: 0.830 ;iou_acc: 0.870 ;edits:0.15 ;time: 0:01:33
# batch: 50 ;B loss: 1.363 ;acc: 0.690 ;iou_acc: 0.780 ;edits:0.16 ;time: 0:01:41
# batch: 100 ;B loss: 1.875 ;acc: 0.555 ;iou_acc: 0.645 ;edits:0.21 ;time: 0:01:51
# batch: 150 ;B loss: 2.013 ;acc: 0.460 ;iou_acc: 0.585 ;edits:0.27 ;time: 0:02:02
# batch: 200 ;B loss: 2.524 ;acc: 0.355 ;iou_acc: 0.500 ;edits:0.27 ;time: 0:02:14
# batch: 250 ;B loss: 3.106 ;acc: 0.250 ;iou_acc: 0.360 ;edits:0.30 ;time: 0:02:28
#
# *B test loss: 2.195 ;Test accuracy 0.462 ;IOU accuracy: 0.563 ;Edit num: 0.252 ;Time: 0:02:44
#
# A testing, ephoc: 3 ;Random: True
# batch: 0 ;B loss: 0.952 ;acc: 0.800 ;iou_acc: 0.835 ;edits:0.20 ;time: 0:02:45
# batch: 50 ;B loss: 1.367 ;acc: 0.695 ;iou_acc: 0.775 ;edits:0.21 ;time: 0:02:53
# batch: 100 ;B loss: 1.741 ;acc: 0.565 ;iou_acc: 0.670 ;edits:0.28 ;time: 0:03:03
# batch: 150 ;B loss: 1.881 ;acc: 0.580 ;iou_acc: 0.645 ;edits:0.25 ;time: 0:03:14
# batch: 200 ;B loss: 2.179 ;acc: 0.475 ;iou_acc: 0.555 ;edits:0.24 ;time: 0:03:26
# batch: 250 ;B loss: 2.696 ;acc: 0.350 ;iou_acc: 0.445 ;edits:0.24 ;time: 0:03:38
#
# *B test loss: 1.996 ;Test accuracy 0.516 ;IOU accuracy: 0.626 ;Edit num: 0.252 ;Time: 0:03:54
#
# ==================================================
#
# ==================================================
# Train, ephoc: 4 ; Training B: False
# Edit:True ;batch:0 ;Bloss:2.275 ;Aloss:0.207 ;edits:0.12 ;editRandomlyProb:1.00 ;acc:0.455 ;iou:0.625 ;time: 0:00:00
# Edit:True ;batch:50 ;Bloss:2.829 ;Aloss:0.199 ;edits:0.09 ;editRandomlyProb:1.00 ;acc:0.330 ;iou:0.490 ;time: 0:00:16
# Edit:True ;batch:100 ;Bloss:1.191 ;Aloss:0.166 ;edits:0.09 ;editRandomlyProb:1.00 ;acc:0.735 ;iou:0.785 ;time: 0:00:31
# Edit:True ;batch:150 ;Bloss:1.942 ;Aloss:0.204 ;edits:0.13 ;editRandomlyProb:1.00 ;acc:0.555 ;iou:0.685 ;time: 0:00:47
# Edit:True ;batch:200 ;Bloss:1.655 ;Aloss:0.193 ;edits:0.16 ;editRandomlyProb:1.00 ;acc:0.630 ;iou:0.740 ;time: 0:01:02
# Edit:True ;batch:250 ;Bloss:2.714 ;Aloss:0.196 ;edits:0.13 ;editRandomlyProb:1.00 ;acc:0.415 ;iou:0.565 ;time: 0:01:17
#
# *Training B: False ;B Train loss: 1.938 ;A Train loss: 0.200 ;Edit num: 0.138 MIXER delta:1.000 ;Train accuracy: 0.565 ;IOU accuracy: 0.677 ;Time: 0:01:31
#
# A testing, ephoc: 4 ;Random: False
# batch: 0 ;B loss: 0.902 ;acc: 0.795 ;iou_acc: 0.860 ;edits:0.17 ;time: 0:01:32
# batch: 50 ;B loss: 1.392 ;acc: 0.685 ;iou_acc: 0.740 ;edits:0.19 ;time: 0:01:39
# batch: 100 ;B loss: 2.079 ;acc: 0.495 ;iou_acc: 0.600 ;edits:0.24 ;time: 0:01:49
# batch: 150 ;B loss: 2.137 ;acc: 0.450 ;iou_acc: 0.535 ;edits:0.30 ;time: 0:02:00
# batch: 200 ;B loss: 2.536 ;acc: 0.330 ;iou_acc: 0.470 ;edits:0.28 ;time: 0:02:11
# batch: 250 ;B loss: 3.131 ;acc: 0.215 ;iou_acc: 0.350 ;edits:0.33 ;time: 0:02:25
#
# *B test loss: 2.222 ;Test accuracy 0.455 ;IOU accuracy: 0.557 ;Edit num: 0.276 ;Time: 0:02:41
#
# A testing, ephoc: 4 ;Random: True
# batch: 0 ;B loss: 0.950 ;acc: 0.820 ;iou_acc: 0.875 ;edits:0.26 ;time: 0:02:41
# batch: 50 ;B loss: 1.295 ;acc: 0.685 ;iou_acc: 0.750 ;edits:0.25 ;time: 0:02:49
# batch: 100 ;B loss: 1.823 ;acc: 0.530 ;iou_acc: 0.585 ;edits:0.24 ;time: 0:02:59
# batch: 150 ;B loss: 1.765 ;acc: 0.535 ;iou_acc: 0.660 ;edits:0.23 ;time: 0:03:10
# batch: 200 ;B loss: 2.282 ;acc: 0.450 ;iou_acc: 0.585 ;edits:0.27 ;time: 0:03:21
# batch: 250 ;B loss: 2.707 ;acc: 0.340 ;iou_acc: 0.485 ;edits:0.28 ;time: 0:03:34
#
# *B test loss: 2.034 ;Test accuracy 0.505 ;IOU accuracy: 0.617 ;Edit num: 0.276 ;Time: 0:03:49
#
# ==================================================
#
# ==================================================
# Train, ephoc: 5 ; Training B: True
# Edit:False ;batch:0 ;gs:892 ;lr:0.050 ;Bloss:1.353 ;acc:0.770 ;iou:0.845 ;time: 0:00:01
# Edit:False ;batch:50 ;gs:942 ;lr:0.050 ;Bloss:2.560 ;acc:0.410 ;iou:0.570 ;time: 0:00:08
# Edit:False ;batch:100 ;gs:992 ;lr:0.050 ;Bloss:1.435 ;acc:0.670 ;iou:0.770 ;time: 0:00:16
# Edit:False ;batch:150 ;gs:1042 ;lr:0.050 ;Bloss:2.001 ;acc:0.560 ;iou:0.695 ;time: 0:00:26
# Edit:False ;batch:200 ;gs:1092 ;lr:0.050 ;Bloss:2.060 ;acc:0.595 ;iou:0.690 ;time: 0:00:34
# Edit:False ;batch:250 ;gs:1142 ;lr:0.050 ;Bloss:1.287 ;acc:0.750 ;iou:0.820 ;time: 0:00:42
#
# *Training B: False ;B Train loss: 1.700 ;Train accuracy: 0.639 ;IOU accuracy: 0.744 ;Time: 0:00:50
#
# Testing, ephoc: 5
# batch: 0 ;B loss: 0.707 ;acc: 0.850 ;iou_acc: 0.910 ;time: 0:00:51
# batch: 50 ;B loss: 0.932 ;acc: 0.815 ;iou_acc: 0.870 ;time: 0:00:55
# batch: 100 ;B loss: 1.385 ;acc: 0.700 ;iou_acc: 0.770 ;time: 0:01:01
# batch: 150 ;B loss: 1.389 ;acc: 0.695 ;iou_acc: 0.775 ;time: 0:01:07
# batch: 200 ;B loss: 1.843 ;acc: 0.580 ;iou_acc: 0.695 ;time: 0:01:14
# batch: 250 ;B loss: 2.347 ;acc: 0.435 ;iou_acc: 0.610 ;time: 0:01:23
#
# *BTrain: False ;Test loss: 1.582 ;Test accuracy 0.637 ;IOU accuracy: 0.743 ;Time: 0:01:33
# ==================================================
#
# ==================================================
# Train, ephoc: 6 ; Training B: False
# Edit:True ;batch:0 ;Bloss:3.201 ;Aloss:0.185 ;edits:0.11 ;editRandomlyProb:1.00 ;acc:0.275 ;iou:0.510 ;time: 0:00:00
# Edit:True ;batch:50 ;Bloss:1.820 ;Aloss:0.189 ;edits:0.13 ;editRandomlyProb:1.00 ;acc:0.615 ;iou:0.715 ;time: 0:00:16
# Edit:True ;batch:100 ;Bloss:0.814 ;Aloss:0.193 ;edits:0.15 ;editRandomlyProb:1.00 ;acc:0.855 ;iou:0.910 ;time: 0:00:30
# Edit:True ;batch:150 ;Bloss:1.077 ;Aloss:0.183 ;edits:0.19 ;editRandomlyProb:1.00 ;acc:0.760 ;iou:0.845 ;time: 0:00:45
# Edit:True ;batch:200 ;Bloss:0.749 ;Aloss:0.223 ;edits:0.15 ;editRandomlyProb:1.00 ;acc:0.825 ;iou:0.935 ;time: 0:01:01
# Edit:True ;batch:250 ;Bloss:1.502 ;Aloss:0.176 ;edits:0.13 ;editRandomlyProb:1.00 ;acc:0.695 ;iou:0.800 ;time: 0:01:17
#
# *Training B: True ;B Train loss: 1.868 ;A Train loss: 0.200 ;Edit num: 0.139 MIXER delta:1.000 ;Train accuracy: 0.588 ;IOU accuracy: 0.698 ;Time: 0:01:32
#
# A testing, ephoc: 6 ;Random: False
# batch: 0 ;B loss: 0.759 ;acc: 0.820 ;iou_acc: 0.885 ;edits:0.10 ;time: 0:01:33
# batch: 50 ;B loss: 1.183 ;acc: 0.755 ;iou_acc: 0.825 ;edits:0.12 ;time: 0:01:41
# batch: 100 ;B loss: 1.680 ;acc: 0.615 ;iou_acc: 0.700 ;edits:0.15 ;time: 0:01:51
# batch: 150 ;B loss: 1.836 ;acc: 0.535 ;iou_acc: 0.645 ;edits:0.20 ;time: 0:02:02
# batch: 200 ;B loss: 2.281 ;acc: 0.460 ;iou_acc: 0.550 ;edits:0.20 ;time: 0:02:15
# batch: 250 ;B loss: 2.851 ;acc: 0.305 ;iou_acc: 0.445 ;edits:0.24 ;time: 0:02:28
#
# *B test loss: 1.994 ;Test accuracy 0.525 ;IOU accuracy: 0.626 ;Edit num: 0.186 ;Time: 0:02:44
#
# A testing, ephoc: 6 ;Random: True
# batch: 0 ;B loss: 0.944 ;acc: 0.820 ;iou_acc: 0.890 ;edits:0.21 ;time: 0:02:44
# batch: 50 ;B loss: 1.248 ;acc: 0.715 ;iou_acc: 0.775 ;edits:0.24 ;time: 0:02:52
# batch: 100 ;B loss: 1.627 ;acc: 0.615 ;iou_acc: 0.720 ;edits:0.16 ;time: 0:03:01
# batch: 150 ;B loss: 1.681 ;acc: 0.605 ;iou_acc: 0.680 ;edits:0.21 ;time: 0:03:12
# batch: 200 ;B loss: 2.057 ;acc: 0.495 ;iou_acc: 0.615 ;edits:0.16 ;time: 0:03:24
# batch: 250 ;B loss: 2.583 ;acc: 0.365 ;iou_acc: 0.515 ;edits:0.19 ;time: 0:03:38
#
# *B test loss: 1.864 ;Test accuracy 0.561 ;IOU accuracy: 0.668 ;Edit num: 0.187 ;Time: 0:03:54
#
# ==================================================
#
# ==================================================
# Train, ephoc: 7 ; Training B: False
# Edit:True ;batch:0 ;Bloss:1.436 ;Aloss:0.184 ;edits:0.14 ;editRandomlyProb:1.00 ;acc:0.685 ;iou:0.770 ;time: 0:00:01
# Edit:True ;batch:50 ;Bloss:2.096 ;Aloss:0.213 ;edits:0.15 ;editRandomlyProb:1.00 ;acc:0.520 ;iou:0.645 ;time: 0:00:16
# Edit:True ;batch:100 ;Bloss:2.806 ;Aloss:0.206 ;edits:0.11 ;editRandomlyProb:1.00 ;acc:0.330 ;iou:0.455 ;time: 0:00:33
# Edit:True ;batch:150 ;Bloss:1.394 ;Aloss:0.190 ;edits:0.17 ;editRandomlyProb:1.00 ;acc:0.715 ;iou:0.765 ;time: 0:00:48
# Edit:True ;batch:200 ;Bloss:1.912 ;Aloss:0.182 ;edits:0.16 ;editRandomlyProb:1.00 ;acc:0.595 ;iou:0.710 ;time: 0:01:04
# Edit:True ;batch:250 ;Bloss:1.961 ;Aloss:0.171 ;edits:0.12 ;editRandomlyProb:1.00 ;acc:0.580 ;iou:0.660 ;time: 0:01:21
#
# *Training B: False ;B Train loss: 1.875 ;A Train loss: 0.194 ;Edit num: 0.140 MIXER delta:1.000 ;Train accuracy: 0.587 ;IOU accuracy: 0.695 ;Time: 0:01:36
#
# A testing, ephoc: 7 ;Random: False
# batch: 0 ;B loss: 0.804 ;acc: 0.810 ;iou_acc: 0.865 ;edits:0.15 ;time: 0:01:37
# batch: 50 ;B loss: 1.246 ;acc: 0.710 ;iou_acc: 0.795 ;edits:0.19 ;time: 0:01:46
# batch: 100 ;B loss: 1.830 ;acc: 0.575 ;iou_acc: 0.680 ;edits:0.23 ;time: 0:01:56
# batch: 150 ;B loss: 2.069 ;acc: 0.505 ;iou_acc: 0.585 ;edits:0.29 ;time: 0:02:06
# batch: 200 ;B loss: 2.621 ;acc: 0.380 ;iou_acc: 0.510 ;edits:0.29 ;time: 0:02:19
# batch: 250 ;B loss: 3.162 ;acc: 0.245 ;iou_acc: 0.360 ;edits:0.34 ;time: 0:02:33
#
# *B test loss: 2.163 ;Test accuracy 0.482 ;IOU accuracy: 0.581 ;Edit num: 0.275 ;Time: 0:02:49
#
# A testing, ephoc: 7 ;Random: True
# batch: 0 ;B loss: 0.912 ;acc: 0.785 ;iou_acc: 0.850 ;edits:0.27 ;time: 0:02:50
# batch: 50 ;B loss: 1.429 ;acc: 0.670 ;iou_acc: 0.735 ;edits:0.32 ;time: 0:02:58
# batch: 100 ;B loss: 1.784 ;acc: 0.585 ;iou_acc: 0.645 ;edits:0.27 ;time: 0:03:08
# batch: 150 ;B loss: 1.803 ;acc: 0.595 ;iou_acc: 0.600 ;edits:0.28 ;time: 0:03:20
# batch: 200 ;B loss: 2.252 ;acc: 0.450 ;iou_acc: 0.580 ;edits:0.27 ;time: 0:03:32
# batch: 250 ;B loss: 2.745 ;acc: 0.335 ;iou_acc: 0.455 ;edits:0.30 ;time: 0:03:47
#
# *B test loss: 1.986 ;Test accuracy 0.525 ;IOU accuracy: 0.631 ;Edit num: 0.274 ;Time: 0:04:03
#
# ==================================================
#
# ==================================================
# Train, ephoc: 8 ; Training B: True
# Edit:False ;batch:0 ;gs:1189 ;lr:0.050 ;Bloss:2.513 ;acc:0.440 ;iou:0.610 ;time: 0:00:01
# Edit:False ;batch:50 ;gs:1239 ;lr:0.050 ;Bloss:1.376 ;acc:0.705 ;iou:0.795 ;time: 0:00:09
# Edit:False ;batch:100 ;gs:1289 ;lr:0.050 ;Bloss:2.607 ;acc:0.410 ;iou:0.605 ;time: 0:00:16
# Edit:False ;batch:150 ;gs:1339 ;lr:0.050 ;Bloss:0.975 ;acc:0.825 ;iou:0.895 ;time: 0:00:24
# Edit:False ;batch:200 ;gs:1389 ;lr:0.050 ;Bloss:0.822 ;acc:0.845 ;iou:0.895 ;time: 0:00:33
# Edit:False ;batch:250 ;gs:1439 ;lr:0.050 ;Bloss:2.659 ;acc:0.435 ;iou:0.570 ;time: 0:00:41
#
# *Training B: False ;B Train loss: 1.629 ;Train accuracy: 0.655 ;IOU accuracy: 0.758 ;Time: 0:00:48
#
# Testing, ephoc: 8
# batch: 0 ;B loss: 0.657 ;acc: 0.845 ;iou_acc: 0.905 ;time: 0:00:49
# batch: 50 ;B loss: 0.901 ;acc: 0.810 ;iou_acc: 0.865 ;time: 0:00:54
# batch: 100 ;B loss: 1.345 ;acc: 0.720 ;iou_acc: 0.790 ;time: 0:01:00
# batch: 150 ;B loss: 1.355 ;acc: 0.690 ;iou_acc: 0.770 ;time: 0:01:06
# batch: 200 ;B loss: 1.805 ;acc: 0.565 ;iou_acc: 0.690 ;time: 0:01:14
# batch: 250 ;B loss: 2.306 ;acc: 0.465 ;iou_acc: 0.605 ;time: 0:01:22
#
# *BTrain: False ;Test loss: 1.541 ;Test accuracy 0.646 ;IOU accuracy: 0.752 ;Time: 0:01:32
# ==================================================
#
# ==================================================
# Train, ephoc: 9 ; Training B: False
# Edit:True ;batch:0 ;Bloss:3.102 ;Aloss:0.197 ;edits:0.14 ;editRandomlyProb:0.50 ;acc:0.330 ;iou:0.490 ;time: 0:00:01
# Edit:True ;batch:50 ;Bloss:2.163 ;Aloss:0.193 ;edits:0.11 ;editRandomlyProb:0.50 ;acc:0.540 ;iou:0.660 ;time: 0:00:17
# Edit:True ;batch:100 ;Bloss:0.846 ;Aloss:0.150 ;edits:0.09 ;editRandomlyProb:0.50 ;acc:0.810 ;iou:0.840 ;time: 0:00:33
# Edit:True ;batch:150 ;Bloss:0.697 ;Aloss:0.112 ;edits:0.07 ;editRandomlyProb:0.50 ;acc:0.905 ;iou:0.925 ;time: 0:00:50
# Edit:True ;batch:200 ;Bloss:1.818 ;Aloss:0.188 ;edits:0.11 ;editRandomlyProb:0.50 ;acc:0.585 ;iou:0.640 ;time: 0:01:05
# Edit:True ;batch:250 ;Bloss:2.103 ;Aloss:0.222 ;edits:0.10 ;editRandomlyProb:0.50 ;acc:0.570 ;iou:0.700 ;time: 0:01:22
#
# *Training B: True ;B Train loss: 1.835 ;A Train loss: 0.181 ;Edit num: 0.119 MIXER delta:2.000 ;Train accuracy: 0.600 ;IOU accuracy: 0.706 ;Time: 0:01:37
#
# A testing, ephoc: 9 ;Random: False
# batch: 0 ;B loss: 0.657 ;acc: 0.845 ;iou_acc: 0.905 ;edits:0.00 ;time: 0:01:38
# batch: 50 ;B loss: 0.901 ;acc: 0.810 ;iou_acc: 0.865 ;edits:0.00 ;time: 0:01:46
# batch: 100 ;B loss: 1.345 ;acc: 0.720 ;iou_acc: 0.790 ;edits:0.00 ;time: 0:01:56
# batch: 150 ;B loss: 1.355 ;acc: 0.690 ;iou_acc: 0.770 ;edits:0.00 ;time: 0:02:08
# batch: 200 ;B loss: 1.805 ;acc: 0.565 ;iou_acc: 0.690 ;edits:0.00 ;time: 0:02:20
# batch: 250 ;B loss: 2.306 ;acc: 0.465 ;iou_acc: 0.605 ;edits:0.00 ;time: 0:02:34
#
# *B test loss: 1.542 ;Test accuracy 0.646 ;IOU accuracy: 0.751 ;Edit num: 0.001 ;Time: 0:02:51
#
# A testing, ephoc: 9 ;Random: True
# batch: 0 ;B loss: 0.657 ;acc: 0.840 ;iou_acc: 0.905 ;edits:0.00 ;time: 0:02:51
# batch: 50 ;B loss: 0.907 ;acc: 0.810 ;iou_acc: 0.865 ;edits:0.00 ;time: 0:02:59
# batch: 100 ;B loss: 1.356 ;acc: 0.720 ;iou_acc: 0.790 ;edits:0.00 ;time: 0:03:09
# batch: 150 ;B loss: 1.355 ;acc: 0.690 ;iou_acc: 0.770 ;edits:0.00 ;time: 0:03:20
# batch: 200 ;B loss: 1.805 ;acc: 0.565 ;iou_acc: 0.690 ;edits:0.00 ;time: 0:03:32
# batch: 250 ;B loss: 2.306 ;acc: 0.460 ;iou_acc: 0.605 ;edits:0.00 ;time: 0:03:46
#
# *B test loss: 1.542 ;Test accuracy 0.646 ;IOU accuracy: 0.751 ;Edit num: 0.001 ;Time: 0:04:02
#
# ==================================================
#
# ==================================================
# Train, ephoc: 10 ; Training B: False
# Edit:True ;batch:0 ;Bloss:1.757 ;Aloss:0.208 ;edits:0.08 ;editRandomlyProb:0.50 ;acc:0.605 ;iou:0.740 ;time: 0:00:01
# Edit:True ;batch:50 ;Bloss:1.544 ;Aloss:0.168 ;edits:0.11 ;editRandomlyProb:0.50 ;acc:0.655 ;iou:0.745 ;time: 0:00:18
# Edit:True ;batch:100 ;Bloss:1.052 ;Aloss:0.169 ;edits:0.14 ;editRandomlyProb:0.50 ;acc:0.805 ;iou:0.845 ;time: 0:00:33
# Edit:True ;batch:150 ;Bloss:1.519 ;Aloss:0.172 ;edits:0.10 ;editRandomlyProb:0.50 ;acc:0.725 ;iou:0.795 ;time: 0:00:50
# Edit:True ;batch:200 ;Bloss:1.736 ;Aloss:0.200 ;edits:0.15 ;editRandomlyProb:0.50 ;acc:0.690 ;iou:0.755 ;time: 0:01:06
# Edit:True ;batch:250 ;Bloss:2.156 ;Aloss:0.179 ;edits:0.13 ;editRandomlyProb:0.50 ;acc:0.480 ;iou:0.605 ;time: 0:01:22
#
# *Training B: False ;B Train loss: 1.840 ;A Train loss: 0.179 ;Edit num: 0.119 MIXER delta:2.000 ;Train accuracy: 0.599 ;IOU accuracy: 0.705 ;Time: 0:01:37
#
# A testing, ephoc: 10 ;Random: False
# batch: 0 ;B loss: 0.811 ;acc: 0.810 ;iou_acc: 0.855 ;edits:0.17 ;time: 0:01:38
# batch: 50 ;B loss: 1.336 ;acc: 0.720 ;iou_acc: 0.765 ;edits:0.21 ;time: 0:01:46
# batch: 100 ;B loss: 1.894 ;acc: 0.545 ;iou_acc: 0.655 ;edits:0.25 ;time: 0:01:56
# batch: 150 ;B loss: 1.996 ;acc: 0.465 ;iou_acc: 0.580 ;edits:0.31 ;time: 0:02:08
# batch: 200 ;B loss: 2.509 ;acc: 0.390 ;iou_acc: 0.525 ;edits:0.31 ;time: 0:02:20
# batch: 250 ;B loss: 3.079 ;acc: 0.295 ;iou_acc: 0.385 ;edits:0.38 ;time: 0:02:34
#
# *B test loss: 2.155 ;Test accuracy 0.485 ;IOU accuracy: 0.583 ;Edit num: 0.300 ;Time: 0:02:50
#
# A testing, ephoc: 10 ;Random: True
# batch: 0 ;B loss: 0.874 ;acc: 0.750 ;iou_acc: 0.880 ;edits:0.32 ;time: 0:02:50
# batch: 50 ;B loss: 1.406 ;acc: 0.680 ;iou_acc: 0.750 ;edits:0.34 ;time: 0:02:58
# batch: 100 ;B loss: 1.798 ;acc: 0.595 ;iou_acc: 0.660 ;edits:0.31 ;time: 0:03:08
# batch: 150 ;B loss: 1.803 ;acc: 0.500 ;iou_acc: 0.610 ;edits:0.29 ;time: 0:03:19
# batch: 200 ;B loss: 2.273 ;acc: 0.440 ;iou_acc: 0.535 ;edits:0.33 ;time: 0:03:31
# batch: 250 ;B loss: 2.885 ;acc: 0.365 ;iou_acc: 0.480 ;edits:0.30 ;time: 0:03:45
#
# *B test loss: 2.007 ;Test accuracy 0.521 ;IOU accuracy: 0.631 ;Edit num: 0.301 ;Time: 0:04:00
#
# ==================================================
#
# ==================================================
# Train, ephoc: 11 ; Training B: True
# Edit:False ;batch:0 ;gs:1486 ;lr:0.050 ;Bloss:1.761 ;acc:0.650 ;iou:0.730 ;time: 0:00:00
# Edit:False ;batch:50 ;gs:1536 ;lr:0.050 ;Bloss:1.046 ;acc:0.780 ;iou:0.865 ;time: 0:00:08
# Edit:False ;batch:100 ;gs:1586 ;lr:0.050 ;Bloss:1.743 ;acc:0.610 ;iou:0.695 ;time: 0:00:16
# Edit:False ;batch:150 ;gs:1636 ;lr:0.050 ;Bloss:1.384 ;acc:0.705 ;iou:0.805 ;time: 0:00:24
# Edit:False ;batch:200 ;gs:1686 ;lr:0.050 ;Bloss:2.715 ;acc:0.380 ;iou:0.570 ;time: 0:00:31
# Edit:False ;batch:250 ;gs:1736 ;lr:0.050 ;Bloss:0.891 ;acc:0.830 ;iou:0.880 ;time: 0:00:40
#
# *Training B: False ;B Train loss: 1.581 ;Train accuracy: 0.667 ;IOU accuracy: 0.768 ;Time: 0:00:47
#
# Testing, ephoc: 11
# batch: 0 ;B loss: 0.625 ;acc: 0.880 ;iou_acc: 0.935 ;time: 0:00:47
# batch: 50 ;B loss: 0.868 ;acc: 0.805 ;iou_acc: 0.865 ;time: 0:00:52
# batch: 100 ;B loss: 1.311 ;acc: 0.730 ;iou_acc: 0.795 ;time: 0:00:57
# batch: 150 ;B loss: 1.350 ;acc: 0.690 ;iou_acc: 0.775 ;time: 0:01:03
# batch: 200 ;B loss: 1.779 ;acc: 0.565 ;iou_acc: 0.700 ;time: 0:01:10
# batch: 250 ;B loss: 2.261 ;acc: 0.465 ;iou_acc: 0.640 ;time: 0:01:18
#
# *BTrain: False ;Test loss: 1.510 ;Test accuracy 0.653 ;IOU accuracy: 0.756 ;Time: 0:01:28
# ==================================================
#
# ==================================================
# Train, ephoc: 12 ; Training B: False
# Edit:True ;batch:0 ;Bloss:1.317 ;Aloss:0.190 ;edits:0.15 ;editRandomlyProb:0.50 ;acc:0.745 ;iou:0.800 ;time: 0:00:01
# Edit:True ;batch:50 ;Bloss:1.279 ;Aloss:0.170 ;edits:0.14 ;editRandomlyProb:0.50 ;acc:0.750 ;iou:0.805 ;time: 0:00:16
# Edit:True ;batch:100 ;Bloss:2.326 ;Aloss:0.181 ;edits:0.12 ;editRandomlyProb:0.50 ;acc:0.505 ;iou:0.620 ;time: 0:00:31
# Edit:True ;batch:150 ;Bloss:1.683 ;Aloss:0.183 ;edits:0.12 ;editRandomlyProb:0.50 ;acc:0.630 ;iou:0.720 ;time: 0:00:46
# Edit:True ;batch:200 ;Bloss:2.463 ;Aloss:0.171 ;edits:0.11 ;editRandomlyProb:0.50 ;acc:0.445 ;iou:0.635 ;time: 0:01:01
# Edit:True ;batch:250 ;Bloss:1.575 ;Aloss:0.156 ;edits:0.12 ;editRandomlyProb:0.50 ;acc:0.735 ;iou:0.790 ;time: 0:01:17
#
# *Training B: True ;B Train loss: 1.803 ;A Train loss: 0.176 ;Edit num: 0.117 MIXER delta:2.000 ;Train accuracy: 0.606 ;IOU accuracy: 0.711 ;Time: 0:01:31
#
# A testing, ephoc: 12 ;Random: False
# batch: 0 ;B loss: 0.766 ;acc: 0.840 ;iou_acc: 0.895 ;edits:0.18 ;time: 0:01:32
# batch: 50 ;B loss: 1.388 ;acc: 0.690 ;iou_acc: 0.755 ;edits:0.23 ;time: 0:01:39
# batch: 100 ;B loss: 1.927 ;acc: 0.545 ;iou_acc: 0.625 ;edits:0.27 ;time: 0:01:49
# batch: 150 ;B loss: 2.082 ;acc: 0.500 ;iou_acc: 0.560 ;edits:0.33 ;time: 0:02:00
# batch: 200 ;B loss: 2.384 ;acc: 0.410 ;iou_acc: 0.510 ;edits:0.32 ;time: 0:02:11
# batch: 250 ;B loss: 3.110 ;acc: 0.280 ;iou_acc: 0.370 ;edits:0.38 ;time: 0:02:24
#
# *B test loss: 2.154 ;Test accuracy 0.483 ;IOU accuracy: 0.583 ;Edit num: 0.309 ;Time: 0:02:40
#
# A testing, ephoc: 12 ;Random: True
# batch: 0 ;B loss: 0.864 ;acc: 0.845 ;iou_acc: 0.895 ;edits:0.30 ;time: 0:02:41
# batch: 50 ;B loss: 1.551 ;acc: 0.715 ;iou_acc: 0.685 ;edits:0.32 ;time: 0:02:48
# batch: 100 ;B loss: 1.892 ;acc: 0.535 ;iou_acc: 0.630 ;edits:0.34 ;time: 0:02:59
# batch: 150 ;B loss: 2.062 ;acc: 0.555 ;iou_acc: 0.640 ;edits:0.34 ;time: 0:03:10
# batch: 200 ;B loss: 2.352 ;acc: 0.465 ;iou_acc: 0.585 ;edits:0.32 ;time: 0:03:22
# batch: 250 ;B loss: 2.833 ;acc: 0.335 ;iou_acc: 0.500 ;edits:0.32 ;time: 0:03:36
#
# *B test loss: 2.001 ;Test accuracy 0.524 ;IOU accuracy: 0.631 ;Edit num: 0.309 ;Time: 0:03:52
#
# ==================================================
#
# ==================================================
# Train, ephoc: 13 ; Training B: False
# Edit:True ;batch:0 ;Bloss:1.016 ;Aloss:0.177 ;edits:0.15 ;editRandomlyProb:0.50 ;acc:0.795 ;iou:0.860 ;time: 0:00:00
# Edit:True ;batch:50 ;Bloss:2.436 ;Aloss:0.184 ;edits:0.11 ;editRandomlyProb:0.50 ;acc:0.415 ;iou:0.575 ;time: 0:00:15
# Edit:True ;batch:100 ;Bloss:1.782 ;Aloss:0.176 ;edits:0.12 ;editRandomlyProb:0.50 ;acc:0.570 ;iou:0.660 ;time: 0:00:30
# Edit:True ;batch:150 ;Bloss:1.046 ;Aloss:0.165 ;edits:0.14 ;editRandomlyProb:0.50 ;acc:0.730 ;iou:0.815 ;time: 0:00:45
# Edit:True ;batch:200 ;Bloss:1.609 ;Aloss:0.163 ;edits:0.11 ;editRandomlyProb:0.50 ;acc:0.670 ;iou:0.745 ;time: 0:01:02
# Edit:True ;batch:250 ;Bloss:1.480 ;Aloss:0.155 ;edits:0.11 ;editRandomlyProb:0.50 ;acc:0.695 ;iou:0.770 ;time: 0:01:16
#
# *Training B: False ;B Train loss: 1.810 ;A Train loss: 0.177 ;Edit num: 0.118 MIXER delta:2.000 ;Train accuracy: 0.607 ;IOU accuracy: 0.712 ;Time: 0:01:30
#
# A testing, ephoc: 13 ;Random: False
# batch: 0 ;B loss: 0.648 ;acc: 0.880 ;iou_acc: 0.930 ;edits:0.05 ;time: 0:01:30
# batch: 50 ;B loss: 1.080 ;acc: 0.750 ;iou_acc: 0.820 ;edits:0.08 ;time: 0:01:38
# batch: 100 ;B loss: 1.636 ;acc: 0.625 ;iou_acc: 0.720 ;edits:0.11 ;time: 0:01:48
# batch: 150 ;B loss: 1.781 ;acc: 0.555 ;iou_acc: 0.660 ;edits:0.15 ;time: 0:01:59
# batch: 200 ;B loss: 2.220 ;acc: 0.455 ;iou_acc: 0.585 ;edits:0.15 ;time: 0:02:12
# batch: 250 ;B loss: 2.725 ;acc: 0.320 ;iou_acc: 0.485 ;edits:0.18 ;time: 0:02:25
#
# *B test loss: 1.856 ;Test accuracy 0.555 ;IOU accuracy: 0.654 ;Edit num: 0.131 ;Time: 0:02:41
#
# A testing, ephoc: 13 ;Random: True
# batch: 0 ;B loss: 0.663 ;acc: 0.860 ;iou_acc: 0.925 ;edits:0.11 ;time: 0:02:41
# batch: 50 ;B loss: 1.144 ;acc: 0.760 ;iou_acc: 0.795 ;edits:0.16 ;time: 0:02:48
# batch: 100 ;B loss: 1.542 ;acc: 0.640 ;iou_acc: 0.755 ;edits:0.16 ;time: 0:02:58
# batch: 150 ;B loss: 1.600 ;acc: 0.620 ;iou_acc: 0.700 ;edits:0.13 ;time: 0:03:07
# batch: 200 ;B loss: 1.902 ;acc: 0.490 ;iou_acc: 0.665 ;edits:0.11 ;time: 0:03:19
# batch: 250 ;B loss: 2.421 ;acc: 0.430 ;iou_acc: 0.605 ;edits:0.11 ;time: 0:03:31
#
# *B test loss: 1.706 ;Test accuracy 0.600 ;IOU accuracy: 0.706 ;Edit num: 0.130 ;Time: 0:03:47
#
# ==================================================
#
# ==================================================
# Train, ephoc: 14 ; Training B: True
# Edit:True ;batch:0 ;gs:1783 ;lr:0.050 ;Bloss:1.730 ;Aloss:0.166 ;edits:0.04 ;editRandomlyProb:0.00 ;acc:0.580 ;iou:0.680 ;time: 0:00:00
# Edit:True ;batch:50 ;gs:1833 ;lr:0.050 ;Bloss:1.046 ;Aloss:0.138 ;edits:0.04 ;editRandomlyProb:0.00 ;acc:0.760 ;iou:0.790 ;time: 0:00:19
# Edit:True ;batch:100 ;gs:1883 ;lr:0.050 ;Bloss:1.383 ;Aloss:0.162 ;edits:0.08 ;editRandomlyProb:0.00 ;acc:0.660 ;iou:0.755 ;time: 0:00:40
# Edit:True ;batch:150 ;gs:1933 ;lr:0.050 ;Bloss:0.680 ;Aloss:0.167 ;edits:0.00 ;editRandomlyProb:0.00 ;acc:0.875 ;iou:0.910 ;time: 0:00:59
# Edit:True ;batch:200 ;gs:1983 ;lr:0.050 ;Bloss:2.311 ;Aloss:0.192 ;edits:0.03 ;editRandomlyProb:0.00 ;acc:0.440 ;iou:0.540 ;time: 0:01:20
# Edit:True ;batch:250 ;gs:2033 ;lr:0.050 ;Bloss:0.974 ;Aloss:0.125 ;edits:0.02 ;editRandomlyProb:0.00 ;acc:0.795 ;iou:0.850 ;time: 0:01:39
#
# *Training B: False ;B Train loss: 1.686 ;A Train loss: 0.161 ;Edit num: 0.053 MIXER delta:3.000 ;Train accuracy: 0.599 ;IOU accuracy: 0.697 ;Time: 0:01:58
#
# No Edit
# ooooooo
# Edit:False ;batch:0 ;gs:2079 ;lr:0.050 ;Bloss:1.559 ;acc:0.670 ;iou:0.775 ;time: 0:01:59
# Edit:False ;batch:50 ;gs:2079 ;lr:0.050 ;Bloss:0.906 ;acc:0.805 ;iou:0.865 ;time: 0:02:05
# Edit:False ;batch:100 ;gs:2079 ;lr:0.050 ;Bloss:1.239 ;acc:0.725 ;iou:0.810 ;time: 0:02:13
# Edit:False ;batch:150 ;gs:2079 ;lr:0.050 ;Bloss:0.684 ;acc:0.860 ;iou:0.900 ;time: 0:02:20
# Edit:False ;batch:200 ;gs:2079 ;lr:0.050 ;Bloss:2.111 ;acc:0.515 ;iou:0.625 ;time: 0:02:27
# Edit:False ;batch:250 ;gs:2079 ;lr:0.050 ;Bloss:0.959 ;acc:0.805 ;iou:0.875 ;time: 0:02:34
#
# *Training B: False ;B Train loss: 1.520 ;Train accuracy: 0.673 ;IOU accuracy: 0.773 ;Time: 0:02:40
#
# Testing, ephoc: 14
# batch: 0 ;B loss: 0.615 ;acc: 0.895 ;iou_acc: 0.940 ;time: 0:02:41
# batch: 50 ;B loss: 0.855 ;acc: 0.825 ;iou_acc: 0.875 ;time: 0:02:45
# batch: 100 ;B loss: 1.287 ;acc: 0.730 ;iou_acc: 0.805 ;time: 0:02:50
# batch: 150 ;B loss: 1.336 ;acc: 0.690 ;iou_acc: 0.780 ;time: 0:02:56
# batch: 200 ;B loss: 1.742 ;acc: 0.585 ;iou_acc: 0.710 ;time: 0:03:04
# batch: 250 ;B loss: 2.230 ;acc: 0.465 ;iou_acc: 0.610 ;time: 0:03:12
#
# *BTrain: False ;Test loss: 1.485 ;Test accuracy 0.662 ;IOU accuracy: 0.762 ;Time: 0:03:21
# ==================================================
#
# ==================================================
# Train, ephoc: 15 ; Training B: False
# Edit:True ;batch:0 ;Bloss:0.875 ;Aloss:0.146 ;edits:0.09 ;editRandomlyProb:0.33 ;acc:0.835 ;iou:0.865 ;time: 0:00:01
# Edit:True ;batch:50 ;Bloss:1.524 ;Aloss:0.193 ;edits:0.16 ;editRandomlyProb:0.33 ;acc:0.670 ;iou:0.770 ;time: 0:00:16
# Edit:True ;batch:100 ;Bloss:2.464 ;Aloss:0.168 ;edits:0.11 ;editRandomlyProb:0.33 ;acc:0.490 ;iou:0.585 ;time: 0:00:29
# Edit:True ;batch:150 ;Bloss:1.670 ;Aloss:0.158 ;edits:0.10 ;editRandomlyProb:0.33 ;acc:0.645 ;iou:0.745 ;time: 0:00:45
# Edit:True ;batch:200 ;Bloss:3.091 ;Aloss:0.172 ;edits:0.12 ;editRandomlyProb:0.33 ;acc:0.280 ;iou:0.520 ;time: 0:01:00
# Edit:True ;batch:250 ;Bloss:1.442 ;Aloss:0.177 ;edits:0.12 ;editRandomlyProb:0.33 ;acc:0.665 ;iou:0.775 ;time: 0:01:16
#
# *Training B: True ;B Train loss: 1.694 ;A Train loss: 0.168 ;Edit num: 0.098 MIXER delta:3.000 ;Train accuracy: 0.633 ;IOU accuracy: 0.737 ;Time: 0:01:30
#
# A testing, ephoc: 15 ;Random: False
# batch: 0 ;B loss: 0.618 ;acc: 0.895 ;iou_acc: 0.940 ;edits:0.01 ;time: 0:01:31
# batch: 50 ;B loss: 0.863 ;acc: 0.825 ;iou_acc: 0.875 ;edits:0.01 ;time: 0:01:38
# batch: 100 ;B loss: 1.300 ;acc: 0.735 ;iou_acc: 0.805 ;edits:0.02 ;time: 0:01:48
# batch: 150 ;B loss: 1.431 ;acc: 0.660 ;iou_acc: 0.750 ;edits:0.03 ;time: 0:01:58
# batch: 200 ;B loss: 1.800 ;acc: 0.565 ;iou_acc: 0.680 ;edits:0.03 ;time: 0:02:08
# batch: 250 ;B loss: 2.347 ;acc: 0.425 ;iou_acc: 0.570 ;edits:0.05 ;time: 0:02:22
#
# *B test loss: 1.544 ;Test accuracy 0.643 ;IOU accuracy: 0.743 ;Edit num: 0.025 ;Time: 0:02:37
#
# A testing, ephoc: 15 ;Random: True
# batch: 0 ;B loss: 0.641 ;acc: 0.890 ;iou_acc: 0.925 ;edits:0.02 ;time: 0:02:37
# batch: 50 ;B loss: 0.885 ;acc: 0.810 ;iou_acc: 0.865 ;edits:0.02 ;time: 0:02:45
# batch: 100 ;B loss: 1.321 ;acc: 0.715 ;iou_acc: 0.800 ;edits:0.03 ;time: 0:02:55
# batch: 150 ;B loss: 1.377 ;acc: 0.680 ;iou_acc: 0.770 ;edits:0.02 ;time: 0:03:05
# batch: 200 ;B loss: 1.849 ;acc: 0.580 ;iou_acc: 0.705 ;edits:0.03 ;time: 0:03:18
# batch: 250 ;B loss: 2.247 ;acc: 0.445 ;iou_acc: 0.620 ;edits:0.02 ;time: 0:03:31
#
# *B test loss: 1.518 ;Test accuracy 0.653 ;IOU accuracy: 0.754 ;Edit num: 0.025 ;Time: 0:03:47
#
# ==================================================
#
# ==================================================
# Train, ephoc: 16 ; Training B: False
# Edit:True ;batch:0 ;Bloss:2.859 ;Aloss:0.184 ;edits:0.08 ;editRandomlyProb:0.33 ;acc:0.400 ;iou:0.535 ;time: 0:00:01
# Edit:True ;batch:50 ;Bloss:1.392 ;Aloss:0.144 ;edits:0.06 ;editRandomlyProb:0.33 ;acc:0.710 ;iou:0.790 ;time: 0:00:16
# Edit:True ;batch:100 ;Bloss:1.754 ;Aloss:0.169 ;edits:0.09 ;editRandomlyProb:0.33 ;acc:0.615 ;iou:0.720 ;time: 0:00:31
# Edit:True ;batch:150 ;Bloss:1.268 ;Aloss:0.188 ;edits:0.16 ;editRandomlyProb:0.33 ;acc:0.715 ;iou:0.805 ;time: 0:00:48
# Edit:True ;batch:200 ;Bloss:2.083 ;Aloss:0.173 ;edits:0.09 ;editRandomlyProb:0.33 ;acc:0.565 ;iou:0.700 ;time: 0:01:03
# Edit:True ;batch:250 ;Bloss:0.891 ;Aloss:0.130 ;edits:0.06 ;editRandomlyProb:0.33 ;acc:0.835 ;iou:0.890 ;time: 0:01:18
#
# *Training B: False ;B Train loss: 1.693 ;A Train loss: 0.165 ;Edit num: 0.094 MIXER delta:3.000 ;Train accuracy: 0.634 ;IOU accuracy: 0.737 ;Time: 0:01:31
#
# A testing, ephoc: 16 ;Random: False
# batch: 0 ;B loss: 0.618 ;acc: 0.895 ;iou_acc: 0.940 ;edits:0.03 ;time: 0:01:31
# batch: 50 ;B loss: 0.967 ;acc: 0.795 ;iou_acc: 0.855 ;edits:0.06 ;time: 0:01:40
# batch: 100 ;B loss: 1.467 ;acc: 0.680 ;iou_acc: 0.740 ;edits:0.09 ;time: 0:01:50
# batch: 150 ;B loss: 1.617 ;acc: 0.600 ;iou_acc: 0.725 ;edits:0.10 ;time: 0:02:00
# batch: 200 ;B loss: 1.955 ;acc: 0.520 ;iou_acc: 0.650 ;edits:0.10 ;time: 0:02:12
# batch: 250 ;B loss: 2.476 ;acc: 0.360 ;iou_acc: 0.530 ;edits:0.14 ;time: 0:02:25
#
# *B test loss: 1.657 ;Test accuracy 0.609 ;IOU accuracy: 0.709 ;Edit num: 0.096 ;Time: 0:02:40
#
# A testing, ephoc: 16 ;Random: True
# batch: 0 ;B loss: 0.677 ;acc: 0.885 ;iou_acc: 0.925 ;edits:0.10 ;time: 0:02:41
# batch: 50 ;B loss: 1.029 ;acc: 0.790 ;iou_acc: 0.840 ;edits:0.10 ;time: 0:02:48
# batch: 100 ;B loss: 1.373 ;acc: 0.670 ;iou_acc: 0.750 ;edits:0.09 ;time: 0:02:58
# batch: 150 ;B loss: 1.426 ;acc: 0.670 ;iou_acc: 0.740 ;edits:0.10 ;time: 0:03:09
# batch: 200 ;B loss: 1.848 ;acc: 0.540 ;iou_acc: 0.670 ;edits:0.09 ;time: 0:03:20
# batch: 250 ;B loss: 2.410 ;acc: 0.425 ;iou_acc: 0.575 ;edits:0.10 ;time: 0:03:33
#
# *B test loss: 1.613 ;Test accuracy 0.629 ;IOU accuracy: 0.729 ;Edit num: 0.097 ;Time: 0:03:49
#
# ==================================================
#
# ==================================================
# Train, ephoc: 17 ; Training B: True
# Edit:True ;batch:0 ;gs:2080 ;lr:0.050 ;Bloss:1.740 ;Aloss:0.165 ;edits:0.06 ;editRandomlyProb:0.00 ;acc:0.605 ;iou:0.695 ;time: 0:00:01
# Edit:True ;batch:50 ;gs:2130 ;lr:0.050 ;Bloss:1.585 ;Aloss:0.140 ;edits:0.03 ;editRandomlyProb:0.00 ;acc:0.660 ;iou:0.715 ;time: 0:00:19
# Edit:False ;batch:100 ;gs:2180 ;lr:0.050 ;Bloss:1.263 ;acc:0.725 ;iou:0.825 ;time: 0:00:39
# Edit:True ;batch:150 ;gs:2230 ;lr:0.050 ;Bloss:0.572 ;Aloss:0.110 ;edits:0.00 ;editRandomlyProb:0.00 ;acc:0.885 ;iou:0.930 ;time: 0:00:58
# Edit:True ;batch:200 ;gs:2280 ;lr:0.050 ;Bloss:1.584 ;Aloss:0.161 ;edits:0.09 ;editRandomlyProb:0.00 ;acc:0.625 ;iou:0.725 ;time: 0:01:16
# Edit:True ;batch:250 ;gs:2330 ;lr:0.050 ;Bloss:1.346 ;Aloss:0.150 ;edits:0.08 ;editRandomlyProb:0.00 ;acc:0.695 ;iou:0.765 ;time: 0:01:36
#
# *Training B: False ;B Train loss: 1.581 ;A Train loss: 0.154 ;Edit num: 0.034 MIXER delta:3.000 ;Train accuracy: 0.639 ;IOU accuracy: 0.737 ;Time: 0:01:55
#
# No Edit
# ooooooo
# Edit:False ;batch:0 ;gs:2376 ;lr:0.050 ;Bloss:1.545 ;acc:0.670 ;iou:0.790 ;time: 0:01:55
# Edit:False ;batch:50 ;gs:2376 ;lr:0.050 ;Bloss:1.535 ;acc:0.730 ;iou:0.820 ;time: 0:02:02
# Edit:False ;batch:100 ;gs:2376 ;lr:0.050 ;Bloss:1.277 ;acc:0.715 ;iou:0.820 ;time: 0:02:09
# Edit:False ;batch:150 ;gs:2376 ;lr:0.050 ;Bloss:0.663 ;acc:0.865 ;iou:0.920 ;time: 0:02:15
# Edit:False ;batch:200 ;gs:2376 ;lr:0.050 ;Bloss:1.373 ;acc:0.675 ;iou:0.760 ;time: 0:02:22
# Edit:False ;batch:250 ;gs:2376 ;lr:0.050 ;Bloss:1.305 ;acc:0.775 ;iou:0.840 ;time: 0:02:29
#
# *Training B: False ;B Train loss: 1.519 ;Train accuracy: 0.673 ;IOU accuracy: 0.773 ;Time: 0:02:35
#
# Testing, ephoc: 17
# batch: 0 ;B loss: 0.632 ;acc: 0.885 ;iou_acc: 0.940 ;time: 0:02:36
# batch: 50 ;B loss: 0.844 ;acc: 0.805 ;iou_acc: 0.860 ;time: 0:02:40
# batch: 100 ;B loss: 1.285 ;acc: 0.735 ;iou_acc: 0.805 ;time: 0:02:46
# batch: 150 ;B loss: 1.325 ;acc: 0.695 ;iou_acc: 0.785 ;time: 0:02:52
# batch: 200 ;B loss: 1.721 ;acc: 0.580 ;iou_acc: 0.700 ;time: 0:02:59
# batch: 250 ;B loss: 2.222 ;acc: 0.490 ;iou_acc: 0.620 ;time: 0:03:08
#
# *BTrain: False ;Test loss: 1.484 ;Test accuracy 0.659 ;IOU accuracy: 0.759 ;Time: 0:03:18
# ==================================================
#
# ==================================================
# Train, ephoc: 18 ; Training B: False
# Edit:True ;batch:0 ;Bloss:1.191 ;Aloss:0.164 ;edits:0.07 ;editRandomlyProb:0.33 ;acc:0.750 ;iou:0.855 ;time: 0:00:00
# Edit:True ;batch:50 ;Bloss:1.058 ;Aloss:0.167 ;edits:0.10 ;editRandomlyProb:0.33 ;acc:0.805 ;iou:0.875 ;time: 0:00:15
# Edit:True ;batch:100 ;Bloss:1.772 ;Aloss:0.163 ;edits:0.11 ;editRandomlyProb:0.33 ;acc:0.610 ;iou:0.720 ;time: 0:00:30
# Edit:True ;batch:150 ;Bloss:1.663 ;Aloss:0.165 ;edits:0.07 ;editRandomlyProb:0.33 ;acc:0.610 ;iou:0.760 ;time: 0:00:45
# Edit:True ;batch:200 ;Bloss:1.162 ;Aloss:0.149 ;edits:0.05 ;editRandomlyProb:0.33 ;acc:0.750 ;iou:0.840 ;time: 0:01:01
# Edit:True ;batch:250 ;Bloss:1.917 ;Aloss:0.165 ;edits:0.09 ;editRandomlyProb:0.33 ;acc:0.580 ;iou:0.675 ;time: 0:01:16
#
# *Training B: True ;B Train loss: 1.655 ;A Train loss: 0.160 ;Edit num: 0.086 MIXER delta:3.000 ;Train accuracy: 0.643 ;IOU accuracy: 0.746 ;Time: 0:01:31
#
# A testing, ephoc: 18 ;Random: False
# batch: 0 ;B loss: 0.703 ;acc: 0.870 ;iou_acc: 0.925 ;edits:0.09 ;time: 0:01:31
# batch: 50 ;B loss: 0.982 ;acc: 0.755 ;iou_acc: 0.830 ;edits:0.11 ;time: 0:01:38
# batch: 100 ;B loss: 1.502 ;acc: 0.660 ;iou_acc: 0.730 ;edits:0.15 ;time: 0:01:48
# batch: 150 ;B loss: 1.582 ;acc: 0.635 ;iou_acc: 0.745 ;edits:0.17 ;time: 0:01:59
# batch: 200 ;B loss: 1.923 ;acc: 0.495 ;iou_acc: 0.635 ;edits:0.17 ;time: 0:02:11
# batch: 250 ;B loss: 2.540 ;acc: 0.430 ;iou_acc: 0.530 ;edits:0.23 ;time: 0:02:25
#
# *B test loss: 1.717 ;Test accuracy 0.595 ;IOU accuracy: 0.696 ;Edit num: 0.175 ;Time: 0:02:41
#
# A testing, ephoc: 18 ;Random: True
# batch: 0 ;B loss: 0.792 ;acc: 0.835 ;iou_acc: 0.935 ;edits:0.18 ;time: 0:02:41
# batch: 50 ;B loss: 1.096 ;acc: 0.730 ;iou_acc: 0.770 ;edits:0.18 ;time: 0:02:49
# batch: 100 ;B loss: 1.473 ;acc: 0.650 ;iou_acc: 0.715 ;edits:0.18 ;time: 0:02:59
# batch: 150 ;B loss: 1.629 ;acc: 0.645 ;iou_acc: 0.730 ;edits:0.21 ;time: 0:03:10
# batch: 200 ;B loss: 2.027 ;acc: 0.565 ;iou_acc: 0.610 ;edits:0.18 ;time: 0:03:21
# batch: 250 ;B loss: 2.443 ;acc: 0.390 ;iou_acc: 0.565 ;edits:0.18 ;time: 0:03:35
#
# *B test loss: 1.716 ;Test accuracy 0.601 ;IOU accuracy: 0.706 ;Edit num: 0.177 ;Time: 0:03:50
#
# ==================================================
#
# ==================================================
# Train, ephoc: 19 ; Training B: False
# Edit:True ;batch:0 ;Bloss:1.514 ;Aloss:0.152 ;edits:0.08 ;editRandomlyProb:0.33 ;acc:0.670 ;iou:0.755 ;time: 0:00:01
# Edit:True ;batch:50 ;Bloss:2.262 ;Aloss:0.190 ;edits:0.18 ;editRandomlyProb:0.33 ;acc:0.535 ;iou:0.625 ;time: 0:00:15
# Edit:True ;batch:100 ;Bloss:2.172 ;Aloss:0.169 ;edits:0.08 ;editRandomlyProb:0.33 ;acc:0.490 ;iou:0.600 ;time: 0:00:29
# Edit:True ;batch:150 ;Bloss:3.122 ;Aloss:0.205 ;edits:0.18 ;editRandomlyProb:0.33 ;acc:0.305 ;iou:0.525 ;time: 0:00:44
# Edit:True ;batch:200 ;Bloss:1.164 ;Aloss:0.148 ;edits:0.12 ;editRandomlyProb:0.33 ;acc:0.790 ;iou:0.875 ;time: 0:00:59
# Edit:True ;batch:250 ;Bloss:0.907 ;Aloss:0.150 ;edits:0.08 ;editRandomlyProb:0.33 ;acc:0.830 ;iou:0.845 ;time: 0:01:14
#
# *Training B: False ;B Train loss: 1.651 ;A Train loss: 0.160 ;Edit num: 0.085 MIXER delta:3.000 ;Train accuracy: 0.644 ;IOU accuracy: 0.747 ;Time: 0:01:27
#
# A testing, ephoc: 19 ;Random: False
# batch: 0 ;B loss: 0.764 ;acc: 0.820 ;iou_acc: 0.900 ;edits:0.22 ;time: 0:01:28
# batch: 50 ;B loss: 1.149 ;acc: 0.720 ;iou_acc: 0.775 ;edits:0.28 ;time: 0:01:36
# batch: 100 ;B loss: 1.643 ;acc: 0.635 ;iou_acc: 0.740 ;edits:0.34 ;time: 0:01:46
# batch: 150 ;B loss: 1.802 ;acc: 0.570 ;iou_acc: 0.665 ;edits:0.38 ;time: 0:01:56
# batch: 200 ;B loss: 2.115 ;acc: 0.460 ;iou_acc: 0.585 ;edits:0.37 ;time: 0:02:07
# batch: 250 ;B loss: 2.724 ;acc: 0.340 ;iou_acc: 0.485 ;edits:0.46 ;time: 0:02:20
#
# *B test loss: 1.915 ;Test accuracy 0.548 ;IOU accuracy: 0.647 ;Edit num: 0.376 ;Time: 0:02:37
#
# A testing, ephoc: 19 ;Random: True
# batch: 0 ;B loss: 0.872 ;acc: 0.770 ;iou_acc: 0.900 ;edits:0.36 ;time: 0:02:37
# batch: 50 ;B loss: 1.378 ;acc: 0.700 ;iou_acc: 0.750 ;edits:0.37 ;time: 0:02:44
# batch: 100 ;B loss: 1.973 ;acc: 0.550 ;iou_acc: 0.680 ;edits:0.37 ;time: 0:02:53
# batch: 150 ;B loss: 1.909 ;acc: 0.585 ;iou_acc: 0.680 ;edits:0.37 ;time: 0:03:04
# batch: 200 ;B loss: 2.117 ;acc: 0.425 ;iou_acc: 0.570 ;edits:0.33 ;time: 0:03:15
# batch: 250 ;B loss: 2.679 ;acc: 0.375 ;iou_acc: 0.470 ;edits:0.36 ;time: 0:03:28
#
# *B test loss: 1.994 ;Test accuracy 0.532 ;IOU accuracy: 0.642 ;Edit num: 0.377 ;Time: 0:03:44
#
# ==================================================
#
# ==================================================
# Train, ephoc: 20 ; Training B: True
# Edit:True ;batch:0 ;gs:2377 ;lr:0.050 ;Bloss:1.043 ;Aloss:0.150 ;edits:0.00 ;editRandomlyProb:0.00 ;acc:0.785 ;iou:0.855 ;time: 0:00:00
# Edit:True ;batch:50 ;gs:2427 ;lr:0.050 ;Bloss:1.610 ;Aloss:0.138 ;edits:0.08 ;editRandomlyProb:0.00 ;acc:0.580 ;iou:0.750 ;time: 0:00:21
# Edit:True ;batch:100 ;gs:2477 ;lr:0.050 ;Bloss:0.609 ;Aloss:0.126 ;edits:0.00 ;editRandomlyProb:0.00 ;acc:0.880 ;iou:0.915 ;time: 0:00:43
# Edit:True ;batch:150 ;gs:2527 ;lr:0.050 ;Bloss:1.655 ;Aloss:0.166 ;edits:0.01 ;editRandomlyProb:0.00 ;acc:0.625 ;iou:0.740 ;time: 0:01:02
# Edit:True ;batch:200 ;gs:2577 ;lr:0.050 ;Bloss:2.088 ;Aloss:0.149 ;edits:0.04 ;editRandomlyProb:0.00 ;acc:0.510 ;iou:0.660 ;time: 0:01:21
# Edit:True ;batch:250 ;gs:2627 ;lr:0.050 ;Bloss:0.741 ;Aloss:0.164 ;edits:0.00 ;editRandomlyProb:0.00 ;acc:0.880 ;iou:0.925 ;time: 0:01:41
#
# *Training B: False ;B Train loss: 1.526 ;A Train loss: 0.151 ;Edit num: 0.023 MIXER delta:4.000 ;Train accuracy: 0.659 ;IOU accuracy: 0.756 ;Time: 0:01:58
#
# No Edit
# ooooooo
# Edit:False ;batch:0 ;gs:2673 ;lr:0.050 ;Bloss:0.952 ;acc:0.800 ;iou:0.875 ;time: 0:01:59
# Edit:False ;batch:50 ;gs:2673 ;lr:0.050 ;Bloss:1.361 ;acc:0.730 ;iou:0.815 ;time: 0:02:06
# Edit:False ;batch:100 ;gs:2673 ;lr:0.050 ;Bloss:0.644 ;acc:0.880 ;iou:0.920 ;time: 0:02:13
# Edit:False ;batch:150 ;gs:2673 ;lr:0.050 ;Bloss:1.583 ;acc:0.630 ;iou:0.745 ;time: 0:02:20
# Edit:False ;batch:200 ;gs:2673 ;lr:0.050 ;Bloss:2.048 ;acc:0.605 ;iou:0.750 ;time: 0:02:27
# Edit:False ;batch:250 ;gs:2673 ;lr:0.050 ;Bloss:0.682 ;acc:0.875 ;iou:0.930 ;time: 0:02:34
#
# *Training B: False ;B Train loss: 1.457 ;Train accuracy: 0.689 ;IOU accuracy: 0.786 ;Time: 0:02:40
#
# Testing, ephoc: 20
# batch: 0 ;B loss: 0.559 ;acc: 0.880 ;iou_acc: 0.935 ;time: 0:02:41
# batch: 50 ;B loss: 0.787 ;acc: 0.830 ;iou_acc: 0.880 ;time: 0:02:45
# batch: 100 ;B loss: 1.229 ;acc: 0.765 ;iou_acc: 0.830 ;time: 0:02:50
# batch: 150 ;B loss: 1.268 ;acc: 0.740 ;iou_acc: 0.810 ;time: 0:02:56
# batch: 200 ;B loss: 1.697 ;acc: 0.600 ;iou_acc: 0.745 ;time: 0:03:02
# batch: 250 ;B loss: 2.168 ;acc: 0.505 ;iou_acc: 0.650 ;time: 0:03:10
#
# *BTrain: False ;Test loss: 1.428 ;Test accuracy 0.675 ;IOU accuracy: 0.773 ;Time: 0:03:20
# ==================================================
#
# ==================================================
# Train, ephoc: 21 ; Training B: False
# Edit:True ;batch:0 ;Bloss:1.082 ;Aloss:0.155 ;edits:0.06 ;editRandomlyProb:0.25 ;acc:0.770 ;iou:0.820 ;time: 0:00:01
# Edit:True ;batch:50 ;Bloss:2.017 ;Aloss:0.168 ;edits:0.05 ;editRandomlyProb:0.25 ;acc:0.515 ;iou:0.670 ;time: 0:00:16
# Edit:True ;batch:100 ;Bloss:1.122 ;Aloss:0.132 ;edits:0.04 ;editRandomlyProb:0.25 ;acc:0.760 ;iou:0.825 ;time: 0:00:32
# Edit:True ;batch:150 ;Bloss:1.081 ;Aloss:0.139 ;edits:0.05 ;editRandomlyProb:0.25 ;acc:0.825 ;iou:0.875 ;time: 0:00:47
# Edit:True ;batch:200 ;Bloss:0.905 ;Aloss:0.145 ;edits:0.04 ;editRandomlyProb:0.25 ;acc:0.815 ;iou:0.880 ;time: 0:01:01
# Edit:True ;batch:250 ;Bloss:1.858 ;Aloss:0.153 ;edits:0.08 ;editRandomlyProb:0.25 ;acc:0.605 ;iou:0.720 ;time: 0:01:16
#
# *Training B: True ;B Train loss: 1.564 ;A Train loss: 0.157 ;Edit num: 0.072 MIXER delta:4.000 ;Train accuracy: 0.668 ;IOU accuracy: 0.765 ;Time: 0:01:29
#
# A testing, ephoc: 21 ;Random: False
# batch: 0 ;B loss: 0.579 ;acc: 0.875 ;iou_acc: 0.930 ;edits:0.05 ;time: 0:01:29
# batch: 50 ;B loss: 0.868 ;acc: 0.815 ;iou_acc: 0.875 ;edits:0.07 ;time: 0:01:38
# batch: 100 ;B loss: 1.299 ;acc: 0.735 ;iou_acc: 0.805 ;edits:0.11 ;time: 0:01:48
# batch: 150 ;B loss: 1.421 ;acc: 0.725 ;iou_acc: 0.795 ;edits:0.12 ;time: 0:01:58
# batch: 200 ;B loss: 1.862 ;acc: 0.560 ;iou_acc: 0.710 ;edits:0.14 ;time: 0:02:08
# batch: 250 ;B loss: 2.418 ;acc: 0.400 ;iou_acc: 0.530 ;edits:0.19 ;time: 0:02:22
#
# *B test loss: 1.572 ;Test accuracy 0.636 ;IOU accuracy: 0.735 ;Edit num: 0.133 ;Time: 0:02:37
#
# A testing, ephoc: 21 ;Random: True
# batch: 0 ;B loss: 0.655 ;acc: 0.880 ;iou_acc: 0.930 ;edits:0.11 ;time: 0:02:37
# batch: 50 ;B loss: 0.952 ;acc: 0.815 ;iou_acc: 0.835 ;edits:0.13 ;time: 0:02:45
# batch: 100 ;B loss: 1.400 ;acc: 0.710 ;iou_acc: 0.760 ;edits:0.12 ;time: 0:02:56
# batch: 150 ;B loss: 1.491 ;acc: 0.695 ;iou_acc: 0.780 ;edits:0.10 ;time: 0:03:07
# batch: 200 ;B loss: 1.832 ;acc: 0.505 ;iou_acc: 0.670 ;edits:0.10 ;time: 0:03:19
# batch: 250 ;B loss: 2.394 ;acc: 0.455 ;iou_acc: 0.610 ;edits:0.15 ;time: 0:03:33
#
# *B test loss: 1.597 ;Test accuracy 0.633 ;IOU accuracy: 0.737 ;Edit num: 0.133 ;Time: 0:03:49
#
# ==================================================
#
# ==================================================
# Train, ephoc: 22 ; Training B: False
# Edit:True ;batch:0 ;Bloss:1.025 ;Aloss:0.127 ;edits:0.05 ;editRandomlyProb:0.25 ;acc:0.765 ;iou:0.860 ;time: 0:00:00
# Edit:True ;batch:50 ;Bloss:0.956 ;Aloss:0.130 ;edits:0.04 ;editRandomlyProb:0.25 ;acc:0.800 ;iou:0.870 ;time: 0:00:17
# Edit:True ;batch:100 ;Bloss:1.359 ;Aloss:0.173 ;edits:0.10 ;editRandomlyProb:0.25 ;acc:0.700 ;iou:0.800 ;time: 0:00:33
# Edit:True ;batch:150 ;Bloss:1.706 ;Aloss:0.164 ;edits:0.09 ;editRandomlyProb:0.25 ;acc:0.650 ;iou:0.745 ;time: 0:00:49
# Edit:True ;batch:200 ;Bloss:0.884 ;Aloss:0.143 ;edits:0.07 ;editRandomlyProb:0.25 ;acc:0.815 ;iou:0.890 ;time: 0:01:03
# Edit:True ;batch:250 ;Bloss:1.454 ;Aloss:0.140 ;edits:0.06 ;editRandomlyProb:0.25 ;acc:0.665 ;iou:0.770 ;time: 0:01:16
#
# *Training B: False ;B Train loss: 1.557 ;A Train loss: 0.155 ;Edit num: 0.070 MIXER delta:4.000 ;Train accuracy: 0.668 ;IOU accuracy: 0.768 ;Time: 0:01:29
#
# A testing, ephoc: 22 ;Random: False
# batch: 0 ;B loss: 0.656 ;acc: 0.870 ;iou_acc: 0.930 ;edits:0.09 ;time: 0:01:30
# batch: 50 ;B loss: 0.890 ;acc: 0.820 ;iou_acc: 0.865 ;edits:0.11 ;time: 0:01:38
# batch: 100 ;B loss: 1.399 ;acc: 0.730 ;iou_acc: 0.780 ;edits:0.16 ;time: 0:01:48
# batch: 150 ;B loss: 1.470 ;acc: 0.680 ;iou_acc: 0.765 ;edits:0.18 ;time: 0:01:58
# batch: 200 ;B loss: 1.856 ;acc: 0.525 ;iou_acc: 0.705 ;edits:0.18 ;time: 0:02:10
# batch: 250 ;B loss: 2.432 ;acc: 0.435 ;iou_acc: 0.555 ;edits:0.25 ;time: 0:02:24
#
# *B test loss: 1.641 ;Test accuracy 0.615 ;IOU accuracy: 0.716 ;Edit num: 0.189 ;Time: 0:02:40
#
# A testing, ephoc: 22 ;Random: True
# batch: 0 ;B loss: 0.754 ;acc: 0.850 ;iou_acc: 0.925 ;edits:0.16 ;time: 0:02:40
# batch: 50 ;B loss: 1.058 ;acc: 0.755 ;iou_acc: 0.830 ;edits:0.18 ;time: 0:02:48
# batch: 100 ;B loss: 1.467 ;acc: 0.710 ;iou_acc: 0.780 ;edits:0.21 ;time: 0:02:58
# batch: 150 ;B loss: 1.477 ;acc: 0.655 ;iou_acc: 0.745 ;edits:0.17 ;time: 0:03:09
# batch: 200 ;B loss: 1.889 ;acc: 0.520 ;iou_acc: 0.655 ;edits:0.17 ;time: 0:03:21
# batch: 250 ;B loss: 2.346 ;acc: 0.440 ;iou_acc: 0.595 ;edits:0.19 ;time: 0:03:35
#
# *B test loss: 1.677 ;Test accuracy 0.611 ;IOU accuracy: 0.719 ;Edit num: 0.188 ;Time: 0:03:51
#
# ==================================================
#
# ==================================================
# Train, ephoc: 23 ; Training B: True
# Edit:True ;batch:0 ;gs:2674 ;lr:0.050 ;Bloss:1.997 ;Aloss:0.161 ;edits:0.02 ;editRandomlyProb:0.00 ;acc:0.530 ;iou:0.685 ;time: 0:00:00
# Edit:True ;batch:50 ;gs:2724 ;lr:0.050 ;Bloss:0.928 ;Aloss:0.118 ;edits:0.00 ;editRandomlyProb:0.00 ;acc:0.785 ;iou:0.870 ;time: 0:00:21
# Edit:True ;batch:100 ;gs:2774 ;lr:0.050 ;Bloss:1.148 ;Aloss:0.127 ;edits:0.00 ;editRandomlyProb:0.00 ;acc:0.765 ;iou:0.815 ;time: 0:00:41
# Edit:True ;batch:150 ;gs:2824 ;lr:0.050 ;Bloss:0.612 ;Aloss:0.107 ;edits:0.00 ;editRandomlyProb:0.00 ;acc:0.895 ;iou:0.965 ;time: 0:01:01
# ...
# batch: 0 ;B loss: 0.473 ;acc: 0.910 ;iou_acc: 0.960 ;time: 0:02:55
# batch: 50 ;B loss: 0.736 ;acc: 0.835 ;iou_acc: 0.860 ;time: 0:03:00
# batch: 100 ;B loss: 1.060 ;acc: 0.800 ;iou_acc: 0.850 ;time: 0:03:05
# batch: 150 ;B loss: 1.114 ;acc: 0.745 ;iou_acc: 0.800 ;time: 0:03:12
# batch: 200 ;B loss: 1.448 ;acc: 0.660 ;iou_acc: 0.805 ;time: 0:03:19
# batch: 250 ;B loss: 2.029 ;acc: 0.525 ;iou_acc: 0.665 ;time: 0:03:27
#
# *BTrain: False ;Test loss: 1.293 ;Test accuracy 0.707 ;IOU accuracy: 0.798 ;Time: 0:03:54
# ==================================================
#
# ==================================================
# Train, ephoc: 60 ; Training B: False
# Edit:True ;batch:0 ;Bloss:0.390 ;Aloss:0.121 ;edits:0.02 ;editRandomlyProb:0.10 ;acc:0.920 ;iou:0.965 ;time: 0:00:00
# Edit:True ;batch:50 ;Bloss:0.971 ;Aloss:0.125 ;edits:0.05 ;editRandomlyProb:0.10 ;acc:0.805 ;iou:0.880 ;time: 0:00:16
# Edit:True ;batch:100 ;Bloss:2.239 ;Aloss:0.142 ;edits:0.20 ;editRandomlyProb:0.10 ;acc:0.530 ;iou:0.625 ;time: 0:00:32
# Edit:True ;batch:150 ;Bloss:0.889 ;Aloss:0.124 ;edits:0.06 ;editRandomlyProb:0.10 ;acc:0.805 ;iou:0.870 ;time: 0:00:48
# Edit:True ;batch:200 ;Bloss:1.059 ;Aloss:0.125 ;edits:0.15 ;editRandomlyProb:0.10 ;acc:0.795 ;iou:0.825 ;time: 0:01:07
# Edit:True ;batch:250 ;Bloss:0.700 ;Aloss:0.143 ;edits:0.06 ;editRandomlyProb:0.10 ;acc:0.890 ;iou:0.935 ;time: 0:01:21
#
# *Training B: True ;B Train loss: 1.454 ;A Train loss: 0.142 ;Edit num: 0.130 MIXER delta:10.000 ;Train accuracy: 0.692 ;IOU accuracy: 0.782 ;Time: 0:01:39
#
# A testing, ephoc: 60 ;Random: False
# batch: 0 ;B loss: 1.123 ;acc: 0.715 ;iou_acc: 0.825 ;edits:0.87 ;time: 0:01:39
# batch: 50 ;B loss: 1.922 ;acc: 0.480 ;iou_acc: 0.595 ;edits:0.88 ;time: 0:01:47
# batch: 100 ;B loss: 2.175 ;acc: 0.470 ;iou_acc: 0.540 ;edits:0.84 ;time: 0:01:57
# batch: 150 ;B loss: 2.222 ;acc: 0.405 ;iou_acc: 0.510 ;edits:0.82 ;time: 0:02:08
# batch: 200 ;B loss: 2.621 ;acc: 0.330 ;iou_acc: 0.450 ;edits:0.80 ;time: 0:02:20
# batch: 250 ;B loss: 3.155 ;acc: 0.270 ;iou_acc: 0.395 ;edits:0.81 ;time: 0:02:34
#
# *B test loss: 2.411 ;Test accuracy 0.392 ;IOU accuracy: 0.513 ;Edit num: 0.845 ;Time: 0:03:03
#
# A testing, ephoc: 60 ;Random: True
# batch: 0 ;B loss: 0.947 ;acc: 0.720 ;iou_acc: 0.865 ;edits:0.86 ;time: 0:03:03
# batch: 50 ;B loss: 1.644 ;acc: 0.600 ;iou_acc: 0.705 ;edits:0.83 ;time: 0:03:11
# batch: 100 ;B loss: 1.950 ;acc: 0.535 ;iou_acc: 0.605 ;edits:0.86 ;time: 0:03:20
# batch: 150 ;B loss: 2.158 ;acc: 0.460 ;iou_acc: 0.585 ;edits:0.87 ;time: 0:03:31
# batch: 200 ;B loss: 2.541 ;acc: 0.395 ;iou_acc: 0.545 ;edits:0.83 ;time: 0:03:43
# batch: 250 ;B loss: 2.988 ;acc: 0.285 ;iou_acc: 0.430 ;edits:0.84 ;time: 0:03:57
#
# *B test loss: 2.225 ;Test accuracy 0.462 ;IOU accuracy: 0.573 ;Edit num: 0.847 ;Time: 0:04:23
#
# ==================================================
#
# ==================================================
# Train, ephoc: 61 ; Training B: False
# Edit:True ;batch:0 ;Bloss:1.095 ;Aloss:0.159 ;edits:0.25 ;editRandomlyProb:0.10 ;acc:0.760 ;iou:0.840 ;time: 0:00:00
# Edit:True ;batch:50 ;Bloss:0.555 ;Aloss:0.108 ;edits:0.01 ;editRandomlyProb:0.10 ;acc:0.905 ;iou:0.940 ;time: 0:00:15
# Edit:True ;batch:100 ;Bloss:2.570 ;Aloss:0.186 ;edits:0.26 ;editRandomlyProb:0.10 ;acc:0.450 ;iou:0.575 ;time: 0:00:35
# Edit:True ;batch:150 ;Bloss:0.473 ;Aloss:0.109 ;edits:0.04 ;editRandomlyProb:0.10 ;acc:0.910 ;iou:0.960 ;time: 0:00:50
# Edit:True ;batch:200 ;Bloss:1.083 ;Aloss:0.142 ;edits:0.14 ;editRandomlyProb:0.10 ;acc:0.775 ;iou:0.835 ;time: 0:01:05
# Edit:True ;batch:250 ;Bloss:0.986 ;Aloss:0.114 ;edits:0.05 ;editRandomlyProb:0.10 ;acc:0.830 ;iou:0.865 ;time: 0:01:19
#
# *Training B: False ;B Train loss: 1.446 ;A Train loss: 0.142 ;Edit num: 0.126 MIXER delta:10.000 ;Train accuracy: 0.693 ;IOU accuracy: 0.784 ;Time: 0:01:34
#
# A testing, ephoc: 61 ;Random: False
# batch: 0 ;B loss: 1.101 ;acc: 0.715 ;iou_acc: 0.815 ;edits:0.89 ;time: 0:01:35
# batch: 50 ;B loss: 1.930 ;acc: 0.500 ;iou_acc: 0.590 ;edits:0.91 ;time: 0:01:43
# batch: 100 ;B loss: 2.117 ;acc: 0.470 ;iou_acc: 0.565 ;edits:0.87 ;time: 0:01:52
# batch: 150 ;B loss: 2.367 ;acc: 0.400 ;iou_acc: 0.500 ;edits:0.88 ;time: 0:02:03
# batch: 200 ;B loss: 2.648 ;acc: 0.345 ;iou_acc: 0.470 ;edits:0.84 ;time: 0:02:16
# batch: 250 ;B loss: 3.109 ;acc: 0.265 ;iou_acc: 0.345 ;edits:0.86 ;time: 0:02:30
#
# *B test loss: 2.410 ;Test accuracy 0.398 ;IOU accuracy: 0.516 ;Edit num: 0.881 ;Time: 0:02:50
#
# A testing, ephoc: 61 ;Random: True
# batch: 0 ;B loss: 1.016 ;acc: 0.750 ;iou_acc: 0.870 ;edits:0.88 ;time: 0:02:50
# batch: 50 ;B loss: 1.730 ;acc: 0.580 ;iou_acc: 0.660 ;edits:0.90 ;time: 0:02:58
# batch: 100 ;B loss: 1.948 ;acc: 0.540 ;iou_acc: 0.605 ;edits:0.88 ;time: 0:03:07
# batch: 150 ;B loss: 2.201 ;acc: 0.440 ;iou_acc: 0.555 ;edits:0.88 ;time: 0:03:18
# batch: 200 ;B loss: 2.577 ;acc: 0.385 ;iou_acc: 0.520 ;edits:0.88 ;time: 0:03:30
# batch: 250 ;B loss: 3.108 ;acc: 0.260 ;iou_acc: 0.455 ;edits:0.89 ;time: 0:03:44
#
# *B test loss: 2.275 ;Test accuracy 0.450 ;IOU accuracy: 0.558 ;Edit num: 0.881 ;Time: 0:04:04
#
# ==================================================
#
# ==================================================
# Train, ephoc: 62 ; Training B: True
# Edit:True ;batch:0 ;gs:6535 ;lr:0.050 ;Bloss:1.029 ;Aloss:0.162 ;edits:0.12 ;editRandomlyProb:0.00 ;acc:0.570 ;iou:0.640 ;time: 0:00:01
# Edit:True ;batch:50 ;gs:6585 ;lr:0.050 ;Bloss:2.349 ;Aloss:0.136 ;edits:0.14 ;editRandomlyProb:0.00 ;acc:0.275 ;iou:0.405 ;time: 0:00:21
# Edit:True ;batch:100 ;gs:6635 ;lr:0.050 ;Bloss:0.429 ;Aloss:0.135 ;edits:0.00 ;editRandomlyProb:0.00 ;acc:0.860 ;iou:0.925 ;time: 0:00:40
# Edit:True ;batch:150 ;gs:6685 ;lr:0.050 ;Bloss:2.150 ;Aloss:0.158 ;edits:0.25 ;editRandomlyProb:0.00 ;acc:0.280 ;iou:0.415 ;time: 0:01:00
# Edit:True ;batch:200 ;gs:6735 ;lr:0.050 ;Bloss:0.911 ;Aloss:0.097 ;edits:0.05 ;editRandomlyProb:0.00 ;acc:0.535 ;iou:0.675 ;time: 0:01:21
# Edit:True ;batch:250 ;gs:6785 ;lr:0.050 ;Bloss:1.340 ;Aloss:0.139 ;edits:0.20 ;editRandomlyProb:0.00 ;acc:0.510 ;iou:0.570 ;time: 0:01:42
#
# *Training B: False ;B Train loss: 1.435 ;A Train loss: 0.140 ;Edit num: 0.110 MIXER delta:11.000 ;Train accuracy: 0.521 ;IOU accuracy: 0.627 ;Time: 0:02:01
#
# No Edit
# ooooooo
# Edit:False ;batch:0 ;gs:6831 ;lr:0.050 ;Bloss:0.802 ;acc:0.830 ;iou:0.895 ;time: 0:02:01
# Edit:False ;batch:50 ;gs:6831 ;lr:0.050 ;Bloss:2.044 ;acc:0.545 ;iou:0.690 ;time: 0:02:09
# Edit:False ;batch:100 ;gs:6831 ;lr:0.050 ;Bloss:0.437 ;acc:0.930 ;iou:0.970 ;time: 0:02:15
# Edit:False ;batch:150 ;gs:6831 ;lr:0.050 ;Bloss:1.831 ;acc:0.635 ;iou:0.760 ;time: 0:02:22
# Edit:False ;batch:200 ;gs:6831 ;lr:0.050 ;Bloss:0.763 ;acc:0.870 ;iou:0.910 ;time: 0:02:30
# Edit:False ;batch:250 ;gs:6831 ;lr:0.050 ;Bloss:0.990 ;acc:0.820 ;iou:0.885 ;time: 0:02:38
#
# *Training B: False ;B Train loss: 1.263 ;Train accuracy: 0.742 ;IOU accuracy: 0.825 ;Time: 0:02:45
#
# Testing, ephoc: 62
# batch: 0 ;B loss: 0.480 ;acc: 0.905 ;iou_acc: 0.950 ;time: 0:02:45
# batch: 50 ;B loss: 0.726 ;acc: 0.835 ;iou_acc: 0.860 ;time: 0:02:50
# batch: 100 ;B loss: 1.020 ;acc: 0.800 ;iou_acc: 0.850 ;time: 0:02:55
# batch: 150 ;B loss: 1.087 ;acc: 0.750 ;iou_acc: 0.805 ;time: 0:03:01
# batch: 200 ;B loss: 1.442 ;acc: 0.660 ;iou_acc: 0.785 ;time: 0:03:08
# batch: 250 ;B loss: 1.997 ;acc: 0.545 ;iou_acc: 0.685 ;time: 0:03:17
#
# *BTrain: False ;Test loss: 1.284 ;Test accuracy 0.710 ;IOU accuracy: 0.799 ;Time: 0:03:31
# ==================================================
#
# ==================================================
# Train, ephoc: 63 ; Training B: False
# Edit:True ;batch:0 ;Bloss:0.568 ;Aloss:0.127 ;edits:0.02 ;editRandomlyProb:0.09 ;acc:0.885 ;iou:0.915 ;time: 0:00:00
# Edit:True ;batch:50 ;Bloss:2.078 ;Aloss:0.157 ;edits:0.17 ;editRandomlyProb:0.09 ;acc:0.590 ;iou:0.735 ;time: 0:00:16
# Edit:True ;batch:100 ;Bloss:2.177 ;Aloss:0.188 ;edits:0.36 ;editRandomlyProb:0.09 ;acc:0.520 ;iou:0.595 ;time: 0:00:32
# Edit:True ;batch:150 ;Bloss:1.422 ;Aloss:0.141 ;edits:0.12 ;editRandomlyProb:0.09 ;acc:0.700 ;iou:0.735 ;time: 0:00:49
# Edit:True ;batch:200 ;Bloss:1.825 ;Aloss:0.158 ;edits:0.24 ;editRandomlyProb:0.09 ;acc:0.590 ;iou:0.690 ;time: 0:01:05
# Edit:True ;batch:250 ;Bloss:2.226 ;Aloss:0.159 ;edits:0.24 ;editRandomlyProb:0.09 ;acc:0.490 ;iou:0.645 ;time: 0:01:21
#
# *Training B: True ;B Train loss: 1.448 ;A Train loss: 0.142 ;Edit num: 0.135 MIXER delta:11.000 ;Train accuracy: 0.694 ;IOU accuracy: 0.783 ;Time: 0:01:36
#
# A testing, ephoc: 63 ;Random: False
# batch: 0 ;B loss: 1.139 ;acc: 0.715 ;iou_acc: 0.840 ;edits:0.62 ;time: 0:01:36
# batch: 50 ;B loss: 1.522 ;acc: 0.590 ;iou_acc: 0.670 ;edits:0.55 ;time: 0:01:44
# batch: 100 ;B loss: 1.906 ;acc: 0.510 ;iou_acc: 0.590 ;edits:0.57 ;time: 0:01:54
# batch: 150 ;B loss: 1.869 ;acc: 0.500 ;iou_acc: 0.615 ;edits:0.51 ;time: 0:02:05
# batch: 200 ;B loss: 2.304 ;acc: 0.390 ;iou_acc: 0.530 ;edits:0.56 ;time: 0:02:17
# batch: 250 ;B loss: 2.824 ;acc: 0.310 ;iou_acc: 0.445 ;edits:0.50 ;time: 0:02:31
#
# *B test loss: 2.101 ;Test accuracy 0.453 ;IOU accuracy: 0.576 ;Edit num: 0.546 ;Time: 0:02:51
#
# A testing, ephoc: 63 ;Random: True
# batch: 0 ;B loss: 0.828 ;acc: 0.820 ;iou_acc: 0.895 ;edits:0.52 ;time: 0:02:51
# batch: 50 ;B loss: 1.304 ;acc: 0.670 ;iou_acc: 0.800 ;edits:0.56 ;time: 0:02:59
# batch: 100 ;B loss: 1.696 ;acc: 0.645 ;iou_acc: 0.700 ;edits:0.56 ;time: 0:03:09
# batch: 150 ;B loss: 1.649 ;acc: 0.580 ;iou_acc: 0.695 ;edits:0.54 ;time: 0:03:20
# batch: 200 ;B loss: 1.963 ;acc: 0.485 ;iou_acc: 0.610 ;edits:0.54 ;time: 0:03:32
# batch: 250 ;B loss: 2.530 ;acc: 0.385 ;iou_acc: 0.520 ;edits:0.55 ;time: 0:03:46
#
# *B test loss: 1.840 ;Test accuracy 0.562 ;IOU accuracy: 0.666 ;Edit num: 0.545 ;Time: 0:04:07
#
# ==================================================
#
# ==================================================
# Train, ephoc: 64 ; Training B: False
# Edit:True ;batch:0 ;Bloss:0.486 ;Aloss:0.089 ;edits:0.02 ;editRandomlyProb:0.09 ;acc:0.910 ;iou:0.940 ;time: 0:00:00
# Edit:True ;batch:50 ;Bloss:1.495 ;Aloss:0.150 ;edits:0.27 ;editRandomlyProb:0.09 ;acc:0.680 ;iou:0.735 ;time: 0:00:16
# Edit:True ;batch:100 ;Bloss:0.945 ;Aloss:0.107 ;edits:0.03 ;editRandomlyProb:0.09 ;acc:0.785 ;iou:0.840 ;time: 0:00:31
# Edit:True ;batch:150 ;Bloss:1.506 ;Aloss:0.157 ;edits:0.31 ;editRandomlyProb:0.09 ;acc:0.620 ;iou:0.710 ;time: 0:00:47
# Edit:True ;batch:200 ;Bloss:1.031 ;Aloss:0.144 ;edits:0.13 ;editRandomlyProb:0.09 ;acc:0.790 ;iou:0.875 ;time: 0:01:03
# Edit:True ;batch:250 ;Bloss:2.050 ;Aloss:0.156 ;edits:0.16 ;editRandomlyProb:0.09 ;acc:0.485 ;iou:0.670 ;time: 0:01:21
#
# *Training B: False ;B Train loss: 1.436 ;A Train loss: 0.141 ;Edit num: 0.127 MIXER delta:11.000 ;Train accuracy: 0.697 ;IOU accuracy: 0.787 ;Time: 0:01:34
#
# A testing, ephoc: 64 ;Random: False
# batch: 0 ;B loss: 1.093 ;acc: 0.705 ;iou_acc: 0.835 ;edits:0.70 ;time: 0:01:35
# batch: 50 ;B loss: 1.685 ;acc: 0.550 ;iou_acc: 0.625 ;edits:0.65 ;time: 0:01:43
# batch: 100 ;B loss: 2.029 ;acc: 0.475 ;iou_acc: 0.560 ;edits:0.67 ;time: 0:01:53
# batch: 150 ;B loss: 2.024 ;acc: 0.460 ;iou_acc: 0.590 ;edits:0.64 ;time: 0:02:04
# batch: 200 ;B loss: 2.515 ;acc: 0.335 ;iou_acc: 0.480 ;edits:0.67 ;time: 0:02:16
# batch: 250 ;B loss: 3.048 ;acc: 0.200 ;iou_acc: 0.435 ;edits:0.65 ;time: 0:02:29
#
# *B test loss: 2.253 ;Test accuracy 0.413 ;IOU accuracy: 0.534 ;Edit num: 0.673 ;Time: 0:02:50
#
# A testing, ephoc: 64 ;Random: True
# batch: 0 ;B loss: 0.909 ;acc: 0.780 ;iou_acc: 0.895 ;edits:0.69 ;time: 0:02:50
# batch: 50 ;B loss: 1.310 ;acc: 0.640 ;iou_acc: 0.750 ;edits:0.64 ;time: 0:02:58
# batch: 100 ;B loss: 1.747 ;acc: 0.545 ;iou_acc: 0.685 ;edits:0.66 ;time: 0:03:08
# batch: 150 ;B loss: 1.895 ;acc: 0.550 ;iou_acc: 0.670 ;edits:0.70 ;time: 0:03:19
# batch: 200 ;B loss: 2.271 ;acc: 0.475 ;iou_acc: 0.535 ;edits:0.69 ;time: 0:03:31
# batch: 250 ;B loss: 2.713 ;acc: 0.355 ;iou_acc: 0.470 ;edits:0.67 ;time: 0:03:45
#
# *B test loss: 1.982 ;Test accuracy 0.522 ;IOU accuracy: 0.629 ;Edit num: 0.674 ;Time: 0:04:06
#
# ==================================================
#
# ==================================================
# Train, ephoc: 65 ; Training B: True
# Edit:True ;batch:0 ;gs:6832 ;lr:0.050 ;Bloss:1.155 ;Aloss:0.107 ;edits:0.08 ;editRandomlyProb:0.00 ;acc:0.525 ;iou:0.610 ;time: 0:00:00
# Edit:True ;batch:50 ;gs:6882 ;lr:0.050 ;Bloss:1.946 ;Aloss:0.155 ;edits:0.15 ;editRandomlyProb:0.00 ;acc:0.315 ;iou:0.420 ;time: 0:00:19
# Edit:True ;batch:100 ;gs:6932 ;lr:0.050 ;Bloss:2.253 ;Aloss:0.162 ;edits:0.24 ;editRandomlyProb:0.00 ;acc:0.305 ;iou:0.420 ;time: 0:00:39
# Edit:True ;batch:150 ;gs:6982 ;lr:0.050 ;Bloss:1.203 ;Aloss:0.113 ;edits:0.09 ;editRandomlyProb:0.00 ;acc:0.490 ;iou:0.570 ;time: 0:01:01
# Edit:True ;batch:200 ;gs:7032 ;lr:0.050 ;Bloss:2.137 ;Aloss:0.151 ;edits:0.18 ;editRandomlyProb:0.00 ;acc:0.340 ;iou:0.480 ;time: 0:01:22
# Edit:True ;batch:250 ;gs:7082 ;lr:0.050 ;Bloss:0.799 ;Aloss:0.123 ;edits:0.01 ;editRandomlyProb:0.00 ;acc:0.680 ;iou:0.800 ;time: 0:01:44
#
# *Training B: False ;B Train loss: 1.433 ;A Train loss: 0.138 ;Edit num: 0.115 MIXER delta:11.000 ;Train accuracy: 0.504 ;IOU accuracy: 0.614 ;Time: 0:02:03
#
# No Edit
# ooooooo
# Edit:False ;batch:0 ;gs:7128 ;lr:0.050 ;Bloss:1.051 ;acc:0.790 ;iou:0.830 ;time: 0:02:04
# Edit:False ;batch:50 ;gs:7128 ;lr:0.050 ;Bloss:1.732 ;acc:0.645 ;iou:0.735 ;time: 0:02:10
# Edit:False ;batch:100 ;gs:7128 ;lr:0.050 ;Bloss:1.911 ;acc:0.615 ;iou:0.765 ;time: 0:02:17
# Edit:False ;batch:150 ;gs:7128 ;lr:0.050 ;Bloss:1.016 ;acc:0.840 ;iou:0.890 ;time: 0:02:25
# Edit:False ;batch:200 ;gs:7128 ;lr:0.050 ;Bloss:1.790 ;acc:0.625 ;iou:0.775 ;time: 0:02:32
# Edit:False ;batch:250 ;gs:7128 ;lr:0.050 ;Bloss:0.817 ;acc:0.865 ;iou:0.925 ;time: 0:02:39
#
# *Training B: False ;B Train loss: 1.251 ;Train accuracy: 0.745 ;IOU accuracy: 0.828 ;Time: 0:02:45
#
# Testing, ephoc: 65
# batch: 0 ;B loss: 0.465 ;acc: 0.895 ;iou_acc: 0.950 ;time: 0:02:46
# batch: 50 ;B loss: 0.717 ;acc: 0.825 ;iou_acc: 0.855 ;time: 0:02:50
# batch: 100 ;B loss: 1.040 ;acc: 0.795 ;iou_acc: 0.855 ;time: 0:02:56
# batch: 150 ;B loss: 1.070 ;acc: 0.775 ;iou_acc: 0.835 ;time: 0:03:02
# batch: 200 ;B loss: 1.456 ;acc: 0.660 ;iou_acc: 0.785 ;time: 0:03:09
# batch: 250 ;B loss: 2.019 ;acc: 0.545 ;iou_acc: 0.680 ;time: 0:03:17
#
# *BTrain: False ;Test loss: 1.280 ;Test accuracy 0.713 ;IOU accuracy: 0.802 ;Time: 0:03:31
# ==================================================
#
# ==================================================
# Train, ephoc: 66 ; Training B: False
# Edit:True ;batch:0 ;Bloss:1.535 ;Aloss:0.142 ;edits:0.16 ;editRandomlyProb:0.09 ;acc:0.680 ;iou:0.760 ;time: 0:00:00
# Edit:True ;batch:50 ;Bloss:1.401 ;Aloss:0.128 ;edits:0.10 ;editRandomlyProb:0.09 ;acc:0.745 ;iou:0.795 ;time: 0:00:15
# Edit:True ;batch:100 ;Bloss:0.814 ;Aloss:0.118 ;edits:0.06 ;editRandomlyProb:0.09 ;acc:0.835 ;iou:0.890 ;time: 0:00:30
# Edit:True ;batch:150 ;Bloss:1.057 ;Aloss:0.119 ;edits:0.05 ;editRandomlyProb:0.09 ;acc:0.775 ;iou:0.850 ;time: 0:00:46
# Edit:True ;batch:200 ;Bloss:2.001 ;Aloss:0.150 ;edits:0.03 ;editRandomlyProb:0.09 ;acc:0.590 ;iou:0.715 ;time: 0:01:02
# Edit:True ;batch:250 ;Bloss:2.801 ;Aloss:0.166 ;edits:0.20 ;editRandomlyProb:0.09 ;acc:0.400 ;iou:0.565 ;time: 0:01:19
#
# *Training B: True ;B Train loss: 1.406 ;A Train loss: 0.137 ;Edit num: 0.113 MIXER delta:11.000 ;Train accuracy: 0.707 ;IOU accuracy: 0.795 ;Time: 0:01:34
#
# A testing, ephoc: 66 ;Random: False
# batch: 0 ;B loss: 1.026 ;acc: 0.715 ;iou_acc: 0.815 ;edits:0.71 ;time: 0:01:35
# batch: 50 ;B loss: 1.682 ;acc: 0.505 ;iou_acc: 0.615 ;edits:0.64 ;time: 0:01:43
# batch: 100 ;B loss: 1.949 ;acc: 0.445 ;iou_acc: 0.560 ;edits:0.69 ;time: 0:01:52
# batch: 150 ;B loss: 2.078 ;acc: 0.445 ;iou_acc: 0.545 ;edits:0.67 ;time: 0:02:03
# batch: 200 ;B loss: 2.538 ;acc: 0.300 ;iou_acc: 0.445 ;edits:0.68 ;time: 0:02:15
# batch: 250 ;B loss: 3.048 ;acc: 0.265 ;iou_acc: 0.405 ;edits:0.66 ;time: 0:02:29
#
# *B test loss: 2.244 ;Test accuracy 0.420 ;IOU accuracy: 0.542 ;Edit num: 0.685 ;Time: 0:02:49
#
# A testing, ephoc: 66 ;Random: True
# batch: 0 ;B loss: 0.864 ;acc: 0.750 ;iou_acc: 0.855 ;edits:0.67 ;time: 0:02:49
# batch: 50 ;B loss: 1.566 ;acc: 0.670 ;iou_acc: 0.725 ;edits:0.69 ;time: 0:02:57
# batch: 100 ;B loss: 1.610 ;acc: 0.605 ;iou_acc: 0.635 ;edits:0.64 ;time: 0:03:05

# %%
np.save(open('../data/training/results/MIXER_rl2_tst.bin', 'wb'), rl_tst)
np.save(open('../data/training/results/MIXER_rl2_trn.bin', 'wb'), rl_trn)
np.save(open('../data/training/results/MIXER_rl2_uetst.bin', 'wb'), rl_uetst)
np.save(open('../data/training/results/MIXER_rl2_AtstRand.bin', 'wb'), rl_AtstRand)
np.save(open('../data/training/results/MIXER_rl2_AtstValn.bin', 'wb'), rl_AtstVal)
